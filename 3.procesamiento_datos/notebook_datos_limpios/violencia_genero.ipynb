# %%
from googleapiclient.discovery import build
from dateutil import parser
import pandas as pd

# Data viz packages
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# NLP
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
from wordcloud import WordCloud
from FunctionsYoutube import *
# !pip install wordcloud 
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/usuario/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/usuario/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 17
#      15 nltk.download('punkt')
#      16 from wordcloud import WordCloud
# ---> 17 from FunctionsYoutube import *
#      18 get_ipython().system('pip install wordcloud')
#      19 from wordcloud import WordCloud
#
# ModuleNotFoundError: No module named 'FunctionsYoutube'

# %%
api_key="AIzaSyDBJWJl3fxjbiVb4PE2YG4xRviQ5MJj1Mk"

# %%
api_service_name = "youtube"
api_version = "v3"

# Creamos la conexión con youtube API
youtube = build(
    api_service_name, api_version, developerKey=api_key)

# %%
next_page_token = None
all_video = []

while True:
    search_response = youtube.search().list(
        q="Opiniones españolas sobre violencia de genero", # q es la query 
        part="id,snippet",
        maxResults= 50, 
        regionCode='ES', 
        pageToken=next_page_token if next_page_token else ""
    ).execute()  # Mover la ejecución aquí

    for item in search_response['items']:
        all_video.append(item) 
        

    next_page_token = search_response.get('nextPageToken')

    if not next_page_token:
        break

# %%
len(all_video)
# Out:
# 692

# %%
[x['snippet']['title'] for x in all_video]
# Out:
# ['6 ideas sobre la Violencia de Género/Intrafamiliar/Machista/Doméstica',
#  'Santiago Abascal sobre la violencia de género: &quot;Busca la guerra de sexos y criminalizar al hombre&quot;',
#  '&quot;La sociedad aún no entiende lo que es la violencia de género&quot;. Marina Marroquí, educadora social',
#  'LEY DE VIOLENCIA DE GÉNERO | Claves de la ley que critica VOX en cinco minutos | Explainer',
#  'Violencia de género y violencia doméstica no son lo mismo y ya lo recoge la ley',
#  '¿Qué opina VOX de la violencia contra la mujer?',
#  'La Ley de Vio***cia de Género es BASURA, te lo dice una MUJER ABOGADA',
#  'Opinión: La violencia de género | Ana Velasco Abogada',
#  '¿Cómo son las víctimas de violencia de género? | Lorena Álvarez | TEDxTukuyWomen',
#  'Vox avisa que quiere derogar la Ley de Violencia de Género',
#  '&quot;Mi mujer es la que manda en casa&quot;: la proclama de Abascal que provoca revuelo en el Congreso',
#  'La igualdad de género es injusta - Agustín Laje',
# ...

# %%
channel_ids = []  
for item in all_video:
    channelId = item['snippet']['channelId']
    channel_ids.append(channelId)  

print(channel_ids)
# Out:
# ['UCJKQNkpFXC3fRiVE3C6fZuQ', 'UC84t25xqhPEPpGY7NBZJ_eA', 'UCI6QcXatdaEAaRTRjl3dc0w', 'UCnsvJeZO4RigQ898WdDNoBw', 'UCCJs5mITIqxqJGeFjt9N1Mg', 'UCRvpumrJs0qY1xLzeU0Ss1Q', 'UCMP7jOcevdMVAycZvlOGK3w', 'UCK2uga7UOX0KjtdNSOiFxdg', 'UCsT0YIqwnpJCM-mx7-gSA4Q', 'UCUS73_bjTYwBFAfXbvIjM8Q', 'UCQ2Fej5pr1ipVeBWTX8Sc_Q', 'UCJKjzEoy91UYS-bZLc4CLCQ', 'UCUdOoVWuWmgo1wByzcsyKDQ', 'UC06JTzRaYRy7M6Y6KaNLCCw', 'UCsT0YIqwnpJCM-mx7-gSA4Q', 'UCJKjzEoy91UYS-bZLc4CLCQ', 'UCWpBYQF-ZuL6FQ05OIL9Yzg', 'UCwtu3Ul-eiQEN81HNN6RQtw', 'UCHnUxhbsapsYyriBKmRRnUg', 'UC6nVHOzgFSU1p-zQHfv7czw', 'UCI6QcXatdaEAaRTRjl3dc0w', 'UCI6QcXatdaEAaRTRjl3dc0w', 'UCT4Jg8h03dD0iN3Pb5L0PMA', 'UCig8aKQHLt8E35_LJKwOscA', 'UC93Ma0SxmdoWgUJUHr8Nf6g', 'UCKPJu4HMTiY3elhw9hEmMNw', 'UCQSLny1RMIQ0jTp0o8h0yPg', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCQ2Fej5pr1ipVeBWTX8Sc_Q', 'UCjL0MieykNqPrGPcPbEw0eQ', 'UChgFx1rj1_XCuputSpSSeDA', 'UCqQJPK3wnKutQGKaOALX9Pg', 'UCC_S0QQ-8veIIHZ7OdnOYMA', 'UC6D6pRbdTJuFuCS6UKPs6HQ', 'UCWpBYQF-ZuL6FQ05OIL9Yzg', 'UCKJNeVvjAI25bHQ
# ...

# %%
len(channel_ids)
# Out:
# 692

# %%
video_ids = []  # Lista para almacenar los videoIds

# Iterar sobre cada elemento de all_videos
for video_info in all_video:
    # Acceder a la clave 'id' y luego a 'videoId'
    video_id = video_info.get('id', {}).get('videoId') #.get() para acceder al valor de 'videoId' dentro de la estructura del diccionario. Si se encuentra un 'videoId', se agrega a la lista video_ids.
    
    # Verificar si se encontró el 'videoId' y agregarlo a la lista video_ids
    if video_id:
        video_ids.append(video_id) 
    else:
        # Si no se encuentra el 'videoId', agregar None a la lista video_ids
        video_ids.append(None)

# %%
len(video_ids)
# Out:
# 692

# %%
v_title = []
for item in all_video:
    video_title = item['snippet']['title'] 
    v_title.append(video_title)
    print(video_title)
# Out:
# 6 ideas sobre la Violencia de Género/Intrafamiliar/Machista/Doméstica
# Santiago Abascal sobre la violencia de género: &quot;Busca la guerra de sexos y criminalizar al hombre&quot;
# &quot;La sociedad aún no entiende lo que es la violencia de género&quot;. Marina Marroquí, educadora social
# LEY DE VIOLENCIA DE GÉNERO | Claves de la ley que critica VOX en cinco minutos | Explainer
# Violencia de género y violencia doméstica no son lo mismo y ya lo recoge la ley
# ¿Qué opina VOX de la violencia contra la mujer?
# La Ley de Vio***cia de Género es BASURA, te lo dice una MUJER ABOGADA
# Opinión: La violencia de género | Ana Velasco Abogada
# ¿Cómo son las víctimas de violencia de género? | Lorena Álvarez | TEDxTukuyWomen
# Vox avisa que quiere derogar la Ley de Violencia de Género
# &quot;Mi mujer es la que manda en casa&quot;: la proclama de Abascal que provoca revuelo en el Congreso
# La igualdad de género es injusta - Agustín Laje
# ...

# %%
len(v_title)
# Out:
# 692

# %%
df_violencia_genero= pd.DataFrame({'canal_ID' : channel_ids, 'video_ID': video_ids, 'video_Title' : v_title})

# %%
df_violencia_genero.to_csv('/Users/usuario/Downloads/irunela/csv/videos_violencia_genero.csv')

# %%
df_violencia_genero.head()
# Out:
#                    canal_ID     video_ID  \
# 0  UCJKQNkpFXC3fRiVE3C6fZuQ  a7it63FFDYQ
# 1  UC84t25xqhPEPpGY7NBZJ_eA  i_t19HsTKZo
# 2  UCI6QcXatdaEAaRTRjl3dc0w  I4TSXVPr8_8
# 3  UCnsvJeZO4RigQ898WdDNoBw  iokz2R67Azk
# 4  UCCJs5mITIqxqJGeFjt9N1Mg  VhdvJLKVIHQ
#
#                                          video_Title
# 0  6 ideas sobre la Violencia de Género/Intrafami...
# 1  Santiago Abascal sobre la violencia de género:...
# 2  &quot;La sociedad aún no entiende lo que es la...
# 3  LEY DE VIOLENCIA DE GÉNERO | Claves de la ley ...
# 4  Violencia de género y violencia doméstica no s...

# %%
from pprint import pprint
def get_comments(video_ids):
    comments = []
    try:
        response = youtube.commentThreads().list(
            part='snippet',
            videoId=video_ids,
            textFormat='plainText'
        ).execute()
    except Exception:
        print(f"Fallo conseguir comentarios de {video_ids}")
        return []

    for item in response['items']:
        try:
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            author_channel_id = item['snippet']['topLevelComment']['snippet']['authorChannelId']["value"]
            #author_channel_id = comment['authorChannelId']['value']
            comments.append({"video_id": video_ids, "author": author_channel_id, "comment": comment})
        except KeyError as e:
            print(f"Falta algun valor de un comentario, {e}")
            comments.append(None)
            continue
    return comments

# %%
from tqdm.notebook import tqdm 
comment_video = [] 
for video in tqdm(video_ids): 
    comments = get_comments(video) 
    comment_video.extend(comments)
# Out:
#   0%|          | 0/692 [00:00<?, ?it/s]
# Fallo conseguir comentarios de uqWUys5Kg_A
# Fallo conseguir comentarios de WbnxzVW6ngo
# Fallo conseguir comentarios de None
# Fallo conseguir comentarios de aLDTy5VQOF0
# Fallo conseguir comentarios de -llPnyTH7Vs
# Fallo conseguir comentarios de G1BxUFc6upE
# Fallo conseguir comentarios de UHgU4tZdWko
# Fallo conseguir comentarios de UHgU4tZdWko
# Fallo conseguir comentarios de I3FuIJnPyIM
# Fallo conseguir comentarios de rcMAFwc1nBA
# Fallo conseguir comentarios de oSAlK-Fvhh4
# Fallo conseguir comentarios de vup8Y4eb0Vw
# Fallo conseguir comentarios de WFALr0T2NEs
# Fallo conseguir comentarios de 72Md_DypqRE
# Fallo conseguir comentarios de qh7WNAG117w
# Fallo conseguir comentarios de IRyUzAyhIYc
# Fallo conseguir comentarios de GcRMVkk0UWM
# Fallo conseguir comentarios de tsoscbexYp4
# Fallo conseguir comentarios de iR5xRlaExqM
# Fallo conseguir comentarios de Uo6eWV-LQH0
# Fallo conseguir comentarios de tIn4m5Tb8KA
# ...

# %%
len(comment_video)
# Out:
# 9347

# %%
comentarios_violencia_genero = pd.DataFrame(filter(None, comment_video))

# %%
comentarios_violencia_genero.to_csv('/Users/usuario/Downloads/irunela/csv/comentarios_violencia_genero.csv')

# %% [markdown]
# Data pre-processing

# %%
comentarios_violencia_genero = pd.read_csv('/Users/usuario/Downloads/irunela/csv/comentarios_violencia_genero.csv')

# %%
valores_nulos = comentarios_violencia_genero.isnull().sum()  # Esto devuelve la cantidad de valores nulos por columna
print(valores_nulos)
# Out:
# Unnamed: 0    0
# video_id      0
# author        0
# comment       3
# dtype: int64

# %%
# Check data types
comentarios_violencia_genero.dtypes
# Out:
# Unnamed: 0     int64
# video_id      object
# author        object
# comment       object
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
comentarios_violencia_genero.shape
# Out:
# (9347, 6)

# %%
index_random = np.random.randint(0,high = comentarios_violencia_genero.shape[0])
comentario = comentarios_violencia_genero.iloc[index_random].comment
print(index_random, comentario)
# Out:
# 252 Sra la violencia no tiene genero, ambos son capaces de cometer violencia..

# %% [markdown]
# Tokenización

# %%
comment = str(comentarios_violencia_genero['comment'])

# %%
#sent_tokenize todo el comentario
comment_st = nltk.tokenize.sent_tokenize(comment)
comment_st
# Out:
# ['0       Gracias!!',
#  'Yo sufri una denuncia falsa!!',
#  ':( Es ...\n1       que aire mas fresco el escuchar a una mujer ha...\n2       La violencia no tiene género, viva España viva...\n3       Gracias por decir las cosas tal cual son, falt...\n4       Hola ,quisiera de tu consejo, mi hermana vive ...\n                              ...                        \n9342                                       🤣 🤣 🤣 👏🏻👏🏻👏🏻👏🏻\n9343                                                 😂😂😂😂\n9344                 Lol lo volvió hacer xD este youtuber\n9345             Que lista e inteligente eres MUJER !',
#  '!!',
#  '😉\n9346    El diccionario se llama lumbreras?',
#  'O es la edi...\nName: comment, Length: 9347, dtype: object']

# %%
#word_tokenize tokeniza palabra por palabra
comment_wt = nltk.tokenize.word_tokenize(comment)
comment_wt
# Out:
# ['0',
#  'Gracias',
#  '!',
#  '!',
#  'Yo',
#  'sufri',
#  'una',
#  'denuncia',
#  'falsa',
#  '!',
#  '!',
#  ':',
#  '(',
#  'Es',
#  '...',
#  '1',
#  'que',
#  'aire',
#  'mas',
#  'fresco',
#  'el',
#  'escuchar',
#  'a',
#  'una',
#  'mujer',
#  'ha',
#  '...',
#  '2',
#  'La',
#  'violencia',
#  'no',
#  'tiene',
#  'género',
#  ',',
#  'viva',
#  'España',
#  'viva',
#  '...',
#  '3',
#  'Gracias',
#  'por',
#  'decir',
#  'las',
#  'cosas',
#  'tal',
#  'cual',
#  'son',
#  ',',
#  'falt',
#  '...',
#  '4',
#  'Hola',
#  ',',
#  'quisiera',
#  'de',
#  'tu',
#  'consejo',
#  ',',
#  'mi',
#  'hermana',
#  'vive',
#  '...',
#  '...',
#  '9342',
#  '🤣',
#  '🤣',
#  '🤣',
#  '👏🏻👏🏻👏🏻👏🏻',
#  '9343',
#  '😂😂😂😂',
#  '9344',
#  'Lol',
#  'lo',
#  'volvió',
#  'hacer',
#  'xD',
#  'este',
#  'youtuber',
#  '9345',
#  'Que',
#  'lista',
#  'e',
#  'inteligente',
#  'eres',
#  'MUJER',
#  '!',
#  '!',
#  '!',
#  '😉',
#  '9346',
#  'El',
#  'diccionario',
#  'se',
#  'llama',
# ...

# %% [markdown]
# Normalización

# %%
Stopwords

# %%
stopwords = nltk.corpus.stopwords.words('spanish')
stopwords = [palabra for palabra in stopwords if 'not' not in palabra]
stopwords
# Out:
# ['de',
#  'la',
#  'que',
#  'el',
#  'en',
#  'y',
#  'a',
#  'los',
#  'del',
#  'se',
#  'las',
#  'por',
#  'un',
#  'para',
#  'con',
#  'no',
#  'una',
#  'su',
#  'al',
#  'lo',
#  'como',
#  'más',
#  'pero',
#  'sus',
#  'le',
#  'ya',
#  'o',
#  'este',
#  'sí',
#  'porque',
#  'esta',
#  'entre',
#  'cuando',
#  'muy',
#  'sin',
#  'sobre',
#  'también',
#  'me',
#  'hasta',
#  'hay',
#  'donde',
#  'quien',
#  'desde',
#  'todo',
#  'nos',
#  'durante',
#  'todos',
#  'uno',
#  'les',
#  'ni',
#  'contra',
#  'otros',
#  'ese',
#  'eso',
#  'ante',
#  'ellos',
#  'e',
#  'esto',
#  'mí',
#  'antes',
#  'algunos',
#  'qué',
#  'unos',
#  'yo',
#  'otro',
#  'otras',
#  'otra',
#  'él',
#  'tanto',
#  'esa',
#  'estos',
#  'mucho',
#  'quienes',
#  'nada',
#  'muchos',
#  'cual',
#  'poco',
#  'ella',
#  'estar',
#  'estas',
#  'algunas',
#  'algo',
#  'nosotros',
#  'mi',
#  'mis',
#  'tú',
#  'te',
#  'ti',
#  'tu',
#  'tus',
#  'ellas',
#  'nosotras',
#  'vosotros',
# ...

# %%
comment_wt_sin_sw = [word for word in comment_wt if word not in stopwords]
comment_wt_sin_sw
# Out:
# ['0',
#  'Gracias',
#  '!',
#  '!',
#  'Yo',
#  'sufri',
#  'denuncia',
#  'falsa',
#  '!',
#  '!',
#  ':',
#  '(',
#  'Es',
#  '...',
#  '1',
#  'aire',
#  'mas',
#  'fresco',
#  'escuchar',
#  'mujer',
#  '...',
#  '2',
#  'La',
#  'violencia',
#  'género',
#  ',',
#  'viva',
#  'España',
#  'viva',
#  '...',
#  '3',
#  'Gracias',
#  'decir',
#  'cosas',
#  'tal',
#  ',',
#  'falt',
#  '...',
#  '4',
#  'Hola',
#  ',',
#  'quisiera',
#  'consejo',
#  ',',
#  'hermana',
#  'vive',
#  '...',
#  '...',
#  '9342',
#  '🤣',
#  '🤣',
#  '🤣',
#  '👏🏻👏🏻👏🏻👏🏻',
#  '9343',
#  '😂😂😂😂',
#  '9344',
#  'Lol',
#  'volvió',
#  'hacer',
#  'xD',
#  'youtuber',
#  '9345',
#  'Que',
#  'lista',
#  'inteligente',
#  'MUJER',
#  '!',
#  '!',
#  '!',
#  '😉',
#  '9346',
#  'El',
#  'diccionario',
#  'llama',
#  'lumbreras',
#  '?',
#  'O',
#  'edi',
#  '...',
#  'Name',
#  ':',
#  'comment',
#  ',',
#  'Length',
#  ':',
#  '9347',
#  ',',
#  'dtype',
#  ':',
#  'object']

# %% [markdown]
# Frecuencia de palabras

# %%
freq = nltk.FreqDist(comment_wt_sin_sw)
freq
# Out:
# FreqDist({'!': 7, '...': 7, ',': 6, ':': 4, '🤣': 3, 'Gracias': 2, 'viva': 2, '0': 1, 'Yo': 1, 'sufri': 1, ...})

# %% [markdown]
# Stemming

# %%
# Importamos esta libreria que nos permite reemplzar caracteres
import re

# Importamos la función que nos permite Stemmizar de nltk y definimos el stemmer
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# Traemos nuevamente las stopwords
spanish_stopwords = nltk.corpus.stopwords.words('spanish')
#spanish_stopwords.remove('no')
#stopword.remove('not')

# %%
# Recorremos todos los comentarios y le vamos aplicando la Normalizacion y luega el Stemming a cada uno
comment_list=[]
for comment in comentarios_violencia_genero.comment:
    # Vamos a reemplzar los caracteres que no sean letras por espacios, limpiando los numeros 
    comment=re.sub("[^a-zA-Z]"," ",str(comment))
    # Pasamos todo a minúsculas
    comment=comment.lower()
    # Remover caracteres especiales
    comment = re.sub(r'\W', ' ', comment)
    # Remover múltiples espacios con uno solo
    comment = re.sub(r'\s+', ' ', comment, flags=re.I)
    # Tokenizar el texto
    # Tokenizamos para separar las palabras del titular 
    comment=nltk.word_tokenize(comment)
    # Eliminamos las palabras de menos de 3 letras
    comment= [palabra for palabra in comment if len(palabra)>3]
    # Sacamos las Stopwords
    comment = [palabra for palabra in comment if not palabra in stopwords]

    ## Hasta acá Normalizamos, ahora a stemmizar

    # Aplicamos la funcion para buscar la raiz de las palabras
    comment=[stemmer.stem(palabra) for palabra in comment]
    # Por ultimo volvemos a unir el titular
    comment=" ".join(comment)

    # Vamos armando una lista con todos los titulares
    comment_list.append(comment)
    #dataset["titular_normalizado"] = titular_list

# %%
comentarios_violencia_genero["comment_stem"] = comment_list
comentarios_violencia_genero.tail()
# Out:
#       Unnamed: 0     video_id                    author  \
# 9342        9342  uD-Keydp0FE  UC8Wi9KcC86vDNWuKL2BbCjA
# 9343        9343  uD-Keydp0FE  UC6ALf-DpeOarxLwwmA5QFBw
# 9344        9344  uD-Keydp0FE  UCkW0dNtwju7nTyNQ7nJLTDA
# 9345        9345  uD-Keydp0FE  UCSn8VqnYu41Hgd4Wn7sQ0dQ
# 9346        9346  uD-Keydp0FE  UC2bngofL3p3myaYXAI0_iiA
#
#                                                 comment  \
# 9342                                     🤣 🤣 🤣 👏🏻👏🏻👏🏻👏🏻
# 9343                                               😂😂😂😂
# 9344               Lol lo volvió hacer xD este youtuber
# 9345           Que lista e inteligente eres MUJER !!! 😉
# 9346  El diccionario se llama lumbreras? O es la edi...
#
#                             comment_stem
# 9342
# 9343
# 9344                  volvi hacer youtub
# 9345              lista inteligent mujer
# 9346  diccionario llama lumbrera editori

# %% [markdown]
# Vectorizar

# %%
list_comment = list(comentarios_violencia_genero['comment_stem'].values)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Usaremos solo las 1000 palabras con mas frecuencia en todo el corpus para generar los vectores
max_features=1000
# spanish=stopwords.words("spanish")
# Es decir que cada instancia tendrá 1000 features
cou_vec=CountVectorizer(max_features=max_features, stop_words = spanish_stopwords) # stop_words="english" , ngram_range=(1, 2)

# %%
#enerarnos los vectores para cada título a partir del corpus total. 
matriz_titulos = cou_vec.fit_transform(list_comment)

# Tomamos las palabras
all_words = cou_vec.get_feature_names_out()

# Vizualizamos las 50 palabras mas usadas
print("50 palabras mas usadas: ",all_words[0:50])
# Out:
# 50 palabras mas usadas:  ['abasc' 'abierta' 'abogado' 'aborto' 'abrazo' 'abuso' 'acaba' 'acabar'
#  'acabo' 'acaso' 'acceso' 'acerca' 'acoso' 'actitud' 'actividad' 'acto'
#  'actual' 'actualment' 'acuerdo' 'adelant' 'adem' 'adema' 'adolescent'
#  'adulto' 'agenda' 'agredir' 'agresi' 'agresion' 'agresor' 'agust' 'ahora'
#  'alguien' 'alguna' 'alma' 'alta' 'alto' 'amant' 'ambo' 'amenaza' 'amiga'
#  'amigo' 'amnist' 'amo' 'amor' 'anda' 'ando' 'antonio' 'apart' 'apena'
#  'apoyo']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()

# Transformar el texto en vectores TF-IDF
vectores_tfidf = vectorizer.fit_transform(list_comment)

# Obtener el tamaño del vocabulario
tamaño_vocabulario = len(vectorizer.get_feature_names_out())

# Ver los vectores TF-IDF resultantes 
print(vectores_tfidf)
# Out:
#   (0, 14104)	0.364963085088505
#   (0, 18941)	0.6025106489012935
#   (0, 7972)	0.3705807418173865
#   (0, 5269)	0.34817586240968523
#   (0, 18091)	0.4389713016447798
#   (0, 8882)	0.22919542631749473
#   (1, 4256)	0.3438507261424969
#   (1, 3885)	0.4154228388784608
#   (1, 9120)	0.2956280631347739
#   (1, 12777)	0.1770886470263227
#   (1, 7236)	0.33704013885246153
#   (1, 8440)	0.4892758784587433
#   (1, 673)	0.4439651943343042
#   (1, 8882)	0.2008535990004879
#   (2, 13002)	0.4178273946601497
#   (2, 7883)	0.4115831737060714
#   (2, 7296)	0.25227950699514085
#   (2, 19725)	0.6794655864185086
#   (2, 13073)	0.2719268865865864
#   (2, 19651)	0.23823705624464842
#   (3, 11759)	0.177015823419933
#   (3, 512)	0.21816172961594113
#   (3, 9424)	0.08809535056809599
#   (3, 3020)	0.12236442434307955
#   (3, 4075)	0.15463412465019175
#   :	:
#   (9338, 19831)	0.5843646825015023
#   (9338, 11182)	0.525012867860675
#   (9339, 16027)	0.4638993365228773
#   (9339, 8256)	0.4638993365228773
# ...

# %%
# Convertir la matriz dispersa a un array NumPy
vectores_tfidf_array = vectores_tfidf.toarray()

# Asegurar que el número de filas en vectores_tfidf coincida con la cantidad de filas en comentarios_inmigracion
# (vectores_tfidf_array debe tener la misma cantidad de filas que comentarios_inmigracion)
if vectores_tfidf_array.shape[0] == len(comentarios_violencia_genero):
    # Asignar los vectores TF-IDF al DataFrame como una nueva columna
    comentarios_violencia_genero['vectores_tfidf'] = list(vectores_tfidf_array)
else:
    print("Las longitudes no coinciden entre la matriz dispersa y el DataFrame.")

# %%
comentarios_violencia_genero['comment_stem'][10]
# Out:
# 'bonita violencia violencia mareemo perdiz violencia feminista ust forma verbal president violencia seca'
