# %%
from googleapiclient.discovery import build
from dateutil import parser
import pandas as pd

# Data viz packages
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# NLP
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
from wordcloud import WordCloud
from FunctionsYoutube import *
# !pip install wordcloud 
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/usuario/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/usuario/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 17
#      15 nltk.download('punkt')
#      16 from wordcloud import WordCloud
# ---> 17 from FunctionsYoutube import *
#      18 get_ipython().system('pip install wordcloud')
#      19 from wordcloud import WordCloud
#
# ModuleNotFoundError: No module named 'FunctionsYoutube'

# %%
api_key="AIzaSyDBJWJl3fxjbiVb4PE2YG4xRviQ5MJj1Mk"

# %%
api_service_name = "youtube"
api_version = "v3"

# Creamos la conexión con youtube API
youtube = build(
    api_service_name, api_version, developerKey=api_key)

# %%
next_page_token = None
all_video = []

while True:
    search_response = youtube.search().list(
        q="Opiniones españolas sobre el feminismo", # q es la query 
        part="id,snippet",
        maxResults= 50, 
        regionCode='ES', 
        pageToken=next_page_token if next_page_token else ""
    ).execute()  # Mover la ejecución aquí

    for item in search_response['items']:
        all_video.append(item) 
        

    next_page_token = search_response.get('nextPageToken')

    if not next_page_token:
        break

# %%
len(all_video)
# Out:
# 695

# %%
[x['snippet']['title'] for x in all_video]
# Out:
# ['¿El feminismo se contrapone a las libertades del mal llamado «neoliberalismo», como dijo Karamanos?',
#  '¿Por qué existe el feminismo?',
#  'La contundente respuesta de Olona frente al feminismo: &quot;hombres y mujeres somos complementarios&quot;',
#  'Machismo, feminismo y misandria',
#  '8M: MUJERES contra la &#39;LEY TRANS&#39; interrumpen el ACTO FEMINISTA presidido por IRENE MONTERO | RTVE',
#  '¿Qué con el feminismo? Opinión de Patricia Castañeda',
#  'Paro feminista, excusa para mujeres &quot;huevonas&quot;, dice &quot;La Mars&quot;',
#  'Cuando el FEMINISMO deja fuera a algunas mujeres',
#  'Zasca de Nadal a una periodista por la diferencia salarial entre hombres y mujeres | Diario AS',
#  'Mucho FEMINISMO pero LAS VACAS ¿qué? | #ELQH 1x11',
#  'Reflexionando sobre roles de género, machismo y feminismo.',
#  'FEMINISTAS RAZONANDO',
#  'PREGUNTAS A MUJERES SOBRE LA LEY SOLO SÍ ES SÍ #feminismo',
#  '8M ENTREVISTAS A FEMINISTAS EN EL 8M 2023',
#  'Machismo | Feminismo',
#  'Mujeres frente a las soflamas feministas del 8-M: «Me valgo por mí misma»',
#  'Policía herida responde a feministas del #8M | Noticias con Ciro Gómez Leyva',
#  'El machismo también afecta a los hombres☝🏼‼️ #feminismo #parati #shorts #youtube #paraellos',
#  'Hombre increpa a feminista durante marcha por los 43 de Ayotzinapa',
#  '&quot;Mi mujer es la que manda en casa&quot;: la proclama de Abascal que provoca revuelo en el Congreso',
#  '¿A quién más le han dicho esto? 🤷🏽\u200d♀️💜 #shorts  #feminista',
#  'Los ADOLESCENTES consideran que el FEMINISMO ACTUAL &quot;va contra la IGUALDAD&quot; | Ac2ality',
#  'Responde a Vox: &quot;¿Quién es usted para decir aquí quién es más español?&quot;',
#  'Abascal (Vox) critica la vestimenta para la moción de censura de algunos diputados',
#  'PREGUNTANDO SOBRE MACHISMO PRIMERA PARTE | Feminismo 4.0',
#  '&quot;En esta sociedad la verdera machista es la mujer&quot; #feminismo #shorts #debate',
#  'FEMINISMO ECOSOSTENIBLE CON PERSPECTIVA DE GÉNERO INTEGRAL EMPODERADO #shorts #madrid',
#  'La opinión de Pablo Casado sobre feminismo: &quot;El colectivismo no es bueno, soy liberal&quot;',
#  '¿Qué es el machismo? - Las Noticias',
#  'IRENE MONTERO: EDUCACIÓN SEXUAL para la MINISTRA, PEDERASTIA para VOX y Cs que piden su CESE | RTVE',
#  '¿Por qué existe aún desigualdad entre hombres y mujeres? EP8: El desafío de la Igualdad',
#  'Feminista Heterosexual | Patricia Sornosa | Comedy Central España',
#  '¿Quién es el responsable de los destrozos de la marcha feminista? | Noticias con Francisco Zea',
#  'Roxana Kreimer, dura contra el feminismo: &quot;Los varones sufren más violencia que las mujeres&quot;',
#  '¿Igualdad de género?',
#  'MUJERES se dan CUENTA de que el FEMINISMO las ha ESTAFADO…',
#  'Mi Feminismo, mi opinión.',
#  'Una diputada de Vox ironiza en el Congreso: &quot;¿Me están mirando? Podría denunciarles por violación&quot;',
#  '&quot;La sociedad aún no entiende lo que es la violencia de género&quot;. Marina Marroquí, educadora social',
#  '#TaniaLlasera y nueva masculinidad: &quot;El hombre tíazo no me gusta y me cansa&quot; #feminismo #hombres',
#  'Cinthia Fernández fulminó a las feministas &quot;Son discriminadoras y selectivas a la hora de bancar&quot;',
#  'Puntos importantes para entender el feminismo | Milenio Explica',
#  'Un muchacho salió a comprobar que los hombres también son acosados',
#  'Las mujeres no somos centros de rehabilitación. #feminismo #ideas #live #shorts #youtube #parati',
#  '&quot;En este momento me siento mujer&quot;: Hombre se niega a bajar de zona exclusiva del Metrobús',
#  'Rafa Nadal: “Qué más quiero yo que el hombre y la mujer sean exactamente iguales”',
#  'SOL DESPEINADA: LA DISCUSIÓN CON MILEI, ¿PRESIDENTA O PRESIDENTE?',
#  '¿Por qué debes HUIR de las FEMINISTAS?',
#  'Las opiniones divididas sobre los movimientos feministas en la CDMX | BIPOLAR',
#  'Breve Historia del Feminismo',
#  'Esto es el feminismo💜 #feminismo #feminista #shorts #youtube #ideas #parati #amorpropio',
#  '¿Qué es el feminismo?',
#  '&quot;Los hombres sobreviven por la falta de solidaridad entre las mujeres&quot; #feminismo #debate #shorts',
#  'Ciudadanos: &quot;No entiendo que una mujer feminista niegue la libertad de decidir a otras mujeres&quot;',
#  'Feminismo en la calle',
#  '¿Por qué &quot;feminismo&quot; no es antónimo de &quot;machismo&quot;?',
#  'Roxana Kreimer vuelve a atacar al feminismo: &quot;El femicidio es un término equivocado&quot;',
#  'El feminismo hegemónico es machista | Marina de la Torre | TEDxChamberi',
#  'Feministas critican ante Igualdad las leyes Trans y LGTBI',
#  'El feminismo complaciente que le gusta a Pedro Sánchez',
#  'PAPA FRANCISCO: CONVERSA con JÓVENES sobre el ABORTO o la PEDERASTIA en un DOCUMENTAL | RTVE',
#  'Feministas 4.0 | Debate | El País Semanal',
#  'FEMINISMO para torpes: ¿Es esto ACOSO?',
#  'La lección de un niño granjero a una vegana que le había criticado por criar gallinas MARCA',
#  'MILEI HUMILLÓ A FEMINISTA EN ESTADOS UNIDOS 🇺🇸: &quot;¿SER LIBERAL ES MACHISTA?&quot;',
#  'El duro discurso de Giorgia Meloni contra la ideología de género',
#  'PATRICIA BULLRICH: “MILEI NO ES HITLER O UN LOCO; COMPITE CON NOSOTROS Y TENEMOS QUE SER MEJORES”',
#  'SOY FEMINISTA MODERNA',
#  'El feminismo y el lenguaje inclusivo según Vargas Llosa',
#  'A Ayuso:&quot;Llaman vagos a quienes reciben una ayuda para comer pero ensalzan a los que van de palco&quot;',
#  'Una concejala de Podemos denuncia micromachismo por la temperatura del aire acondicionado',
#  'Los polémicos dichos de Roberto Piazza sobre las feministas: &quot;Les regalaría un consolador&quot;| #Bendita',
#  'Putin, contra la homosexualidad',
#  'Cómo educar en la igualdad de género. Marina Subirats, socióloga',
#  'Un pastor evangélico pisa una bandera LGTB en televisión',
#  'Hanglin: &quot;El feminismo me parece desagradable y facho, el machismo murió hace más de 100 años&quot;',
#  'MILEI LE CERRÓ LA BOCA A PERIODISTA ZURDA',
#  '8M: El FEMINISMO DIVIDIDO convoca DOS MANIFESTACIONES distintas en MADRID | RTVE Noticias',
#  'Represión feministas en marcha del 8M en Monterrey - N+',
#  'Arrimadas destroza a Montero: &quot;Lo suyo no es feminismo, es sectarismo&quot;',
#  'Seis minutos de broncas: el vídeo que resume el tenso clima político en España',
#  'LA ENTREVISTA MÁS POLÉMICA de FRANK CUESTA: El FEMINISMO y el BESO de RUBIALES (PARTE 1) | UTBH',
#  'Abascal, a las diputadas de Podemos: &quot;Ustedes son mujeres, pero no representan a las mujeres&quot;',
#  '#8M | Debate sobre feminismo y mujer con políticas españolas',
#  '¿Por qué la calle y no otras formas? la protesta feminista | Paulina Millán | TEDxTecdeMty',
#  '8M: ¿Qué papel deben jugar los hombres en el feminismo? | BBC Mundo',
#  'Anuncio MACHISTA en la televisión española #shorts #feminismo #machismo',
#  'Así piensan los niños sobre el matrimonio gay',
#  'Vox: «De día dicen ser feministas, pero de noche son el partido que más gasta en prostitutas»',
#  'Santiago Abascal sobre la violencia de género: &quot;Busca la guerra de sexos y criminalizar al hombre&quot;',
#  'Debate feminismo: El libro &#39;Lolita&#39; y y la representación de la mujer en la cultura | Opinión',
#  'Sergio Pérez opina sobre las mujeres en la Fórmula 1',
#  'La rotunda respuesta de una niña trans a la intrusiva pregunta sobre sus genitales - El Intermedio',
#  'Ricky NO es Feminista por ESTE Motivo #delox #rickyedit #smae_podcast #feminismo #shorts',
#  'Flor Amargo llora y lamenta ataques por usar lenguaje inclusivo',
#  'FEMINISMO 2.0 | Preguntando a feministas #2',
#  'DEBATE #4M | Los RIFIRRAFES entre AYUSO e IGLESIAS',
#  'Las precursoras del feminismo en España',
#  'Feministas Cuando Anuncian Que Hay Guerra 😂🔥 #shorts',
#  'MILEI DESTRUYÓ EL MITO DE LA BRECHA SALARIAL',
#  'El FUERTE CRUCE entre Javier Milei y Manuela Castañeira: “Tu plan económico es el de Videla”',
#  'La opinión de Carles Francino | Feminismo con un par',
#  'PREGUNTAS A UNA FEMINISTA',
#  '🟣 Esta la opinión de los españoles sobre el contexto actual de la mujer a través de Sigma Dos',
#  '8M: ¿La DIVISIÓN del FEMINISMO está provocando que pierda FUERZA? | RTVE Noticias',
#  'FEMINISMO para torpes: Cosas que parecen feministas, pero no',
#  'LEY TRANS: Su APROBACIÓN ha generado POSTURAS ENFRENTADAS dentro del FEMINISMO | RTVE Noticias',
#  'VARGAS LLOSA 🤫 sobre el LENGUAJE INCLUSIVO (Entrevista) #shorts',
#  'Las mujeres más influyentes de la historia del feminismo en España',
#  '¿Hay privilegios por ser hombre? #pedrobuerbaum #igualdad #feminismo',
#  'EL XOKAS genera POLÉMICA al elogiar a quienes se aprovechan de MUJERES &quot;COLOCADAS&quot; | RTVE Noticias',
#  'feministas intentando tener la razón',
#  'RUBIALES habla de “FALSO FEMINISMO” y dice que DEMANDARÁ a DÍAZ, MONTERO, BELARRA y ECHENIQUE | RTVE',
#  'FEMINISMO | Del &#39;Se Acabó&#39; al #MeToo: seis himnos feministas que cambiaron el mundo | EL PAÍS',
#  'Golpea a un ciego y recibe su merecido',
#  '8M: El FEMINISMO marcha DIVIDIDO por la LEY TRANS, el &#39;SOLO SÍ ES SÍ&#39; y la PROSTITUCIÓN | RTVE',
#  'Milei eliminará el Ministerio de la Mujer &quot;si es Presidente &quot; | A24',
#  '&quot;Dios es mujer&quot;, gritó una feminista en el pesebre del Vaticano | #TPANoticias',
#  'FEMINISIMO para torpes: ¿Soy feminazi? #8M',
#  'Taxista denuncia acoso de pasajera; video se vuelve viral',
#  'Tremendo enfado de Nadal por una pregunta sobre su mujer | Diario AS',
#  'Inés Hernand: ¿Qué piensa la generación Z sobre el feminismo?',
#  'Polémica por periodista que pronuncia correctamente nombres en español | Noticias Telemundo',
#  'Retratos del feminismo | Tráiler oficial VOS en ESPAÑOL | Netflix España',
#  'Anuncio MACHISTA en la televisión española #shorts #feminismo #machismo',
#  'Obama responde a la interrupción de una activista transexual',
#  'LAS 4 OLAS ¿Cómo es la historia del feminismo? - Ellas Más',
#  'Una reflexión sobre el feminismo y la cultura musulmana',
#  'Yolanda Díaz explica por qué el feminismo no enfrenta a hombres y mujeres en #HoraVeintipico #shorts',
#  'Feministas: ¿qué estaban pensando? I Tráiler oficial I Netflix',
#  'Sufragistas. Pioneras de las luchas feministas - Canal Encuentro',
#  '&quot;La Reinota&quot;, alaban en redes a la mujer que regresó una bomba de humo a policías el 8M',
#  'El movimiento feminista: origen 🚺El feminismo, resumen.',
#  'Famosas que responden a preguntas sexistas',
#  'Rapera española hace rimas feministas en CDMX | Noticias con Ciro Gómez Leyva',
#  'FEMINISTA Y LA PROMISCUIDAD',
#  'Analizando el concepto de “verdadera feminista” | OPINIÓN',
#  'Debate sobre la ideología de género/ 2',
#  'Salud mental, feminismo y diversidad sexual, tabúes en el trabajo',
#  'Los dos lados de la marcha feminista',
#  'Javier Milei y Soledad Silveyra, cruce de opiniones y pensamientos en Mujeres de eltrece',
#  '&quot;El feminismo no es mujeres contra hombres. El machismo es ideología&quot;, por Marta Flich',
#  'Anuncio MACHISTA en la televisión española #shorts #feminismo #machismo',
#  'Provocadores golpean a reporteros en marcha contra violencia de género',
#  'Lo Bueno de una MUJER FEMINISTA #shorts',
#  'LENGUAJE INCLUSIVO 🔴 ¿Tiene sentido lingüístico?',
#  'Feminismo para torpes: del chiste a la violación, así funciona la pirámide de la violencia machista',
#  '&quot;¿Dónde están las feministas españolas?&quot;, por Ana Bernal-Triviño',
#  'Tenso cara a cara entre Sofía Rincón y Angélica Rubio: &quot;Sois unas dictadoras&quot;',
#  '😯📚 QUÉ es FEMINISMO?... #shorts',
#  '¿Cómo ven los niños la igualdad?',
#  'Javier Milei: &quot;Venezuela logró la igualdad, son todos igual de pobres&quot;',
#  'Machismo en la Red: &quot;Me llaman feminazi&quot; | España',
#  '¿Qué piensan las mujeres ELLE sobre el feminismo? | Elle España',
#  'El patriarcado del salario: críticas feministas al marxismo, de Silvia Federici',
#  '&quot;El feminismo no ha salvado a las mujeres&quot; Agustín Laje en #VivianaConVos 25 03 2022',
#  'JORNADA DE BUENAS PRÁCTICAS - ADiFem –Archivo Digital del Movimiento Feminista en España',
#  '&quot;El FEMINISMO es una DESGRACIA&quot; - Dalas Review en contra el feminismo | Sin Miedo Al Éxito',
#  'Cuando llevar el velo islámico te deja sin trabajo | España',
#  'Ayuso llama &quot;malcriadas&quot; a las feministas e Irene Montero le responde',
#  '¿No te ha pasado que...? - Micromachismos | eldiario.es',
#  '¿Por qué el Ejército ruso no consigue vencer en Ucrania?',
#  '3 generaciones hablan de feminismo - En Todo Caso',
#  'Así se aprobó la Ley de libertad sexual en España 🇪🇸 #SoloSíesSí',
#  'El feminismo radical es excluyente | María Blanco',
#  'Romper estereotipos de género en los colegios',
#  'Los retos del feminismo, a debate en Foros de Vanguardia',
#  'Feminismo: el concepto que cambió a Chile para siempre',
#  'Chistes machistas vs feministas - Videomatch',
#  'Diálogos en democracia II: España feminista',
#  'Diferencia entre el feminismo y pseudofeminismo, en opinión de Francisco Moreno',
#  'Expulsan de vuelo a pareja pro Trump por insultos racistas y homofóbicos',
#  '&quot;Bukele va más rápido que Chávez desmantelando la democracia&quot; | Contexto DW',
#  'FEMINISTAS CONTESTAN',
#  '¿Qué opinan los jóvenes? - Feminismo',
#  '¿Igualdad o equidad? ¿patriarcado y machismo? Estíbaliz te explica el feminismo en TikTok',
#  'El cruce de Milei en TN Central por las denuncias de maltrato contra mujeres',
#  'Así es ser musulmán y gay en España | España',
#  'Las mujeres se rebelan en Latinoamérica | DW Documental',
#  'Diputado Schalper a Boric: &quot;Ríase todo lo que quiera, le va a servir para bajar de peso&quot;',
#  'DEBATE de INVESTIDURA | LA FUERTE BRONCA COMPLETA durante la intervención de EH BILDU',
#  'El feminismo ha muerto. Vive la igualdad real. | Cristina Manzano | TEDxUniversidadEuropeaMadrid',
#  'Si el feminismo se trata de la igualdad de géneros, ¿por qué no somos feministas?',
#  'El FEMINISMO MACHISTA y el BESO de RUBIALES | UTBED',
#  'Historia crítica del feminismo español (IV):(...)',
#  '&quot;SI ME INSISTES ES AC0S0&quot; FEMINISTAS VS ROMA PARTE 4 / 29-9-2023',
#  'Huelga feminista en España: &quot;Se espera un seguimiento del 75%&quot;',
#  '¿Por qué es importante hablar de feminismo? | Catalina Ruiz-Navarro | TEDxBogotaMujeres',
#  'Jesús Adrián Romero en Cala  | CNN en Español',
#  'Picante cruce verbal entre Cristina Kirchner y una senadora tucumana',
#  'Mujer que humilla a vendedora recibe pequeña dosis de karma',
#  'Las FEMINISTAS NO entienden por qué HUYEN de elllas - feat Carla Galeote',
#  'Late Motiv: Patricia Sornosa, humor feminista #LateMotiv126 | #0',
#  'Feminismo y mujeres en la disputa por el poder | Cierre EIF2023',
#  'Así se representaba a la mujer en el No-do | Franco. La vida del dictador en color',
#  'Aitana - Ni Una Más (video oficial)',
#  '¿Qué Dice La Biblia Acerca Del Feminismo?',
#  'La estruendosa superioridad del capitalismo | Javier Milei | TEDxSanNicolas',
#  'La Voz de Iñaki: Mujeres y hombres',
#  'FEMINISTAS EXPLICAN POR QUÉ DEBE EXISTIR EL MINISTERIO DE IGUALDAD 🚺💜',
#  'La Voz de Iñaki: Mujeres y hombres',
#  'La estruendosa superioridad del capitalismo | Javier Milei | TEDxSanNicolas',
#  'FEMINISTAS EXPLICAN POR QUÉ DEBE EXISTIR EL MINISTERIO DE IGUALDAD 🚺💜',
#  'FEMINISTA VS ROMA GALLARDO',
#  '8M en el Congreso ♀️ | IRENE MONTERO contrapone las conquistas FEMINISTAS al modelo de la DERECHA',
#  'HISTORIA DEL FEMINISMO EN 10 MINUTOS',
#  'Las mujeres de VOX se rebelan contra el feminismo supremacista',
#  '¿Eres de izquierda o de derecha?',
#  'Feminismo: ¿Cuál es su origen y cómo surgió en México?',
#  'Historia crítica del feminismo español (III):(...)',
#  '¿La HOMOSEXUALIDAD va contra la EVOLUCIÓN? | DARWIN, TE NECESITO',
#  'Revelando estereotipos que no nos representan | Yolanda Domínguez | TEDxMadrid',
#  'Emma Watson y sus frases feministas más icónicas',
#  'ROSTROS 8M Misionera española: Defiendo el feminismo de la vida que nos hará más felices',
#  'NO SE NACE FEMINISTA | Simone De Beauvoir (1908-1986) | TEDxCuauhtémoc',
#  '📖 El Debate entrevista a Julia Navarro, que critica un nuevo feminismo que «borra a las mujeres»',
#  'Libros, mujeres y feminismo. Laura Freixas',
#  'Bebe: &quot;Apoyo el feminismo cuando es coherente, pero a veces llega a un punto radical, violento&quot;',
#  'Feminismo; ¿por qué usan el color morado? - Bien y de Buenas',
#  '&quot;ME AUTOPERCIBO IMPALA&quot; FEMINISTAS VS ROMA PARTE 3 / 29-9.2023',
#  'LA HISTORIA DEL FEMINISMO en 6 minutos',
#  '07-12-2012. Historia crítica del Feminismo español. Parte 1: Las pioneras.',
#  '&quot;La sociedad es machista porque a la mujer le interesa&quot; #feminismo #shorts #debate',
#  'las FEMINISTAS NUNCA CAMBIARÁN lo que nos ATRAE a las MUJERES #shorts',
#  'El CONGRESO aprueba la LEY del &#39;SOLO SÍ ES SÍ&#39; a favor del CONSENTIMIENTO SEXUAL | RTVE Noticias',
#  '¿El lenguaje inclusivo sirve de algo?',
#  'Consejos de un experto para ganar un debate',
#  '8M, de la manada hasta hoy: un debate intergeneracional sobre el feminismo',
#  'III Edición Sala de Columnas: FEMINISMO Y OPINION (1ª Sesión)',
#  'Abascal: &quot;Son mujeres pero no las representan&quot;',
#  'Experiencias feministas en torno a la salud | EIF2023',
#  '15-02-2013. Historia crítica del Feminismo español (2):  El Feminismo en la Segunda República.',
#  'Una historia mundial de los derechos de las mujeres en 3 minutos',
#  'Arturo Pérez-Reverte habla del lenguaje inclusivo y la evolución de la lengua - El Hormiguero',
#  'Feminismo interseccional: un feminismo diverso | AJ+ Español',
#  'FEMINISMO para torpes: Cómo insultar (bien) a una mujer',
#  '&quot;En las primarias, la estrella va a ser Milei&quot; : Jaime Bayly, Periodista',
#  'Anuncio MACHISTA en la televisión española #shorts #machismo #feminismo',
#  '¿Por qué el 99% de las MUJERES SON FEMINISTAS? #shorts',
#  'Discriminación de  género',
#  '¿Por qué el morado es el color del feminismo? La historia detrás del 8M',
#  '¿Qué es ser mujer? | Agustín Laje',
#  'VOX vs. MONTERO: RIFIRRAFE por el ASESINATO de la NIÑA de GIJÓN, presuntamente, por SU MADRE | RTVE',
#  'María Galindo en el Encuentro Internacional Feminista',
#  '&quot;Feminismo para principiantes&quot;  de Nuria Varela - Debate 1 - Sáb 5 Dic 19hrs España',
#  'Puta y feminista: Crónica de una trabajadora sexual | Georgina Orellano | TEDxRiodelaPlata',
#  'Debate &quot;El feminismo a través de las generaciones&quot;',
#  'FEMINISTAS DEMUESTRAN EL PATRIARCADO PRIMERA PARTE / 15-10-2023',
#  '¿Qué es ser feminista hoy? Las reflexiones de cinco mujeres uruguayas',
#  'The Wild Project #21 feat Roma Gallardo | Feminismo, VOX, Okupas y Menas, Risto Mejide',
#  'Conversación delirante entre una okupa y la propietaria de la casa',
#  'III Edición Sala de Columnas: FEMINISMO Y OPINION (1ª Sesión)',
#  '8 mujeres reaccionan a comentarios machistas',
#  'Anuncio MACHISTA en la televisión española #shorts #machismo #feminismo',
#  'Increpan a Irene Montero durante un encuentro feminista | EL PAÍS',
#  'LAS FEMINISTAS SOLO APOYAN MUJERES POR LAS QUE NO SIENTEN CELOS #SHORTS',
#  'El problema del feminismo #pedrobuerbaum #feminismo #vox',
#  'Las imágenes del 8M en España: el feminismo vuelve a llenar las calles, pero por separado',
#  '¿Están RESURGIENDO los grupos NEONAZIS en España? I RTVE Noticias',
#  'Guerra - Residente (Video Oficial)',
#  'Experiencias feministas en torno a la salud | EIF2023',
#  'La bronca de Belén Rueda y Ricardo Darín con Pablo Motos',
#  '¿Cuánto pesan los prejuicios? - El Hormiguero',
#  'Análisis crítico del movimiento feminista desde la óptica de un psicólogo - Esteban Cañamares',
#  'Sofía Rincón contra el FEMINISMO ♀️ supremacista',
#  '&quot;Feminismo para principiantes&quot;  de Nuria Varela - Debate 1 - Sáb 5 Dic 19hrs España',
#  'Seminario La ultraderecha y el (anti)feminismo: el caso de España',
#  '&quot;EL FEMINISMO DA VOZ A MI AMIGA&quot; FEMINISTAS VS ROMA PARTE 2 / 29-9-2023',
#  'Anuncio MACHISTA en la televisión española #shorts #feminismo #machismo',
#  'Afrodita desenmascarada, una defensa del feminismo liberal',
#  '¿El FEMINISMO es lo MEJOR de ESPAÑA? #shorts',
#  'Soy mujer y NO soy feminista - Preguntas y respuestas | Mars Aguirre',
#  'Feminismo: encuentro con la filósofa y escritora Amelia Valcárcel',
#  '8M: Día de REIVINDICACIONES FEMINISTAS en muchas ciudades de ESPAÑA  | RTVE Noticias',
#  'JAVIER MILEI: &quot;¿Me podés mostrar la lista completa de los 30 mil desaparecidos?&quot;',
#  'Por esto las FEMINISTAS son poco ATRACTIVAS…',
#  'Franco Escamilla - Monólogo No somos iguales',
#  'IRENE MONTERO DESTROZA EL FEMINISMO CON LA LEY TRANS.',
#  'Ayuso: &quot;Nadie feminista es ministra por ser la mujer de un vicepresidente&quot;',
#  'El feminismo es de las mujeres | Cristina Almeida',
#  'Franco Escamilla.- &quot;Ventajas de ser mujer&quot;',
#  '¿Qué significa este #8M para vos? | #Cobertura #Shorts',
#  'Hablemos de sexualidad: ¿Qué es ser normal? | Raquel Rottmann Rottmann | TEDxTukuyWomen',
#  'EP16: Hablemos del feminismo con Jessica Fernández - Alma y Psicología Podcast',
#  'Corto documental JUNTAS',
#  'Estereotipos de género.',
#  'No tenemos hijos por egoísmo #redpill #feminismo #mujeres #podcast #feministas',
#  'Santiago Abascal: &quot;VOX no tiene una posición sobre Franco&quot; - El Hormiguero 3.0',
#  'FEMINISMO para torpes: esto del feminismo, ¿ES UNA MODA?',
#  'FEMINISTAS VS ROMA PARTE 1 / 29-9-2023',
#  'Anuncios MACHISTAS en la televisión española #shorts #machismo #feminismo',
#  '“El Populismo ama tanto a los pobres que los multiplica”: Gloria Álvarez',
#  '🎙 PODCAST | Mujeres contra el feminismo: las troyanas de la ultraderecha',
#  'DEBATE: María Blanco y Camila Rojas | Feminismo: perspectivas sociales y económicas',
#  'Caperucita dice NO - #CambiaelCuento - Violencias machistas',
#  'Estulin: “Para que la élite sobreviva, la mayoría de nosotros debe morir” - Al Rincón',
#  'Santiago Abascal sobre adopción gay: &quot;Se prefiere que un niño tenga padre y madre&quot; - El Hormiguero',
#  'FEMINISMO ISLÁMICO | ¿Una respuesta necesaria o incompatible? PARTE 2 | ramiaschannel',
#  'ME CRITICA UNA FEMINISTA YOUTUBER',
#  'El diálogo jugadora-técnico que indigna al tenis: &quot;¿Eres estúpido?&quot; | Diario AS',
#  'El diálogo jugadora-técnico que indigna al tenis: &quot;¿Eres estúpido?&quot; | Diario AS',
#  'ME CRITICA UNA FEMINISTA YOUTUBER',
#  'La moda del feminismo | Nerea Perez de las Heras | TEDxLeon',
#  'Feminismo con Henar Álvarez | Poco se habla! 2x04',
#  'Irene Montero increpada en la Complutense: &quot;¡No eres feminista, ser mujer no es un sentimiento!&quot;',
#  'FEMINISMO PARA TORPES: Así se ha silenciado LA VOZ DE LAS MUJERES',
#  'por esto el FEMINISMO está haciendo INFELICES a las MUJERES ... #shorts',
#  'El feminismo contado para niños: &quot;Érase una vez una lucha justa&quot;',
#  'Las aberraciones del feminismo radical',
#  '5 libros sobre feminismo | El librero de Elyse',
#  'Only Fans, ¿mercantiliza o libera a la mujer? | Gen Playz',
#  'VICE Meets: Florence Thomas, fundadora del feminismo en Colombia',
#  'Feminismo, machismo y sororidad con @manuela_camacho CAP #65 | T03',
#  'JAVIER MILEI DEFINE A SUS CONTRINCANTES CON EMOJIS 👆',
#  '¿Qué es la perspectiva de género y para qué sirve?',
#  'El &#39;colmo&#39; de la okupación: &quot;He perdido mi trabajo para vigilar que no me quiten mi casa&quot;',
#  'FEMINISTAS DEL PSOE recurren a la BIOLOGÍA contra la LEY TRANS y ERREJÓN HABLA. LO NUNCA VISTO!',
#  'TOP5 Youtubers Feministas | Código Nuevo',
#  'Carmen de Burgos Colombine, pionera del periodismo y el feminismo',
#  'ESTA SEÑORA ESPAÑOLA DICE LO QUE PIENSA DEL FEMINISMO #shorts',
#  'Rosalía habló sobre el feminismo y el patriarcado con Bebe Sanzo',
#  '¿Qué es la diversidad sexual?',
#  'ME INSULTAN FEMINISTAS DE NUEVO | PRIMERA PARTE',
#  'Victoria Villarruel: &quot;Cristina Kirchner fue una tragedia para este país&quot;',
#  'Marcos de Quinto Exvicepresidente ejecutivo de Coca-Cola en #PodcastNTY #cocacola #feminismo #españa',
#  '¿ES NECESARIO el FEMINISMO? | Draw My Life en Español',
#  'BERTÍN OSBORNE: “España NO necesita un MOVIMIENTO FEMINISTA como agua de mayo”',
#  'Mujeres NoMo, la generación de mujeres sin hijos',
#  'Libros FEMINISTAS y mujeres literarias que admiro💜💚💖',
#  '¿Qué pasa si pones un niño frente a un niña y le pides que la abofetee?',
#  'VOY A CHARLA FEMINISTA EN LA UNIVERSIDAD',
#  'GORDOFOBIA A LAS MUJERES',
#  'Las mujeres y la literatura | Con vos propia',
#  'Frank Cuesta se sincera sobre su opinión acerca de los grupos animalistas - El Hormiguero 3.0',
#  '#CTXTfeminismoZGZ Barómetro de 40dB. para CTXT El feminismo en España: ¿realidad o burbuja?',
#  'Simone de Beauvoir',
#  'Debate sobre la ley Trans en &#39;Hora 25&#39;',
#  'El papa Francisco explica por qué la Iglesia silenció los abusos sexuales - Salvados',
#  'El machista no soy yo | Himno Igualdad Real | Anti-himno Feminista | La Culpa no era mía (Parodia)',
#  'Un currículo de educación sexual en Canadá atemoriza a padres de familia conservadores',
#  'feminismo para  principiantes - parte 1',
#  'INACEPTABLE! MIRA QUÉ DICE LA MINISTRA DE IGUALDAD',
#  'La opinión del doctor Pedro Cavadas sobre la gestión del coronavirus en España - El Hormiguero',
#  'La marcha feminista en Ciudad de México deja 81 mujeres heridas, 62 de ellas policías',
#  'RESPONDO A LAS ACTIVISTAS DE GÉNERO MÁS FAMOSAS (en el Día de la Mujer #8M)',
#  'Revientan el acto del 8M e Irene Montero responde: &quot;Las mujeres trans son mujeres&quot;',
#  '¿Es malo el FEMINISMO?',
#  'PRUEBAS de acceso GUARDIA CIVIL MUJERES VS HOMBRES',
#  'El feminismo #FernandoLozano #DianaPerlaChapa #feminismo #activismo',
#  'En defensa del feminismo liberal | María Blanco',
#  '¿Es malo el FEMINISMO?',
#  'PRUEBAS de acceso GUARDIA CIVIL MUJERES VS HOMBRES',
#  '¿Existe el PATRIARCADO?',
#  '8-M: ¿Por qué una huelga feminista en España?',
#  'El feminismo #FernandoLozano #DianaPerlaChapa #feminismo #activismo',
#  'En defensa del feminismo liberal | María Blanco',
#  'Interrumpió mi programa para insultarme y le salió mal (debate en vivo) | Emmanuel Danann',
#  '¿Cuál es la joda con la ideología de género?',
#  '&#39;Yo soy feminismo&#39;, por Cayetana Álvarez de Toledo',
#  'Hombres de alto valor #redpill #podcast #mujeres #feminismo #feministas',
#  'Vivir Quintana - Canción sin miedo ft. El Palomar',
#  'El feminismo actual en España | Intermediate Spanish Podcast | Spanish Listening',
#  'Arturo Pérez-Reverte: “Los héroes por la mañana eran violadores por la noche” - El Hormiguero',
#  'Rufián la llama &quot;palmera&quot;, esta le responde &quot;imbécil&quot;',
#  'Versión Completa. ¿Para qué sirve la ética? Adela Cortina, filósofa',
#  'Celia Amorós: filosofía y feminismo. Día Internacional de la Mujer',
#  'Una senadora del PP acorrala a Irene Montero por el &quot;machismo&quot; de Iglesias',
#  'Feministas Tóxicas Quieren ACABAR CON LOS HOMBRES (y médula ósea)',
#  'Inspirando al futuro sin estereotipos',
#  'Amén. Francisco responde | Tráiler oficial en castellano | Disney+',
#  'Arturo Pérez-Reverte nos hace reflexionar sobre las redes sociales - El Hormiguero',
#  '8M 2023: PREGUNTANDO A FEM1N1$TAS | Emmanuel Danann',
#  'ENTREVISTAS EN LA CALLE: “¿ERES FEMINISTA?” 🥴',
#  '10 FORMAS DE RECONOCER A UNA FEMINISTA FANÁTICA (Roxana Kreimer)',
#  'Discurso de niña indígena en la @ieepcnlmx  Natalia López López | Versión Completa',
#  'ENTREVISTAS EN MANIFESTACIÓN BESO RUBIALES DISFRAZADO DE FEMINISTA ¿SABEN DE FÚTBOL FEMENINO?',
#  'Fuertes críticas a Andrés Calamaro por su estado en la TV española',
#  'Frank de la Jungla sobre el FEMINISMO en España 🧨🧨🧨',
#  'Artículo de opinión: Feminismo para &quot;dummies&quot;',
#  'El MACHISMO a través del ANIME Y EL MANGA | Análisis y opinión',
#  'Judith Butler, filósofa: “Los hombres deberían ser feministas porque la igualdad es sexy”',
#  'NO SE PUEDE DECIR NADA',
#  'Pura Lujuria. Filosofía feminista elemental. Mary Daly',
#  '✨Una opinión sobre el feminismo por parte de Ayn Rand ✨#objetivismo #aynrand #libertad #fyp #viral',
#  'El Fary: &quot;Detesto al hombre blandengue&quot; #LaVidaModerna',
#  'TIK TOKS FEMINISTAS PEDANTES',
#  'Agustín Laje - ¿Por qué las feministas no defienden a todas las mujeres?',
#  'La Crítica Feminista al Derecho - Resumen del artículo de la Dra. JARAMILLO',
#  'Diferencia entre SOCIALISMO y COMUNISMO - Explicada para principiantes!',
#  'NO LOS NECESITAMOS, SOLAS PODEMOS SOBREVIVIR',
#  'La REALIDAD TRANS. Respuesta a La gata de Schrödinger',
#  'FEMINISMO: Breve historia y significado (NO APTO para masculinidades frágiles) - Versión Extendida',
#  '‘Ayudar en casa’ no es suficiente, hay que compartir la carga mental. Alberto Soler, psicólogo',
#  'MI CAMBIO A MUJER / BULOS DE LA LEY TRANS',
#  'Ricardo Darín íntimo: habla sobre el feminismo, la política Argentina y qué haría si no fuese actor',
#  'Por qué la feminidad y el empoderamiento son compatibles | análisis y opinión',
#  'Judith Butler y la Performatividad de Género - Filosofía Actual',
#  '8M MADRID: El FEMINISMO partido en 2 MARCHAS por la LEY TRANS y el &quot;SÓLO SÍ ES SÍ&quot; | RTVE',
#  '#Shorts La militancia feminista logra objetivos (Ley del Borrado)',
#  'CÓMO HACER UN ENSAYO EN 3 PASOS ✅ ¡más fácil que nunca! 😎. edutuber',
#  'El FEMINISMO en la URSS: ¿mujeres eslavas son cazafortunas? - Comunismo ✦ Iryna Fedchenko',
#  'Polémica en España por determinar si los gallos violan o no a las gallinas',
#  'FEMINISTAS VS ROMA PARTE 5 FINAL / 29-9-2023',
#  'LOS ERRORES DEL FEMINISMO *autocrítica* 8M',
#  'Nuestra vicesecretaria Alicia Rubio deja en ridículo a una activista de Femen',
#  'LA RESISTENCIA - Entrevista a El Jincho | #LaResistencia 09.03.2020',
#  'Ley trans: ¿Por qué está siendo objeto de debate? | Gen Playz',
#  'La Base #21 - 8M: avance feminista vs reacción machista',
#  'Las reivindicaciones feministas irrumpen en el pleno de Portugalete',
#  'Debate picante con militante de #NiUnaMenos | Emmanuel Danann',
#  'Mi hija quiere entender el sistema financiero | Hernan Casciari | TEDxMontevideo',
#  'La entrevista más POLÉMICA que me han hecho: AUTODETERMINACIÓN, FEMINISMO, ANIMALISMO, FRENTE OBRERO',
#  '¿La desigualdad entre hombres y mujeres ya no existe?, con Carmen Sarasúa',
#  'Este debate acerca del machismo hizo desesperar enormemente a Karla',
#  'Versión Completa. ¿Qué da sentido a tu vida? Pilar Sordo, psicóloga y escritora',
#  '8M: Cuando Cayetana Álvarez de Toledo arrasó a Irene Montero por su feminismo de pega',
#  '¿Qué significa ser una persona trans?',
#  'Feminismo y marxismo, una mirada sobre los desafíos actuales del movimiento de mujeres',
#  '¿ESTÁ CRECIENDO LA VIOLENCIA SOCIAL EN TODAS PARTES? - Vlog de Marc Vidal',
#  'EL FEMINISMO DE IRENE MONTERO ¡DESTAPADO! #shorts #irenemontero #feminismo #unidaspodemos #vox',
#  '💥 Carlos Alsina devora a Pedro Sánchez en directo: ¡Le suelta en la cara lo que todos pensamos! 💥',
#  'La Dra. Marilú Rojas Salazar nos explica ¿Qué es el feminismo?',
#  '🤔 ¿Cuánto sabes de FEMINISMO?  🎲 TEST sobre feminismo e igualdad con 10 preguntas TRIVIAL QUIZ | PSC',
#  '¿De dónde viene y qué es el FASCISMO?',
#  'El feminismo moderno no busca igualdad #podcast #mujeres #feminismo #feministas #machismo',
#  'El vídeo más impactante sobre el maltrato psicológico | Silvia Congost',
#  '¿ por qué siendo de IZQUIERDAS me alejé del &quot;FEMINISMO&quot;?',
#  'Resistencias y creatividad. Asociación de Teólogas Españolas.',
#  'Milei discute con una feminista por la brecha salarial de género- 20/10/21',
#  'IRENE MONTERO LLORA PORQUE ES UNA VICTIMA DEL MACHISMO',
#  'Conferencia LNF 2018: Género y políticas del conocimiento, Por Diana Maffía - Canal Encuentro',
#  'Qué significa FEMINISMO',
#  'SOY GORDA Y TÚ NEGRO',
#  'MARIAN ROJAS, psiquiatra | Las tres puertas',
#  'Más allá del rosa- Las hermanas olvidadas del feminismo con Maryangel García-Ramos',
#  'Versión Completa. Cómo aprender a amar en igualdad. Marina Marroquí, educadora social',
#  'EL NUEVO LENGUAJE',
#  'Opiniones? #España #Derecha #Vox #igualdad #Feminismo #Mujer #Hombre #antifeminismo #ElPensadorLibre',
#  '¿Por qué FEMINISMO y no IGUALISIMO?',
#  'DEBATE: Ideología de Género ¿Mito o realidad? | Agustín Laje Vs Valentina Verbal',
#  'LA CONFERENCIA MÁS POLÉMICA VS EL FEMINISMO RADICAL 🔥',
#  'La Base #2x43 - Pablo Motos rompe el machistómetro',
#  'Debate ÉPICO con mujer tr4ns (¡FINAL INESPERADO!)  | Emmanuel Danann',
#  'SARA SÁLAMO USA EL FEMINISMO BARATO PARA ATACAR UNA RECAUDACIÓN DE FONDOS PARA EL CÁNCER DE PRÓSTATA',
#  'Políticas identitarias: ¿Hemos olvidado la conciencia de clase? | Gen Playz',
#  'La mujer tiene mayor valor que el hombre #redpill #podcast #feminismo #feministas #mujeres',
#  'El alegato de una estudiante que desenmascara a las feministas radicales de la Complutense',
#  'EVARISTO sobre el FEMINISMO 💥',
#  'Opino de MASCULINIDAD y Andrew Tate con Feminista',
#  'LA RESISTENCIA - Entrevista a José María García | #LaResistencia 30.05.2023',
#  'Platicando sobre MACHISMO con FEMINISTAS',
#  'Late Motiv: Patricia Sornosa, Monologuista Feminista #LateMotiv105 | #0',
#  '&quot;Os intimidan las mujeres empoderadas&quot; #redpill #podcast #feminismo #feministas #mujeres',
#  'Agustin Laje debate sobre feminismo: 1 vs. 5',
#  'Qué es el feminismo - Ellas Dicen',
#  '¿El feminismo te libra del racismo? con Desirée Bela | Una Habitación Propia 01',
#  'FEMINISTA QUISO ACUSARLO DE 4C0S0 Y FUÉ EXPULSADA DEL GYM POR MENTIROSA',
#  '8M ENTREVISTAS A FEMINISTAS EN EL 8M 2023 MEXICO',
#  'Tania J. Rodríguez, Feminismos populares en América latina',
#  'LA VERDAD SOBRE LAS MUJERES',
#  'Gustavo Bueno. Feminismo, género y posmodernidad',
#  'EL FEMINISMO',
#  'Feministas buscaban igualdad de derechos pero no de obligaciones #feminismo #feministas #feminista',
#  'COSAS MACHISTAS',
#  'LA ORGANIZACIÓN QUE FUMA CACA | HABLEMOS SOBRE EL VEGANISMO Y LA PESIMA ORGANIZACIÓN PETA',
#  '&quot;IGUALDAD de GENERO&quot;👀🥊#deportes #igualdad #fuerza',
#  '#podcast #feminismo #cuestiónate #parati',
#  'PROHIBEN EL DÍA DEL PADRE EN LOS COLEGIOS PÚBLICOS',
#  'Feminismo...',
#  'DEBATE EN LA TELE en CUATRO AL DÍA / Les sale mal...',
#  'Diputado de Vox confronta a diputada socialista por el &quot;lenguaje inclusivo&quot; #Shorts',
#  'Rap del Feminismo (😔Rap reflexivo 2021😔) - McMasterRap (Prod.AcheEseBeats)',
#  '🤮 FEMINISMO HIPÓCRITA #shorts #short #feminismo',
#  'DESAFIO AL FEMINISMO y ME AGREDEN',
#  'ESTOICISMO: Un ANTÍDOTO contra la INSATISFACCIÓN',
#  'FAMOSA ACTRIZ DA SU OPINIÓN SOBRE FEMINISMO ⚡',
#  'El test de Bechdel en nuestra vida diaria',
#  'Feminista agrede a un hombre #españa #feministas #feminismo #shorts #short',
#  '1974. Ni las mujeres quieren feminismo. #feminismo #machismo #entrevista #mujeres',
#  'FEMINISMO y la juventud',
#  'Más Madrid critica la llamada de atención de Israel a Sánchez, para quien reclaman &quot;respeto&quot;',
#  'EE.UU.: MUERE el EXSECRETARIO de ESTADO Henry KISSINGER, controvertido DIPLOMÁTICO | RTVE Noticias',
#  'TIER LIST de YOUTUBERS/STREAMERS ESPAÑOLES de FÚTBOL | Fuera Caretas',
#  'TREMENDO DEBATE: Agustín Laje vs. 2 diputadas feministas dominicanas',
#  '¿Eres mujer? ¡Huye de México pt. 1',
#  'La TikToker feminista que ROBA a otras Mujeres para Lucrarse - (Day Namo)',
#  'Futbol Femenil ¿Deberían ganar lo mismo las mujeres?',
#  'Lo comestible y lo común: nuevos paradigmas más allá de lo humano',
#  'MISÓGINO o MÁRTIR? Reacciono a Andrew Tate ...',
#  'Nicolás Morás: &quot;El feminismo es una secta de fanáticas victimistas, utilizadas por el poder&quot;',
#  'Por qué muchas FEMINISTAS ODIAN a los HOMBRES',
#  'REVERTE DESTRIPA LA PERSONALIDAD DE SÁNCHEZ. LOS MEDIOS NO PUEDEN SEGUIR OCULTANDO ESTOS DATOS.',
#  '#8M - Guadalajara - Canción &quot;Sin miedo&quot; de Vivir Quintana #JuntasSomoMásFuertes',
#  '#43 - Inocente Duke sobre Izquierda Radical, Feminismo e Independencia',
#  'Worldcast #45 | Roberto Vaquero - Frente Obrero, Comunismo, Patriotismo, Sociedad Frágil, Feminismo',
#  'Un 60% de los españoles creen que la amnistía es injusta y un privilegio',
#  '¿El FEMINISMO es una MODA?',
#  'Las MUJERES son superiores a los HOMBRES',
#  'La Fem1nista que quiso ser Hombre',
#  'De la reforma a la represión. Escuela rural en tres concejos asturianos',
#  'Worldcast #45 | Roberto Vaquero - Frente Obrero, Comunismo, Patriotismo, Sociedad Frágil, Feminismo',
#  'Un 60% de los españoles creen que la amnistía es injusta y un privilegio',
#  'Las Feministas reales ya No Existen | #feminismo #machismo #feministas',
#  'Las MUJERES son superiores a los HOMBRES',
#  'ESCRACHE FEMINISTA EN UNA PONENCIA SOBRE LA CUSTODIA COMPARTIDA | UNIDAS PODEMOS Y ALICIA RUBIO(VOX)',
#  'Feminismo, tan difícil de entender, pasifico y extremista. #opinion #hombres #mujeres #cambiosocial',
#  'Agustín Laje Tremenda respuesta a feminista Sergia Galvan sobre tema ideología  genero parte 2',
#  '#3 - Leyre Khyal sobre Feminismo Disidente, Foucault y Sexología',
#  'VOX Y FEMINISMO EN UNA NOCHE DE MARINA',
#  'RESPONDO A JORDI WILD SOBRE SU OPINIÓN DE LOS PIROPOS',
#  '&#39;La izquierda traicionada&#39; en Barcelona: «Han abandonado a los que se opusieron al injusto &#39;procés&#39;»',
#  'EN DIRECTO | MONTSE TOMÉ y LAIA ALEXANDRI, en RUEDA DE PRENSA | ESPAÑA - SUECIA',
#  '&quot;Mi ex estaba loca&quot; #feminismo #machismo #igualdad #hipocresiaprogre',
#  'Opinión sobre el feminismo y su marcha',
#  'VideoSerie 2: LA ESTAFA DEL FEMINISMO en 5 minutos - Agustín Laje',
#  'FALTAN 🥚🥚 #shorts #política #España #PedroSánchez #IreneMontero #Feminismo #Vox #PP #PSOE #comedia',
#  'EXPLICACION PARA IRENE MONTERO Y FEMILOCAS DE RUBIALES #shorts #feminismo #rubiales #irenemontero',
#  '¿Que Opinan los Españoles sobre el Feminismo?',
#  'PAULATTIER DESTROZANDO FEMINISTAS en ESPAÑA',
#  '&quot;Sánchez tiene cero empatía con la gente&quot; David Hatchwell en #DNEWS',
#  'EL VOXER #1 |EL FEMINISMO MODERNO- Experiencia personal (De dos y Alexa), OMG pizza, No me hace caso',
#  'Desmontando a la FEMINISTA MODERNA',
#  'Dejemos de luchar contra los hombres #mujeres #feminismo #feminista',
#  'Proyecto Arkano TVE. Feminismo o Hembrismo?',
#  'Si juegas videojuegos, esta mujer TE ODIA 😡',
#  'Ayuso contra la amnistía: «España no va a tragar con este atropello de Sánchez»',
#  'ENTREVISTAS EN LA CALLE: ¿QUÉ ES UNA MUJER? 🥵',
#  'Feminismo radical. Explicación simple.',
#  'SOBRE LA SEXUALIDAD FEMENINA. CHARLA EN DIRECTO DE PSICOLOGIA, PSICOANALISIS',
#  '🚨 Cataluña vs. España: ¿El Principio del Fin? 🇪🇸🔥 | Análisis Completo 2023',
#  'Razones por las que irse a la primera es un privilegio',
#  '¿De verdad son tan complicadas las niñas?',
#  'La FARSA del FEMINISMO #shorts',
#  'El mensaje de Ana Pardo de Vera a los seguidores de &#39;Público&#39; tras superar el ataque informático',
#  'Agustín Laje Arrigoni',
#  'Dalas Review',
#  'Hablemos de Feminismo.',
#  'La CANTANTE BEBE CANCELADA por ir CONTRA el FEMINISMO',
#  'Marina Lobo: &quot;Usan titulares para justificar la violencia y que sintamos pena por el agresor&quot;',
#  'MACARENA GÓMEZ: &quot;Estamos forzando el FEMINISMO, hay un discurso de ODIO hacia los HOMBRES',
#  'La cultura como motor de la ciudad',
#  '🟡 Este TENISTA DESTRUYÓ el FEMINISMO 🟡',
#  'El incierto futuro de Europa | EN VIVO | FIL Guadalajara 2023',
#  'Tu YouTuber Marxista:  Crítica marxista al feminismo.  Entrevista a Santiago Armesilla (Cap. 13)',
#  'Roberto Vaquero',
#  'Reflexiones sobre FEMINISMO | LENGUAJE INCLUSIVO y mi experimento (TESIS)',
#  'Intervención de Polina por el Día Internacional de la Eliminación de la Violencia contra las Mujeres',
#  'Las Feministas se despertaron de su siesta+El ocaso del &quot;jodedor&quot;',
#  'García Serrano no se corta y lanza esta dura crítica contra los que “apalean a patriotas”',
#  'HACIA LA GUERRA CIVIL 102. JUNIO Y EL PRINCIPIO DE AUTORIDAD',
#  'LA OSCURA REALIDAD de GANAR DINERO en ONLYFANS 🔞 FAVDAFAKA',
#  'Feminismo: ¿Verdadera representación de la mujer?',
#  'El Ministro de Cultura cree que un lustro son 50 años, ¿se puede ser más id*ota?',
#  '🔥 Un 41% de votantes del PSOE está en contra de la Amnistía 🤔 ¡Lo que Piensan los Españoles! 🇪🇸',
#  'Carlos Taibo, &quot;Decrecimiento y colapso&quot;',
#  'NOTICIAS CINCO DÍAS 02 03 23 Onda Cádiz TV',
#  'Marcha del 8M 2023: mujer liberal doma a feministas',
#  '4 de diciembre de 2023',
#  'Opinión sobre las FEMINISTAS, ¡¡¡¡Ya estamos hartos!!!',
#  'DIGO QUE SOY MUJER EL DÍA del ORGULLO. LO ACEPTARÁN...?',
#  '👿FRANK: EL FALSO FEMINISMO ESTÁ HACIENDO MUCHO DAÑO❌ #frankcuesta #españa #feminismo',
#  'Yo también fui progre... y constitucionalista. FORJA 232 #progresismo #politica #actualidad #españa',
#  'GAME OVER ROSALÍA FEMINISTA',
#  'Feminismo = MI opinión',
#  'Vanguardia Española - La IZQUIERDA NACIONAL [Entrevista a Santiago ARMESILLA en El Gato al Agua]',
#  'Federico a las 7: Sánchez no divide España, ahora también a la UE',
#  '🚨 LA MUJER ESPAÑOLA Y LA PROGRESISTA DEL PSOE 🤔',
#  'DEFENDAMOS JUNTOS A LAS MUJERES | FEMINISMO PARA TORPES |',
#  '🔴 Las Feminist4s NO merecen tener ministerio | Agustín Laje',
#  'ENTREVISTAS DÍA del HOMBRE ( 19 de NOVIEMBRE y MASCULINISMO)',
#  '&quot;El sexo anal es muy placentero incluso para la mujer&quot;. Cadena SER',
#  '4 de diciembre de 2023',
#  '¿ÉS LEGAL la AMNISTÍA en ESPAÑA?',
#  'Alan',
#  'DEBATE SOBRE FEMINISMO CON UNA FEMINISTA',
#  'QUÉ ES SER MUJER',
#  'HIJAS DE TWITTER con TESH SIDI | La gran minoría 1x12',
#  'Escuchando RAP FEMINISTA XD /opinión y reflexión',
#  'Erasmus+ Hungría: ¿Qué es para ti el feminismo?',
#  'MIS 7 PROBLEMAS CON EL FEMINISMO.',
#  'TurboPlant y Nauterplay hablan del Rubius y Dalas, y yo estreno video',
#  'LA NUEVA PASARELA DE LA CASA',
#  '¿Los Hombres Son Malos? - Sen-cillamente Platicando | #2 | Plática Sobre Feminismo.',
#  '¿Pueden triunfar las mujeres frente a una cultura laboral machista? - Es la Hora Opinar',
#  'Igualdad a lo Atria | Por Francisco Cancino',
#  'Por qué creéis que la primera reacción al enterarse es la negación? 🤔 #feminismo #shorts #reels',
#  'EL BIONDAZO con MIMI XXL | Al Lerele 3x04',
#  'Mi *OPINIÓN* sobre el caso de Úrsula | Agustín Laje',
#  'Irene Montero: lección de feminismo',
#  'FEMILOCA: OJALÁ NO EXISTAN LOS HOMBRES',
#  '🟣 BLINDAN a Rocío Carrasco en TVE: estará en &#39;Bake Off&#39; junto a Terelu Campos y Alba Carrillo',
#  'Conversaciones España: Contreras-Irune- Higinio M-Santiago N y José Palacios. (extractos)',
#  '🌈 LOS DATOS NO GUSTAN A LAS FEMINISTAS 🦄 #shorts #feminismo #vox #abascal #igualdad #política #niños',
#  'REACCIONANDO a ARGUMENTOS FEMINISTAS',
#  'VIVIR en PARAGUAY o EUROPA - ¿Dónde es MEJOR?',
#  'Vestidas de azul, una continuación de &#39;Veneno&#39; | Rueda de prensa',
#  'Passport Gringos 2x07 | 5 películas imprescindibles de deporte, con Daniel Lorenzo (Cinemanicomio)',
#  'SANCHEZ MANDA AL NÚMERO 2 DEL PSOE  RENDIR ESPAÑA A UN GOLPISTA EN SUIZA',
#  'Julia Janeiro da un zasca al feminismo - IMO (In My Opinion)',
#  '🛑 Rocío Carrasco y los apoyos políticos y mediáticos de la VERGÜENZA: Lo que NO puede volver a pasar',
#  'Passport Gringos 2x07 | 5 películas imprescindibles de deporte, con Daniel Lorenzo (Cinemanicomio)',
#  'SANCHEZ MANDA AL NÚMERO 2 DEL PSOE  RENDIR ESPAÑA A UN GOLPISTA EN SUIZA',
#  'Julia Janeiro da un zasca al feminismo - IMO (In My Opinion)',
#  '🛑 Rocío Carrasco y los apoyos políticos y mediáticos de la VERGÜENZA: Lo que NO puede volver a pasar',
#  'Abascal dice que no odia a las &quot;mujeres libres&quot; porque la suya &quot;es la que manda en casa&quot;',
#  'SÁNCHEZ EXPLICA su &quot;CAMBIO de OPINIÓN&quot; con la AMNISTÍA y ADMITE que LOS ESPAÑOLES NO LE APOYAN',
#  'Entrevista a: &quot;ALEXIUS Y DANY SUELTA&quot;  Una Noche y Ya con Hector Uriarte',
#  'LOLDEMOS',
#  'Mi review de Napoleón I Todo mal en mi mayor decepción',
#  'Recordando el &quot;caso Miguel Lacambra&quot; por el que se criticó a Antonio Maestre - 2020',
#  '🤬 LOS MISMOS FEMINISTAS SE CONTRADICEN ! | COMENTANDO PT.1 Y 2 DE PAULATTIER',
#  'Feminismo Disidencias sexo genéricas y pánico cristiano en la Nueva Constitución',
#  'ENTREVISTAS A FEMINISTAS EN EL 25 N BY PAULATTIER. LAS RESPUESTAS NO TE DEJARÁN INDIFERENTE.',
#  '🇪🇸 ESPAÑOLES REACCIONAN a LOS MEJORES COMERCIALES de TECATE 🇲🇽 *son PURA RISA*',
#  'El patetismo del &quot;feminismo&quot; de la extrema izquierda española.',
#  'CRÍTICAS AL FEMINISMO.  Entrevistas. Esther Vilar y otros',
#  'Pleno ordinario del Ayuntamiento de Puerto Lumbreras día 28 de Noviembre de 2023',
#  'SELECCIÓN ESPAÑOLA FEMENINA se PELEAN y solo juegan 10 (NO quiere SALIR)',
#  'Rubén Gisbert',
#  'Feminismo de Frontera: Programa 2 (T1)',
#  'Tertulia en Camelot: Un viaje a la igualdad',
#  'MUJERES ESPAÑOLAS ROMANTIZANDO EL MALTRATO DE EXTRANJEROS: EL &quot;FEMINISMO&quot; EN ESPAÑA NO LLEGA A ESTO',
#  'Feminismo de Frontera: Programa 3 (T1)',
#  '👑 Reseña: &quot;Los Reyes Católicos y sus locuras&quot; de César Cervera',
#  'CASO EMANUEL: DENUNCIADO JUNTO A SU MADRE POR DELITOS QUE NO COMETIÓ | ¿Cuáles son las pruebas?',
#  'Catalanes reaccionan por primera vez al HIMNO DE ESPAÑA | El PODCAST más ESPAÑOL - Cono-Cidos #2',
#  'El poder del feminismo  rompiendo estereotipos y fomentando igualdad',
#  'PILAR AGUILAR  CARRASCO habla con Mujeres Abolicionistas de Rivas sobre &quot;Feminismo o Barbarie&quot;',
#  'AZAFATA ESPAÑOLA DEJANDO EN EVIDENCIA AL FEMINISMO MODERNO (TOMADO DEL CANAL J. DOBBS)',
#  'ELON MUSK habla sobre JAVIER MILEI y su INVERSIÓN',
#  'LA MUJER MÁS MACHISTA (de hoy)',
#  'ESPAÑOLES REACCIONAN A COMPARACION - Doblaje Gokú latino vs Doblaje Gokú IA/JEFFAR VLOGS',
#  '🇦🇷 ARGENTINA, el mejor país del mundo⭐⭐⭐ RESUMEN SEMANAL',
#  'MILEI vs SÁNCHEZ: COMPARACIONES ODIOSAS | UTBED',
#  '“Ya tenemos gobierno, ahora qué”',
#  '💊 MUJERES QUEDAN PERPLEJAS ANTE LA HONESTIDAD DE LOS HOMBRES',
#  'La MALA RODRIGUEZ SEÑALA EL “FEMINISMO BLANCO” de las CHAROS',
#  '🔴 Rocío Carrasco TOCADA y HUNDIDA: El Supremo ARCHIVA la causa contra Antonio David',
#  'La PSICOLOGÍA e IDIOSINCRASIA de los MEXICANOS | Minidocumental',
#  'Feministas bailan por Javier Milei #milei',
#  '♟️ El Partido Judicial contraataca  | El Tablero',
#  '#MéxicoAlas2 | Xóchitl y su falso feminismo | AMLO defiende su terna\xa0para\xa0la\xa0SCJN',
#  'POLITA ESPAÑOLA DA DISCUR0 SOBRE FEMINISMO Y MACHISMO',
#  '🕎✝️ PORQUÉ NO HAY PAZ EN ESTE MUNDO?_ Hablando muy Claro_ Mario Sabán.',
#  'Un MARROQUÍ D3G*ELLA a su MUJER en SAGUNTO',
#  'EL FE*******IO QUE HA SACUDIDO TODO ITALIA... #feminismo #noticias #noticiasdehoy #actualidad',
#  'La PSICOLOGÍA de las ACTRICES PORNO',
#  'Libertad Y Lo Que Surja',
#  'ARDE TROYA RECULA! OLIVITA RECOGE CABLE! COMO SER SWAG!',
#  'BOLAÑOS MIENTE A TODA ESPAÑA',
#  'TERELU, ROCIO CARRASCO, ALBA CARRILLO en TVE1',
#  'MUJERES LATINAS: ¿¿LES GUSTAN LOS HOMBRES ESPAÑOLES?? #entrevistas',
#  'TVE-1. 1983. &quot;Buenas Noches&quot; del 29 de Diciembre',
#  'Las mujeres Venezolanas dicen 5 veces Si por el Esequibo.     Dra. Herlinda Niconiello de MINMUJER',
#  'El Club Del Moro: Viernes 1 de Diciembre 2023 (Programa Completo)',
#  'RafitaSUR y el Lalo: Videocurso rápido de feminismo y +ones en la historia francesa, española y mex.',
#  '♟️ PABLO MOTOS VS HUMORISTAS  | El Tablero',
#  '¿HOMBRES LATINOS O ESPAÑOLES? | Maricel',
#  '🟣 RECHAZAN a una JUGADORA por ser MUJER por CULPA de las FEMINISTAS 🟣',
#  'Feminista explica los derechos conseguidos gracias al Ministerio de Igualdad',
#  '🤠 Feminista NO TIENE PRUEBAS Pero Tampoco Dudas',
#  'RTVE: ENCHUFA A LA BANDA DE ROCIO CARRASCO EN BAKE OFF',
#  'SÁNCHEZ SE METE EN PROBLEMAS CON ISRAEL Y ESTADOS UNIDOS E INVOLUCRA A ESPAÑA:',
#  'LA VERDAD SOBRE LA MANADA Y EL FEMINISMO RADICAL EN ESPAÑA',
#  'RESPONSABILIDAD AFECTIVA: El 🔫 de las mujeres para MANIPULAR a los HOMBRES',
#  'El feminismo es una Trampa',
#  'FEMINAZIS:&quot;¡CÓMEME EL COÑO!&quot;',
#  'Milei No Es La Solución - Juan Manuel Vaz',
#  'El Podcast de Loldemos Ep. 58 | ¿HA MUERTO PODEMOS? PERRO SANXE, NETANYAHU Y MÁS FACHABORROKA',
#  'POLEMICAS Y NOTICIAS FITNNES, ESPAÑA Y LATINOAMERICA *SI, ASI ES* !redes !charla',
#  'PABLO IGLESIAS ARREMETE CONTRA YOLANDA DÍAZ Y LE ACUSA DE ESTO:',
#  'EL SUR GLOBAL  un reto geopolítico para las grandes potencias  *Emilio G. Carrillo de Albornoz*',
#  'PODCAST DE ACTUALIDAD 29 DE NOVIEMBRE DE 2023',
#  'MUJER: UNIDAD Y VIDA DESDE EL CORAZÓN - Tercer episodio de LA AMÉRICA TODA EXISTE EN NACIÓN',
#  'Carolina Garate rompe su silencio y su renuncia a Republicanos',
#  '💣SE VA A LIAR💣 YA VIENEN LAS NAVIDADES',
#  '👉𝐁𝐑𝐔𝐓𝐀𝐋!! 𝐀𝐏𝐎𝐘𝐎 𝐀 𝐋𝐀 𝐀𝐌𝐍𝐈𝐒𝐓𝐈́𝐀 𝐃𝐄𝐒𝐃𝐄 𝐋𝐀 𝐃𝐄𝐑𝐄𝐂𝐇𝐀!!👈😱😱😱 ISRAEL INCREMENTA PRESIÓN SOBRE ESPAÑA❌',
#  'La industria del sexo de pago en España',
#  '¿Las MUJERES reciben MÁS ODIO que los HOMBRES?',
#  'Elynes Barros (AE): «El agujero de la ignorancia». Anima el debate: Ana Maeso.',
#  '💊POR ESTO LOS HOMBRES DECIDEN NO ACERCARSE A LAS MUJERES MODERNAS',
#  '02/12/2023 / CARA AL 2024--',
#  'PODCAST DE ACTUALIDAD 01 DE DICIEMBRE DE 2023',
#  'Silvia Intxaurrondo, no sabe no contesta',
#  'Ni amnistía , ni autodeterminación! Viva España 🇪🇸',
#  'FERRAZ: PROHIBIDO REZAR EL ROSARIO, LA CONTRARREVOLUCIÓN DEL ROSARIO',
#  'EL FEMINISMO ES UNA TRAMPA (Alicia Rubio) #mujeres #vida #vox #parati #feminismo #shorts #amnistía',
#  'ESTO NO VA DE FOROFISMOS, VA DE LÓGICA',
#  '🟣 OCTUBRE es el PEOR MES de VI0L3NClA MACHISTA ¿HACE AUTOCRÍTICA el MINISTERIO FEMINISTA? 🟣',
#  '&quot;Los beneficios de beber Agua de Mar&quot;, con Miguel Celades en Onda España Radio TV',
#  'Cómo y porque los hombres abusados no hablan',
#  'CONTESTO A TIKTOKER FEMINISTA SOBRE LEY TRANS',
 'UCnsvJeZO4RigQ898WdDNoBw', 'UC6NVDkuzY2exMOVFw4i9oHw', 'UCz489cQmrgH57sShDiatwfw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCUsm-fannqOY02PNN67C0KA', 'UCUS73_bjTYwBFAfXbvIjM8Q', 'UClLLRs_mFTsNT5U-DqTYAGg', 'UCW3iqZr2cQFYKdO9Kpa97Yw', 'UCUS73_bjTYwBFAfXbvIjM8Q', 'UCQ2Fej5pr1ipVeBWTX8Sc_Q', 'UCsT0YIqwnpJCM-mx7-gSA4Q', 'UCUBIrDsIVzRpKsClMlSlTpQ', 'UCSvUmtylZGPDqxjha3OXE6Q', 'UC2SEk1w7DgoHs_G3w1biz-w', 'UC8FOhz3iXhF1iqqzAFfBjmA', 'UC84t25xqhPEPpGY7NBZJ_eA', 'UCnsvJeZO4RigQ898WdDNoBw', 'UCS6Y-E3Rwm3XXOfSi4RDnBQ', 'UCh1OgMIWOlDBhFEYL3DHWjQ', 'UC63B0Nnt7KE1d6EEUp-cB8Q', 'UC2SEk1w7DgoHs_G3w1biz-w', 'UCWpBYQF-ZuL6FQ05OIL9Yzg', 'UCnsvJeZO4RigQ898WdDNoBw', 'UCTJXx9onKH6g4cWHS9pLqsQ', 'UCp9DjLRLJaghHg9tZiQL66Q', 'UC70cFXqSdlnyA6CrbzS5wvQ', 'UCj6PcyLvpnIRT_2W_mwa9Aw', 'UCvIuCDYS_YoxCZvMXOg_GAQ', 'UCJufShm_lek_NjinsoRwvnQ', 'UCacWETW7N0ohwNaWJgOQBpA', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCnsvJeZO4RigQ898WdDNoBw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCwYfLVGQqE6VJerflYJtuNg', 'UCVimQoXNCZuEnZRVAbuYMiw', 'UCuDm45jKrsTeEpx7BayVaiw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCVUhIjFt6RaMYpjjEseoDaA', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCnsvJeZO4RigQ898WdDNoBw', 'UC2SEk1w7DgoHs_G3w1biz-w', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCR9120YBAqMfntqgRTKmkjQ', 'UCqmZBc7T8J5TFuRT5uf-j_g', 'UCnsvJeZO4RigQ898WdDNoBw', 'UC2SEk1w7DgoHs_G3w1biz-w', 'UCXISYK3xagaK5DHnhQ4X0hw', 'UCTJXx9onKH6g4cWHS9pLqsQ', 'UCRwA1NUcUnwsly35ikGhp0A', 'UCT2UUebPuLke_BShrDh_YEA', 'UCSvUmtylZGPDqxjha3OXE6Q', 'UCUBIrDsIVzRpKsClMlSlTpQ', 'UC5wPK0-Z6LpWlqyEfKoaBWA', 'UCv2BcgqxHSrl2QQfIkjR5Eg', 'UCPrSrtwcgim_KpNlwhUB64A', 'UC5ZiUaIJ2b5dYBYGf5iEUrA', 'UC1zLDoKL-eKmd_K7qkUZ-ow', 'UC2SEk1w7DgoHs_G3w1biz-w', 'UC3SBuQKzSgDfO2xPhxUJu9g', 'UCTJXx9onKH6g4cWHS9pLqsQ', 'UCcHtke0raf8vNYLM1Hbq3Jw', 'UCWpBYQF-ZuL6FQ05OIL9Yzg', 'UCGgIP42KeoTy1kAOBGJfCXw', 'UCcH3aydyR7QygJ25-6EDeAg', 'UCYAvRxM0ShTDUxkDpDPMPQQ', 'UCFxHplbcoJK9m70c4VyTIxg', 'UC0DM_mHV2u6dj8ig51GkQwg', 'UCTJXx9onKH6g4cWHS9pLqsQ', 'UCSvUmtylZGPDqxjha3OXE ...

# %%
len(channel_ids)
# Out:
# 695

# %%
video_ids = []  # Lista para almacenar los videoIds

# Iterar sobre cada elemento de all_videos
for video_info in all_video:
    # Acceder a la clave 'id' y luego a 'videoId'
    video_id = video_info.get('id', {}).get('videoId') #.get() para acceder al valor de 'videoId' dentro de la estructura del diccionario. Si se encuentra un 'videoId', se agrega a la lista video_ids.
    
    # Verificar si se encontró el 'videoId' y agregarlo a la lista video_ids
    if video_id:
        video_ids.append(video_id) 
    else:
        # Si no se encuentra el 'videoId', agregar None a la lista video_ids
        video_ids.append(None)

# %%
len(video_ids)
# Out:
# 695

# %%
v_title = []
for item in all_video:
    video_title = item['snippet']['title'] 
    v_title.append(video_title)
    print(video_title)
# Out:
# ¿El feminismo se contrapone a las libertades del mal llamado «neoliberalismo», como dijo Karamanos?
# ¿Por qué existe el feminismo?
# La industria del sexo de pago en España
# ¿Las MUJERES reciben MÁS ODIO que los HOMBRES?
# Elynes Barros (AE): «El agujero de la ignorancia». Anima el debate: Ana Maeso.
# 💊POR ESTO LOS HOMBRES DECIDEN NO ACERCARSE A LAS MUJERES MODERNAS
# 02/12/2023 / CARA AL 2024--
# PODCAST DE ACTUALIDAD 01 DE DICIEMBRE DE 2023
# Silvia Intxaurrondo, no sabe no contesta
# Ni amnistía , ni autodeterminación! Viva España 🇪🇸
# FERRAZ: PROHIBIDO REZAR EL ROSARIO, LA CONTRARREVOLUCIÓN DEL ROSARIO
# EL FEMINISMO ES UNA TRAMPA (Alicia Rubio) #mujeres #vida #vox #parati #feminismo #shorts #amnistía
# ESTO NO VA DE FOROFISMOS, VA DE LÓGICA
# 🟣 OCTUBRE es el PEOR MES de VI0L3NClA MACHISTA ¿HACE AUTOCRÍTICA el MINISTERIO FEMINISTA? 🟣
# &quot;Los beneficios de beber Agua de Mar&quot;, con Miguel Celades en Onda España Radio TV
# Cómo y porque los hombres abusados no hablan
# CONTESTO A TIKTOKER FEMINISTA SOBRE LEY TRANS
# Feminista explica los derechos que han conseguido las mujeres.
# Fuimos una de ustedes ✊💜 #podcast #humor #selfaware #clips #feministas #mujeres #entertainment
# 2_ ¿Feminismo?

# %%
len(v_title)
# Out:
# 695

# %%
df_feminismo= pd.DataFrame({'canal_ID' : channel_ids, 'video_ID': video_ids, 'video_Title' : v_title})

# %%
df_feminismo.to_csv('/Users/usuario/Downloads/irunela/csv/videos_feminismo.csv')

# %%
df_feminismo.head()
# Out:
#                    canal_ID     video_ID  \
# 0  UCc8TbSged5O_G8_eVD-YmbQ  V8gDOj2V6Wo
# 1  UCX16cLWl6dCjlZMgUBxgGkA  hL1VUOOGWFw
# 2  UCRvpumrJs0qY1xLzeU0Ss1Q  Q17aWaMXyvs
# 3  UCb940RkXaCiORG12GCPqtoA  CzAEvUdJbBU
# 4  UC7QZIf0dta-XPXsp9Hv4dTw  wun4hWsx67s
#
#                                          video_Title
# 0  ¿El feminismo se contrapone a las libertades d...
# 1                      ¿Por qué existe el feminismo?
# 2  La contundente respuesta de Olona frente al fe...
# 3                    Machismo, feminismo y misandria
# 4  8M: MUJERES contra la &#39;LEY TRANS&#39; inte...

# %%
from pprint import pprint
def get_comments(video_ids):
    comments = []
    try:
        response = youtube.commentThreads().list(
            part='snippet',
            videoId=video_ids,
            textFormat='plainText'
        ).execute()
    except Exception:
        print(f"Fallo conseguir comentarios de {video_ids}")
        return []

    for item in response['items']:
        try:
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            author_channel_id = item['snippet']['topLevelComment']['snippet']['authorChannelId']["value"]
            #author_channel_id = comment['authorChannelId']['value']
            comments.append({"video_id": video_ids, "author": author_channel_id, "comment": comment})
        except KeyError as e:
            print(f"Falta algun valor de un comentario, {e}")
            comments.append(None)
            continue
    return comments

# %%
from tqdm.notebook import tqdm 
comment_video = [] 
for video in tqdm(video_ids): 
    comments = get_comments(video) 
    comment_video.extend(comments)
# Out:
#   0%|          | 0/695 [00:00<?, ?it/s]
# Fallo conseguir comentarios de qh7WNAG117w
# Fallo conseguir comentarios de nPTizCyNnrE
# Fallo conseguir comentarios de APF2wBZizo4
# Fallo conseguir comentarios de 08KfasjRug4
# Fallo conseguir comentarios de UHgU4tZdWko
# Fallo conseguir comentarios de SqMoie8aMfQ
# Fallo conseguir comentarios de -xETHiOlczw
# Fallo conseguir comentarios de pdleyPBpMSs
# Fallo conseguir comentarios de GwoalpNTz8E
# Fallo conseguir comentarios de GwoalpNTz8E
# Fallo conseguir comentarios de dkE7JEkBlVY
# Fallo conseguir comentarios de O_PlryFIWsY
# Fallo conseguir comentarios de ViVkhoEbxYg
# Fallo conseguir comentarios de None
# Fallo conseguir comentarios de None
# Fallo conseguir comentarios de None
# Fallo conseguir comentarios de b3k-H4JNg9g
# Fallo conseguir comentarios de JmA9cwol-lA
# Fallo conseguir comentarios de None
# Fallo conseguir comentarios de None
# Fallo conseguir comentarios de None
# Fallo conseguir comentarios de 0LUUIe8_TiE
# Fallo conseguir comentarios de None
# Fallo conseguir comentarios de NOBCdWiC0cU
# Fallo conseguir comentarios de None

# %%
len(comment_video)
# Out:
# 10799

# %%
comentarios_feminismo = pd.DataFrame(filter(None, comment_video))

# %%
comentarios_feminismo.to_csv('/Users/usuario/Downloads/irunela/csv/comentarios_feminismo.csv')

# %%
comentarios_feminismo.head()
# Out:
#       video_id                    author  \
# 0  V8gDOj2V6Wo  UCHod-i12nNNdYtTJIqeXRLA
# 1  V8gDOj2V6Wo  UCEIylx-a-CPhMnXNUxv_LNA
# 2  V8gDOj2V6Wo  UC3IJ88t0um1drra78GUSNLg
# 3  V8gDOj2V6Wo  UCx71QVpr8WRY2HIALeabUzw
# 4  V8gDOj2V6Wo  UC_uq4nmAsi3fFo0JOHKZ63w
#
#                                              comment
# 0                                   Viva el machismo
# 1  Hay que amar a las  mujeres y tratarlas como tal,
# 2  Feminismo es una palabra para referirse a una ...
# 3  Es que la verdad el feminismo ya no busca igua...
# 4  Diré como dijo un sabio\nLas Mujeres solo saca...

# %% [markdown]
# Data pre-processing

# %%
comentarios_feminismo = pd.read_csv('/Users/usuario/Downloads/irunela/csv/comentarios_feminismo.csv')

# %%
valores_nulos = comentarios_feminismo.isnull().sum()  # Esto devuelve la cantidad de valores nulos por columna
print(valores_nulos)
# Out:
# Unnamed: 0    0
# video_id      0
# author        0
# comment       5
# dtype: int64

# %%
# Check data types
comentarios_feminismo.dtypes
# Out:
# Unnamed: 0     int64
# video_id      object
# author        object
# comment       object
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
comentarios_feminismo.shape
# Out:
# (10799, 4)

# %%
index_random = np.random.randint(0,high = comentarios_feminismo.shape[0])
comentario = comentarios_feminismo.iloc[index_random].comment
print(index_random, comentario)
# Out:
# 397 Las feninistas sirven para... para...para...para...para...para que sirven?
# Like si son inutiles  ¦¦
#                                       ¦¦
#                                       ¥

# %% [markdown]
# Tokenización

# %%
comment = str(comentarios_feminismo['comment'])

# %%
#sent_tokenize todo el comentario
comment_st = nltk.tokenize.sent_tokenize(comment)
comment_st
# Out:
# ['0                                         Viva el machismo\n1        Hay que amar a las  mujeres y tratarlas como tal,\n2        Feminismo es una palabra para referirse a una ...\n3        Es que la verdad el feminismo ya no busca igua...\n4        Diré como dijo un sabio\\nLas Mujeres solo saca...\n                               ...                        \n10794                         XD duras verdades  han dicho\n10795                               Muy whitexican para mi\n10796                                                 Bro💀\n10797                                      No tienen papà?',
#  '10798     😂😂😂😂😂 a todos nos valen las feministas radicales\nName: comment, Length: 10799, dtype: object']

# %%
#word_tokenize tokeniza palabra por palabra
comment_wt = nltk.tokenize.word_tokenize(comment)
comment_wt
# Out:
# ['0',
#  'Viva',
#  'el',
#  'machismo',
#  '1',
#  'Hay',
#  'que',
#  'amar',
#  'a',
#  'las',
#  'mujeres',
#  'y',
#  'tratarlas',
#  'como',
#  'tal',
#  ',',
#  '2',
#  'Feminismo',
#  'es',
#  'una',
#  'palabra',
#  'para',
#  'referirse',
#  'a',
#  'una',
#  '...',
#  '3',
#  'Es',
#  'que',
#  'la',
#  'verdad',
#  'el',
#  'feminismo',
#  'ya',
#  'no',
#  'busca',
#  'igua',
#  '...',
#  '4',
#  'Diré',
#  'como',
#  'dijo',
#  'un',
#  'sabio\\nLas',
#  'Mujeres',
#  'solo',
#  'saca',
#  '...',
#  '...',
#  '10794',
#  'XD',
#  'duras',
#  'verdades',
#  'han',
#  'dicho',
#  '10795',
#  'Muy',
#  'whitexican',
#  'para',
#  'mi',
#  '10796',
#  'Bro💀',
#  '10797',
#  'No',
#  'tienen',
#  'papà',
#  '?',
#  '10798',
#  '😂😂😂😂😂',
#  'a',
#  'todos',
#  'nos',
#  'valen',
#  'las',
#  'feministas',
#  'radicales',
#  'Name',
#  ':',
#  'comment',
#  ',',
#  'Length',
#  ':',
#  '10799',
#  ',',
#  'dtype',
#  ':',
#  'object']

# %% [markdown]
# Normalización

# %% [markdown]
# Stopwords

# %%
stopwords = nltk.corpus.stopwords.words('spanish')
stopwords = [palabra for palabra in stopwords if 'not' not in palabra]
stopwords
# Out:
# ['de',
#  'la',
#  'que',
#  'el',
#  'en',
#  'y',
#  'a',
#  'los',
#  'del',
#  'se',
#  'las',
#  'por',
#  'un',
#  'para',
#  'con',
#  'no',
#  'una',
#  'su',
#  'al',
#  'lo',
#  'como',
#  'más',
#  'pero',
#  'sus',
#  'le',
#  'ya',
#  'o',
#  'este',
#  'sí',
#  'porque',
#  'esta',
#  'entre',
#  'cuando',
#  'muy',
#  'sin',
#  'sobre',
#  'también',
#  'me',
#  'hasta',
#  'hay',
#  'donde',
#  'quien',
#  'desde',
#  'todo',
#  'nos',
#  'durante',
#  'todos',
#  'uno',
#  'les',
#  'ni',
#  'contra',
#  'otros',
#  'ese',
#  'eso',
#  'ante',
#  'ellos',
#  'e',
#  'esto',
#  'mí',
#  'antes',
#  'algunos',
#  'qué',
#  'unos',
#  'yo',
#  'otro',
#  'otras',
#  'otra',
#  'él',
#  'tanto',
#  'esa',
#  'estos',
#  'mucho',
#  'quienes',
#  'nada',
#  'muchos',
#  'cual',
#  'poco',
#  'ella',
#  'estar',
#  'estas',
#  'algunas',
#  'algo',
#  'nosotros',
#  'mi',
#  'mis',
#  'tú',
#  'te',
#  'ti',
#  'tu',
#  'tus',
#  'ellas',
#  'nosotras',
#  'vosotros',
#  'vosotras',
#  'os',
#  'mío',
#  'mía',
#  'míos',
#  'mías',
#  'tuyo',
#  'tuya',
#  'tuyos',
#  'tuyas',
#  'suyo',
#  'suya',
#  'suyos',
#  'suyas',
#  'nuestro',
#  'nuestra',
#  'nuestros',
#  'nuestras',
#  'vuestro',
#  'vuestra',
#  'vuestros',
#  'vuestras',
#  'esos',
#  'esas',
#  'estoy',
#  'estás',
#  'está',
#  'estamos',
#  'estáis',
#  'están',
#  'esté',
#  'estés',
#  'estemos',
#  'estéis',
#  'estén',
#  'estaré',
#  'estarás',
#  'estará',
#  'estaremos',
#  'estaréis',
#  'estarán',
#  'estaría',
#  'estarías',
#  'estaríamos',
#  'estaríais',
#  'estarían',
#  'estaba',
#  'estabas',
#  'estábamos',
#  'estabais',
#  'estaban',
#  'estuve',
#  'estuviste',
#  'estuvo',
#  'estuvimos',
#  'estuvisteis',
#  'estuvieron',
#  'estuviera',
#  'estuvieras',
#  'estuviéramos',
#  'estuvierais',
#  'estuvieran',
#  'estuviese',
#  'estuvieses',
#  'estuviésemos',
#  'estuvieseis',
#  'estuviesen',
#  'estando',
#  'estado',
#  'estada',
#  'estados',
#  'estadas',
#  'estad',
#  'he',
#  'has',
#  'ha',
#  'hemos',
#  'habéis',
#  'han',
#  'haya',
#  'hayas',
#  'hayamos',
#  'hayáis',
#  'hayan',
#  'habré',
#  'habrás',
#  'habrá',
#  'habremos',
#  'habréis',
#  'habrán',
#  'habría',
#  'habrías',
#  'habríamos',
#  'habríais',
#  'habrían',
#  'había',
#  'habías',
#  'habíamos',
#  'habíais',
#  'habían',
#  'hube',
#  'hubiste',
#  'hubo',
#  'hubimos',
#  'hubisteis',
#  'hubieron',
#  'hubiera',
#  'hubieras',
#  'hubiéramos',
#  'hubierais',
#  'hubieran',
#  'hubiese',
#  'hubieses',
#  'hubiésemos',
#  'hubieseis',
#  'hubiesen',
#  'habiendo',
#  'habido',
#  'habida',
#  'habidos',
#  'habidas',
#  'soy',
#  'eres',
#  'es',
#  'somos',
#  'sois',
#  'son',
#  'sea',
#  'seas',
#  'seamos',
#  'seáis',
#  'sean',
#  'seré',
#  'serás',
#  'será',
#  'seremos',
#  'seréis',
#  'serán',
#  'sería',
#  'serías',
#  'seríamos',
#  'seríais',
#  'serían',
#  'era',
#  'eras',
#  'éramos',
#  'erais',
#  'eran',
#  'fui',
#  'fuiste',
#  'fue',
#  'fuimos',
#  'fuisteis',
#  'fueron',
#  'fuera',
#  'fueras',
#  'fuéramos',
#  'fuerais',
#  'fueran',
#  'fuese',
#  'fueses',
#  'fuésemos',
#  'fueseis',
#  'fuesen',
#  'sintiendo',
#  'sentido',
#  'sentida',
#  'sentidos',
#  'sentidas',
#  'siente',
#  'sentid',
#  'tengo',
#  'tienes',
#  'tiene',
#  'tenemos',
#  'tenéis',
#  'tienen',
#  'tenga',
#  'tengas',
#  'tengamos',
#  'tengáis',
#  'tengan',
#  'tendré',
#  'tendrás',
#  'tendrá',
#  'tendremos',
#  'tendréis',
#  'tendrán',
#  'tendría',
#  'tendrías',
#  'tendríamos',
#  'tendríais',
#  'tendrían',
#  'tenía',
#  'tenías',
#  'teníamos',
#  'teníais',
#  'tenían',
#  'tuve',
#  'tuviste',
#  'tuvo',
#  'tuvimos',
#  'tuvisteis',
#  'tuvieron',
#  'tuviera',
#  'tuvieras',
#  'tuviéramos',
#  'tuvierais',
#  'tuvieran',
#  'tuviese',
#  'tuvieses',
#  'tuviésemos',
#  'tuvieseis',
#  'tuviesen',
#  'teniendo',
#  'tenido',
#  'tenida',
#  'tenidos',
#  'tenidas',
#  'tened']

# %%
comment_wt_sin_sw = [word for word in comment_wt if word not in stopwords]
comment_wt_sin_sw
# Out:
# ['0',
#  'Viva',
#  'machismo',
#  '1',
#  'Hay',
#  'amar',
#  'mujeres',
#  'tratarlas',
#  'tal',
#  ',',
#  '2',
#  'Feminismo',
#  'palabra',
#  'referirse',
#  '...',
#  '3',
#  'Es',
#  'verdad',
#  'feminismo',
#  'busca',
#  'igua',
#  '...',
#  '4',
#  'Diré',
#  'dijo',
#  'sabio\\nLas',
#  'Mujeres',
#  'solo',
#  'saca',
#  '...',
#  '...',
#  '10794',
#  'XD',
#  'duras',
#  'verdades',
#  'dicho',
#  '10795',
#  'Muy',
#  'whitexican',
#  '10796',
#  'Bro💀',
#  '10797',
#  'No',
#  'papà',
#  '?',
#  '10798',
#  '😂😂😂😂😂',
#  'valen',
#  'feministas',
#  'radicales',
#  'Name',
#  ':',
#  'comment',
#  ',',
#  'Length',
#  ':',
#  '10799',
#  ',',
#  'dtype',
#  ':',
#  'object']

# %% [markdown]
# Frecuencia de palabras

# %%
freq = nltk.FreqDist(comment_wt_sin_sw)
freq
# Out:
# FreqDist({'...': 4, ',': 3, ':': 3, '0': 1, 'Viva': 1, 'machismo': 1, '1': 1, 'Hay': 1, 'amar': 1, 'mujeres': 1, ...})

# %% [markdown]
# Stemming

# %%
# Importamos esta libreria que nos permite reemplzar caracteres
import re

# Importamos la función que nos permite Stemmizar de nltk y definimos el stemmer
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# Traemos nuevamente las stopwords
spanish_stopwords = nltk.corpus.stopwords.words('spanish')
#spanish_stopwords.remove('no')
#stopword.remove('not')

# %%
# Recorremos todos los comentarios y le vamos aplicando la Normalizacion y luega el Stemming a cada uno
comment_list=[]
for comment in comentarios_feminismo.comment:
    # Vamos a reemplzar los caracteres que no sean letras por espacios, limpiando los numeros 
    comment=re.sub("[^a-zA-Z]"," ",str(comment))
    # Pasamos todo a minúsculas
    comment=comment.lower()
    # Remover caracteres especiales
    comment = re.sub(r'\W', ' ', comment)
    # Remover múltiples espacios con uno solo
    comment = re.sub(r'\s+', ' ', comment, flags=re.I)
    # Tokenizar el texto
    # Tokenizamos para separar las palabras del titular 
    comment=nltk.word_tokenize(comment)
    # Eliminamos las palabras de menos de 3 letras
    comment= [palabra for palabra in comment if len(palabra)>3]
    # Sacamos las Stopwords
    comment = [palabra for palabra in comment if not palabra in stopwords]

    ## Hasta acá Normalizamos, ahora a stemmizar

    # Aplicamos la funcion para buscar la raiz de las palabras
    comment=[stemmer.stem(palabra) for palabra in comment]
    # Por ultimo volvemos a unir el titular
    comment=" ".join(comment)

    # Vamos armando una lista con todos los titulares
    comment_list.append(comment)
    #dataset["titular_normalizado"] = titular_list

# %%
comentarios_feminismo["comment_stem"] = comment_list
comentarios_feminismo.tail()
# Out:
#        Unnamed: 0     video_id                    author  \
# 10794       10794  N6uyDEZLvQc  UCScSsx9c6EnCy0N_xSShakA
# 10795       10795  N6uyDEZLvQc  UCuX4IsGehl8iVL0nQSKdDLA
# 10796       10796  N6uyDEZLvQc  UCrSLx6J1gRohY6LhuAhqGDA
# 10797       10797  N6uyDEZLvQc  UCAb55BYUaoZp6hNfghqgVgQ
# 10798       10798  N6uyDEZLvQc  UC3lY1VAzTmPW28KvgASuwWw
#
#                                                 comment  \
# 10794                      XD duras verdades  han dicho
# 10795                            Muy whitexican para mi
# 10796                                              Bro💀
# 10797                                   No tienen papà?
# 10798  😂😂😂😂😂 a todos nos valen las feministas radicales
#
#                   comment_stem
# 10794        dura verdad dicho
# 10795               whitexican
# 10796
# 10797
# 10798  valen feminista radical

# %% [markdown]
# Vectorizar

# %%
list_comment = list(comentarios_feminismo['comment_stem'].values)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Usaremos solo las 1000 palabras con mas frecuencia en todo el corpus para generar los vectores
max_features=1000
# spanish=stopwords.words("spanish")
# Es decir que cada instancia tendrá 1000 features
cou_vec=CountVectorizer(max_features=max_features, stop_words = spanish_stopwords) # stop_words="english" , ngram_range=(1, 2)

# %%
#enerarnos los vectores para cada título a partir del corpus total. 
matriz_titulos = cou_vec.fit_transform(list_comment)

# Tomamos las palabras
all_words = cou_vec.get_feature_names_out()

# Vizualizamos las 50 palabras mas usadas
print("50 palabras mas usadas: ",all_words[0:50])
# Out:
# 50 palabras mas usadas:  ['abasc' 'aborto' 'abrazo' 'absolutament' 'absurda' 'absurdo' 'abuela'
#  'abuso' 'acaba' 'acabar' 'acabo' 'acaso' 'aceptar' 'acoso' 'actitud'
#  'acto' 'actual' 'actualment' 'acuerdo' 'adelant' 'adem' 'adema'
#  'adoctrinamiento' 'adolescent' 'adulto' 'agenda' 'agua' 'agust' 'ahora'
#  'ajena' 'alba' 'alguien' 'alguna' 'alma' 'alto' 'ambo' 'amiga' 'amigo'
#  'amo' 'amor' 'anda' 'ando' 'anim' 'animal' 'anti' 'apart' 'apoyar'
#  'apoyo' 'aprend' 'aquel']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()

# Transformar el texto en vectores TF-IDF
vectores_tfidf = vectorizer.fit_transform(list_comment)

# Obtener el tamaño del vocabulario
tamaño_vocabulario = len(vectorizer.get_feature_names_out())

# Ver los vectores TF-IDF resultantes 
print(vectores_tfidf)
# Out:
#   (0, 12315)	0.6636878793873457
#   (0, 20853)	0.7480096247738581
#   (1, 20028)	0.7474295956953986
#   (1, 13535)	0.21006604160781328
#   (1, 963)	0.6302549148097437
#   (2, 10706)	0.3648305754099726
#   (2, 13495)	0.3000052440316026
#   (2, 9669)	0.16140921260196134
#   (2, 10132)	0.3648305754099726
#   (2, 8578)	0.14578068459540477
#   (2, 8913)	0.2606064594746072
#   (2, 13707)	0.25187658359243636
#   (2, 18076)	0.2348669368907941
#   (2, 5539)	0.3076360162204608
#   (2, 13475)	0.19819813863241714
#   (2, 16901)	0.3076360162204608
#   (2, 17197)	0.33847272472319967
#   (2, 14696)	0.19226850877419388
#   (2, 8575)	0.13914826804840155
#   (2, 13535)	0.1025360987513082
#   (3, 9965)	0.18720527642836088
#   (3, 16191)	0.3686994020887
#   (3, 5695)	0.28312853346276406
#   (3, 10241)	0.2778116541986703
#   (3, 2702)	0.7389695319259569
#   :	:
#   (10791, 8207)	0.2656803154701954
#   (10791, 5413)	0.22514666026998706
#   (10791, 3197)	0.19318264811101807
#   (10791, 4895)	0.1785558089898363
#   (10791, 4874)	0.21798384032190857
#   (10791, 4844)	0.25492932348766706
#   (10791, 9965)	0.11205248743680131
#   (10791, 5695)	0.16946774708552018
#   (10791, 8578)	0.2865373155971786
#   (10791, 13535)	0.10076924309125239
#   (10792, 6852)	0.4292277443085201
#   (10792, 424)	0.39821740263857947
#   (10792, 2794)	0.3882343024229693
#   (10792, 11302)	0.37318105065666496
#   (10792, 8434)	0.33908407374156274
#   (10792, 12411)	0.32850840239743384
#   (10792, 7185)	0.2676808155267443
#   (10792, 1669)	0.2695323266188874
#   (10794, 6749)	0.7090123410913304
#   (10794, 6238)	0.560822921806264
#   (10794, 20593)	0.4275267834380391
#   (10795, 21015)	1.0
#   (10798, 20391)	0.6540303863983915
#   (10798, 16847)	0.6775681816570286
#   (10798, 8578)	0.33637124263759344

# %%
# Convertir la matriz dispersa a un array NumPy
vectores_tfidf_array = vectores_tfidf.toarray()

# Asegurar que el número de filas en vectores_tfidf coincida con la cantidad de filas en comentarios_inmigracion
# (vectores_tfidf_array debe tener la misma cantidad de filas que comentarios_inmigracion)
if vectores_tfidf_array.shape[0] == len(comentarios_feminismo):
    # Asignar los vectores TF-IDF al DataFrame como una nueva columna
    comentarios_feminismo['vectores_tfidf'] = list(vectores_tfidf_array)
else:
    print("Las longitudes no coinciden entre la matriz dispersa y el DataFrame.")

# %%
comentarios_feminismo['comment_stem'][10]
# Out:
# 'igualdad feminista pueden pegar hombr hombr pued pegar'
