# %%
from googleapiclient.discovery import build
from dateutil import parser
import pandas as pd

# Data viz packages
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# NLP
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
from wordcloud import WordCloud
from FunctionsYoutube import *
# !pip install wordcloud 
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/usuario/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/usuario/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 17
#      15 nltk.download('punkt')
#      16 from wordcloud import WordCloud
# ---> 17 from FunctionsYoutube import *
#      18 get_ipython().system('pip install wordcloud')
#      19 from wordcloud import WordCloud
#
# ModuleNotFoundError: No module named 'FunctionsYoutube'

# %%
api_key="AIzaSyDBJWJl3fxjbiVb4PE2YG4xRviQ5MJj1Mk"

# %%
api_service_name = "youtube"
api_version = "v3"

# Creamos la conexión con youtube API
youtube = build(
    api_service_name, api_version, developerKey=api_key)

# %%
next_page_token = None
all_video = []

while True:
    search_response = youtube.search().list(
        q="Opiniones españolas sobre la monarquia", # q es la query 
        part="id,snippet",
        maxResults= 50, 
        regionCode='ES', 
        pageToken=next_page_token if next_page_token else ""
    ).execute()  # Mover la ejecución aquí

    for item in search_response['items']:
        all_video.append(item) 
        

    next_page_token = search_response.get('nextPageToken')

    if not next_page_token:
        break

# %%
len(all_video)
# Out:
# 678

# %%
[x['snippet']['title'] for x in all_video]
# Out:
# ['¿POR QUÉ APOYAR LA MONARQUÍA ESPAÑOLA ES LO MÁS INTELIGENTE?',
#  '“¿Qué opina la juventud españolade la figura de la monarquía?” Por Inés Hernand',
#  'MONARQUÍA VS REPÚBLICA',
#  'REPÚBLICA o MONARQUÍA, ¿qué es mejor? (DEBATE)',
#  'Los granadinos opinan sobre la situación de España, Monarquía o República',
#  'España, sí o no a la monarquía',
#  'La VERDADERA OPINIÓN del PEQUEÑO NICOLÁS sobre la MONARQUÍA ESPAÑOLA | Club 113',
#  '¿Por qué HAY REYES EN ESPAÑA y no una REPÚBLICA? Reflexiones sobre la MONARQUÍA ESPAÑOLA 🇪🇸',
#  '&#39;Hay un DEBATE en nuestro país sobre si la MONARQUÍA es útil para la democracia española&#39; | RTVE',
#  'España: cientos salieron a marchar en Madrid para pedir el fin de la monarquía',
#  'La baja popularidad de la monarquía española, menguada por los escándalos de Juan Carlos I',
#  'Monarquía Española I La Verdad NO CONTADA sobre la PRINCESA LEONOR',
#  '¿Monarquía o República? La jura constitucional de Leonor vista por la ciudadanía',
#  '¿DEBERÍA SER ESPAÑA UNA REPÚBLICA? | Jordi Wild y Roma Gallardo',
#  'Piden en España el fin de la Monarquía',
#  'Cual sería tu opinión sobre la monarquía española?',
#  'Catalanes reaccionan al discurso del rey de España',
#  '🔴DURAS IMÁGENES Y CRÍTICAS REINA Letizia por DISCURSO REY Felipe VI con PRINCESA Leonor en CORTES',
#  'Pablo Iglesias - ¿Para qué sirve hoy la monarquía en España?',
#  '¿ESPAÑA SERÁ UNA REPÚBLICA? Esta encuesta dice que SÍ',
#  'RS | El apoyo o la indiferencia a la monarquía española: ¿qué se gana sin ella y cuánto nos cuesta?',
#  '«¿Monarquía o República?» Con Arturo Pérez-Reverte. Fundación Cajasol, Sevilla. 28.3.22',
#  '¿Qué opina la población sobre la monarquía?',
#  'La VIRAL REACCIÓN de la PRINCESA al PROBAR el CHAMPÁN y la MIRADA de la REINA LETIZIA',
#  '¿Monarquía o república?',
#  'NO ME LLENA DE ORGULLO! Crítica: Monarquía Española',
#  '¿Monarquía o república?: Revilla, Armengol, Garrido, Fernández Vara y Miras se &#39;mojan&#39; - Salvados',
#  '👑🇪🇸 Princesa Leonor de España: El Futuro Brillante de la Monarquía y su Impacto en la Nación 🌟',
#  '👑🇪🇸 Princesa Leonor de España: El Futuro Brillante de la Monarquía y su Impacto en la Nación 🌟',
#  '👑🇪🇸 Princesa Leonor de España: El Futuro Brillante de la Monarquía y su Impacto en la Nación 🌟',
#  '👑🇪🇸 Princesa Leonor de España: El Futuro Brillante de la Monarquía y su Impacto en la Nación 🌟',
#  'Esto piensan los Españoles de los LATINOS - Son los Españoles Racistas?',
#  'Felipe, la esperanza de la monarquía española',
#  'El divertido momento entre Felipe VI y Leonor tras el discurso de la Princesa',
#  'Pablo Iglesias ataca la historia de la monarquía española',
#  '¿Qué opinan los británicos sobre la monarquía? #Shorts',
#  '👑🇪🇸 Princesa Leonor de España: El Futuro Brillante de la Monarquía y su Impacto en la Nación 🌟',
#  'Opiniones encontradas sobre la monarquía española entre sectores políticos y ciudadanía',
#  'EspaTv - ¿Cómo se coló la Monarquía española? Lo explica Adolfo Suárez',
#  'Mensaje del Rey sobre Cataluña | España',
#  'LEONOR JURA LA CONSTITUCIÓN (ÚLTIMA OPORTUNIDAD DE LA MONARQUÍA)',
#  '60 minutos - Lo que está pasando en la monarquía española',
#  '&#39;Felipe VI el último rey de España.',
#  'Pérez-Reverte: &quot;Soy republicano, pero soy español&quot; - El Hormiguero',
#  'Especial Monarquías: ¿por qué siguen existiendo?',
#  'Monarquía VS República - ¿Qué es mejor?',
#  'La Base #59 - El regreso de Juan Carlos: ¿Monarquía o República?',
#  '¿Por qué los españoles tienen a un Rey como Jefe de Estado?',
#  'Los últimos escándalos de la monarquía española',
#  'Ruben Gisbert en directo: Diferencia entre la monarquia española y otras monarquías europeas',
#  'Opinión sobre monarquía y principio dinástico',
#  '👑 ¿MONARQUÍA = Unidad de España? 🏛 ¿REPÚBLICA = Plurinacionalidad?',
#  'Leonor de España #realeza #monarquia #españa #infanta_sofía #ladyleo #princesa #princesaleonor',
#  'La Monarquía de todos',
#  'Realeza en España: ¿Podría caer la MONARQUÍA? ¿Es tiempo de una REPÚBLICA?',
#  'Los escándalos del Rey Juan Carlos: ocaso y exilio',
#  'El verde en la Monarquía española// Viva El Rey De España.',
#  'Que pasaría con la OTAN si España y Marruecos entran en un Conflicto? #short',
#  'Relaciones institucionales de la monarquía española y Guatemala',
#  '🔍 ¿PUEDE EL REY NEGARSE A FIRMAR LA AMNISTÍA? 👑  ¿Corre algún peligro la corona? 👑  Riesgos y Retos',
#  '👑 ¿Por qué los españoles siguen teniendo un rey? Monarquía en España: ¿Tradición Costosa o Pilar?',
#  'España no es para repúblicas #españa #monarquia #republica',
#  'El papel de los monarcas en Europa',
#  'Santiago Abascal: &quot;VOX no tiene una posición sobre Franco&quot; - El Hormiguero 3.0',
#  'Los catalanes se confiesan a Andrea Ropero: ¿qué piensan de la independencia?',
#  'España: la salida del rey Juan Carlos I precipita la crisis de la monarquía',
#  'PRINCESA LEONOR: Así será su FORMACIÓN MILITAR, de TRES años y en los TRES EJÉRCITOS | RTVE Noticias',
#  'Ana Pardo de Vera: &quot;El PSOE, con la monarquía, es como con los toros: espera que se extinga&quot;',
#  'EL PEOR REY DE LA HISTORIA DE ESPAÑA',
#  'Sobre la MONARQUÍA #shorts',
#  '¿MONARQUÍA O REPÚBLICA? 🤔 #finanzas #economia',
#  'Cuanto dinero cobran los reyes ?? #monarquia #reyes #salario',
#  '¿República o monarquía? Los resultados de la encuesta',
#  'Realeza británica: opiniones a favor y en contra de mantener la monarquía en este siglo',
#  'Rey Juan Carlos: La vida y escándalos de corrupción que estremece al país',
#  'Rey de Jerusalén #monarquia #españa #historia #felipevi',
#  'Relaciones institucionales entre la monarquía española y la Unión Soviética',
#  '¿Un &#39;The Crown&#39; con la monarquía de España?',
#  '👑 Quién puede SER REY en ESPAÑA 👑 Linea de sucesion al trono español',
#  '🤔Macarena Olona pide un referéndum sobre la monarquía🤔 #shorts',
#  '¿Qué es la Monarquía?',
#  'Los Reyes Católicos en 10 minutos! | El reinado de Isabel y Fernando',
#  'Juan Pablo Fusi - Letras en Sevilla - La Monarquía en España',
#  'INFORME SEMANAL: La REINA LETIZIA felicita al PROGRAMA que PRESENTÓ hace MÁS de 20 AÑOS | RTVE',
#  'El franquismo',
#  'EL VIRREINATO DE NUEVA ESPAÑA',
#  'RUFIÁN sobre el REY: &quot;Es el DIPUTADO 53 de VOX&quot; I RTVE',
#  '👑 La RESTAURACIÓN BORBÓNICA',
#  '2012/04/16 Comentarios escándalo monarquía española',
#  'Documental | De Juan Carlos a Felipe',
#  'La Monarquía más antigua de Europa',
#  'La historia detrás del mito - Letizia Ortiz',
#  'Relaciones institucionales entre la monarquía española y Uruguay',
#  'La crisis del Imperio Romano y la monarquía visigoda',
#  'Línea de sucesión a la Monarquía Española',
#  '📕 Las CORTES de CÁDIZ y la CONSTITUCIÓN de 1812 | RESUMEN',
#  'Crisis en la monarquía española',
#  '👑 ISABEL II y la construcción del ESTADO LIBERAL (1833-1868) | Resumen',
#  'Cómo estudiar HISTORIA de España para 2º BACHILLERATO y SELECTIVIDAD (ebau) | consejos, trucos 2020',
#  'La monarquia española,cazeria en Botswana y la prensa extranjera.',
#  '(SEGUNDA PARTE) Las Mejores Citas y Frases Sobre España y Los Españoles',
#  'Seis minutos de broncas: el vídeo que resume el tenso clima político en España',
#  '2012/04/16 Comentarios escándalo monarquía española',
#  '🔴 El ANTIGUO RÉGIMEN | Absolutismo, parlamentarismo y sociedad estamental',
#  'El Rey a Chávez: &#39;¿Por qué no te callas?&#39;  (Telediario TVE)',
#  '&#39;&#39;Preguntar justo ahora si se quiere vivir en monarquía o en república es oportunista&#39;&#39;',
#  'RescueYouFitness y la monarquía española',
#  'La Guerra de la Independencia Española',
#  'Relaciones institucionales entre la monarquía española y Uruguay',
#  'Lo que hay detrás de la tensa escena entre la REINA LETIZIA y doña Sofía | Gente',
#  'LA CRISIS DEL ANTIGUO RÉGIMEN (1788-1833) | Historia de España 🇪🇸',
#  '¿Peligra la monarquía en España? Dos expertos analizan las polémicas de Juan Carlos I',
#  'HISTORIA DE ESPAÑA (Parte 1) - Prehistoria, Prerromanos (íberos y celtas), Romanización y Visigodos',
#  '💥AVISO BOMBA REY EMÉRITO HUNDE A PEDRO SÁNCHEZ POR REY FELIPE VI ANTE ESCÁNDALO DE REINA LETIZIA',
#  'La REVOLUCIÓN FRANCESA | Draw My Life',
#  'Carlos III, el mejor alcalde de Madrid',
#  'El LIBERALISMO - Resumen | Liberalismo Político y Liberalismo Económico',
#  'Conexión de las familias reales europeas  (Árbol genealógico y explicación)',
#  'Al descubierto la gran mentira de la transición española',
#  'Reportaje | ¿Qué saben los JÓVENES VASCOS sobre ETA?',
#  'Harry revela la verdadera razón de su salida de la realeza | Al Rojo Vivo | Telemundo',
#  'El Intrigante Secreto de la Reina Letizia que Está Transformando la Monarquía Española',
#  '¿Cuánto cuesta la monarquía a los belgas?',
#  'La Monarquía de todos',
#  'HISTORIA DE ESPAÑA - Antigua y Medieval - Hasta 1492 - (Documental resumen)',
#  'Significado de la Monarquia Española',
#  'La monarquía de los Reyes Católicos',
#  'CRISIS DE LA MONARQUÍA ESPAÑOLA | Historia del Perú 🇵🇪',
#  'Buen Día - Rey Juan Carlos: Polémica en la monarquía española',
#  'Aprender español: Organización política de España (nivel intermedio)',
#  '👑 El REINADO de FERNANDO VII | RESUMEN',
#  '¿Monarquía o República?  ¿Qué es mas barato de mantener? Evaluación de costes y beneficios',
#  '🔴 La ILUSTRACIÓN del SIGLO XVIII en 5 minutos ‼',
#  'El origen del conflicto en el Sahara Occidental (y qué papel tiene España)',
#  'La Princesa LEONOR: El Lado Desconocido de su LUJOSA VIDA',
#  'Así es cómo la princesa Leonor está &quot;salvando&quot; la monarquía española',
#  'Presente y futuro de la monarquía española',
#  'Momentos incómodos entre infanta Sofía y el rey Felipe',
#  'La decadencia de la monarquía española',
#  'La Guerra Civil española',
#  'Historia de España y su Monarquía 2: Casa de Borbón',
#  'La caída de la monarquía',
#  'Dominicanos en España opinan sobre la Monarquía Española',
#  'La MONARQUÍA es INÚTIL #shorts',
#  'Rufián critica que el PSOE vete investigar a la Monarquía y a Felipe González',
#  'La Base 4x32 | OPERACIÓN DE RÉGIMEN para apuntalar la MONARQUÍA en ESPAÑA',
#  'Rompen más de tres años de silencio sobre la monarquía española',
#  'La REINA LETIZIA cumple 50 AÑOS: Cómo era la JOVEN PERIODISTA que conocimos en el TELEDIARIO | RTVE',
#  'LOS HABSBURGO, La casa de Austria en España - CASAS Y DINASTÍAS MODERNAS I -',
#  'Debate sobre la monarquia española',
#  'La Princesa LEONOR: El Lado Desconocido de su LUJOSA VIDA',
#  'Pilar Rahola se jacta de críticar la democracia y monarquía Española',
#  'Historia de España y su Monarquía 2: Casa de Borbón',
#  'La caída de la monarquía',
#  '#HuellasVlog: ¿QUÉ PASA CON LA MONARQUÍA ESPAÑOLA? - VLOG POR EUROPA',
#  'Momentos incómodos entre infanta Sofía y el rey Felipe',
#  'La Guerra Civil española',
#  'La MONARQUÍA es INÚTIL #shorts',
#  '&quot;Mi opinión sobre la monarquía&quot;',
#  'El Rey histórico: Mesa de opinión sobre el rey emérito Juan Carlos I de España (hecho con Spreaker)',
#  'LOS HABSBURGO, La casa de Austria en España - CASAS Y DINASTÍAS MODERNAS I -',
#  'La REINA LETIZIA cumple 50 AÑOS: Cómo era la JOVEN PERIODISTA que conocimos en el TELEDIARIO | RTVE',
#  'Olga Ulianova analiza la monarquía española',
#  'Jaime Peñafiel: &quot;La infanta Cristina se ha cargado la monarquía española&quot;',
#  'La Base 4x32 | OPERACIÓN DE RÉGIMEN para apuntalar la MONARQUÍA en ESPAÑA',
#  'La TREGUA de los 12 AÑOS: paz entre la Monarquía Española y las Provincias Unidas',
#  'La monarquía absoluta',
#  'Millares reclaman fin de la monarquía española',
#  '¿Qué tan influeyente es hoy la monarquía británica y qué la diferencia de las otras?',
#  'Pablo Victoria: Monarquía española es de las menos costosas de Europa,la izquierda quiere eliminarla',
#  'Alberto Peláez nos explica las distintas etapas de la monarquía de España..',
#  '¿Qué papel juega la monarquía española?',
#  'Así era la situación de España justo después de la guerra | España después de la Guerra',
#  'La Monarquía Hispánica durante el siglo XVII',
#  'En3vistas - Juan Carlos I e a monarquía',
#  '¿Por qué en España se permite la monarquía, institución antidemocrática y anacrónica? (2)',
#  'Lo que decía hace tres años la ministra Sira Rego, prometió lealtad al rey: &quot;La monarquía española.',
#  'La Monarquía Española y el Origen de la Dinastía Borbón',
#  'Carmen Calvo e Ignacio Camacho - Letras en Sevilla - Monarquía o Repúblcia',
#  '8° Básico &quot;La Monarquía Absoluta y La monarquía Parlamentaria &quot;',
#  '@opinionpublica.es - Emisión especial: ¿Monarquía o República? Con la colaboración de Jorge Cardoso',
#  'Napoleón Bonaparte y las guerras napoleónicas',
#  'La salida de Juan Carlos I vuelve a sacar a debate la cuestión de la monarquía en España',
#  'Santiago Abascal: &quot;El Rey Felipe VI es la cabeza de la Nación&quot;',
#  'Crisis de la monarquía española La farsa de Bayona y la Junta central de Sevilla',
#  'Historia de España y su Monarquía 3: República, guerra civil, dictadura y transición.',
#  'CONGRESO: APERTURA de la CORTES GENERALES de la XV LEGISLATURA | RTVE Noticias',
#  'Felicidades, Letizia',
#  'CONGRESO: El REY FELIPE VI defiende la CONSTITUCIÓN y una España &quot;SÓLIDA y UNIDA&quot; | RTVE',
#  'La sociedad española opina sobre la Monarquía',
#  'Diferencia entre SOCIALISMO y COMUNISMO - Explicada para principiantes!',
#  'Día clave para una monarquía española cada vez más contestada',
#  'Debate en el Parlament de Cataluña sobre la Monarquía Española. CORRUPCIÓN Catalana también 👏👏😅',
#  'EL VIRREINATO DE LA NUEVA ESPAÑA CUARTO GRADO PRIMARIA',
#  '&#39;&#39;Hubo un pacto tácito para no discutir sobre la monarquía como forma de Estado&#39;&#39;',
#  '👑 ¿PARA QUÉ SIRVE LA REALEZA? / LOS REYES EN EL MUNDO',
#  'La Monarquía Española 🤴🏻👸 y su historia....',
#  'Juan José Laborda sobre la monarquía española',
#  'POR QUÉ UNA MONARQUÍA EN 1975?',
#  'Monarquías europeas: el tabú de la abdicación',
#  'El ABSOLUTISMO - Resumen |  Las Monarquías Absolutas entre los Siglos XVI y XVIII',
#  'El Programa de Cuesta: Especial Investidura, ¿Sánchez a prisión? ¿Peligra la monarquía?',
#  'Jon Iñarritu: «La mejor encuesta, un referéndum sobre monarquía o república»',
#  'ENCUESTA sobre la MONARQUÍA española',
#  'Experto en temas de monarquía explica funciones del nuevo rey de España',
#  'LA  MONARQUIA   ESPAÑOLA   video 1476 y ultimo',
#  '✅ La CONQUISTA y COLONIZACIÓN española de AMÉRICA | Historia, mitos, verdades, leyenda negra...',
#  '🇧🇪Historia de BÉLGICA en 16 minutos y 13 mapas  (resumen) 🇧🇪 - El Mapa de Sebas',
#  'ABSOLUTISMO MONARQUIAS ABSOLUTAS Y PARLAMENTARIAS',
#  '3.9. CRISIS Y DECADENCIA DE LA MONARQUÍA HISPÁNICA: EL REINADO DE CARLOS II Y EL PROBLEMA SUCESORIO',
#  '❌ El IMPERIO ESPAÑOL en 15 minutos con MAPAS ❌',
#  '👑 La RESTAURACIÓN y el CONGRESO de VIENA',
#  'Paises monárquicos #españa #monarquia #rey',
#  'Corrupción , falta de transparencia, comportamientos inadecuados: la monarquía española',
#  'Monarquía y República: sobre qué forma de Estado es más deseable para España',
#  'La España de los Borbones - Documental',
#  'Millones de británicos contra la monarquía',
#  '¿Qué FUTURO tiene la MONARQUÍA en EUROPA?',
#  'Fallece último rey de Grecia: Funeral de Constantino II reúne a monarquía española después de años',
#  'La monarquía absoluta [ABSOLUTISMO] en 1 minuto ✅ #SHORTS #CORTOS',
#  '&quot;La monarquía, en España, ha funcionado&quot;',
#  'Así era la educación durante la dictadura franquista | Franco. La vida del dictador en color',
#  'ABASCAL recuerda a los REYES y a todos los españoles que el socialista SÁNCHEZ es un ‘traidor‘',
#  'El Rey Felipe en Colombia, la espada de Bolívar: ¿por qué tanta polémica? | Inna Afinogenova',
#  '&quot;Podemos no quiere conocer qué piensan los españoles de la Monarquía, sino acabar con ella&quot;',
#  '🇪🇸 🇪🇸 FUTURO ESCENARIO EN LA MONARQUIA ESPAÑOLA  🇪🇸 🇪🇸',
#  '&quot;La monarquía, en España, ha funcionado&quot;',
#  'EL ABSOLUTISMO en 5 minutos',
#  '¿Qué es una monarquía absoluta? tipo de monarquias',
#  'Federico a las 7: La importancia de la monarquía hereditaria',
#  'El futuro que planeaba Franco y la monarquía en España (versión 2)',
#  'La Monarquía Hispánica en el siglo XVII',
#  'PREHISTORIA, HISPANIA ROMANA y REINO VISIGODO | Historia de España 🇪🇸',
#  'CTH1. A crise da monarquía absoluta (abdicacións, ocupación napoleónica)',
#  'España: Detuvieron a un rapero que criticó a la monarquía',
#  'LA MONARQUIA PARLAMENTARIA ESPAÑOLA SIN GOBERNABILIDAD - Ancizar Villa',
#  'La EXPANSIÓN EUROPEA entre los Siglos XV y XVIII  | Portugal, España, Países Bajos, Francia...',
#  'crisis de la monarquía española',
#  'Anna R. Costa: &quot;Me relamo con la monarquía española&quot;',
#  '¿ EL PRINCIPIO DEL FIN DE LA MONARQUIA ESPAÑOLA? CASO CORINNA - Política',
#  'Monarquía española y Provincias Unidas ¿ALIADOS?',
#  'LOS BORBONES - UNA FAMILIA REAL',
#  'Iglesias cuestiona el papel de la monarquía en España',
#  'Relaciones institucionales entre la monarquía española y Colombia',
#  'Cayetana Álvarez de Toledo y Teresa Rodríguez - Letras en Sevilla - Monarquía o República',
#  'COLOQUIO CON TREVIJANO EN VALENCIA (VIII): ACCIÓN Y MONARQUÍA',
#  'La Encuesta | ¿Le parece bien que se haga una consulta sobre monarquía o república?',
#  '¿Monarquía o República? La realidad de España / LogicaPolítica',
#  'C. TANGANA critica la MONARQUÍA y APOYA a VALTONYC',
#  'Como acabar con el debate de la monarquia española',
#  'El fin de la monarquia de los Borbones en España?',
#  'ENCUESTA sobre la MONARQUÍA española',
#  'Conferencia: La monarquía parlamentaria.',
#  'JUAN PABLO FUSI AIZPURÚA: La Monarquía como problema y como solución',
#  'MARÍA ANTONIETA | Draw My Life',
#  'Cómo fue la República Federal en la que Centroamérica fue un solo país y por qué fracasó | BBC Mundo',
#  '🔴GOLPE HISTÓRICO REY EMÉRITO DEMANDA TRAS DISCURSO DE FELIPE VI Y PRINCESA LEONOR POR TELECINCO',
#  'CAYETANA ALERTA AL REY y LEONOR ¡¡LA MONARQUÍA CORRE PELIGRO!! ¡¡Y DEFIENDE LOS PACTOS CON VOX!!',
#  'Árbol Genealógico de los Reyes de España',
#  'Mi opinión sobre la monarquía primavera 2014.',
#  'La monarquía se tambalea',
#  'Relevo en la monarquía española',
#  '¿ EL PRINCIPIO DEL FIN DE LA MONARQUIA ESPAÑOLA? CASO CORINNA - Política',
#  'Monarquía | Juan Manuel de Prada',
#  'REFORMAS BORBONICAS en minutos',
#  'Salvar al Rey | Episodio 1 | HBO Max',
#  'Iglesias cuestiona el papel de la monarquía en España',
#  '&quot;La monarquía, en España, ha funcionado&quot;',
#  'Juan Carlos I Rey de España, hacemos un repaso para que puedas tener tu propia opinión.',
#  '70 años del Rey',
#  'El poder de la monarquía en la Edad Media',
#  '3.9. Crisis y decadencia de la Monarquía Hispánica. El reinado de Carlos II y el problema sucesorio',
#  'El futuro que planeaba Franco y la monarquía en España (versión 2)',
#  '&quot;La monarquía, en España, ha funcionado&quot;',
#  '15 MIEMBROS DE LA REALEZA que sufrieron MUTACIONES HEREDITARIAS',
#  'Relaciones institucionales entre la monarquía española y Colombia',
#  'El caluroso recibimiento de los españoles a la llegada de Don Juan Carlos',
#  '¿Monarquía o República?',
#  'FELIPE VI | El Rey afirma que en España &quot;las soluciones llegarán de la unidad, nunca de la división&quot;',
#  '10 HECHOS SOBRE LA MONARQUÍA ESPAÑOLA',
#  '¿Qué pasaría si en México tuviéramos una monarquía? | Editorial Pamela | De Pisa y Corre',
#  'LA PULLA DE FELIPE VI A SÁNCHEZ Y EL DESPRECIO DE LOS SOCIOS DEL GOBIERNO A LA CORONA',
#  'Leonor de España #monarquia #realeza #españa #princesaleonor  #princesa #rey #infanta_sofía #mexico',
#  '&quot;El rey patriota: monarquía escénica y proyectos nacionalistas en la España de Alfonso XIII&quot;',
#  'Encuesta NC Report: ni república ni referéndum, los españoles apoyan la Monarquía',
#  'El MERCANTILISMO - Resumen | Definición, Características, Representantes.',
#  'Así los reyes de españa sorprendieron a los vecinos de Palma de Mallorca | ¡HOLA! TV',
#  'TRIBUNA INDEPENDIENTE «LA MONARQUÍA ESPAÑOLA CONTEMPORÁNEA: DE JUAN CARLOS I A FELIPE VI» calidad HD',
#  'Así empezó el Alzamiento Nacional en julio de 1936  | España dividida: La Guerra Civil en color',
#  'ESPAÑA (Borbón: La Maldición de un Apellido-1) Carlos I / Felipe II-III-IV / Carlos II / Felipe V',
#  '🚨 JAIME PEÑAFIEL INSULTA a La MONARQUÍA Carga Contra El REY El Emérito JUAN CARLOS y LETIZIA',
#  'El doble relato de la historia de México y España',
#  'Como acabar con el debate de la monarquia española',
#  'Esta es la herencia que dejó la reina Isabel II a Kate Middleton y su hija Charlotte',
#  '🔮Los hijos bastardos del Rey Emérito y la continuidad de la Monarquía en España🔮',
#  'Garzón, crítico con el Rey Juan Carlos: &quot;La Monarquía hace daño a España&quot;',
#  '¿Por qué en España se permite la monarquía, institución antidemocrática y anacrónica? (3)',
#  'La monarquía Borbónica corrupta e insolidaria de España. Felipe VI complice de corrupción',
#  'Escándalos del rey Juan Carlos, ¿daño irreparable a la monarquía española?',
#  'La REVOLUCIÓN INGLESA y el surgimiento de la MONARQUÍA PARLAMENTARIA - Resumen',
#  '🚨 JAIME PEÑAFIEL INSULTA a La MONARQUÍA Carga Contra El REY El Emérito JUAN CARLOS y LETIZIA',
#  'Leonor de España #realeza #monarquia #españa #princesaleonor #leonor #leonor_de_borbón #ladyleo #rey',
#  '&quot;No es mi rey&quot;: ¿se puede protestar contra la monarquía en los eventos reales?',
#  'Así los reyes de españa sorprendieron a los vecinos de Palma de Mallorca | ¡HOLA! TV',
#  'PRIVILEGIOS de los reyes 🤴🏻 ¿Cuánto cuesta la MONARQUÍA española? 💰 Privilegios de la CASA REAL',
#  '&quot;Manifestación por la República&quot; &quot;Republicanos Españoles&quot; &quot;Monarquía Corrupta&quot; &quot;Monarquía impuesta&quot;',
#  'Escándalos del rey Juan Carlos, ¿daño irreparable a la monarquía española?',
#  'La monarquía española (I) | Intermediate Spanish Podcast | Podcast en español',
#  'Cayetana Álvarez de Toledo - Letras en Sevilla - Monarquía o República',
#  'La REVOLUCIÓN INGLESA y el surgimiento de la MONARQUÍA PARLAMENTARIA - Resumen',
#  'Esta es la herencia que dejó la reina Isabel II a Kate Middleton y su hija Charlotte',
#  '20. La Crisis de la Monarquía Española',
#  'El MERCANTILISMO - Resumen | Definición, Características, Representantes.',
#  '🇵🇹HISTORIA del IMPERIO PORTUGUÉS (Reino de Portugal) en 14 minutos🇵🇹 - El Mapa de Sebas',
#  'Por qué la América española se dividió en muchos países y Brasil quedó en uno solo | BBC Mundo',
#  'Arturo Pérez-Reverte analiza a los líderes políticos actuales - El Hormiguero',
#  'Podcast #432 ¿Monarquía o república? ¿Qué prefieren los españoles?',
#  'El polémico regreso del rey Juan Carlos I a España después de sus escándalos',
#  'Por qué Filipinas no es hispanohablante si fue una colonia de España durante 300 años  | BBC Mundo',
#  'El análisis de Arturo Pérez-Reverte sobre sistema educativo - El Hormiguero',
#  'Momentos estelares del programa Opina Younth sobre la monarquía española',
#  'Juan Carlos Monedero - Letras en Sevilla - Monarquia o República',
#  'Ceremonias de proclamación de Felipe VI como rey de España - 2ª parte',
#  '👑\u200aUn FRANCO sería REY de FRANCIA👑',
#  'Arturo Pérez-Reverte: “Los héroes por la mañana eran violadores por la noche” - El Hormiguero',
#  'Charlas Web  -   La Monarquia',
#  'La crisis de la monarquía española - reporter',
#  'E4',
#  '¿Cómo es que la FAMILIA REAL BRITÁNICA es DUEÑA del PLANETA? | LA HERENCIA DEL REY CARLOS III',
#  '✅ El IMPERIO ROMANO en 10 minutos | Resumen de la historia de la ANTIGUA ROMA',
#  '📢 TOP BULOS 12 | Monarquía',
#  '&#39;Yo, Juan Carlos I, Rey de España&#39; | DOCUMENTAL COMPLETO | RTVE',
#  'Felipe VI y la Monarquía Española',
#  'La guerra anglo-española (1585-1604) en 13 minutos',
#  'Grupos de izquierda piden en España un referéndum sobre la monarquía',
#  'España y la Monarquía: Una aproximación histórica',
#  'Ayuso: &quot;España debe mucho al rey Juan Carlos&quot;',
#  '¿SE ACABA LA MONARQUÍA INGLESA?',
#  'La primera serie sobre la monarquía española |  &#39;Los Borbones&#39; capítulos 1 y 2 ya disponibles',
#  'Rap contra la monarquía',
#  'Historia de la restauración de la monarquía en España por el golpista y dictador fascista Franco',
#  'Principe Felipe se encara a una ciudadana que le pregunta sobre un referéndum de la monarquía',
#  '✅ La HISTORIA DE ESPAÑA en 15 minutos | El RESUMEN definitivo',
#  'La Reforma protestante y Lutero',
#  'Eugenio Casado - T3E11 - Monarquía en España: ¿símbolo político de todos los españoles?',
#  'CORONACIÓN CARLOS III: ¿Logrará mantener a flote la MONARQUÍA BRITÁNICA? | RTVE Noticias',
#  'Jorge Pastrano - T3E11 - Monarquía en España: ¿símbolo político de todos los españoles?',
#  'La VERDAD sobre SIMÓN BOLÍVAR',
#  'Monarca | Tráiler oficial | Netflix',
#  'El surgimiento en España de la monarquía parlamentaria',
#  'Las curiosidades más oscuras de la infanta Sofía de Borbón',
#  'CRISIS DE LA MONARQUÍA ESPAÑOLA',
#  'El Rey Abdica. Opinión',
#  'Debate monarquía / República por abdicación del rey (1 de 3) con Alberto Garzón',
#  'República o Monarquía: El eterno Debate - La segunda República Española - Análisis y opinión',
#  'El Real Podio Juramental de la Monarquía española del Palacio de La Zarzuela',
#  'El gran problema de la monqrquía en España 👑⛔',
#  '🔴 El SEXENIO DEMOCRÁTICO (1868-1875) | Resumen',
#  'ARTEguillotina, la monarquía española en tela de juicio.',
#  'LA CONSTRUCCIÓN DEL ESTADO LIBERAL (1833-1868) | Historia de España 🇪🇸',
#  'Montaje Documental - La gran mentira de la monarquía española',
#  'Así sucedió el rey Juan Carlos I de Borbón a Franco | Franco. La vida del dictador en color',
#  'Tema 8: La monarquía de Juan Carlos I (Memorias de España)',
#  'Abolicion de la monarquia en España',
#  'Cuestionamientos a monarquía de España',
#  'ALACANT CONTRA LA MONARQUÍA ESPAÑOLA.',
#  'Relación entre MONARQUÍA y la CORRUPCIÓN ABSOLUTA DEL SISTEMA. Antonio García-Trevijano',
#  '🧔 Las INVASIONES BÁRBARAS y la DISOLUCIÓN del IMPERIO ROMANO',
#  'Rey Felipe defendió el papel de la monarquía parlamentaria',
#  '👑\u200aUn FRANCO sería REY de FRANCIA👑',
#  '🇬🇧 ¿QUÉ OPINAS SOBRE LA MONARQUÍA? 🇬🇧 #reina #rey  #personasreales #monarquia #inglaterra #corona',
#  'LA EDAD MEDIA: AL-ÁNDALUS Y REINOS CRISTIANOS | Historia de España 🇪🇸',
#  'FELIPE VI DISCURSO SIN CAFEINA VIENEN PROBLEMAS PARA LA MONARQUÍA Top Ten Life Noticias Actualidad',
#  'Elena Torres - T3E11 - Monarquía en España: ¿símbolo político de todos los españoles?',
#  'Cuál es el papel de la monarquía en Reino Unido | BBC Mundo',
#  'España: Monarquía o República',
#  'PÉREZ REVERTE SACUDE A ZARZUELA CON LO QUE DICE SOBRE EL REY FELIPE Y LEONOR! MÁS GRECIA QUE BORBÓN',
#  'Acusación de racismo sacude a monarquía británica',
#  'princesa Leonor #realeza #monarquia #españa #princesaleonor #princesasofia #infanta_sofía #rey',
#  'La confesión de la reina María Luisa ¿Se han extinguido los borbones en España?',
#  'El declive de un rey cazador, la  monarquía española.',
#  'La verdad sobre la Transición española que molesta a los reyes - Zasca - #EnLaFrontera633',
#  'EL FEUDALISMO en 5 minutos',
#  'Isabel II de Borbón, la Reina maltratada',
#  '✅  La GUERRA CIVIL ESPAÑOLA en 13 minutos | Resumen fácil y divertido',
#  'Reformas Borbónicas',
#  '✅ ¿Por qué NORUEGA es tan RICA? | El modelo económico PERFECTO',
#  'El Rey Felipe LO DEJA CLARO ! Y Resalta el Juramento de la Princesa Leonor en el Congreso',
#  '🔴EXPULSIÓN HISTÓRICA PRINCESA Leonor PREOCUPA AL REY Felipe VI y el REY Juan Carlos I PLANTA CARA',
#  'Juan Carlos I abandona España Parte 2',
#  'DEMOCRACIA VS MONARQUÍA | MIGUEL ANXO BASTOS y las ideas de HANS-HERMANN HOPPE',
#  'Estupor y temblores en la monarquía española',
#  'El País Vasco Independiente, por José Antonio Zarzalejos',
#  'Alfonso Guerra y Laurence Debray - Letras en Sevilla - Monarquía o República',
#  '⚔️ La EDAD MODERNA en ESPAÑA RESUMEN ⚔️ [ para NIÑOS de PRIMARIA ]',
#  '¿MONARQUÍA O REPÚBLICA?',
#  '13 La Monarquía española: Álvaro de Bazán, Spínola, Olivares',
#  '[RADIO] ❌ Quel futur pour la monarchie espagnole // la monarquía española? - Intermédiaires',
#  'Historia de la Esclavitud - Resumen',
#  'O &quot;tabú&quot; xornalístico da monarquía en España. A crise real e crise coxuntural',
#  'RescueYouFitness y la monarquía española',
#  '¿MONARQUÍA O REPÚBLICA?',
#  '&#39;Yo, Juan Carlos I, Rey de España&#39; | DOCUMENTAL COMPLETO | RTVE',
#  'O &quot;tabú&quot; xornalístico da monarquía en España. A crise real e crise coxuntural',
#  'Alfonso Guerra y Laurence Debray - Letras en Sevilla - Monarquía o República',
#  '🇳🇱🇳🇱HISTORIA del IMPERIO NEERLANDÉS en 13 minutos 🇳🇱🇳🇱 - El Mapa de Sebas',
#  'Título II de la Constitución española',
#  '[RADIO] ❌ Quel futur pour la monarchie espagnole // la monarquía española? - Intermédiaires',
#  'Resumen de la guerra de sucesión española',
#  'Historia de FRANCIA - Resumen | Desde sus orígenes hasta la REVOLUCIÓN FRANCESA.',
#  'La Constitución Española y la Monarquía',
#  'Hernán Cortés y la Conquista de México',
#  'Tesoros de la Corona - De los Austrias a los Borbones',
#  'El enigma de Cristóbal Colón y la monarquía portuguesa',
#  '&#39;Señoras que opinan... sobre monarquía o república&#39;: ¿Qué prefieren?',
#  'DEBATE NDIRECTO | Modelo de Estado: Monarquía VS República',
#  'Diálogos FAES | 1917 y el fin de la Monarquía liberal',
#  '2DO MONARQUÍA ESPAÑOLA DEL SIGLO XVI',
#  'Reflexión sobre la monarquía española. Encuentro con José Antonio Zarzalejos',
#  'Derechos históricos de la monarquía española: EL DISCURSO DE DON JUAN | Demos TV',
#  'VENTILANDO MONARQUIA',
#  'Monarquía VS República (ESPAÑA) - Episodio 1',
#  'Monarquía de los RRCC y el siglo XVI en España',
#  '👑 𝗖𝗢𝗡𝗢𝗖𝗘 𝗾𝘂é 𝗲𝘀 𝗹𝗮 𝗠𝗢𝗡𝗔𝗥𝗤𝗨Í𝗔 𝗣𝗔𝗥𝗟𝗔𝗠𝗘𝗡𝗧𝗔𝗥𝗜𝗔 (¿𝗤𝘂𝗶é𝗻 𝗺𝗮𝗻𝗱𝗮 𝗮𝗾𝘂í?) 😵 [𝗖𝗼𝗻𝘀𝘁𝗶𝘁𝘂𝗰𝗶ó𝗻 𝗘𝘀𝗽𝗮ñ𝗼𝗹𝗮 𝟭𝟵𝟳𝟴]]',
#  'Mi opinión sobre la monarquía primavera 2014.',
#  'Los TUDOR - Casas y dinastías Modernas II',
#  'Los Borbones | 2da parte - Versalles y el Rey Sol ¿Una monarquía sin contrapesos?',
#  'LA RESTAURACIÓN BORBÓNICA (1875-1902) | Historia de España 🇪🇸',
#  'El HUMANISMO Renacentista - Resumen | Definición, Características y Principales Representantes.',
#  'La ÉPOCA COLONIAL en Hispanoamérica - Resumen | Organización Política, Económica y Social.',
#  'Monarquía y República. Especial Informativo (30-01-13) (y IV)',
#  'Cómo aprendí 5 idiomas a los 20 años? Políglota autodidacta comparte su método',
#  '🤯LO PEOR 🤯  QUE PASARIA EN ESPAÑA🇪🇸 EN ESTA CRISIS🚨 SIN MONARQUIA? 👑 SIN EURO? 🇪🇺 MOCION DE CENSURA?',
#  '¿Qué es el fascismo y en qué se diferencia de la extrema derecha?',
#  'EL VIRREINATO DEL RIÓ DE LA PLATA en minutos',
#  'Muere Albert Solà, el hijo ilegítimo del rey?  #borbones #monarquia #república',
#  'CONTANDO HISTORIAS. LOS CAPITANES DE JACA',
#  'INACEPTABLE! MIRA QUÉ DICE LA MINISTRA DE IGUALDAD',
#  'Muerte de Isabel II y futuro de la monarquía inglesa',
#  'Infanta SOFIA AMENAZA CON IRSE DE CASA en defensa de DOÑA SOFIA en RIFIRRAFE CON LA REINA LETIZIA',
#  '🎙️ El Estado de Derecho en España 🇪🇸 👉 ¡La Verdad Al Descubierto! 👉 Rueda de prensa de Abascal',
#  'Que el Rey Juan Carlos I vuelva a España de visita no sirve para nada',
#  'Vídeo rápido: MONARQUÍA Y REPÚBLICA',
#  'Cap. 20. República o Monarquía.',
#  'Ciudadana pide al Príncipe Felipe un referéndum sobre la Monarquía',
#  'Juan Carlos I - Especial Informativo COMPLETO | RTVE',
#  'Cuando España pudo haber ganado La Guerra de las Independencias Hispanoamericanas.',
#  'Arturo Pérez-Reverte: &quot;Tengo 32.000 libros en casa. Mi biblioteca es mi Wikipedia&quot; | EL PAÍS',
#  'ALFONSO GUERRA GONZÁLEZ: Monarquía o República ¿Cuál es el problema?',
#  'Felipe VI, proclamado rey de España',
#  'El nuevo ataque de Carmena a la Monarquía',
#  'Hablando del rey de Roma: La Monarquía Romana. Viaje por el Mundo Romano (II)',
#  'Villarroya carga contra la izquierda española  | OpinaCat',
#  'La Revolución francesa en 14 minutos',
#  'Revuelo por video de la Reina Letizia y la Reina Sofía en la misa de Pascua | La Hora ¡HOLA!',
#  'PERRY ANDERSON- NOBLEZA Y MONARQUÍA en EL ESTADO ABSOLUTISTA',
#  'Fin de la Monarquía Española',
#  '🔴BRUTAL VENGANZA Juan Carlos I ATERRORIZA a Letizia y Felipe VI por Bárbara Rey y Telecinco',
#  'UNBOXING #1 TAULER &amp; FAU -21 Monedas Monarquía Española-',
#  'PÉREZ REVERTE SACUDE A ZARZUELA CON LO QUE DICE SOBRE EL REY FELIPE Y LEONOR: &quot;MÁS GRECIA QUE BORBÓN',
#  'EL MERCANTILISMO en 5 minutos',
#  '¿Monarquia Peruana para desarrollo economico de todos los ciudadanos?',
#  'La expansión del islam',
#  'CRISIS DE LA MONARQUÍA ESPAÑOLA 1808   1812',
#  '✅ La historia de FRANCIA en 16 minutos | Resumen rápido y fácil',
#  'LAS CORTES DE CÁDIZ Y LA CONSTITUCIÓN DE 1812 📝 ¡Explicado en la misma CÁDIZ!',
#  '🔥 Un 41% de votantes del PSOE está en contra de la Amnistía 🤔 ¡Lo que Piensan los Españoles! 🇪🇸',
#  'LA TRANSFORMACION DE LA MONARQUIA ESPAÑOLA Y LAS REFORMAS DE NUEVA ESPAÑA.',
#  'Videoartículo: &quot;¿Monarquía o república?&quot; - Pablo Castro Abad (EL TRAPEZIO)',
#  'José Bono (PSOE) VS. Gaspar Llamazares (IU) debate República / monarquía y aforamiento rey',
#  '¿El ANARQUISMO busca el caos?',
#  'La monarquía de los Reyes Católicos (Memoria de España 10/26)',
#  'SPENCER y el lado negativo monarquía inglesa | Review SV',
#  '¿En qué consiste la MONARQUÍA PARLAMENTARIA? Artículo 1 Constitución Española',
#  'FEIJÓO califica el DISCURSO de ARMENGOL como &quot;LAMENTABLE&quot; y ABASCAL lo tilda de &quot;MITIN&quot; | RTVE',
#  'Federico a las 7: Sánchez consuma la traición a España',
#  'El Programa de Cuesta: El plan de Puigdemont, los jueces en jaque y la frutera Mónica García',
#  'Cantó: &quot;Compromís pretende atacar a Monarquía y Constitución para instaurar su república bananera&quot;',
#  'Portugal bajo la Monarquía Hispánica (Especial 1000)',
#  'Joaquin Torremocha - T3E11 - Monarquía en España: ¿símbolo político de todos los españoles?',
#  'PABLO IGLESIAS abandona el debate de la Cadena Ser tras un enfrentamiento con MONASTERIO (VOX)',
#  'Liechtenstein, El PAÍS MÁS RICO del MUNDO | Aquí GOBIERNA una MONARQUIA - Gabriel Herrera',
#  '#Shorts - Un Día Como Hoy - Abdicación del rey Juan Carlos I en favor del Príncipe Felipe',
#  'El monopolio, sistema económico de la Monarquía Hispánica',
#  'La CORONACIÓN de CARLOS III, en 10 MOMENTOS | El País',
#  '🎙️ El Estado de Derecho en España 🇪🇸 👉 ¡La Verdad Al Descubierto! 👉 Rueda de prensa de Abascal',
#  'La REVOLUCIÓN CUBANA en 10 minutos | Breve historia de CUBA',
#  'Monarquía es democracia',
#  '¿Qué pasará con la Monarquía británica? – Alejandro Linares',
#  'El CONTUNDENTE MENSAJE del REY FELIPE en los PREMIOS PRINCESA DE ASTURIAS ¡QUE ENFURECIÓ A MONCLOA!',
#  'MARÍA ANTONIETA, Reina de FRANCIA y la REVOLUCIÓN francesa (La Reina de los excesos)',
#  'MONARQUÍA ABSOLUTA en 5 minutos',
#  'Alsina desvela lo que habló con el Rey en el premio Cerecedo: &quot;Yo lo intenté, pero he fracasado&quot;',
#  '¿Referéndum de monarquía del Perú?',
#  'LA REINA SOFÍA NO LOGRA LIBRARSE DEL REY JUAN CARLOS',
#  'El TOTALITARISMO - Resumen | El Tercer Reich Alemán, La Italia Fascista y La Unión Soviética',
#  'LO QUE LLAMAN LEYENDA NEGRA NO ES MÁS QUE LA OPINIÓN DE LOS REPUBLICANOS CONTRA LA CORONA ESPAÑOLA',
#  'BRUNEI: ¿el SULTÁN más EXTRAVAGANTE y SINIESTRO del MUNDO? - VisualPolitik',
#  'Conferencia Tomás García López. España, Monarquía y Guerra en Juan de Mariana.',
#  '🔴Filtran MENSAJE URGENTE Felipe VI a Juan Carlos I por Bárbara Rey y la Infanta Elena ECHA a Letizia',
#  'LA REINA SOFÍA NO LOGRA LIBRARSE DEL REY JUAN CARLOS',
#  'El TOTALITARISMO - Resumen | El Tercer Reich Alemán, La Italia Fascista y La Unión Soviética',
#  'LO QUE LLAMAN LEYENDA NEGRA NO ES MÁS QUE LA OPINIÓN DE LOS REPUBLICANOS CONTRA LA CORONA ESPAÑOLA',
#  'BRUNEI: ¿el SULTÁN más EXTRAVAGANTE y SINIESTRO del MUNDO? - VisualPolitik',
#  'Conferencia Tomás García López. España, Monarquía y Guerra en Juan de Mariana.',
#  '🔴Filtran MENSAJE URGENTE Felipe VI a Juan Carlos I por Bárbara Rey y la Infanta Elena ECHA a Letizia',
#  'MÉXICO INDEPENDIENTE - MÉXICO DESPUÉS DE LA INDEPENDENCIA',
#  'Nápoles: poder y belleza en la capital mediterránea de la Monarquía Hispánica. Hugo Huidobro',
#  '¿Monarquia Peruana guiara al Peru a ser pais desarrollado en 30 años?',
#  'LA BURGUESÍA en minutos',
#  '🇬🇧HISTORIA del IMPERIO BRITÁNICO en (casi) 16 minutos🇬🇧 - El Mapa de Sebas',
#  'Los Reyes y la princesa Leonor presiden la apertura de la XV Legislatura de las Cortes Generales',
#  '💥EXPULSIÓN BOMBA PRINCESA LEONOR EN ZARZUELA DA LA CARA ANTE LETIZIA Y REGRESA EMÉRITO Y FELIPE VI',
#  'Primer año de reinado',
#  'La monarquía en Noruega. La aventura del saber. TVE-2',
#  'La monarquía española, comienza una nueva era - Martínez Serrano.',
#  'LA INDEPENDENCIA DEL PERÚ en minutos',
#  'El IMPERIALISMO durante el Siglo XIX - Resumen | El Imperialismo en África y en Asia.',
#  'Arturo Pérez-Reverte habla del lenguaje inclusivo y la evolución de la lengua - El Hormiguero',
#  'El ROMANTICISMO - Resumen | Características, Literatura, Pintura, Música...',
#  'LOS AMIGOS DEL BORBÓN (1ª PARTE) - LA MONARQUÍA SAUDÍ',
#  'REINSTAURANDO LA MONARQUIA EN ESPAÑA /Hearts of Iron IV/ Directo 1',
#  'Parte 2 ENTREVISTA a...RESCUEYOUFITNESS ! Política , INDEPENDENCIA, MONARQUIA Y MAS...',
#  'La dictadura franquista a ojos de la comunidad internacional | España después de la Guerra',
#  'ARTURO PÉREZ-REVERTE EN EL HORMIGUERO',
#  'Opinión del rey sobre urdangarin',
#  'SALLY HEMINGS LA HISTORIA DE UN ESCANDALO. COMPLETA',
#  'La historia de la música en Argentina - Cambios en la corona española - Los Borbones',
#  'Historia del ANTIGUO EGIPTO - Resumen | Origen, Política, Sociedad, Economía, Aportes...',
#  'EN DIRECTO | MONTSE TOMÉ y LAIA ALEXANDRI, en RUEDA DE PRENSA | ESPAÑA - SUECIA',
#  'El robo de bebés durante el franquismo y la monarquía parlamentaria',
#  '8TV JEREZ - LA ENCUESTA - LA MONARQUIA',
#  '30 Curiosidades que no Sabías sobre Turquía | La cuna del Imperio Otomano',
#  'Reporte Indigo (Edición 521): Las huellas del escándalo',
#  'GEOG90 periodo2 S3 Repaso sobre monarquía de Fernando VII',
#  '¿Que diferencia a los griegos de los romanos?',
#  'Ustedes Mataron A Nuestro Rey | Carlos Ballarta | CC Presents T2',
#  '200 Años de la DOCTRINA MONROE (1823-2023) - Santiago ARMESILLA en la Fundación GUSTAVO BUENO',
#  'He leído el libro del Príncipe Harry y me he enfadado bastante',
#  '🔴EXPULSIÓN BOMBA DE ZARZUELA por REY Juan Carlos I ORDENADA por Reina Letizia y el Rey Felipe VI',
#  '✅La HISTORIA del COMUNISMO en 12 minutos | Resumen fácil y divertido',
#  '🔴COMUNICADO URGENTE REY Juan Carlos I por GRABACIONES por GRABACIONES y REY FELIPE VI y Letizia',
#  '🔵⚪La HISTORIA ARGENTINA en 14 minutos🔵⚪| Resumen fácil y rápido',
#  'Historia de la ANTIGUA INDIA - Resumen',
#  'Historia para tontos VS historia para listos',
#  '🚨 Cataluña vs. España: ¿El Principio del Fin? 🇪🇸🔥 | Análisis Completo 2023',
#  '+30 Podcast | Monarquía en tiempos modernos',
#  '🔴 DIRECTO | El rey Felipe VI abre la XV Legislatura en el Congreso (29/11/2023)',
#  'Hora Veintipico #179 | Entrevista a Nieves Concostrina',
#  'Discurso completo del Rey con la defensa de la unidad y la Constitución como eje central',
#  'COLECCIONISMO-BILLETES DE PESETAS - 5000 PESETAS DE 1976  BILLETES DE LA MONARQUIA EPISODIO 1.',
#  'G98: ¿Monarquía o República?',
#  '🔴FILTRACIÓN BESTIAL X INFIDELIDAD DE LA REINA LETIZIA Y GRAVE ABORTO CON FUERTE DECISIÓN FELIPE VI',
#  'El Rey no se moja en un discurso, ¡revisado por Moncloa!',
#  'Jesús Á.Rojo💥Letizia toma partido por políticas radicales mientras Felipe VI calla sobre la amnistía',
#  'EL ANTIGUO RÉGIMEN | Absolutismo, parlamentarismo y sociedad estamental',
#  'Sánchez censura el discurso de Navidad del Rey',
#  'España no se rompe, YA ESTÁ ROTA',
#  '&#39;YO SI LO MANDÉ A LA MIERD**&#39; El MENSAJE DE LA REINA LETIZIA por EXILIO DEL REY FELIPE VI ¡BOMBAZO!',
#  'Guerra de la Independencia Española (1808-1814).',
#  'Cómo sería el discurso ideal de Felipe VI, ¡los españoles se mojan!',
#  'Parodia De La Abdicación Y Del Futuro Incierto De La Monarquía Y La Familia Real Españolas',
#  'La gira de Luis Miguel por España, el libro de Peñafiel sobre la Reina Letizia... - Visillo 30/11',
#  'CONFERENCIA RICARDO FELIU, ECOSISTEMA DE LA MONARQUÍA ESPAÑOLA.',
#  '¿QUIÉNES construyeron el Río de la Plata?',
#  'Jordi Muñoz: &quot;A l&#39;Estat hi ha una monarquia desgastada, qüestionada, discutida i parcial&quot;',
#  'Los sanchistas, títeres de los golpistas rinden cuentas en Suiza ante verificadores anónimos',
#  'COLECCIONISMO-BILLETES DE PESETAS - 1000 PESETAS 1979 GALDOS BILLETES DE LA MONARQUIA EPISODIO 3.',
#  'SALE A LA LUZ el VÍDEO que AVERGÜENZA A LETIZIA, AL REY FELIPE Y A L PRINCESA LEONOR POR VICTORIA F.',
#  'Los Reyes presiden la reunión anual del Patronato del Instituto Cervantes',
#  'Eurodiputado DENUNCIA a Sánchez en Europa: “Es una amenaza para España”',
#  'Carlos Taibo, &quot;Decrecimiento y colapso&quot;',
#  'JAIME PEÑAFIEL vuelve a destrozar a LETIZIA.',
#  'REINSTAURANDO LA MONARQUIA EN ESPAÑA /Hearts of Iron IV/ Directo 1',
#  'Podcast HISTORIA | El pequeño batallón que España envió para conquistar Escocia',
#  'M. Isabel Vicente Maroto, &quot; La fábrica de navíos en la Monarquía Hispánica (1580-1640)&quot;, 29/04/21',
#  'Esta es la venganza que prepara Puigdemont contra el Rey',
#  'Pilar Eyre: &quot;La soledat de la reina Sofia és dramàtica&quot; - Col·lapse',
#  '¡CONMOCIÓN EN ZARZUELA CON LA CAÍDA EN PICADO DE LA POPULARIDAD DEL REY!',
#  '¡Tengo miedo! REACCIÓN de Felipe VI a IMÁGENES de Juan Carlos I con Bárbara Rey',
#  '🔴¡LOS ESCOLTAS HABLAN! DEL REY Juan Carlos I y PREOCUPAN al REY Felipe VI y la REINA Letizia',
#  '&quot;La reforma liberal de 1857 y la disputa por la nación&quot; Sesión 6',
#  'XLV Aniversario de la Constitución Española. Lectura de la Constitución 9h (29/11/2023)',
#  'Militar de Vox SE ENCARA a un independentista de Junts: “¡Respete a España!”',
#  '#Abocajarro9📡. ¿Qué hacer con Pedro Sánchez?  Hablan los juristas',
#  'REVERTE DESTRIPA LA PERSONALIDAD DE SÁNCHEZ. LOS MEDIOS NO PUEDEN SEGUIR OCULTANDO ESTOS DATOS.',
#  '🔴 DIRECTO | El Rey preside la apertura de las Cortes Generales de la XV legislatura en el Congreso',
#  '&#39;Salvados&#39;: Tita Cervera revela a Jordi Évole su opinión sobre la monarquía, el feminismo o la ecolo',
#  'VOX SALE EN DEFENSA DEL ESPAÑOL, NINGUNA LENGUA COOFICIAL PUEDE ESTAR POR ENCIMA DEL ESPAÑOL',
#  'La VIRAL REACCIÓN de la PRINCESA al PROBAR el CHAMPÁN y la MIRADA de la REINA LETIZIA | Diario AS',
#  '👑Leonor👑 LA MEJOR VALORADA POR LOS ESPAÑOLES',
#  'Monarquia espanyola i marroquina: quina relació tenen? - Tot es mou',
#  'FRANCIA ALERTA con ESPAÑA ¡A-FOX para TARSIS! ¿MISIL FNSM en 2035?',
#  'Felipe VI y la princesa Leonor vuelven al Congreso para inaugurar la XV Legislatura',
#  'Napoleón derrotado. Waterloo, la batalla que selló su destino',
#  'Roberto Vaquero',
#  '🔴 DIRECTO | Respondo a tus PREGUNTAS SOBRE EL PAPEL DEL REY',
#  'Vanguardia Española - La IZQUIERDA NACIONAL [Entrevista a Santiago ARMESILLA en El Gato al Agua]',
#  '¿4 ESTRELLAS? ¿VAR MANEJADO? ¿SAD? - Respondo vuestras preguntas - SIN FILTRO Episodio 1',
#  'LA VERDAD SOBRE EL IMPERIO ESPAÑOL EN LAS AMERICAS, POR PABLO VICTORIA',
#  '🟣 Expediente Bárbara Rey: Así fueron sus DOS PRESIONES ECONÓMICAS al Rey',
#  '¡ESPAÑA AL GRUPO DE LA MUERTE! | ANÁLISIS DEL SORTEO #EURO2024',
#  'DIRECTO | El Rey preside la apertura de la legislatura',
#  'ENTRE MIRADAS Y SILENCIOS: LA RELACIÓN DE LETIZIA Y LEONOR QUE NADIE CONOCE',
#  'EL PP DE JUANMA MORENO DEFIENDE EL &quot;NACIONALISMO ANDALUZ&quot;, EL DÍA DE LA BANDERA',
#  'DIRECTO | El rey preside la solemne apertura de la XV Legislatura en el Congreso de los Diputados',
#  '¿Desconfianza en Zarzuela? La infanta Cristina y el escepticismo de el Rey de España por Leonor',
#  'ELON MUSK habla sobre JAVIER MILEI y su INVERSIÓN',
#  'Samuel Moncada en foro &quot;Imperialismo, Monroísmo y la cuestión de la Guayana Esequiba hoy&quot;',
#  '¿A qué se enfrenta judicialmente Jaime del Burgo por su publicación sobre Letizia Ortiz?',
#  '💥El ESCÁNDALO de la REINA LETIZIA y su AMANTE Jaime del Burgo que ha CABREADO a Felipe VI y España',
#  '🤣 JAVIER LOZANO le DA CON TODO a AMLO: &quot;ES UN ENANO ACOMPLEJADO Y FRUSTRADO&quot;',
#  '💥FULMINAN TELECINCO por Ángel Cristo Jr y ENTREVISTA de Bárbara Rey con Santi Acosta en ¡De Viernes!',
#  'Resines dice lo q opina el resto de 🇪🇸🇪🇸🇪🇸 España',
#  '¿Perú le debe su independencia a Venezuela?',
#  '🟣Jaime Peñafiel APUNTA de nuevo a la reina Letizia y DESTAPA su relación con su excuñado',
#  '⚔ El Verdadero #napoleonbonaparte  Frases Geniales y Comienzos Reales #historia #grandesfrases',
#  'RP Montse Tomé I Rueda de prensa oficial España - Suecia I MARCA',
#  'Felipe VI y la princesa Leonor vuelven al Congreso para inaugurar la XV Legislatura',
#  'DIRECTO | Bolaños y Reynders comparecen tras la reunión de ministros de Justicia en Bruselas',
#  'El discurso bilingüe del Rey en Cataluña',
#  'Felipe VI y la princesa Leonor vuelven al Congreso para inaugurar la XV Legislatura',
#  'Sesión de apertura de legislatura: El vergonzoso estilismo y modales de Pedro Sánchez',
#  'FORO INTERNACIONAL ANTIIMPERIALISTA',
#  'BOMBA!! La Iglesia, contra LETIZIA, insulta a Dios en Zarzuela, LEONOR ha salido a la madre.',
#  'Los Cañaris - El Pueblo de Ecuador que Lucho Contra los Incas',
#  'Tu Voz en Europa:  ¿Qué hay detrás de la reforma de los tratados?',
#  'LA TRAICIÓN de Napoleón a ESPAÑA',
#  'Jesús Á.Rojo:💥Juan Carlos I se planta ente la AMNISTÍA y golpea a Sánchez y a todos sus ministros💥',
#  'Murió Henry Kissinger, el hombre que odiaba a España',
#  'Jesús Á.Rojo:💥La sintonía entre Felipe VI y Pedro Sánchez es total, la nación está huerfana💥',
#  'Ep. 354 - La dedicación a varias carreras (feat. Abelardo de la Espriella)',
#  'PODCAST DE ACTUALIDAD 29 DE NOVIEMBRE DE 2023',
#  'LECCIÓN del Rey Felipe VI al independentismo catalán por su DESPLANTE',
#  '🔴#ENVIVO/MUNDO ROJO:Felipe VI defrauda a la nación y allana el camino del golpe de Estado de Sánchez',
#  'DIRECTO | Sesión de Apertura de las Cortes Generales de la XV Legislatura | EL PAÍS',
#  'La Pizarra de Quintana | EN DIRECTO',
#  'Las noticias del MIÉRCOLES 29 de NOVIEMBRE en 10 minutos | RTVE Noticias',
#  'Catalanes reaccionan por primera vez al HIMNO DE ESPAÑA | El PODCAST más ESPAÑOL - Cono-Cidos #2',
#  '🔴 ENTREVISTA A IVAN SAN ANTONIO DEL SPORT | JOÃO FÉLIX SE CARGA AL ATLETI Y EL BARÇA SIGUE VIVO',
#  'BIS narrativa y Rodrigo Rato',
#  '🚨🚨TODAS LAS ACTIVIDADES nocturnas de la Infanta Sofía que no se aprueban desde La Zarzuela',
#  'Arturo Pérez Reverte ESTALLA contra Echenique: “Rata sectaria”',
#  'SORTEO EUROCOPA 2024 - ESPAÑA NO TIENE FORTUNA CON LOS RIVALES',
#  '🗣️ Miguel Pascual #VOX: &quot;el PSOE tiene más de 140 de historia repletos de corrupción&quot;',
#  '🚨🚨Juan José Ballesta recibe el mensaje más inesperado de una persona especial en medio del escándalo',
#  'Arturo Pérez Reverte EXPLOTA contra Echenique: “Rata sectaria”',
#  'DIRECTO| Solemne Sesión de Apertura de las Cortes Generales de la XV legislatura',
#  'ESTAMOS ACORRALADOS POR PEDRO SÁNCHEZ Y SU GOBIERNO Top Ten Life Noticias',
#  'Pérez-Reverte SE LA SACA en el Hormiguero y pasa lo que pasa',
#  'Pérez-Reverte SE LA SACA en el Hormiguero y pasa lo que pasa',
#  '¿Éxito del abastecimiento y racionamiento en la Madrid republicana?',
#  '🔴VENGANZA BRUTAL REY Juan Carlos I EXPLOTA y REY Felipe VI le SEÑALA con REINA Letizia y DOÑA Sofía',
#  'Los Lencas - La Cultura Mesoamericana que Persiste Hasta Nuestros Dias',
#  '¿Aceptaría Feijóo los votos de Puigdemont para una moción de censura?',
#  'EXMILITAR ESPAÑOL Y RAQUELITA REACCIONAN A LA GUERRA DEL PACIFICO PARTE 1 #chile #bolivia #peru',
#  'Centauros de la Alcarria: Pablo Berger nos habla de Robot Dream y pisamos charcos con Napoleón',
#  'AUDIO Radio Cadena SER | 29/11/2023',
#  '🔴SALE A LA LUZ POR PRIMERA VEZ LA BRONCA DEL REY JUAN CARLOS A LA REINA LETIZIA Y FELIPE VI',
#  '02/12/2023 / CARA AL 2024--',
#  'Federico Trillo: &quot;El pacto entre el PSOE y Puigdemont equivale a una voladura de la Constitución&quot;',
#  '¿PORQUE SUBIERON DE PRECIO LAS CARTAS DE ORO UTILIZABLES EN BLACK FRIDAY?🤔',
#  'ESPAÑA intenta conquistar CHINA',
#  'La excusa que estaría usando la reina Sofía para no divorciarse del rey Juan Carlos',
#  'Noviembre Nacional | Enric Juliana',
#  '🔴BRUTAL NUEVA PILLADA por INFIDELIDAD REINA Letizia al REY Felipe VI DESMONTA a Jaime del Burgo',
#  '¿Chantaje a la corona?: El &quot;romance&quot; de la reina Letizia con su ex cuñado',
#  'Catalá dice que el retirar títulos es exclusividad del Rey',
#  'EL AMANTE DE LA REINA LETIZIA MIENTRAS ESTABA CON EL REY FELIPE VI',
#  '¿QUIÉN ES JAIME DEL BURGO? EL AMANTE DE LA REINA LETIZIA MIENTRAS ESTABA CON EL REY FELIPE VI',
#  '¿Por qué no ha podido hablar Monasterio? #eldebate #vox #madrid',
#  'ESCANDALO!!🚨El dinero que se gasta Irene Urdangarin cuando Letizia le deja vivir en la Zarzuela',
#  '🤔La monarquía española es una máquina de corrupción',
#  'El Prontuario Delictivo De La Monarquía Española!',
#  'Peñafiel hunde a la monarquía española: Felipe es el usurpador de la Corona - CASA REAL',
#  '09/12 - La farsa de la &quot;DEMOCRACIA&quot; española. La Monarquía  - Desmontando Mentiras - 23 F',
#  'Desvelan los cambios que Juan Carlos ha hecho en su testamento! afectan al rey Felipe VI',
#  'ESCÁNDALO🔥 Todos los &#39;feos&#39; que la reina Letizia aguantó de la reina Sofía, el rey Juan Carlos y más']

# %%
channel_ids = []  
for item in all_video:
    channelId = item['snippet']['channelId']
    channel_ids.append(channelId)  

print(channel_ids)
# Out:
# ['UCAzHwdDrNQ9hThUDApVh_Bg', 'UCTJXx9onKH6g4cWHS9pLqsQ', 'UCWpBYQF-ZuL6FQ05OIL9Yzg', 'UC_Q7-uOJy3BPWjKNdATqrag', 'UCD_gyb-Fg3eMYetyFnhslsA', 'UCT4Jg8h03dD0iN3Pb5L0PMA', 'UCL23kQyh0o-jF17t_etwD4w', 'UCzDmu6QviXbf0cbeFBh2_zA', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCUdOoVWuWmgo1wByzcsyKDQ', 'UCUdOoVWuWmgo1wByzcsyKDQ', 'UCnKwGq_JDhM5N-5v1e8-Qng', 'UCVimQoXNCZuEnZRVAbuYMiw', 'UCBYyJBCtCvgqA4NwtoPMwpQ', 'UC2SEk1w7DgoHs_G3w1biz-w', 'UChJg9lSVxx1u0X5wf5slRcw', 'UCUdOoVWuWmgo1wByzcsyKDQ', 'UCrJRTSSrbv2G7mA8FEvRYqA', 'UCvgvaidjuGVHi1F3bUctaig', 'UCSPD27Cs5gDePZ07G4m70Cg', 'UCpsTZm-EKa55aU1CiAq-ScA', 'UCJH8qCTPyDQH5CFqwvFwQpA', 'UCVimQoXNCZuEnZRVAbuYMiw', 'UCXISYK3xagaK5DHnhQ4X0hw', 'UCBLCvUUCiSqBCEc-TqZ9rGw', 'UCDxvywwOq1zwnq8Dc6FlbTw', 'UCh1OgMIWOlDBhFEYL3DHWjQ', 'UCWZvD9i6M01UY5XIHpCDhrQ', 'UCWZvD9i6M01UY5XIHpCDhrQ', 'UCWZvD9i6M01UY5XIHpCDhrQ', 'UCWZvD9i6M01UY5XIHpCDhrQ', 'UCfHg6-CQ97Et2qBklzI7PVg', 'UCY8d83kIW6sK4au73qeZZTw', 'UClLLRs_mFTsNT5U-DqTYAGg', 'UCh_chnQ7OJPQ8mZ7vbXFpIQ', 'UCDv9E3mNNQNL2wDOLkSy_Qw', 'UCWZvD9i6M01UY5XIHpCDhrQ', 'UCEJs1fTF3KszRJGxJY14VrA', 'UCY7G68HdJYDqImwrMGRoQAw', 'UCnsvJeZO4RigQ898WdDNoBw', 'UCSPD27Cs5gDePZ07G4m70Cg', 'UCOHCRQDAr9HC5d59XvziJFQ', 'UCjxqdJb5lRF3Ni2kc81pzrg', 'UCLNZvDlwQJMaQg477NAxvjQ', 'UCdwdFOhBP9CoAOlHDTmTxaw', 'UCATNLtVD9iXXzOmFc4bZ87A', 'UCVimQoXNCZuEnZRVAbuYMiw', '
 'UCv05qOuJ6Igbe-EyQibJgwQ', 'UCBWF6OT9sHQU0rnMmUPdmyA', 'UCTVEB8qiadgWTBy_mT1Kn2w', 'UCDNrhsx2ehcfUBXuQIjzskw', 'UCnsvJeZO4RigQ898WdDNoBw', 'UCDUxOvbwu1bnyD7AucP0ESw', 'UCtBpYvKo5Q69mVtafO4cyuA', 'UCyoGb3SMlTlB8CLGVH4c8Rw', 'UCQiMUpAmskFqrcP77ue5vSw', 'UCBIMW0ZhwULY_x7fdaPRPiQ', 'UCO9cQ9FLGRRJs_t5QVm3mSQ', 'UCWzQmDWp_mjh3AOzPCZNzEQ', 'UC5wWSpXpO_rOuP3e62Fqv7Q', 'UCp6X5jzfmwbOeclRArOi18g', 'UCTyCyyV0eKfEoMWI_V11z6A', 'UCnKlfDXaVP-6uIACOJeVPfw', 'UCMPko5LzK57hWuYIxRupIFg', 'UCnKlfDXaVP-6uIACOJeVPfw', 'UCUBIrDsIVzRpKsClMlSlTpQ', 'UCJZfGmDMk_r2yV-EMVEeKmg', 'UC6UcLexTVtRCgv42PEv6LmA', 'UCU2pGkCsT2InFTQBeTFdn5w', 'UCTU5w8mXt53dumCy7BNvyHA', 'UCijOSUTXgksRjtZu7Xg322Q', 'UCv05qOuJ6Igbe-EyQibJgwQ', 'UCkh2i4imLJG5z_OtvBgSo0Q', 'UCSQsCiCxmK9takNgpkIujiA', 'UCcMFxfgITvyeNfxKtp1gg ...

# %%
len(channel_ids)
# Out:
# 678

# %%
video_ids = []  # Lista para almacenar los videoIds

# Iterar sobre cada elemento de all_videos
for video_info in all_video:
    # Acceder a la clave 'id' y luego a 'videoId'
    video_id = video_info.get('id', {}).get('videoId') #.get() para acceder al valor de 'videoId' dentro de la estructura del diccionario. Si se encuentra un 'videoId', se agrega a la lista video_ids.
    
    # Verificar si se encontró el 'videoId' y agregarlo a la lista video_ids
    if video_id:
        video_ids.append(video_id) 
    else:
        # Si no se encuentra el 'videoId', agregar None a la lista video_ids
        video_ids.append(None)

# %%
len(video_ids)
# Out:
# 678

# %%
v_title = []
for item in all_video:
    video_title = item['snippet']['title'] 
    v_title.append(video_title)
    print(video_title)
# Out:
# ¿POR QUÉ APOYAR LA MONARQUÍA ESPAÑOLA ES LO MÁS INTELIGENTE?
# “¿Qué opina la juventud españolade la figura de la monarquía?” Por Inés Hernand
# MONARQUÍA VS REPÚBLICA
# REPÚBLICA o MONARQUÍA, ¿qué es mejor? (DEBATE)
# Los granadinos opinan sobre la situación de España, Monarquía o República
# España, sí o no a la monarquía
# La VERDADERA OPINIÓN del PEQUEÑO NICOLÁS sobre la MONARQUÍA ESPAÑOLA | Club 113
# ¿Por qué HAY REYES EN ESPAÑA y no una REPÚBLICA? Reflexiones sobre la MONARQUÍA ESPAÑOLA 🇪🇸
# &#39;Hay un DEBATE en nuestro país sobre si la MONARQUÍA es útil para la democracia española&#39; | RTVE
# España: cientos salieron a marchar en Madrid para pedir el fin de la monarquía
# La baja popularidad de la monarquía española, menguada por los escándalos de Juan Carlos I
# Monarquía Española I La Verdad NO CONTADA sobre la PRINCESA LEONOR
# ¿Monarquía o República? La jura constitucional de Leonor vista por la ciudadanía
# ¿DEBERÍA SER ESPAÑA UNA REPÚBLICA? | Jordi Wild y Roma Gallardo
# Piden en España el fin de la Monarquía
# Cual sería tu opinión sobre la monarquía española?
# Catalanes reaccionan al discurso del rey de España
# 🔴DURAS IMÁGENES Y CRÍTICAS REINA Letizia por DISCURSO REY Felipe VI con PRINCESA Leonor en CORTES
# Pablo Iglesias - ¿Para qué sirve hoy la monarquía en España?
# ¿ESPAÑA SERÁ UNA REPÚBLICA? Esta encuesta dice que SÍ
# RS | El apoyo o la indiferencia a la monarquía española: ¿qué se gana sin ella y cuánto nos cuesta?
# «¿Monarquía o República?» Con Arturo Pérez-Reverte. Fundación Cajasol, Sevilla. 28.3.22
# ¿Qué opina la población sobre la monarquía?
# La VIRAL REACCIÓN de la PRINCESA al PROBAR el CHAMPÁN y la MIRADA de la REINA LETIZIA
# ¿Monarquía o república?
# NO ME LLENA DE ORGULLO! Crítica: Monarquía Española
# ¿Monarquía o república?: Revilla, Armengol, Garrido, Fernández Vara y Miras se &#39;mojan&#39; - Salvados
# 👑🇪🇸 Princesa Leonor de España: El Futuro Brillante de la Monarquía y su Impacto en la Nación 🌟
# 👑🇪🇸 Princesa Leonor de España: El Futuro Brillante de la Monarquía y su Impacto en la Nación 🌟
# 👑🇪🇸 Princesa Leonor de España: El Futuro Brillante de la Monarquía y su Impacto en la Nación 🌟
# 👑🇪🇸 Princesa Leonor de España: El Futuro Brillante de la Monarquía y su Impacto en la Nación 🌟
# Esto piensan los Españoles de los LATINOS - Son los Españoles Racistas?
# Felipe, la esperanza de la monarquía española
# El divertido momento entre Felipe VI y Leonor tras el discurso de la Princesa
# Pablo Iglesias ataca la historia de la monarquía española
# ¿Qué opinan los británicos sobre la monarquía? #Shorts
# 👑🇪🇸 Princesa Leonor de España: El Futuro Brillante de la Monarquía y su Impacto en la Nación 🌟
# Opiniones encontradas sobre la monarquía española entre sectores políticos y ciudadanía
# EspaTv - ¿Cómo se coló la Monarquía española? Lo explica Adolfo Suárez
# Mensaje del Rey sobre Cataluña | España
# LEONOR JURA LA CONSTITUCIÓN (ÚLTIMA OPORTUNIDAD DE LA MONARQUÍA)
# 60 minutos - Lo que está pasando en la monarquía española
# &#39;Felipe VI el último rey de España.
# Pérez-Reverte: &quot;Soy republicano, pero soy español&quot; - El Hormiguero
# Especial Monarquías: ¿por qué siguen existiendo?
# Monarquía VS República - ¿Qué es mejor?
# La Base #59 - El regreso de Juan Carlos: ¿Monarquía o República?
# ¿Por qué los españoles tienen a un Rey como Jefe de Estado?
# Los últimos escándalos de la monarquía española
# Ruben Gisbert en directo: Diferencia entre la monarquia española y otras monarquías europeas
# Opinión sobre monarquía y principio dinástico
# 👑 ¿MONARQUÍA = Unidad de España? 🏛 ¿REPÚBLICA = Plurinacionalidad?
# Leonor de España #realeza #monarquia #españa #infanta_sofía #ladyleo #princesa #princesaleonor
# La Monarquía de todos
# Realeza en España: ¿Podría caer la MONARQUÍA? ¿Es tiempo de una REPÚBLICA?
# Los escándalos del Rey Juan Carlos: ocaso y exilio
# El verde en la Monarquía española// Viva El Rey De España.
# Que pasaría con la OTAN si España y Marruecos entran en un Conflicto? #short
# Relaciones institucionales de la monarquía española y Guatemala
# 🔍 ¿PUEDE EL REY NEGARSE A FIRMAR LA AMNISTÍA? 👑  ¿Corre algún peligro la corona? 👑  Riesgos y Retos
# 👑 ¿Por qué los españoles siguen teniendo un rey? Monarquía en España: ¿Tradición Costosa o Pilar?
df_monarquia= pd.DataFrame({'canal_ID' : channel_ids, 'video_ID': video_ids, 'video_Title' : v_title})

# %%
df_monarquia.to_csv('/Users/usuario/Downloads/irunela/csv/videos_monarquia.csv')

# %%
df_monarquia.head()
# Out:
#                    canal_ID     video_ID  \
# 0  UCAzHwdDrNQ9hThUDApVh_Bg  WdtyLi2wBDs
# 1  UCTJXx9onKH6g4cWHS9pLqsQ  4i2m9Z47ETc
# 2  UCWpBYQF-ZuL6FQ05OIL9Yzg  KzSlyGHjTX8
# 3  UC_Q7-uOJy3BPWjKNdATqrag  WGC0RtlEIUY
# 4  UCD_gyb-Fg3eMYetyFnhslsA  4mMkLK7khPY
#
#                                          video_Title
# 0  ¿POR QUÉ APOYAR LA MONARQUÍA ESPAÑOLA ES LO MÁ...
# 1  “¿Qué opina la juventud españolade la figura d...
# 2                             MONARQUÍA VS REPÚBLICA
# 3     REPÚBLICA o MONARQUÍA, ¿qué es mejor? (DEBATE)
# 4  Los granadinos opinan sobre la situación de Es...

# %%
from pprint import pprint
def get_comments(video_ids):
    comments = []
    try:
        response = youtube.commentThreads().list(
            part='snippet',
            videoId=video_ids,
            textFormat='plainText'
        ).execute()
    except Exception:
        print(f"Fallo conseguir comentarios de {video_ids}")
        return []

    for item in response['items']:
        try:
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            author_channel_id = item['snippet']['topLevelComment']['snippet']['authorChannelId']["value"]
            #author_channel_id = comment['authorChannelId']['value']
            comments.append({"video_id": video_ids, "author": author_channel_id, "comment": comment})
        except KeyError as e:
            print(f"Falta algun valor de un comentario, {e}")
            comments.append(None)
            continue
    return comments

# %%
from tqdm.notebook import tqdm 
comment_video = [] 
for video in tqdm(video_ids): 
    comments = get_comments(video) 
    comment_video.extend(comments)
# Out:
#   0%|          | 0/678 [00:00<?, ?it/s]
# Fallo conseguir comentarios de _Vh9d3Rcaqg
# Fallo conseguir comentarios de LnskOXkskOE
# Fallo conseguir comentarios de Iw1S2EH-p4U
# Fallo conseguir comentarios de GdUmfEaoILk
# Fallo conseguir comentarios de O9TPP-C8rUk
# Fallo conseguir comentarios de O9TPP-C8rUk
# Fallo conseguir comentarios de TpuZUQYeB-g
# Fallo conseguir comentarios de Dy8l56BEBX4
# Fallo conseguir comentarios de s9PqHXsuvyE
# Fallo conseguir comentarios de g99bTOgSuwU
# Fallo conseguir comentarios de ZdVpSEL_gxc
# Fallo conseguir comentarios de byGC6icDZFA
# Fallo conseguir comentarios de zP5d1Bl51TU
# Fallo conseguir comentarios de N7eiuXZwgYA
# Fallo conseguir comentarios de TLB97deRh94
# Fallo conseguir comentarios de TLB97deRh94
# Fallo conseguir comentarios de Mrd897EU4qo
# Fallo conseguir comentarios de E_NureYtOHs
# Fallo conseguir comentarios de fKu0hZdudVc
# Fallo conseguir comentarios de 68ZtFPWCBcc
# Fallo conseguir comentarios de KOOxePgml3Y
# Fallo conseguir comentarios de EoXnrI-2KWI
# Fallo conseguir comentarios de ll7koplxJLU
# Fallo conseguir comentarios de dkE7JEkBlVY
# Fallo conseguir comentarios de gO6A34JTCvA
# Fallo conseguir comentarios de 1o9SvBqtq9E
# Fallo conseguir comentarios de AilWlQWdtIg
# Fallo conseguir comentarios de None
# Fallo conseguir comentarios de pfI1ZAbuAwY
# Fallo conseguir comentarios de P_Jyh-XGgSE
# Fallo conseguir comentarios de hU0WuvRRWxA
# Fallo conseguir comentarios de iGbt1_t9hnc
# Fallo conseguir comentarios de uCdsR-iOlIA
# Fallo conseguir comentarios de Rr39AN_PgQg

# %%
len(comment_video)
# Out:
# 8044

# %%
comentarios_monarquia = pd.DataFrame(filter(None, comment_video))

# %%
comentarios_monarquia.to_csv('/Users/usuario/Downloads/irunela/csv/comentarios_monarquia.csv')

# %%
Data pre-processing

# %%
comentarios_monarquia = pd.read_csv('/Users/usuario/Downloads/irunela/csv/comentarios_monarquia.csv')

# %%
valores_nulos = comentarios_monarquia.isnull().sum()  # Esto devuelve la cantidad de valores nulos por columna
print(valores_nulos)
# Out:
# Unnamed: 0    0
# video_id      0
# author        0
# comment       7
# dtype: int64

# %%
# Check data types
comentarios_monarquia.dtypes
# Out:
# Unnamed: 0     int64
# video_id      object
# author        object
# comment       object
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
comentarios_monarquia.shape
# Out:
# (8044, 4)

# %%
index_random = np.random.randint(0,high = comentarios_monarquia.shape[0])
comentario = comentarios_monarquia.iloc[index_random].comment
print(index_random, comentario)
# Out:
# 3809 Felipe VI, bruta;-)

# %% [markdown]
# Tokenización

# %%
comment = str(comentarios_monarquia['comment'])

# %%
#sent_tokenize todo el comentario
comment_st = nltk.tokenize.sent_tokenize(comment)
comment_st
# Out:
# ['0       Todos los de la monarquia són únos vividores!',
#  '...\n1       Sabeis porque el viejo se fue de españa?',
#  'Porqu...\n2       De hecho me hubiera gustado que mi país (venez...\n3       1er error.',
#  'Me la pela qué no se haya votado po...\n4       La mayoría que son republicanos la verdad es p...\n                              ...                        \n8039    Y la acusaban en el pasado de haber abortado a...\n8040                       Toma Ya \\nTan seria k se le ve\n8041    Otro que quiere subirse al carro, y ser protag...\n8042    FELIPE ERES UN TRAIDOR, HAS VENDIDO ESPAÑA.',
#  'NO...\n8043    No es extraño.',
#  'En España jamás ha habido democ...\nName: comment, Length: 8044, dtype: object']

# %%
#word_tokenize tokeniza palabra por palabra
comment_wt = nltk.tokenize.word_tokenize(comment)
comment_wt
# Out:
# ['0',
#  'Todos',
#  'los',
#  'de',
#  'la',
#  'monarquia',
#  'són',
#  'únos',
#  'vividores',
#  '!',
#  '...',
#  '1',
#  'Sabeis',
#  'porque',
#  'el',
#  'viejo',
#  'se',
#  'fue',
#  'de',
#  'españa',
#  '?',
#  'Porqu',
#  '...',
#  '2',
#  'De',
#  'hecho',
#  'me',
#  'hubiera',
#  'gustado',
#  'que',
#  'mi',
#  'país',
#  '(',
#  'venez',
#  '...',
#  '3',
#  '1er',
#  'error',
#  '.',
#  'Me',
#  'la',
#  'pela',
#  'qué',
#  'no',
#  'se',
#  'haya',
#  'votado',
#  'po',
#  '...',
#  '4',
#  'La',
#  'mayoría',
#  'que',
#  'son',
#  'republicanos',
#  'la',
#  'verdad',
#  'es',
#  'p',
#  '...',
#  '...',
#  '8039',
#  'Y',
#  'la',
#  'acusaban',
#  'en',
#  'el',
#  'pasado',
#  'de',
#  'haber',
#  'abortado',
#  'a',
#  '...',
#  '8040',
#  'Toma',
#  'Ya',
#  '\\nTan',
#  'seria',
#  'k',
#  'se',
#  'le',
#  've',
#  '8041',
#  'Otro',
#  'que',
#  'quiere',
#  'subirse',
#  'al',
#  'carro',
#  ',',
#  'y',
#  'ser',
#  'protag',
#  '...',
#  '8042',
#  'FELIPE',
#  'ERES',
#  'UN',
#  'TRAIDOR',
#  ',',
#  'HAS',
#  'VENDIDO',
#  'ESPAÑA',
#  '.',
#  'NO',
#  '...',
#  '8043',
#  'No',
#  'es',
#  'extraño',
#  '.',
#  'En',
#  'España',
#  'jamás',
#  'ha',
#  'habido',
#  'democ',
#  '...',
#  'Name',
#  ':',
#  'comment',
#  ',',
#  'Length',
#  ':',
#  '8044',
#  ',',
#  'dtype',
#  ':',
#  'object']

# %% [markdown]
# Normalización

# %% [markdown]
# Stopwords

# %%
stopwords = nltk.corpus.stopwords.words('spanish')
stopwords = [palabra for palabra in stopwords if 'not' not in palabra]
stopwords
# Out:
# ['de',
#  'la',
#  'que',
#  'el',
#  'en',
#  'y',
#  'a',
#  'los',
#  'del',
#  'se',
#  'las',
#  'por',
#  'un',
#  'para',
#  'con',
#  'no',
#  'una',
#  'su',
#  'al',
#  'lo',
#  'como',
#  'más',
#  'pero',
#  'sus',
#  'le',
#  'ya',
#  'o',
#  'este',
#  'sí',
#  'porque',
#  'esta',
#  'entre',
#  'cuando',
#  'muy',
#  'sin',
#  'sobre',
#  'también',
#  'me',
#  'hasta',
#  'hay',
#  'donde',
#  'quien',
#  'desde',
#  'todo',
#  'nos',
#  'durante',
#  'todos',
#  'uno',
#  'les',
#  'ni',
#  'contra',
#  'otros',
#  'ese',
#  'eso',
#  'ante',
#  'ellos',
#  'e',
#  'esto',
#  'mí',
#  'antes',
#  'algunos',
#  'qué',
#  'unos',
#  'yo',
#  'otro',
#  'otras',
#  'otra',
#  'él',
#  'tanto',
#  'esa',
#  'estos',
#  'mucho',
#  'quienes',
#  'nada',
#  'muchos',
#  'cual',
#  'poco',
#  'ella',
#  'estar',
#  'estas',
#  'algunas',
#  'algo',
#  'nosotros',
#  'mi',
#  'mis',
#  'tú',
#  'te',
#  'ti',
#  'tu',
#  'tus',
#  'ellas',
#  'nosotras',
#  'vosotros',
#  'vosotras',
#  'os',
#  'mío',
#  'mía',
#  'míos',
#  'mías',
#  'tuyo',
#  'tuya',
#  'tuyos',
#  'tuyas',
#  'suyo',
#  'suya',
#  'suyos',
#  'suyas',
#  'nuestro',
#  'nuestra',
#  'nuestros',
#  'nuestras',
#  'vuestro',
#  'vuestra',
#  'vuestros',
#  'vuestras',
#  'esos',
#  'esas',
#  'estoy',
#  'estás',
#  'está',
#  'estamos',
#  'estáis',
#  'están',
#  'esté',
#  'estés',
#  'estemos',
#  'estéis',
#  'estén',
#  'estaré',
#  'estarás',
#  'estará',
#  'estaremos',
#  'estaréis',
#  'estarán',
#  'estaría',
#  'estarías',
#  'estaríamos',
#  'estaríais',
#  'estarían',
#  'estaba',
#  'estabas',
#  'estábamos',
#  'estabais',
#  'estaban',
#  'estuve',
#  'estuviste',
#  'estuvo',
#  'estuvimos',
#  'estuvisteis',
#  'estuvieron',
#  'estuviera',
#  'estuvieras',
#  'estuviéramos',
#  'estuvierais',
#  'estuvieran',
#  'estuviese',
#  'estuvieses',
#  'estuviésemos',
#  'estuvieseis',
#  'estuviesen',
#  'estando',
#  'estado',
#  'estada',
#  'estados',
#  'estadas',
#  'estad',
#  'he',
#  'has',
#  'ha',
#  'hemos',
#  'habéis',
#  'han',
#  'haya',
#  'hayas',
#  'hayamos',
#  'hayáis',
#  'hayan',
#  'habré',
#  'habrás',
#  'habrá',
#  'habremos',
#  'habréis',
#  'habrán',
#  'habría',
#  'habrías',
#  'habríamos',
#  'habríais',
#  'habrían',
#  'había',
#  'habías',
#  'habíamos',
#  'habíais',
#  'habían',
#  'hube',
#  'hubiste',
#  'hubo',
#  'hubimos',
#  'hubisteis',
#  'hubieron',
#  'hubiera',
#  'hubieras',
#  'hubiéramos',
#  'hubierais',
#  'hubieran',
#  'hubiese',
#  'hubieses',
#  'hubiésemos',
#  'hubieseis',
#  'hubiesen',
#  'habiendo',
#  'habido',
#  'habida',
#  'habidos',
#  'habidas',
#  'soy',
#  'eres',
#  'es',
#  'somos',
#  'sois',
#  'son',
#  'sea',
#  'seas',
#  'seamos',
#  'seáis',
#  'sean',
#  'seré',
#  'serás',
#  'será',
#  'seremos',
#  'seréis',
#  'serán',
#  'sería',
#  'serías',
#  'seríamos',
#  'seríais',
#  'serían',
#  'era',
#  'eras',
#  'éramos',
#  'erais',
#  'eran',
#  'fui',
#  'fuiste',
#  'fue',
#  'fuimos',
#  'fuisteis',
#  'fueron',
#  'fuera',
#  'fueras',
#  'fuéramos',
#  'fuerais',
#  'fueran',
#  'fuese',
#  'fueses',
#  'fuésemos',
#  'fueseis',
#  'fuesen',
#  'sintiendo',
#  'sentido',
#  'sentida',
#  'sentidos',
#  'sentidas',
#  'siente',
#  'sentid',
#  'tengo',
#  'tienes',
#  'tiene',
#  'tenemos',
#  'tenéis',
#  'tienen',
#  'tenga',
#  'tengas',
#  'tengamos',
#  'tengáis',
#  'tengan',
#  'tendré',
#  'tendrás',
#  'tendrá',
#  'tendremos',
#  'tendréis',
#  'tendrán',
#  'tendría',
#  'tendrías',
#  'tendríamos',
#  'tendríais',
#  'tendrían',
#  'tenía',
#  'tenías',
#  'teníamos',
#  'teníais',
#  'tenían',
#  'tuve',
#  'tuviste',
#  'tuvo',
#  'tuvimos',
#  'tuvisteis',
#  'tuvieron',
#  'tuviera',
#  'tuvieras',
#  'tuviéramos',
#  'tuvierais',
#  'tuvieran',
#  'tuviese',
#  'tuvieses',
#  'tuviésemos',
#  'tuvieseis',
#  'tuviesen',
#  'teniendo',
#  'tenido',
#  'tenida',
#  'tenidos',
#  'tenidas',
#  'tened']

# %%
comment_wt_sin_sw = [word for word in comment_wt if word not in stopwords]
comment_wt_sin_sw
# Out:
# ['0',
#  'Todos',
#  'monarquia',
#  'són',
#  'únos',
#  'vividores',
#  '!',
#  '...',
#  '1',
#  'Sabeis',
#  'viejo',
#  'españa',
#  '?',
#  'Porqu',
#  '...',
#  '2',
#  'De',
#  'hecho',
#  'gustado',
#  'país',
#  '(',
#  'venez',
#  '...',
#  '3',
#  '1er',
#  'error',
#  '.',
#  'Me',
#  'pela',
#  'votado',
#  'po',
#  '...',
#  '4',
#  'La',
#  'mayoría',
#  'republicanos',
#  'verdad',
#  'p',
#  '...',
#  '...',
#  '8039',
#  'Y',
#  'acusaban',
#  'pasado',
#  'haber',
#  'abortado',
#  '...',
#  '8040',
#  'Toma',
#  'Ya',
#  '\\nTan',
#  'seria',
#  'k',
#  've',
#  '8041',
#  'Otro',
#  'quiere',
#  'subirse',
#  'carro',
#  ',',
#  'ser',
#  'protag',
#  '...',
#  '8042',
#  'FELIPE',
#  'ERES',
#  'UN',
#  'TRAIDOR',
#  ',',
#  'HAS',
#  'VENDIDO',
#  'ESPAÑA',
#  '.',
#  'NO',
#  '...',
#  '8043',
#  'No',
#  'extraño',
#  '.',
#  'En',
#  'España',
#  'jamás',
#  'democ',
#  '...',
#  'Name',
#  ':',
#  'comment',
#  ',',
#  'Length',
#  ':',
#  '8044',
#  ',',
#  'dtype',
#  ':',
#  'object']

# %% [markdown]
# Frecuencia de palabras

# %%
freq = nltk.FreqDist(comment_wt_sin_sw)
freq
# Out:
# FreqDist({'...': 10, ',': 4, '.': 3, ':': 3, '0': 1, 'Todos': 1, 'monarquia': 1, 'són': 1, 'únos': 1, 'vividores': 1, ...})

# %% [markdown]
# Stemming

# %%
# Importamos esta libreria que nos permite reemplzar caracteres
import re

# Importamos la función que nos permite Stemmizar de nltk y definimos el stemmer
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# Traemos nuevamente las stopwords
spanish_stopwords = nltk.corpus.stopwords.words('spanish')
#spanish_stopwords.remove('no')
#stopword.remove('not')

# %%
# Recorremos todos los comentarios y le vamos aplicando la Normalizacion y luega el Stemming a cada uno
comment_list=[]
for comment in comentarios_monarquia.comment:
    # Vamos a reemplzar los caracteres que no sean letras por espacios, limpiando los numeros 
    comment=re.sub("[^a-zA-Z]"," ",str(comment))
    # Pasamos todo a minúsculas
    comment=comment.lower()
    # Remover caracteres especiales
    comment = re.sub(r'\W', ' ', comment)
    # Remover múltiples espacios con uno solo
    comment = re.sub(r'\s+', ' ', comment, flags=re.I)
    # Tokenizar el texto
    # Tokenizamos para separar las palabras del titular 
    comment=nltk.word_tokenize(comment)
    # Eliminamos las palabras de menos de 3 letras
    comment= [palabra for palabra in comment if len(palabra)>3]
    # Sacamos las Stopwords
    comment = [palabra for palabra in comment if not palabra in stopwords]

    ## Hasta acá Normalizamos, ahora a stemmizar

    # Aplicamos la funcion para buscar la raiz de las palabras
    comment=[stemmer.stem(palabra) for palabra in comment]
    # Por ultimo volvemos a unir el titular
    comment=" ".join(comment)

    # Vamos armando una lista con todos los titulares
    comment_list.append(comment)
    #dataset["titular_normalizado"] = titular_list

# %%
comentarios_monarquia["comment_stem"] = comment_list
comentarios_monarquia.tail()
# Out:
#       Unnamed: 0     video_id                    author  \
# 8039        8039  4OmN9EOBABQ  UC-5css8sM2g_e2U-NivhHHg
# 8040        8040  4OmN9EOBABQ  UCDtzVRnX4WGDhQrQ9AtvcoQ
# 8041        8041  Q881DsExsIA  UCN146YWKCCxWw-Gz4URUPkw
# 8042        8042  m3Ik9SANJlw  UCJrBrRRy51xokqYOXBGy-Bg
# 8043        8043  dQ1fbDltLtw  UClbAxhGN6OW21K8oPr8bOgg
#
#                                                 comment  \
# 8039  Y la acusaban en el pasado de haber abortado a...
# 8040                     Toma Ya \nTan seria k se le ve
# 8041  Otro que quiere subirse al carro, y ser protag...
# 8042  FELIPE ERES UN TRAIDOR, HAS VENDIDO ESPAÑA. NO...
# 8043  No es extraño. En España jamás ha habido democ...
#
#                                            comment_stem
# 8039  acusaban pasado haber abortado bebe hombr feli...
# 8040                                         toma seria
# 8041  quier subirs carro protagonista poca verg enza...
# 8042             felip traidor vendido espa mejor nchez
# 8043  extra espa democracia formal tica intent pepa ...

# %% [markdown]
# Vectorizar

# %%
list_comment = list(comentarios_monarquia['comment_stem'].values)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Usaremos solo las 1000 palabras con mas frecuencia en todo el corpus para generar los vectores
max_features=1000
# spanish=stopwords.words("spanish")
# Es decir que cada instancia tendrá 1000 features
cou_vec=CountVectorizer(max_features=max_features, stop_words = spanish_stopwords) # stop_words="english" , ngram_range=(1, 2)

# %%
#enerarnos los vectores para cada título a partir del corpus total. 
matriz_titulos = cou_vec.fit_transform(list_comment)

# Tomamos las palabras
all_words = cou_vec.get_feature_names_out()

# Vizualizamos las 50 palabras mas usadas
print("50 palabras mas usadas: ",all_words[0:50])
# Out:
# 50 palabras mas usadas:  ['abajo' 'abasc' 'abrazo' 'absoluta' 'absolutament' 'absoluto' 'abuelo'
#  'acabar' 'acaso' 'acto' 'actual' 'actualment' 'acuerdo' 'adelant' 'adem'
#  'adema' 'afiel' 'agenda' 'agua' 'ahora' 'air' 'alemania' 'alfonso'
#  'alguien' 'algun' 'alguna' 'alta' 'alto' 'amant' 'ambo' 'america'
#  'americano' 'amigo' 'amnist' 'amo' 'amor' 'anda' 'anglo' 'anterior'
#  'antigua' 'antiguo' 'apart' 'apoyo' 'aprend' 'aquel' 'aquello' 'aqui'
#  'argentina' 'argentino' 'argumento']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()

# Transformar el texto en vectores TF-IDF
vectores_tfidf = vectorizer.fit_transform(list_comment)

# Obtener el tamaño del vocabulario
tamaño_vocabulario = len(vectorizer.get_feature_names_out())

# Ver los vectores TF-IDF resultantes 
print(vectores_tfidf)
# Out:
#   (0, 18333)	0.30253299660430977
#   (0, 2352)	0.32460019119007766
#   (0, 5660)	0.5644494483657085
#   (0, 7023)	0.4071858889335995
#   (0, 18482)	0.4777634156378417
#   (0, 11829)	0.3007442312265462
#   (1, 6972)	0.3752966350469012
#   (1, 11336)	0.49879861083778054
#   (1, 11617)	0.34087001457040444
#   (1, 17246)	0.34683573793780736
#   (1, 6874)	0.1459124020370331
#   (1, 18348)	0.353549016634021
#   (1, 15872)	0.4770509924249004
#   (2, 8336)	0.34737100654276637
#   (2, 18319)	0.33613531574857275
#   (2, 10188)	0.17944806792821907
#   (2, 15808)	0.2471945247843006
#   (2, 14319)	0.36320682329600257
#   (2, 6581)	0.2237954052829765
#   (2, 16869)	0.3202994989953365
#   (2, 13832)	0.2773921746946704
#   (2, 18210)	0.23749063540533732
#   (2, 8517)	0.2773921746946704
#   (2, 8712)	0.3821966124396128
#   (2, 11829)	0.17909621032599515
#   :	:
#   (8043, 7419)	0.17021002789099643
#   (8043, 306)	0.33558625297960454
#   (8043, 12565)	0.19432336053781263
#   (8043, 17713)	0.17021002789099643
#   (8043, 9737)	0.19432336053781263
#   (8043, 13168)	0.20244878138035616
#   (8043, 3970)	0.13084081807015752
#   (8043, 12332)	0.14050817915275277
#   (8043, 2808)	0.13770516857153162
#   (8043, 7842)	0.1834084351880701
#   (8043, 4938)	0.29087369856604456
#   (8043, 13161)	0.1289270361110179
#   (8043, 13826)	0.11073783915690552
#   (8043, 5555)	0.13238275831020924
#   (8043, 13093)	0.11801211076127535
#   (8043, 8370)	0.08828775609435509
#   (8043, 16481)	0.1265210890578102
#   (8043, 17370)	0.2378132304700238
#   (8043, 12571)	0.16779312648980227
#   (8043, 17373)	0.2181290433408161
#   (8043, 16515)	0.13402990977198925
#   (8043, 2176)	0.10357502889335289
#   (8043, 15396)	0.13519393556709908
#   (8043, 4940)	0.23290715813530602
#   (8043, 6874)	0.1313894862676282

# %%
# Convertir la matriz dispersa a un array NumPy
vectores_tfidf_array = vectores_tfidf.toarray()

# Asegurar que el número de filas en vectores_tfidf coincida con la cantidad de filas en comentarios_inmigracion
# (vectores_tfidf_array debe tener la misma cantidad de filas que comentarios_inmigracion)
if vectores_tfidf_array.shape[0] == len(comentarios_monarquia):
    # Asignar los vectores TF-IDF al DataFrame como una nueva columna
    comentarios_monarquia['vectores_tfidf'] = list(vectores_tfidf_array)
else:
    print("Las longitudes no coinciden entre la matriz dispersa y el DataFrame.")

# %%
comentarios_monarquia['comment_stem'][10]
# Out:
# 'charla basto monarqu convincent'
