# %%
from googleapiclient.discovery import build
from dateutil import parser
import pandas as pd

# Data viz packages
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# NLP
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
from wordcloud import WordCloud
from FunctionsYoutube import *
# !pip install wordcloud 
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/usuario/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/usuario/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 17
#      15 nltk.download('punkt')
#      16 from wordcloud import WordCloud
# ---> 17 from FunctionsYoutube import *
#      18 get_ipython().system('pip install wordcloud')
#      19 from wordcloud import WordCloud
#
# ModuleNotFoundError: No module named 'FunctionsYoutube'

# %%
api_key="AIzaSyAwbJ-cYUjSvlyd51VGBtlR2-8SvplFeLI"

# %%
api_service_name = "youtube"
api_version = "v3"

# Creamos la conexión con youtube API
youtube = build(
    api_service_name, api_version, developerKey=api_key)

# %%
next_page_token = None
all_video = []

while True:
    search_response = youtube.search().list(
        q="Opiniones españolas territorio español", # q es la query 
        part="id,snippet",
        maxResults= 50, 
        regionCode='ES', 
        pageToken=next_page_token if next_page_token else ""
    ).execute()  # Mover la ejecución aquí

    for item in search_response['items']:
        all_video.append(item) 
        

    next_page_token = search_response.get('nextPageToken')

    if not next_page_token:
        break

# %%
len(all_video)
# Out:
# 719

# %%
[x['snippet']['title'] for x in all_video]
# Out:
# ['🌍 TERRITORIOS ESPAÑOLES  fuera de ESPAÑA 🌍 | la ESPAÑA desconocida',
#  'Por qué Ceuta y Melilla pertenecen a España si están en África',
#  '¿Por que España tiene un territorio atrapado en Francia?',
#  'Fueron territorios de ESPAÑA pero YA NO hablan español 😱',
#  'ESTO PIENSO sobre  España y los Españoles ¿Son raros?',
#  'Mi OPINIÓN Sobre ESPAÑA y los ESPAÑOLES',
#  'España es un país hecho para la guerra descubre el porque 🤯😵',
#  'Por qué la América española se dividió en muchos países y Brasil quedó en uno solo | BBC Mundo',
#  '5 Territorios españoles que quizás no conoces',
#  'Aprender español: Comunidades autónomas de España (nivel básico)',
#  '5 países que fueron territorios españoles pero no hablan español ¿¿O SI??',
#  'Todo sobre ESPAÑA | Cultura, datos y curiosidades',
#  'Territorios Menos Conocidos del Imperio Español',
#  '5 islas del pacifico que aun podrían ser territorio español',
#  'Aprender español: Geografía de España (nivel básico)',
#  '⚠️¿Por qué ESPAÑA NO entró en la SEGUNDA GUERRA MUNDIAL?⚠️',
#  'Esclavos negros en territorio español',
#  'España es África, en parte',
#  'El origen del conflicto en el Sahara Occidental (y qué papel tiene España)',
#  '😱🇪🇦Mi honesta opinión sobre ESPAÑA¡COSTUMBRES ESPAÑOLAS QUE ME HAN SORPRENDIDO !',
#  '¡NO PUEDE SER!😲Entrevista a EXTRANJEROS🎤¿ESTO OPINAN DE ESPAÑA? 🇪🇸',
#  '✅ La CONQUISTA y COLONIZACIÓN española de AMÉRICA | Historia, mitos, verdades, leyenda negra...',
#  'TERRITORIOS ESPAÑOLES fuera de ESPAÑA 🌍 | REACCIONANDO por PRIMERA VEZ',
#  '✅ La HISTORIA DE ESPAÑA en 15 minutos | El RESUMEN definitivo',
#  'Territorios de España que no conocías🇪🇦 | Curiosidades Geográficas🌍',
#  'EL VIRREINATO DE NUEVA ESPAÑA',
#  '30 Datos y Curiosidades que no sabías de España',
#  '¿Por qué GIBRALTAR es el lugar más EXITOSO de EUROPA? - VisualPolitik',
#  'NO ENTIENDO A LOS ESPAÑOLES 🇪🇸🇨🇺. 7 meses en España|@DanyLike',
#  'Breve historia del nacionalismo vasco',
#  'LOS SIMPSON MUY ESPAÑOLES Y MUCHO ESPAÑOLES',
#  'Por qué Filipinas no es hispanohablante si fue una colonia de España durante 300 años  | BBC Mundo',
#  'El Salvador: el Estado ya controla el 80% del territorio del país',
#  'Diálogos de España en América V: España en el territorio de los actuales EEUU.',
#  '🔥 La CRISIS del SÁHARA OCCIDENTAL en 8 minutos 🔥 | ¿Qué está pasando en el SÁHARA OCCIDENTAL?',
#  'El franquismo',
#  'MEXICANO REACCION A LA MENTIRA SOBRE ESPAÑA, LA VERDAD EN ESPAÑA @DarwinDeViajes',
#  '¿Cómo sería México si Estados Unidos no se hubiera apropiado de más de la mitad de su territorio?',
#  'Andalucía, España - Viaje por el Mediterráneo | DW Documental',
#  '✅ CURIOSIDADES sobre ESPAÑA en 1 minuto',
#  'Así empezó el Alzamiento Nacional en julio de 1936  | España dividida: La Guerra Civil en color',
#  'HISTORIA DE ESPAÑA - Antigua y Medieval - Hasta 1492 - (Documental resumen)',
#  'Los cinco primeros sobres interceptados fueron enviados desde territorio español',
#  'La EXPANSIÓN EUROPEA entre los Siglos XV y XVIII  | Portugal, España, Países Bajos, Francia...',
#  'La Guerra Civil española',
#  '¿Por qué Bolivia perdió territorios contra Brasil? #shorts',
#  'FRANCE 24 Español – EN VIVO – Información internacional y noticias del mundo 24 horas',
#  'Permiso de estudios en el territorio español o visado de estudios en el Consulado de España',
#  '🔥La GUERRA CIVIL ESPAÑOLA🇪🇸 en 13 minutos 🔥 - El Mapa de Sebas',
#  '¿Esclavos negros en territorio español?',
#  'los territorios español la fuerza española',
#  'La ÉPOCA COLONIAL en Hispanoamérica - Resumen | Organización Política, Económica y Social.',
#  'El Esequibo, el territorio que enfrenta a Venezuela y Guyana desde hace casi dos siglos | BBC Mundo',
#  '¿Esclavos negros en territorio español?',
#  'La carrera contrarreloj en Alemania para juzgar a los últimos nazis de la Segunda Guerra Mundial',
#  'Así reaccionan playistas que captan llegada de inmigrantes | Noticias Telemundo',
#  'En visita a Nueva Caledonia, Emmanuel Macron aseguró que seguirá siendo territorio francés',
#  'Gibraltar, el lugar más extraño de Europa',
#  '“La frontera partió nuestro territorio”: los indígenas que pueden votar en México y en Estados Unido',
#  'Se aproxima el fenómeno de El Niño y varios países sienten las consecuencias',
#  '3 cosas que cambian para los venezolanos en EE.UU. tras el acuerdo de Biden con México | BBC Mundo',
#  'La España que está en todos los territorios de España.',
#  '¿Cuál es el ORIGEN de la GUERRA DE UCRANIA? | EL PAÍS',
#  'Napoleón Bonaparte y las guerras napoleónicas',
#  'La Segunda Guerra Mundial en 17 minutos',
#  'BRICS, el brazo económico del nuevo Sur Global frente a Occidente',
#  'Los depredadores de África en acción | Ríos de África | Animal Planet',
#  'Geopolítica sobre los escombros de la Unión Soviética | DW Documental',
#  'El atractivo y la política económica de México dan alas al &quot;superpeso&quot;',
#  'La DESCOLONIZACIÓN de África y Asia - Resumen | La independencia de la India, Argelia, Egipto...',
#  '💃 Cómo RECONQUISTAR los territorios americanos del IMPERIO ESPAÑOL (Parte 2) Victoria 2',
#  '¿Qué pasaría si Cristóbal Colón no hubiera descubierto América?',
#  'El Salvador: el Estado ya controla el 80% del territorio del país',
#  'Por qué Jerusalén es clave en el conflicto entre israelíes y palestinos | BBC Mundo',
#  'Confusión por altercado entre militares de México y EU',
#  'HISTORIA DE GALICIA EN 10 MINUTOS',
#  'Organización Colonial',
#  'Rumbo al corazón de la Patagonia | DW Documental',
#  'La REVOLUCIÓN FRANCESA | Draw My Life',
#  'SKODA IRRITA a VOLKSWAGEN POR... ¿HACERLO DEMASIADO BIEN? LO QUE DEBES SABER',
#  'Los polémicos videos racistas que youtubers chinos graban en África para ganar dinero',
#  'Marcando territorio',
#  '🚀 El Increíble PLAN de BRASIL para Expandir su Territorio 🌍 | Cambiará el Mapa Mundial',
#  'Como hacer 1 doctorado: lo que no te han contado, ni te contarán | José Luis Arroyo | TEDxManzanares',
#  'El nacimiento del Estado Moderno en 15 minutos',
#  'El LIBERALISMO - Resumen | Liberalismo Político y Liberalismo Económico',
#  '🇫🇷El MAPA antes y después de NAPOLEÓN Bonaparte 🇫🇷 - El Mapa de Sebas',
#  'El conflicto palestino-israelí (resumen histórico)',
#  'La Guerra de Vietnam',
#  'Los Reyes Católicos en 10 minutos! | El reinado de Isabel y Fernando',
#  'Union Española 0 - Universidad de Chile 2 - Territorio Hispano',
#  '&quot;Argentina entra en territorio desconocido&quot;: &#39;El País&#39; tras la victoria del ultra Milei en las PASO',
#  'La expansión del islam',
#  'La REVOLUCIÓN CUBANA en 10 minutos | Breve historia de CUBA',
#  'Stalingrado, el ocaso del III Reich',
#  'La Guerra de la Independencia Española',
#  '¿Por qué perdió Alemania la Segunda Guerra Mundial?',
#  'ASÍ SE VIVE EN ISLANDIA: ¿El país más extraño del mundo?',
#  '¿4.200.000 en casi 30 años? La gran inmigración en Argentina (1880 a 1914)',
#  'Los ricos, los pobres y la basura | DW Documental',
#  'La desinformación en la invasión rusa a Ucrania',
#  '🇳🇱🇳🇱HISTORIA del IMPERIO NEERLANDÉS en 13 minutos 🇳🇱🇳🇱 - El Mapa de Sebas',
#  'El nacimiento del Estado Moderno en 15 minutos',
#  'LA REALIDAD SUPERA LA FICCION* MEXICANO REACCIONA A LA ARMADA ESPAÑOLA RESCATE DE CIUDADANA FRANCESA',
#  'REACCIONANDO A ¿ES POSIBLE INVADIR ESPAÑA EN LA ACTUALIDAD?',
#  'Los depredadores de África en acción | Ríos de África | Animal Planet',
#  'La REVOLUCIÓN CUBANA en 10 minutos | Breve historia de CUBA',
#  '¿Cuál de los siguientes TERRITORIOS no son entidades locales? [LANDLFORMACION] #shorts',
#  'El SAHARA OCCIDENTAL: ¿La última COLONIA de ESPAÑA?   - VisualPolitik',
#  '¿Quién llegó a América antes que Colón?',
#  'El País Vasco y la ETA | DW Documental',
#  'El litio latinoamericano “preocupa” a EE.UU. ¿Por qué y qué esperar? | Inna Afinogenova',
#  'CONGRESO: El DISCURSO de ARMENGOL, que NO ha GUSTADO a la OPOSICIÓN (ÍNTEGRO) | RTVE Noticias',
#  '🇨🇴¿Por qué COLOMBIA perdió PANAMÁ? (Sí. ¡Fueron un solo país!) 🇵🇦 - El Mapa de Sebas',
#  'Cómo Puerto Rico se convirtió en un territorio de Estados Unidos | BBC Mundo',
#  '🇲🇽 🇪🇸 reaccion 😱&quot;ESTE ES EL VERDADERO PODER MILITAR DE ESPAÑA&quot; Mexicano reacciona a españa',
#  'La expansión del islam',
#  'Un ESPAÑOL en las FILAS de ZELENSKI: &quot;Los ucranianos no se rendirán en la vida&quot; | RTVE Noticias',
#  '1. ¿Qué es y para qué sirve la Constitución?',
#  '¿4.200.000 en casi 30 años? La gran inmigración en Argentina (1880 a 1914)',
#  'Los Viajes de Cristobal Colón | Videos Educativos Aula365',
#  '¿Se dice español o castellano?',
#  'SÁNCHEZ: &quot;Tengo FRANCAS DUDAS de que ISRAEL esté cumpliendo con el DERECHO INTERNACIONAL&quot; | RTVE',
#  'La majestuosa águila real | National Geographic España',
#  'LA INDEPENDENCIA DE MÉXICO en minutos',
#  'Territorio Revival | 2x19 | Los Simpson: Doblaje ft. David García Vázquez',
#  'Orden de Malta, el país sin territorio',
#  'SORTEO DE UN JAMÓN CURADO, EN TERRITORIO ESPAÑOL PENINSULAR. JAMÓN DEL SUPERMERCADO PERÁN.',
#  '🚨 ULTIMA HORA BARÇA 💣¡LAPORTA y GASPART EXPLOTAN!🔥PALANCA TODIBO - REUNIÓN GUNDOGAN y CHRISTENSEN',
#  'Cómo México perdió más de la mitad de su territorio contra Estados Unidos',
#  '💪MILITAR ® COLOMBIANO REACCIONA Arges Artiaga: Un español contra el Est*do Isl*mico💪',
#  'HISTORIA DE GALICIA EN 10 MINUTOS',
#  'España Territorio de Innovación Bibliotecaria',
#  'El LIBERALISMO - Resumen | Liberalismo Político y Liberalismo Económico',
#  '¿Qué es la interculturalidad?',
#  'Guerra Civil Española: Exhumación en Farlete | Territorio Vivo ATV 252',
#  'HISTORIA DE ANDALUCÍA EN 10 MINUTOS',
#  '¿Cómo se formaron las Primeras CIVILIZACIONES? - Resumen | El Surgimiento de la Civilización.',
#  '✅ ¿Por qué ÁFRICA es tan POBRE y por qué puede ser la próxima SUPERPOTENCIA?',
#  'La esposa de Lot y el monte Sodoma | NATIONAL GEOGRAPHIC ESPAÑA',
#  'Territorio Fútbol',
#  '6 conflictos armados que están ocurriendo en el mundo más allá de Rusia y Ucrania | BBC Mundo',
#  'Resumen. La GUERRA CIVIL ESPAÑOLA en 7 minutos // +HD',
#  'La Guayana Esequiba, el rico territorio que Venezuela quiere recuperar ¿Por qué?',
#  'Los ricos, los pobres y la basura | DW Documental',
#  '✅ ¿Por qué LATINOAMERICA es MÁS POBRE que ESTADOS UNIDOS y CANADÁ? ¿Y cómo puede dejar de serlo?',
#  '3 cosas que cambian para los venezolanos en EE.UU. tras el acuerdo de Biden con México | BBC Mundo',
#  '👨\u200d👩\u200d👧\u200d👦 La POBLACION 👨\u200d👩\u200d👧\u200d👦 para NIÑOS de PRIMARIA',
#  'MUNDO EN GUERRA | Europa contra sus miembros, Blinken corre a Israel y la opinión de China',
#  '🇧🇪Historia de BÉLGICA en 16 minutos y 13 mapas  (resumen) 🇧🇪 - El Mapa de Sebas',
#  'El territorio más aislado de EE. UU. | GUAM 🇬🇺🇺🇸',
#  '🇪🇸¿Por qué ESPAÑA fue NEUTRAL durante la Segunda GUERRA Mundial? 💣 🔥 - El Mapa de Sebas',
#  'MUNDO EN GUERRA | Europa contra sus miembros, Blinken corre a Israel y la opinión de China',
#  'Rebeliones indígenas en América | Resistencia indígena',
#  'Políticas Activas de Empleo: personas y territorio',
#  '¿De dónde son los mapuche?',
#  '¿Por qué los españoles utilizan &quot;vosotros&quot; y los latinos no?',
#  'AtE La ingeniería española en los territorios de Ultramar un homenaje en su tricentenario',
#  '¿Cuál es el origen del conflicto en los territorios de los indígenas mapuches?',
#  'Territorios de Latinoamerica que fueron Colonizados por otros Países Europeos.',
#  '✅✅✅ Evolución GEOLÓGICA de la PENÍNSULA IBÉRICA ✅✅✅',
#  'EL VIRREINATO DEL RIÓ DE LA PLATA en minutos',
#  '🇲🇽 🇪🇸🤔&quot;Por ESTO CUBANA SE SIENTE ESPAÑOLA&quot; mexicano reacciona a españa extranjero reaccionaa a españ',
#  'La Caída del Imperio Incaico - La Guerra Civil Inca # 1',
#  'Seminario 6 b REHT: Daniel Tirado &quot;Capital humano y territorio en la historia&quot;',
#  'Union Española 0 - Universidad de Chile 2 - Territorio Hispano',
#  'Huáscar: el barco que divide a Chile y a Perú | BBC Mundo',
#  'CIVILIZACIÓN MAYA',
#  'El enigma del origen (y otras curiosidades) del euskera, la singular lengua de los vascos',
#  'Se aproxima el fenómeno de El Niño y varios países sienten las consecuencias',
#  'Google: las preguntas más buscadas sobre América Latina',
#  '⚔ CONQUISTA y COLONIZACIÓN de AMÉRICA ⚔ para NIÑOS',
#  '🚀 El Increíble PLAN de BRASIL para Expandir su Territorio 🌍 | Cambiará el Mapa Mundial',
#  '¿Reacción Inesperada de Cuba al Ver la Fuerza Militar de España? 🤔',
#  'Por Qué Vive Tan Poca Gente en Esta ENORME ZONA del Centro de España',
#  '¿Y si COLÓN NO hubiese DESCUBIERTO AMÉRICA?',
#  '🚨 EXCLUSIVO: ¡España Refuerza Seguridad en Letonia! 🇪🇸🔍 Nuevos Sistemas de Vigilancia para la OTAN🛡️',
#  'Cómo perdió Bolivia su salida al mar ante Chile (y en qué le afecta realmente)',
#  'El caso de los 5 misioneros que fueron asesinados por una tribu aislada en Ecuador',
#  'Carlos III, el mejor alcalde de Madrid',
#  '🚨 Preparativos Militares en España: ¿Se Avecina un Ataque Químico o Biológico? 🛑 Análisis 2023',
#  '“Integración del territorio nacional y defensa geocultural argentina” Prof. Roberto Magliano',
#  'Qué TERRITORIO RECLAMA GUATEMALA a MÉXICO?',
#  'Escándalo en España de la lista de los Next Generation: ahora se entiende por qué la escondían',
#  'La pérdida de los últimos territorios de ultramar',
#  '&quot;Argentina entra en territorio desconocido&quot;: &#39;El País&#39; tras la victoria del ultra Milei en las PASO',
#  'Cómo fue la Gran Colombia, la ambiciosa república que dio lugar a 4 países de América Latina',
#  'LA INDEPENDENCIA DEL PERÚ en minutos',
#  '✅ La GUERRA DEL GOLFO en 10 minutos | La primera GUERRA televisada de la historia',
#  'EL IMPERIALISMO en 6 minutos',
#  'Cómo fue la guerra más sangrienta de la historia de América Latina | BBC Mundo',
#  'GUERRA UCRANIA: RUSIA AMENAZA con una ESCALADA BÉLICA, tras la REUNIÓN en RAMSTEIN | RTVE Noticias',
#  '🇪🇸¿ESTE PAÍS POSEE ESTO EN TODO SU TERRITORIO⁉️ España | RoKush0 informa',
#  'Mi review de Napoleón I Todo mal en mi mayor decepción',
#  'Moreira podrá salir del territorio español  / Yuriria Sierra',
#  'El Esequibo, el territorio que enfrenta a Venezuela y Guyana desde hace casi dos siglos | BBC Mundo',
#  'Geopolítica sobre los escombros de la Unión Soviética | DW Documental',
#  'Los polémicos videos racistas que youtubers chinos graban en África para ganar dinero',
#  '🇪🇸 ESPAÑOLES REACCIONAN a LOS 10 PAÍSES con MÁS CIUDADANOS en MÉXICO 🇲🇽😱 *NO ESPERÁBAMOS ESTO*',
#  '15 actuales paises que antes pertenecian a MEXICO, virreynato de la nueva España',
#  'Structurer l&#39;argumentation : les connecteurs logiques - Espagnol - Terminale - Les Bons Profs',
#  'MEXICANO REACCION A LA MENTIRA SOBRE ESPAÑA, LA VERDAD EN ESPAÑA @DarwinDeViajes',
#  '¿Y si COLÓN NO hubiese DESCUBIERTO AMÉRICA?',
#  'España Territorio de Innovación Bibliotecaria',
#  'Qué TERRITORIO RECLAMA GUATEMALA a MÉXICO?',
#  'Cómo fue la guerra más sangrienta de la historia de América Latina | BBC Mundo',
#  '¿Qué buscan realmente las tropas rusas en Nicaragua? | Contexto DW',
#  'Cómo Israel se Convirtió en el País más Avanzado en Agricultura',
#  'FRANCE 24 Español – EN VIVO – Información internacional y noticias del mundo 24 horas',
#  'El IMPERIALISMO durante el Siglo XIX - Resumen | El Imperialismo en África y en Asia.',
#  'Territorio Revival | 1x20 | Bob Esponja ft. Álex Saudinós',
#  'Reflexiones sobre el Territorio como bien de Derecho Público',
#  'Escándalo en España de la lista de los Next Generation: ahora se entiende por qué la escondían',
#  '¿Bolivia realmente perdió tantos territorios? -Video opinión-',
#  'NO ENTIENDO A LOS ESPAÑOLES 🇪🇸🇨🇺. 7 meses en España|@DanyLike',
#  'Cómo empezó la guerra de Corea y qué tuvo que ver EE.UU. en ese conflicto | BBC Mundo',
#  'La Conquista de México en 10 minutos! | Hernán Cortés y el Imperio Azteca',
#  'Un viaje por Corea del Norte | DW Documental',
#  '#ContraPrograma REPASO de la ACTUALIDAD SEMANAL (con Manu Levin y Paula Pof) | PANDEMIA DIGITAL',
#  'La Primera Guerra Mundial',
#  '🇨🇱⚔︎🇵🇪🇧🇴La GUERRA del PACÍFICO (o del GUANO y el SALITRE) en 11 minutos 🇨🇱⚔︎🇵🇪🇧🇴 - El Mapa de Sebas',
#  'De los Territorios No Autónomos: Aproximaciones, Miradas y Perspectivas',
#  'REACCION a CUIDANDO EL TERRITORIO - SANTA FE KLAN, BETO SIERRA Y CALIBRE 50',
#  'Territorio Revival | 2x33 | Indiana Jones ft. Ernesto Sevilla',
#  'La Guayana Esequiba, el rico territorio que Venezuela quiere recuperar ¿Por qué?',
#  'TODO ES GEOPOLÍTICA | EEUU y Europa podrían dejar sin ayudas a Ucrania, Irán carga contra Biden',
#  'Entrevista News | Pompeyo Torrealba: no queremos territorio de Guyana',
#  'Alejandro Magno y el Imperio de Macedonia',
#  'Territorio de leones: Rivales de sangre || Documentales nat geo wild Español 2020 HD',
#  'Israel llama a consultas a su embajadora en España tras declaraciones de Pedro Sánchez • FRANCE 24',
#  'Métodos para evaluar los riesgos',
#  '¿Qué opinan los alemanes? | Berlín político',
#  'Volvo XC40 SUV | Primera prueba / Test / Review en español | coches.net',
#  '¿Qué Armas de Fuego y Calibres Están Permitidos para Civiles en México?',
#  'La pérdida de los últimos territorios de ultramar',
#  'Las noticias económicas más destacadas de la semana',
#  'CONEXIÓN VILAR: El futuro de Ucrania, amenazado; Lagarde vuelve a hablar y oro en máximos históricos',
#  'Las 10 Fases del Genocidio',
#  'SANCHEZ MANDA AL NÚMERO 2 DEL PSOE  RENDIR ESPAÑA A UN GOLPISTA EN SUIZA',
#  'Cómo Panamá ha pasado de ser un ejemplo de prosperidad y estabilidad a vivir masivas protestas',
#  'NO SE VIVE MEJOR QUE EN ESTE PAÍS',
#  '¿ANDALUCIA COLONIA INTERIOR? | ZONA COMANCHE',
#  'Proceso de formación del territorio argentino',
#  '✅ ¿Por qué ÁFRICA es tan POBRE y por qué puede ser la próxima SUPERPOTENCIA?',
#  'Arqueología encontrada en la ruta del Tren Maya',
#  '60 CURIOSIDADES💥 que no SABÍAS🤔 sobre ESPAÑA🇪🇦 HACE 5 MINUTOS⏰️ /Cubano Reacciona 2023',
#  'La Conquista del Perú en 10 minutos! | Francisco Pizarro y el Imperio Inca',
#  'Más se Perdió en Cuba | 02/12/23',
#  'TERRITORIO de LEONES #2: CAZADOR de GIGANTES | Documental National Geographic (HD)',
#  '¿Por qué perdió Alemania la Segunda Guerra Mundial?',
#  'FRANCIA ALERTA con ESPAÑA ¡A-FOX para TARSIS! ¿MISIL FNSM en 2035?',
#  'Mundo Maldini',
#  '¿Es ESPAÑA el país que PEOR ha GESTIONADO el CORONAVIRUS? - VisualPolitik',
#  '¿Qué piensan los rusos de la guerra?',
#  'EEUU: Más armas que habitantes | Españoles en conflicto',
#  '🇫🇷El MAPA antes y después de NAPOLEÓN Bonaparte 🇫🇷 - El Mapa de Sebas',
#  'ASENTAMIENTO INGLÉS EN TERRITORIOS ESPAÑOL EN ÁFRICA',
#  'TERRITORIO — trailer',
#  'V. completa: “Hablar en público es un privilegio que deberíamos aprovechar”. Manuel Campo Vidal',
#  '🇬🇾HISTORIA de GUYANA en 9 minutos 🇬🇾 - El Mapa de Sebas',
#  '30 Curiosidades que no Sabías sobre Turquía | La cuna del Imperio Otomano',
#  'Marruecos ame.naza la soberanía de España:«Ceuta y Melilla son territorios marroquíes como el Sáhara',
#  '¿POR QUÉ PERÚ PERDIÓ TANTO TERRITORIO? || HISTORIA TERRITORIAL DEL PERÚ',
#  'GUERRA: RUSIA acusa a UCRANIA de intentar MATAR a PUTIN en un ATAQUE con DRONES al KREMLIN | RTVE',
#  'Conoce las misiones a Día de hoy en las que se encuentra el ejercito español ,Cubano reacciona',
#  'Ciclo Territorio y poder (y 4) La frontera oriental de Europa',
#  'Asómate a la UAM: Grado en Geografía y Ordenación del Territorio',
#  'CONSTRUYAMOS TERRITORIOS LIBRES DE VIOLENCIAS MACHISTAS Viernes 15 octubre',
#  'Versión Completa. Lo que nos enseña la naturaleza. Joaquín Araújo, naturalista y escritor',
#  'La Guerra de Vietnam',
#  '¿Latino o hispano? Cómo se usan estos términos en Estados Unidos | BBC Mundo',
#  'JORNADA INFORMATIVA ‘LISTA (LEY DE IMPULSO PARA LA SOSTENIBILIDAD DEL TERRITORIO DE ANDALUCÍA)’',
#  'La verdad sobre la moda rápida - ¿Mienten los fabricantes de moda a sus clientes? | DW Documental',
#  'Militares del Grupo Wagner bloquean el centro de Rostov del Don, territorio ruso',
#  'GARFIO ¿HÉROE O VILLANO? #territoriorevival #podcast #humor #viral #parati #peterpan #disney #shorts',
#  '¿Cómo se puede enfriar el planeta y frenar el calentamiento global? | BBC Mundo',
#  'Hernán Cortés y la Conquista de México',
#  '🚨 Preparativos Militares en España: ¿Se Avecina un Ataque Químico o Biológico? 🛑 Análisis 2023',
#  'Organización social en las colonias',
#  'TIERMAKER - ¿CUÁL ES LA MEJOR REGIÓN DE ESPAÑA?',
#  'PEDRO SÁNCHEZ: 1ª ENTREVISTA tras ser INVESTIDO PRESIDENTE del GOBIERNO | RTVE',
#  'España no se rompe, YA ESTÁ ROTA',
#  'La Educación Prohibida - Película Completa HD Oficial',
#  'Alejandro Magno y el Imperio de Macedonia',
#  'El Salvador: las medidas del presidente Nayib Bukele en contra de las pandillas',
#  '🔴 La ILUSTRACIÓN del SIGLO XVIII en 5 minutos ‼',
#  'Los Reyes Católicos en 10 minutos! | El reinado de Isabel y Fernando',
#  '🌎La HISTORIA DE ESTADOS UNIDOS en 13 minutos🌎 | Resumen rápido',
#  '🚨 ¿SOY UN FACHA? 📢 ¿SERÉ UN ENERGÚMENO SIN ESCRÚPULOS? - SOY ESPAÑOL – VIVA ESPAÑA',
#  'El correo entre los Estados Unidos y los antiguos territorios Españoles en Norte America',
#  'El proceso de independencia, explicado en 5 minutos',
#  'Stalingrado, el ocaso del III Reich',
#  'RANGOS MILITARES del EJÉRCITO ESPAÑOL - Soldier Spain nos explica cómo funcionan y cuáles son.',
#  'El Descubrimiento de América',
#  'Arqueología encontrada en la ruta del Tren Maya',
#  '¿Qué diferencia a los aztecas de los mayas?',
#  '30 Curiosidades que no Sabías sobre Pakistán  | Una potencia nuclear de Asia',
#  '📌🤔⚔ ¿Qué territorios conquistó Francia en América? | Conquista y colonización francesa en América🌎🇫🇷',
#  'EE.UU. a por el PETRÓLEO de El Esequibo, territorio en DISPUTA entre Venezuela y Guyana | Caféinna',
#  'Me quedo sin palabras ante el poderío militar español ,Desfile de fuerza militar de España',
#  '¿Qué diferencia a los aztecas de los mayas?',
#  '📌🤔⚔ ¿Qué territorios conquistó Francia en América? | Conquista y colonización francesa en América🌎🇫🇷',
#  '30 Curiosidades que no Sabías sobre Pakistán  | Una potencia nuclear de Asia',
#  'PEDRO SÁNCHEZ: 1ª ENTREVISTA tras ser INVESTIDO PRESIDENTE del GOBIERNO | RTVE',
#  'Me quedo sin palabras ante el poderío militar español ,Desfile de fuerza militar de España',
#  'La Conquista del Perú en 10 minutos! | Francisco Pizarro y el Imperio Inca',
#  'Historia de México: El PORFIRIATO - Resumen | El gobierno de PORFIRIO DÍAZ',
#  '🔴 DIRECTO 27/11/2023 - &#39;LA DECADENCIA DE LA EUROPA FAKE&#39;, con Lorenzo Ramírez',
#  'Poblamiento Americano | Teorías Inmigracionistas | Origen del Hombre Americano',
#  'Foucault',
#  '✅ El IMPERIO ROMANO en 10 minutos | Resumen de la historia de la ANTIGUA ROMA',
#  'Structurer l&#39;argumentation : les connecteurs logiques - Espagnol - Terminale - Les Bons Profs',
#  'Diversidad cultural',
#  'Francia le QUITÓ TERRITORIO a MÉXICO #shorts #historiaolvidada',
#  'Día de la croqueta : Barbastro | Territorio Vivo ATV 322',
#  'Ciclo de Conversatorios Urabá Darién Memoria de un Territorio - &quot;Balboa y Ananyansy en Urabá Darién&quot;',
#  'Armada española rescata a ciudadana francesa secuestrada ,Cubano reacciona sorprendido 🤯😱',
#  'Covid-19: el virus que arrasó con todo',
#  'EL CID CAMPEADOR⚔🛡 | Draw My Life en Español',
#  'Reconquistando marruecos y expandiendo territorio/Campaña con España Ep8/Empire Total War/Darth mod',
#  '¿A quién pertenece Jerusalén? | DW Documental',
#  '¿Y si los NAZIS hubieran GANADO la GUERRA?',
#  'EE.UU. a por el PETRÓLEO de El Esequibo, territorio en DISPUTA entre Venezuela y Guyana | Caféinna',
#  'Huáscar: el barco que divide a Chile y a Perú | BBC Mundo',
#  'Aseguran que Chile se quiere quedar con parte del territorio argentino',
#  'MÉXICO ANEXARA A GUATEMALA A SU TERRITORIO |GUATEMALTECA REACCIONA',
#  'CUPRA BORN: Ni Seat Born ¿ni VW ID.3? | Primera Prueba / Test drive / Review en español',
#  '🇲🇽 El TERRITORIO que MÉXICO RECUPERÓ de EEUU | la historia del PUEBLO RIO RICO *REACCIÓN*',
#  'COMO SON😱 los ESPAÑOLES🇪🇦 SEGÚN los ESTADOUNIDENSES🇺🇲 /Cubano Reacciona 2023 #España',
#  '🎥 EL PLEBE DEL CAMARO - PELICULA COMPLETA NARCOS | Ola Studios TV 🎬',
#  'Cómo Panamá ha pasado de ser un ejemplo de prosperidad y estabilidad a vivir masivas protestas',
#  'Territorio de Bellota 100% ibérico: Cata de jamón, paleta y otros ibéricos',
#  'El Territorio del Fut',
#  '*LOS ESTADOUNIDENSES ESTÁN HUYENDO A ESPAÑA | MEXICANOS REACCIONAN',
#  '¿PUEDO REAGRUPAR A UN FAMILIAR UNA VEZ ÉSTE SE ENCUENTRE EN TERRITORIO ESPAÑOL?',
#  'Las colonias más ricas de las Américas terminaron siendo los territorios más pobres',
#  'Venezuela - María Corina Machado rechaza diálogo entre España y Gobierno venezolano - VPItv',
#  'GRUPO WAGNER: PRIGOZHIN y el &quot;EJÉRCITO PARALELO&quot; de PUTIN en la GUERRA de UCRANIA | RTVE',
#  'La Guerra de las Malvinas',
#  'Proceso de formación del territorio argentino',
#  'Comisión de Medio Ambiente y Ordenación del Territorio - 1 de septiembre de 2.015',
#  '¿La Tierra es plana? 🌎 5 pruebas... en contra',
#  'Hannah Arendt',
#  '💣La GUERRA DE VIETNAM en 11 minutos💣 | resumen FÁCIL y RÁPIDO',
#  '¡GIBRALTAR! - Canción Franquista española sobre Gibraltar.',
#  '20 ciudades imprescindibles de España. Argentinos reaccionan',
#  'La Guayana Esequiba, el rico territorio que Venezuela quiere recuperar ¿Por qué?',
#  'Napoleón Bonaparte y las guerras napoleónicas',
#  'Los paisajes de montaña y de llanura. EL RELIEVE⛰| Vídeos Educativos para Niños',
#  'La Reforma protestante y Lutero',
#  'ASÍ SE VIVE EN ISLANDIA: ¿El país más extraño del mundo?',
#  'De 1619 a 1865, un repaso por la historia de esclavitud en los Estados Unidos',
#  'XLV Aniversario de la Constitución Española. Lectura de la Constitución 9h (29/11/2023)',
#  'La invasión a Palestina le saldrá muy cara a Israel - Entrevista con Ezequiel Bistoletti',
#  'EL CANTAR DEL MÍO CID EN 3 MINUTOS',
#  '¿QUE ES EL MARXISMO? en 4 minutos',
#  'LA SEGUNDA GUERRA MUNDIAL EN 20 MINUTOS | INFONIMADOS',
#  '¿Qué son las NORMAS JURÍDICAS y cuáles son sus características? (Con ejemplos)👨\u200d⚖️',
#  'Comida para todos - El futuro de la alimentación | DW Documental',
#  'Papi Wilo - Mi Historia [Official Video]',
#  'Métodos para evaluar los riesgos',
#  '¿Son habladores los españoles? Un estudio revela el ranking de las ciudades más y menos habladoras',
#  '¿Cómo nos influye la música? | DW Documental',
#  'En México habitan 62 pueblos indígenas',
#  'La Prehistoria en 6 minutos',
#  'Marcando territorio',
#  'Mesopotamia. Una civilización entre dos ríos | Vídeos educativos para niños',
#  'Planas destaca la respuesta ante los ataques a los camiones españoles',
#  'Homo sapiens: los orígenes de la humanidad',
#  'Rust - Adueñándonos Del Territorio- Español',
#  'La Edad Media: ¿Qué es el Feudalismo? | Videos Educativos Aula365',
#  'Primeras Impresiones de España!!! #amoespaña #vidanueva',
#  'COMO se HACE el ORO en la TIERRA | Como se EXTRAE el ORO de las MINAS 🥇',
#  'Reacher  - Tráiler Oficial | Prime Video España',
#  'Historia de las maras, las pandillas salvadoreñas enfrentadas a Nayib Bukele',
#  'RODRIGO QUESADA REALIZA UN TIERLIST SOBRE COMUNIDADES AUTÓNOMAS DE ESPAÑA',
#  'Julio César',
#  'Historia del ANTIGUO EGIPTO - Resumen | Origen, Política, Sociedad, Economía, Aportes...',
#  '#29.- Compraventa de territorios entre países',
#  'SER Historia | Rodrigo de Bastidas, la fundación de Santa Marta',
#  'EL RENACIMIENTO en 5 minutos',
#  'GASOLINA: Los PORTUGUESES cruzan la FRONTERA para REPOSTAR con DESCUENTO en ESPAÑA | RTVE',
#  'Cómo fue el conflicto de 1941 entre Perú y Ecuador y qué consecuencias tuvo',
#  'PIB NOMINAL y PIB REAL - Explicado para principiantes!',
#  'INDEPENDENCIA DE TEXAS - PERDIDA DE TERRITORIO MEXICANO',
#  '¿Qué Armas de Fuego y Calibres Están Permitidos para Civiles en México?',
#  'Las multinacionales españolas salen huyendo o se trocean a fondos extranjeros.',
#  '¿Qué une a talibanes con narcos mexicanos? | Contexto DW',
#  'La reacción viral de un canandiense al probar la comida española | Turno de Tarde',
#  'Cada vez más refugiados haitianos llegan a México',
#  'La salvaje advertencia de Guillermo Rocafort que pone patas arriba el futuro de España',
#  'Xornada Diagnose de País. Primeira parte: Transición enerxética e territorio.',
#  'Territorio Revival | 3x07 | La ruta hacia El Dorado ft. Masi',
#  'Cómo Estados Unidos robó el 50% de su territorio a México y Cuba, Puerto Rico y Filipinas a España.',
#  'La importancia de la investigación en la escuela. Juan Fernández, profesor y biólogo',
#  'Ceuta y Melilla ¿Territorio Cuestionado por Marruecos? #geopolitica #historia',
#  '¿Eres descendiente de españoles?: Obtén la nacionalidad bajo la Ley de Memoria Democrática',
#  'Agricultores: ¿Puede hacerse crecer el dinero? | DW Documental',
#  '¿Cómo frenar las guerras orquestadas por la inteligencia artificial? | DW Documental',
#  '¿Qué opinan los rusos y los ucranianos de las tensiones entre Rusia y Occidente?',
#  'EL CANTAR DEL MÍO CID EN 3 MINUTOS',
#  'Los Puertorriqueños 🇵🇷 quieren ser españoles🇪🇸 [Demos Hispanidad]',
#  '🎮 Xbox HUMILLA a prensa y haters | GTA VI trailer OFICIAL | Cyberpunk 2077 NEWS | Sony PS5 - Semons',
#  '¿QUE ES EL MARXISMO? en 4 minutos',
#  'LA SEGUNDA GUERRA MUNDIAL EN 20 MINUTOS | INFONIMADOS',
#  'Papi Wilo - Mi Historia [Official Video]',
#  'ZONAS RURALES DE ESPAÑA CORREN PELIGRO ☣️, CUBANO QUEDA IMPACTADO',
#  '¿Qué son las NORMAS JURÍDICAS y cuáles son sus características? (Con ejemplos)👨\u200d⚖️',
#  'Comida para todos - El futuro de la alimentación | DW Documental',
#  '💻 Autorización para Teletrabajar en España: Nómada Digital 🌎🇪🇸 #reels #shorts',
#  'Métodos para evaluar los riesgos',
#  'ARMENGOL defiende su DISCURSO en la APERTURA de las CORTES que el PP y VOX calificaron de &quot;MITIN&quot; |',
#  'En México habitan 62 pueblos indígenas',
#  '¿Cómo nos influye la música? | DW Documental',
#  'La Prehistoria en 6 minutos',
#  'Marcando territorio',
#  'Mesopotamia. Una civilización entre dos ríos | Vídeos educativos para niños',
#  'Sangre y Misterio: Vampiros de la Mitología de España 🧛\u200d♀️🦇',
#  'Reacher  - Tráiler Oficial | Prime Video España',
#  '🇲🇽 🇪🇸 reaccion &quot;LA SORPRENDENTE EXPEDICION  BALMIS&quot; extranjero reacciona a españa mexicano reacciona',
#  'Homo sapiens: los orígenes de la humanidad',
#  'ESTUDIAR 🔴 Preguntas de Cómo Estudiar en España en 2024 ✈️🇪🇸',
#  'La Edad Media: ¿Qué es el Feudalismo? | Videos Educativos Aula365',
#  'COMO se HACE el ORO en la TIERRA | Como se EXTRAE el ORO de las MINAS 🥇',
#  'Historia de las maras, las pandillas salvadoreñas enfrentadas a Nayib Bukele',
#  'Pensamiento ambiental sur: comprensión de fenómenos y tensiones en los territorios.',
#  'No es válida la venta del territorio de México',
#  'El Objetivo - El Españolisto analiza los precios españoles y su contexto',
#  'Julio César',
#  'Historia del ANTIGUO EGIPTO - Resumen | Origen, Política, Sociedad, Economía, Aportes...',
#  'SOY ESPAÑOL, ¿A QUÉ QUIERES QUE TE GANE? #territoriorevival #podcast #nostalgia #deporte #humor #fy',
#  '60 CURIOSIDADES💥 que no SABÍAS🤔 sobre ESPAÑA🇪🇦 HACE 5 MINUTOS⏰️ /Cubano Reacciona 2023',
#  'EL RENACIMIENTO en 5 minutos',
#  'Cómo fue el conflicto de 1941 entre Perú y Ecuador y qué consecuencias tuvo',
#  'INDEPENDENCIA DE TEXAS - PERDIDA DE TERRITORIO MEXICANO',
#  'Historia de México - La Nueva España',
#  'El día que México PERDIO la MITAD DE SU TERRITORIO',
#  'PIB NOMINAL y PIB REAL - Explicado para principiantes!',
#  '¿Qué Armas de Fuego y Calibres Están Permitidos para Civiles en México?',
#  'Cada vez más refugiados haitianos llegan a México',
#  'Mapuches: resistencias contra el extractivismo en defensa del territorio',
#  'Los Reyes y la princesa Leonor presiden la apertura de la XV Legislatura de las Cortes Generales',
#  'Satanismo en Colombia: Historia &amp; Comentarios',
#  'Territorio Revival | 3x07 | La ruta hacia El Dorado ft. Masi',
#  'La importancia de la investigación en la escuela. Juan Fernández, profesor y biólogo',
#  '¿Cómo frenar las guerras orquestadas por la inteligencia artificial? | DW Documental',
#  'Agricultores: ¿Puede hacerse crecer el dinero? | DW Documental',
#  'Diversidad lingüística y cultural de México',
#  'Gonzalo Pizarro y la gran rebelión de los encomenderos',
#  '📌🤔⚔ ¿Quiénes conquistaron los actuales territorios de 🇧🇷 Brasil? en MENOS de UN MINUTO ⏱',
#  'Los nuevos medicamentos contra el cáncer: ¿motivo de esperanza o perjuicio? | DW Documental',
#  'La Reconquista, ¿un término válido?',
#  'Los Puertorriqueños 🇵🇷 quieren ser españoles🇪🇸 [Demos Hispanidad]',
#  '🌍La HISTORIA DEL MUNDO en 15 minutos🌍 | Resumen de la historia de la HUMANIDAD',
#  '🎮 Xbox HUMILLA a prensa y haters | GTA VI trailer OFICIAL | Cyberpunk 2077 NEWS | Sony PS5 - Semons',
#  '¿Cómo llamaba Colon al territorio que descubrió? #cristóbalcolón #historia',
#  'ZONAS RURALES DE ESPAÑA CORREN PELIGRO ☣️, CUBANO QUEDA IMPACTADO',
#  '¿Y si SE DERRITE todo el HIELO del PLANETA?',
#  '💻 Autorización para Teletrabajar en España: Nómada Digital 🌎🇪🇸 #reels #shorts',
#  'ARMENGOL defiende su DISCURSO en la APERTURA de las CORTES que el PP y VOX calificaron de &quot;MITIN&quot; |',
#  'Crisis económicas a lo largo de la historia',
#  'American Bully - Todo lo que Debes Saber | Terránea',
#  'Alemania lucha por mantenerse en la carrera por la competitividad y sostenibilidad | A fondo DW',
#  'Sangre y Misterio: Vampiros de la Mitología de España 🧛\u200d♀️🦇',
#  'La cultura Tiahuanaco en 9 minutos | Culturas Preincas',
#  '🇲🇽 🇪🇸 reaccion &quot;LA SORPRENDENTE EXPEDICION  BALMIS&quot; extranjero reacciona a españa mexicano reacciona',
#  'Las raíces históricas de los nazis modernos | DW Documental',
#  'ESTUDIAR 🔴 Preguntas de Cómo Estudiar en España en 2024 ✈️🇪🇸',
#  '“El territorio, la territorialidad y la territorialización.”',
#  'Aztecas, Incas y Mayas 🌎 Resumen',
#  'Pensamiento ambiental sur: comprensión de fenómenos y tensiones en los territorios.',
#  'No es válida la venta del territorio de México',
#  'El Objetivo - El Españolisto analiza los precios españoles y su contexto',
#  '«La Florida del Inca», escrito por el Inca Garcilaso. Un diálogo con Carmen de Mora Valcárcel',
#  'SOY ESPAÑOL, ¿A QUÉ QUIERES QUE TE GANE? #territoriorevival #podcast #nostalgia #deporte #humor #fy',
#  'JAIME PEÑAFIEL vuelve a destrozar a LETIZIA.',
#  '60 CURIOSIDADES💥 que no SABÍAS🤔 sobre ESPAÑA🇪🇦 HACE 5 MINUTOS⏰️ /Cubano Reacciona 2023',
#  'Historia de México - La Nueva España',
#  'El día que México PERDIO la MITAD DE SU TERRITORIO',
#  'La Prehistoria - 5 cosas que deberías saber - Historia para niños',
#  'Mapuches: resistencias contra el extractivismo en defensa del territorio',
#  'Los Reyes y la princesa Leonor presiden la apertura de la XV Legislatura de las Cortes Generales',
#  '⚠️VIAJAR a ESPAÑA últimos requisitos 2022 ❗ACTUALIZADO❗',
#  'TIPOLOGÍAS TEXTUALES O TIPOS DE TEXTOS - edutuber',
#  '20 Series TURCAS en [ESPAÑOL COMPLETAS]',
#  'Ep. 117 - Fondos de búsqueda: el camino de la inversión - Territorio Negocios',
#  'Satanismo en Colombia: Historia &amp; Comentarios',
#  'Chevrolet Tahoe 2021 - Mejor en todo y aún más grande - Primer Vistazo',
#  'Territorio Revival | 2x33 | Indiana Jones ft. Ernesto Sevilla',
#  'Mundo Maldini',
#  'Estafas millonarias en Internet | DW Documental',
#  'La caída del Imperio Otomano',
#  'Territorio Revival | 1x20 | Bob Esponja ft. Álex Saudinós',
#  'La mentira del libre comercio | DW Documental',
#  '📌🤔⚔ ¿Quiénes conquistaron los actuales territorios de 🇧🇷 Brasil? en MENOS de UN MINUTO ⏱',
#  'Ni las iglesias podrían ayudar a inmigrantes: los detalles de la nueva ley antiinmigrante de Florida',
#  'Con VOX en el gobierno, esperamos una revitalización del mercado laboral',
#  'Yo también fui progre... y constitucionalista. FORJA 232 #progresismo #politica #actualidad #españa',
#  '🇲🇽 🇪🇸 😬&quot;DIFERENCIAS ENTRE ESPAÑA Y ESTADOS UNIDOS&quot;😮 mexicano reacciona a españa extranjero reaccion',
#  'PRIMERA GUERRA MUNDIAL (Resumen) | Draw My Life',
#  'Los territorios italianos de la Monarquía Hispánica',
#  'Recuperando territorio para recuperarlo todo (Paleando el territorio)',
#  'A custodia do territorio en Galicia. Oportunidades para o Ortegal | AGCT',
#  'LA ESPAÑA DESPOBLADA: Béjar (Salamanca) (01/12/2023)',
#  'VOX propone fomentar un entorno empresarial más libre y competitivo',
#  'Guerras Púnicas. Roma vs. Cartago',
#  '08. La diversidad lingüística del español en los medios de comunicación',
#  '⚠️🛴Futura LEY PATINETES Electricos 2024-2027 ⛔️👮🏻\u200d♂️CERTIFICADO de CIRCULACION 💥',
#  'Sugel Michelén: La historia de la Biblia en español',
#  'Colegio Gringo vs. Colegio Latino | enchufetv',
#  'Ugly History: The Spanish Inquisition - Kayla Wolf',
#  'Alberto Fernández sería propietario de un hotel en España',
#  'Resines dice lo q opina el resto de 🇪🇸🇪🇸🇪🇸 España',
#  'ECUADOR - Territorio Demostrativo Píllaro',
#  'Españoles por Juego de Tronos',
#  '¿Qué es eso de Territorio No incorporado para Puerto Rico?',
#  '¿Es posible acabar con las redes criminales de alcance global? | DW Documental',
#  'Zoom.  6° Prim.  El Territorio Peruano al iniciar la República.  08/07.',
#  'UN CASTILLO DEL IMPERIO ESPAÑOL EN TERRITORIO ESTADOUNIDENSE [Castillo De San Marcos] San Agustin Fl',
#  'La política es para gobernar territorios, no personas',
#  'Monólogo de Alsina, a Pedro Sánchez: &quot;Deje de criticar, que la amnistía es para usted&quot;',
#  '✅ UNA VEZ MAS... ¡AZERBAIYÁN es TERRITORIO de CHECO! 👏 | MAX ENCARA a RUSSELL 👊 | RESUMEN SPRINT F1',
#  'Por qué el Ejército ruso no logra vencer en Ucrania',
#  'Todos los territorios perdidos o ganados por países americanos! #enfemapping #revivalgeo #mapping',
#  '«La Florida del Inca», escrito por el Inca Garcilaso. Un diálogo con Carmen de Mora Valcárcel',
#  'Calibre 50 - Corrido De Juanito',
#  'Así fue la batalla de Boyacá el 7 de agosto de 1819',
#  '🔴 DIRECTO | El rey Felipe VI abre la XV Legislatura en el Congreso (29/11/2023)',
#  '9° Seminario Chiloé: Historia del Contacto. Territorio histórico (2)',
#  'NO SE VIVE MEJOR QUE EN ESTE PAÍS',
#  '12. The Inca - Cities in the Cloud (Part 1 of 2)',
#  'EN DEFENSA DEL CARDENAL BURKE - ESPAÑA ESTÁ CONTIGO',
#  'Socotra, la isla del tesoro verde entre Yemen y Somalia | DW Documental',
#  'REGRESA IBERDROLA! REINVIERTE LO VENDIDO EN MÉXICO',
#  '⭐ La HISTORIA del SIGLO XX en 10 minutos⭐| El resumen definitivo',
#  '🔴📡 DIRECTO -  Territorios Resistentes: ‘Territorios artísticos’',
#  '🇧🇬HISTORIA de BULGARIA en (casi) 19 minutos  (resumen) 🇧🇬 - El Mapa de Sebas',
#  'Historia de México cap 2 Un Territorio Mutilado',
#  'CONQUISTA DEL DESIERTO en minutos',
#  '¿ESPAÑA es Ahora una DICTADURA? | Video Reacción',
#  'GUERRA EN UCRANIA-ESPECIAL INFORMATIVO: PUTIN ataca varias ciudades ucranianas | RTVE',
#  '¿Por qué República Dominicana y Haití son tan distintos? | El Espectador',
#  'Comisión de Agricultura, Desarrollo Rural, Población y Territorio 08/06/2022',
#  'Territorio Urgente: Introducción a la filosofía de la liberación. Hacia un pensamiento decolonial.#3',
#  'Napoleonic Wars 1805 - 09: March of the Eagles',
#  'UNA HISTORIA CONTADA POR MUJERES: Austeridad fiscal y territorios indígenas',
#  'LA HISTORIA DE MÉXICO🇲🇽 en 17 MINUTOS feat. Nación Tesla - El Mapa de Sebas',
#  'Territorio Líder   Capítulo 24   Manuel Pérez Sala   Círculo de Empresarios 1080p',
#  '😨 Los 3 Peores Países para Emigrar desde Venezuela',
#  'TODO ES GEOPOLÍTICA | EEUU y Europa podrían dejar sin ayudas a Ucrania, Irán carga contra Biden',
#  'El Territorio Que Ningún País lo Reclama',
#  'Hearts Of Iron IV | España en la Segunda Guerra Mundial | Unimos Territorios',
#  'La Caída de Constantinopla',
#  'Las dos Guerras Mundiales',
#  'DARWIN EL ALCALDE FAVORITO DE DELCY | FUERA DE ORDEN 714 PARTE 2 | SÁBADO 2.12.2023',
#  'Sobre el famoso mapa de la España incorporada o asimilada...',
#  '🇲🇽 🇪🇸🤔¿QUE ESTA PASANDO EN ESPAÑA? 😬 mexicano reacciona a españa extranjero reaccionando a españa',
#  '&quot;BENDECIDOS&quot; (ANALISIS) @santasuertemusic8056 LOS GRANDES AUSENTES EN ESTE TEMA.',
#  '🇸🇻🇬🇹🇳🇮🇨🇷🇭🇳HISTORIA de la República Federal de CENTROAMÉRICA🇸🇻🇬🇹🇳🇮🇨🇷 🇭🇳 - El Mapa de Sebas',
#  '❗LO TENEMOS❗ España OFICIAL en Euro Truck Simulator 🚛💨 Mi primera ruta 🔥  🟥🟨🟥IBERIA DLC #1 🟩🟥',
#  'La Antigua Grecia - 5 cosas que deberías saber - Historia para niños - Grecia',
#  'AVANCE 2023 II !! RONDADOR, MEFISTO, BATTLEWORLD, DD7 y más de Marvel Strike Force en español',
#  'CONQUISTA DEL TERRITORIO COLOMBIANO   4',
#  'Alice  Madness Returns en Español - 05 Territorio del Sombrerero Pt 2 - 1080p 60fps',
#  'Extremeño CLASIFICA en una TIER LIST TODAS las COMUNIDADES AUTÓNOMAS de ESPAÑA',
#  'CONGRESO: APERTURA de la CORTES GENERALES de la XV LEGISLATURA | RTVE Noticias',
#  '🇲🇽 LA INDEPENDENCIA DE MEXICO Historia causa resumen',
#  'Territorio de leones: Rivales de sangre || Documentales nat geo wild Español 2020 HD',
#  'Vaguada sigue provocando lluvias en gran parte del territorio nacional',
#  'La Edad Media para niños - 5 cosas que deberías saber - Historia para niños',
#  '𝐄𝐥 𝐯𝐚𝐥𝐨𝐫 𝐝𝐞𝐥 𝐓𝐞𝐫𝐫𝐢𝐭𝐨𝐫𝐢𝐨: 𝐃𝐢𝐩𝐥𝐨𝐦𝐚𝐜𝐢𝐚 𝐏𝐫𝐞𝐯𝐞𝐧𝐭𝐢𝐯𝐚, 𝐌𝐞𝐝𝐢𝐚𝐜𝐢𝐨́𝐧 𝐲 𝐀𝐃𝐑’𝐒',
#  'El Pájaro Loco en Español | 1 Hora de Compilación | Dibujos Animados en Español',
#  '&#39;Napoleón&#39; de Ridley Scott y otros estrenos en La Ventana del Cine con Carlos Boyero',
#  '𝗚𝘂í𝗮 𝗱𝗲 𝗧𝗲𝗿𝗿𝗶𝘁𝗼𝗿𝗶𝗼𝘀, 𝗔𝘀𝗲𝗻𝘁𝗮𝗺𝗶𝗲𝗻𝘁𝗼𝘀 𝘆 𝗛𝗼𝘂𝘀𝗶𝗻𝗴',
#  'American Imperialism: Crash Course US History #28',
#  'KENT ES ESPAÑOL (Y CATALÁN) #podcast #territoriorevival #destacame #humor #lossimpson #shorts',
#  'ESPAÑOL PARA EXTRANJEROS _ Una breve Explicación del Sistema... _ Learn Spanish as a Second Language',
#  'Por el Derecho al Territorio: Segundo Momento',
#  'TERRITORIO de LEONES #2: CAZADOR de GIGANTES | Documental National Geographic (HD)',
#  '&quot;Chaitén Indómito&quot;, vivir debajo de la Montaña (Territorio Minchemawida) - Pamela Mayorga',
#  'Conoce a &quot;La Bestia&quot;, el tren que transporta a miles de migrantes',
#  'Don Diego cocina el Territorio Linares',
#  '¿Por Qué La Virgen de Guadalupe de México Ya Existía en España desde el año 1326?',
#  '✅ La historia de los CABALLEROS TEMPLARIOS en 10 minutos',
#  '“El territorio, la territorialidad y la territorialización.”',
#  'CONVOCAN AL FORO &quot;POLICÍA COMUNITARIA, DEFENSA DEL TERRITORIO Y LOS DERECHOS HUMANOS&quot;',
#  'Catalanes reaccionan por primera vez al HIMNO DE ESPAÑA | El PODCAST más ESPAÑOL - Cono-Cidos #2',
#  'Curso sobre Recuperación y Reafirmación de Territorios Indígenas',
#  'Ep. 117 - Fondos de búsqueda: el camino de la inversión - Territorio Negocios',
#  'Cómo Hacer un Mapa Mental Fácil y Rápido 😱 | (Paso a Paso con Ejemplos)',
#  'EVOLUCIÓN DEL TERRITORIO PERUANO',
#  'Arte, comunidad y territorio: una aproximación al patrimonio',
#  'ORGANIZADORES GRÁFICOS ✅ ¡FÁCILES DE HACER!',
#  'Pronostican ingreso de una onda tropical  al territorio nacional',
#  'ESPAÑOL PARA EXTRANJEROS __ práctica 2 _ Learn Spanish as a Second Language',
#  'Cartel De Santa &quot;Babo&quot; Escuchando a Santa Fe klan &quot;Cuidando El Territorio&quot; Ft Beto Sierra Calibre 50',
#  'DIRECTO | Sesión de Apertura de las Cortes Generales de la XV Legislatura | EL PAÍS',
#  '¡LO DIJIMOS! &quot;ISRAEL YA SABÍA DEL ATAQUE DE HAMÁS HACE MÁS DE UN AÑO&quot;, PUBLICA THE NYT',
#  'VENEZUELA CURIOSIDADES SOBRE ESTE PAIS. COMO ESTA CEDIENDO SU TERRITORIO PARA CREAR UN NARCO PAÍS.',
#  'TODO ES GEOPOLÍTICA | Europa frente a Rusia: &quot;Nuestra existencia depende de Ucrania&quot;',
#  'Etimologías curiosas',
#  'TERRITORIOS CON FUTURO ALCAÑICES 2023',
#  'Así será la futurista nueva capital de España. Argentinos reaccionan',
#  'Los hijos del sol: Los 14 incas del Tahuantinsuyo',
#  'Venezuela es un territorio sin ley',
#  'Primera Página | Entrevista con Oscar Arnal (1/2)',
#  'La Cacica María Panana (Pedaleando El Territorio)',
#  'CRYPTONEGOCIOS | España se lanza a por el dinero de las cryptos, CZ renuncia y la SEC contra Binance',
#  'ESPAÑOL PARA EXTRANJEROS __ práctica 1 _ Learn Spanish as a Second Language',
#  'Defendiendo el territorio y los derechos humanos frente al Proyecto Integral Morelos',
#  'REACCION a CUIDANDO EL TERRITORIO - SANTA FE KLAN, BETO SIERRA Y CALIBRE 50',
#  'Las Cruzadas en 14 minutos',
#  '¿Qué cambió en los territorios del rio de la Plata a partir de la revolución de Mayo de 1810?',
#  'Saturday Night Live;  La humillación a España por parte de Sánchez y Puigdemont',
#  '🇪🇸TIERLIST de COMUNIDADES AUTÓNOMAS *se acabo el debate*',
#  'Cómo viajar con tu mascota',
#  'Capítulo 7. Territorio',
#  'Santa Fe Klan x Calibre 50 x Beto Sierra - Cuidando El Territorio [Official Video]/REACCION🇲🇽 RIFADO',
#  'Donald Trump habla desde Florida tras declararse no culpable de cargos por delitos mayores',
#  'Persecución a la mafia en Calabria | DW Documental',
#  '&quot;No hay problema en analizar productos españoles&quot;',
#  'ELBIT SYSTEMS GANA CONTRATO ESPAÑOL UN VISTAZO A LOS SISTEMAS DE RADIOENLACE   TOP NOTICIAS',
#  'Un Mundo Verde - Territorio y Medio Ambiente',
#  'Antártida: Un mensaje de otro planeta | DW Documental',
#  'SPIDER T REX, SPIDER SPINOSAURUS &amp; SPIDER INDOMINUS REX!!! SUPER SPIDER-SAURIOS!!!',
#  '🇲🇽 🇪🇸 🤔&quot;EL ORIGEN DEL CAMINO DE SANTIGO&quot; Asi COMENZO TODO,🙂 mexicano reacciona a españa extranjero',
#  'DESPOBLACIÓN RURAL | ESPAÑA SE VACIA | VirAleX',
#  '¿Extinción  de Lenguas indígenas?',
#  'La GUERRA de SECESIÓN en 10 minutos | La Guerra Civil Estadounidense',
#  'HECTOR CARLOS JANSON - LA MONEDA CIRCULANTE EN EL TERRITORIO ARGENTINO 1574 - 2019',
#  'Resistencias comunitarias y defensa del territorio, México, 2013-2022',
#  'Plenaria 3: Migración y racismo_III Foro Mundial Ciudades y Territorios de Paz',
#  'Defensa confirma que dos españoles están retenidos por piratas',
#  '[En español] Discurso del presidente Biden sobre el Estado de la Nación',
#  'Que soy más español que tu! Una pol.la!',
#  '9° Seminario Chiloé: Historia del Contacto. Territorio histórico (4)',
#  '¿Baraja China las cartas en la guerra de Rusia contra Ucrania? | A Fondo',
#  '🚨ULTIMA HORA : Cazas de la OTAN son avistados cerca del territorio Ucraniano',
#  'Si [NOMBRE] lo dijera aquí | No nos queda más remedio que venir todos los días',
#  'Los mercados reaccionan negativamente a las noticias macro positivas. Por Yuri Rabassa',
#  'Territorio Comanche - Plagio',
#  '(Voces de los) Territorios Posibles por Utopías Reales (Ep. 8). Casos barrios &quot;Santa Ana&quot; y &quot;El Sol&quot;',
#  'GANADERO ESPAÑOL GALLEGO LA VERDAD SOBRE LOS INCENDIOS  en español cristiano',
#  'King Felipe VI of Spain attending the opening of parliament in 2023',
#  'NOTICIAS CINCO DÍAS 02 03 23 Onda Cádiz TV',
#  'Marina Lobo: Tellado, de Gamarra a Macarra',
#  'Real Madrid vs FC Barcelona (0-3) J17 2017/2018 - FULL MATCH',
#  'Chile: Evolución de los Límites y Ocupación del Territorio (Siglo XIX) 2021',
#  'Sorteo Samsung Galaxy S10+',
#  'Si CÉSAR lo dijera aquí | Hemos crecido en el país del &quot;no se puede&quot;',
#  'Murió Henry Kissinger, el hombre que odiaba a España',
#  'Así es el saqueo de los pescadores norcoreanos en aguas extranjeras',
#  'CONEXIÓN VILAR: El futuro de Ucrania, amenazado; Lagarde vuelve a hablar y oro en máximos históricos',
#  'La Revolución francesa en 14 minutos',
#  'La participación y la comunicación claves para la gestión ambiental del territorio.',
#  'El Sultán | Capitulo 39 Completo (4K)',
#  'DIRECTO | Pleno del Congreso de los Diputados | EL PAÍS',
#  'El negro de VOX HUMILLA a Ana Peleteiro: “RACISTA”',
#  'Quien hablar mejor Castellano? 🇦🇷 vs 🇪🇸',
#  'Sigue el tradicional desfile militar con el que México celebra la independencia',
#  'DIRECTO | Feijóo visita la Fundación Once del Perro Guía | EL PAÍS',
#  'Campañas 0% plásticos, Zero Waste y Territorio Tortuga de la Región de Murcia',
#  'Experiencias de investigación sobre el territorio en Uruguay, México y Guatemala',
#  'Pasó Antes De Irte a Dormir!Angelica Rivera Revela Datos Precisos sobre Fortuna De Peña En Una Isla!',
#  'SEÑOR GOLAZO COLOMBIANO EN CAMARA LENTA l CUADRADO EUROPA LEAGUE l MORELOS CRITICAS',
#  'Evento CYBERTRUCK TSLA',
#  'Las ZEDE, el polémico proyecto de &quot;ciudades privadas&quot; de Honduras - Documental BBC',
#  'Después de varios años malos, el sector del cerdo ibérico inicia una montanera con optimismo',
#  'PROGRES Españoles LLORAN por MILEI',
#  'POET Ordenamiento Ecológico del Territorio en México',
#  '100 PREGUNTAS de MÉXICO ¿Cuánto sabes México? 🧐🧐',
#  'A História de Portugal (Parte 1): A Origem dos Portugueses',
#  '#HECD, con Marina Lobo 346. La última de Ayuso, Letizia: pashmina y machismo y Salvini VS Meloni',
#  'Más se Perdió en Cuba | 02/12/23',
#  'Grave crisis diplomática entre España e Israel',
#  'Un MARROQUÍ D3G*ELLA a su MUJER en SAGUNTO',
#  'CITED 2023',
#  'INFORMATIVO: Israel planea una &quot;guerra larga&quot;, Rusia avanza, Zelensky presiona y Europa amenaza',
#  'Feijóo, &quot;el moderado&quot;, busca su sitio entre VOX, Ayuso y Aznar',
#  'VIAJO A EL SALVADOR',
#  'EE.UU e ISRAEL conocían el ataque. RUSIA arrincona a UCRANIA. MILEI aleja a ARGENTINA de los BRICS',
#  'El gobierno divide a los españoles y vende propaganda',
#  'DIPUTADO de SUMAR HACE el RIDÍCULO HABLANDO de FLAMENCOS y JOTAS | UTBED',
#  '7. The Songhai Empire - Africa&#39;s Age of Gold',
#  'Turismo. Simult. turismo e ciencias empresariais (poñente+alumnado) Xeografía ordenación territorio',
#  'Claves del día: Enfrentamiento total en Europa, Biden cuestionado y suenan las alarmas de la crisis',
#  'BIS narrativa y Rodrigo Rato',
#  '¿HABLAMOS DE GEOPOLÍTICA? Conflictos y guerras de El Esequibo a Gaza',
#  'The Animated History of Spain',
#  '¿Qué sabemos del próximo NACIONAL DE RAZAS? 🇪🇸 | Bernardino Crespo | Delegado de la RFEC 👌😊',
#  'DIRECTO | Presentación del libro &#39;El nacionalismo contra España&#39;',
#  'EL OBJETIVO de Rusia es CONQUISTAR NOVORROSSIYA',
#  'Kings of Cannabis (Full Length Documentary)',
#  'El Esequibo, unas tierras ricas en petróleo y minerales son de Venezuela… ¿o no?',
#  'GUYANA vs VENEZUELA en Poder Militar (2024)',
#  'MÁS AMENAZAS A RUSIA! AHORA UN BANCO EUROPEO',
#  'Conversando con Expertos | La CALIDAD DEL AIRE que respiramos',
#  'José Luis Escrivá, no sabe no contesta',
#  '&#39;YA DEBE SER DESTITUÍDA&#39; IÑAKI GABILONDO ESTALLA contra ISABEL DÍAZ ÁYUSO y PRESENTA PRUEBAS BOMBAS',
#  'Ayuso: “España no es propiedad de nadie, como tampoco lo son las banderas.”',
#  '💪 DESPIERTA  Esto NO ES una DEMOCRACIA.',
#  'Silvia Intxaurrondo, no sabe no contesta',
#  'ASI NOS RECIBE SENEGAL 🇸🇳 l ES COMO CREES? l La Vida de M',
#  'sabado',
#  'experiencias emprendedoras en Latinoamérica',
#  'Sergio Errasti. “No hay que tener miedo a la crítica”',
#  'Marina Lobo: paren el genocidio en Palestina',
#  'Dimisión del Primer Ministro Portugués Escándalo de Corrupción el Sector Litio y el Hidrógeno Verde',
#  '2 caminos: las &quot;paguitas&quot; de Ayuso',
#  'El &quot;deber&quot; de la Policía de pegar patadas a las puertas. Por Marina Olmo en @conlavendasenoria3549',
#  'Aproveche oferta AVLO de 7€ a Madrid y como no quería levantarme tan temprano de regreso pagué 15€',
#  'los jóvenes no defienden España, pero si, a Palestina! 😅',
#  'La tierra, al igual que nuestras aventuras, no es plana. #AventuraConDacia #VidaAlAireLibre\u200b\u200b',
#  'ES OFICIAL 🌍\u200b Ya estamos también en… #TikTok \u200b',
#  'Caporales',
#  'Consumo y venta #españatiktok #clavero #travelvlog #podcast #short #podcastespanol #drug',
#  'CLÍTORIS - ¿Cómo tener mejores orgasmos?',
#  'V1r91n T3rr1t0ry  (Legend) S3x',
#  'eeuu autoatentado para invadir y arrevatar los territorios españoles  voladura del maine']

# %%
channel_ids = []  
for item in all_video:
    channelId = item['snippet']['channelId']
    channel_ids.append(channelId)  

print(channel_ids)
# Out:
# ['UCPH3Oz99Y_jrVBCQMjQZNSg', 'UCUBIrDsIVzRpKsClMlSlTpQ', 'UCaSdpaCk2nyPlxj6im46rOQ', 'UCPd6b5PgGntDkBZM1Rf7WfA', 'UCyuH8LBMElHDwMaSa_kZadA', 'UC9-Ocoo9d6Zv8SbV3Dad1Tw', 'UCDXkJkTdneBkEgj58nZ2njg', 'UCUBIrDsIVzRpKsClMlSlTpQ', 'UCa36RF44tVxE9ETZn_-RQhw', 'UCTyCyyV0eKfEoMWI_V11z6A', 'UC7h4VKkd9q9dJQFf9Kfm7SA', 'UCABPlDrpGug7skYJVJuNyhg', 'UC8RpuQuJeE7CMmLOdmEP-kA', 'UC7h4VKkd9q9dJQFf9Kfm7SA', 'UCTyCyyV0eKfEoMWI_V11z6A', 'UCPH3Oz99Y_jrVBCQMjQZNSg', 'UCoLoHvInVxTV_Xpd7eoSPUw', 'UCLzgGM7q2bXebJUs7cymdhg', 'UCUBIrDsIVzRpKsClMlSlTpQ', 'UCs36uUgPco_MLaPXFDpnRTA', 'UC1Tyf256hkcyNQj5PwIPxrw', 'UCPH3Oz99Y_jrVBCQMjQZNSg', 'UCsK-7018T5DU-Gl5-4ythXw', 'UCPH3Oz99Y_jrVBCQMjQZNSg', 'UCQk649RsSqo3QNJbywjPoOg', 'UCBdq2IZdl8bp1OOg5BNawuQ', 'UCwRvBitYM27PF-Yz2LSfABA', 'UCJQQVLyM6wtPleV4wFBK06g', 'UCVk5W9rA2TCJ4B_U_H4bTNA', 'UCv05qOuJ6Igbe-EyQibJgwQ', 'UCy7aAIBUtGqqTVDezGO85hg', 'UCUBIrDsIVzRpKsClMlSlTpQ', 'UCT4Jg8h03dD0iN3Pb5L0PMA', 'UCRKLoUGHLEeSoEF2zsuK80w', 'UCPH3Oz99Y_jrVBCQMjQZNSg', 'UCv05qOuJ6Igbe-EyQibJgwQ', 'UCAbEJ9HByWPPk4Vkxvl7cWA', 'UCUBIrDsIVzRpKsClMlSlTpQ', 'UCQ1GpKa15ulyoQuxz7H4rng', 'UCPH3Oz99Y_jrVBCQMjQZNSg', 'UC9eCLBSj2fCYUsnMuelRloQ', 'UCBIMW0ZhwULY_x7fdaPRPiQ', 'UC8FOhz3iXhF1iqqzAFfBjmA', 'UCBWF6OT9sHQU0rnMmUPdmyA', 'UCv05qOuJ6Igbe-EyQibJgwQ', 'UCaSdpaCk2nyPlxj6im46rOQ', 'UCUdOoVWuWmgo1wByzcsyKDQ', 'UCTcKWYz0sGoExKZ4unKB5Iw', 'UCVbOEcs6RMxXXX3WWNtl_Fw', 'UCoLoHvInVxTV_Xpd7eoSPUw', 'UCbn50nb9GIQFgsF0ehI6q_g', 'UCBWF6OT9sHQU0rnMmUPdmyA', 'UCUBIrDsIVzRpKsClMlSlTpQ', 'UCoLoHvInVxTV_Xpd7eoSPUw', 'UCUdOoVWuWmgo1wByzcsyKDQ', 'UCRwA1NUcUnwsly35ikGhp0A', 'UCUdOoVWuWmgo1wByzcsyKDQ', 'UCdwdFOhBP9CoAOlHDTmTxaw', 'UC32TdiIsh_5X8tKr_9rKQyA', 'UCUdOoVWuWmgo1wByzcsyKDQ', 'UCUBIrDsIVzRpKsClMlSlTpQ', 'UCRG1KLrHnVA6P7U1_TSrjJg', 'UCnsvJeZO4RigQ898WdDNoBw', 'UCv05qOuJ6Igbe-EyQibJgwQ', 'UCv05qOuJ6Igbe-EyQibJgwQ', 'UCT4Jg8h03dD0iN3Pb5L0PMA', 'UCuTSm59-_kap6J7Se-orUVA', 'UCQ1GpKa15ulyoQuxz7H4rng', 'UCT4Jg8h03dD0iN3Pb5L0PMA', 'UCBWF6OT9sHQU0rnMmUPdmyA', 'UCTbq9VeVkmIIEocCDuk5ZEw', 'UC5BW1w7JyJW3r8rpR3BhqKA', 'UCT4Jg8h03dD0iN3Pb5L0PMA', 'UCUBIrDsIVzRpKsClMlSlTpQ', 'UClqo4ZAAZ01HQdCTlovCgkA', 'UCa2yQjbhV7-zMdygwZRFxYQ', 'UC3loD3RAic8B5S90ytaGUXw', 'UCQ1GpKa15ulyoQuxz7H4rng', 'UChmLIRBQh3-bRJp3d6Dnnog', 'UCeymXIrIhMYFmCNIlwrl9Lw', 'UCUBIrDsIVzRpKsClMlSlTpQ', 'UCqvfv4s7PNotHThoYrjIeeg', 'UCr3uN7S9LclosH-scrriniw', 'UCsT0YIqwnpJCM-mx7-gSA4Q', 'UCv05qOuJ6Igbe-EyQibJgwQ', 'UCBWF6OT9sHQU0rnMmUPdmyA', 'UCVbOEcs6RMxXXX3WWNtl_Fw', 'UCv05qOuJ6Igbe-EyQibJgwQ', 'UCv05qOuJ6Igbe-EyQibJgwQ', 'UC40FZRPiODzhhuJA77M01xA', 'UCwtbypfjdw1yblETfqimCtA', 'UCUdOoVWuWmgo1wByzcsyKDQ', 'UCv05qOuJ6Igbe-EyQibJgwQ', 'UCPH3Oz99Y_jrVBCQMjQZNSg', 'UCv05qOuJ6Igbe-EyQibJgwQ', 'UC49nxT5gHSKm2_ha3NfTJtQ', 'UCv05qOuJ6Igbe-EyQibJgwQ', 'UCiP5vmNYR-LuUA3LARZBAoQ', 'UC40FZRPiODzhhuJA77M01xA', 'UCQ1GpKa15ulyoQuxz7H4rng', 'UCT4Jg8h03dD0iN3Pb5L0PMA', 'UCVbOEcs6RMxXXX3WWNtl_Fw', 'UCv05qOuJ6Igbe-EyQibJgwQ', 'UC9KM79hqjtuEMWMA9OOGoFw', 'UC9KM79hqjtuEMWMA9OOGoFw', 'UCuTSm59-_kap6J7Se-orUVA', 'UCPH3Oz99Y_jrVBCQMjQZNSg', 'UC1Z-hdMqVBSmGKuiMGPcPNw', 'UCJQQVLyM6wtPleV4wFBK06g', 'UCv05qOuJ6Igbe-EyQibJgwQ', 'UCQ1GpKa15ulyoQuxz7H4rng', 'UCVimQoXNCZuEnZRVAbuYMiw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCVbOEcs6RMxXXX3WWNtl_Fw', 'UCUBIrDsIVzRpKsClMlSlTpQ', 'UChrsTAJloNe_vCB6P8AIhiw', 'UCv05qOuJ6Igbe-EyQibJgwQ', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UC6PvaaFrODFBfNnvG8FR4Zg', 'UC40FZRPiODzhhuJA77M01xA', 'UCE3m5uW9fUnf_tuKsVAmVPw', 'UCUBIrDsIVzRpKsClMlSlTpQ', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCpyYUq9kcBMLPlfE8EzguvA', 'UCpFPwQOxBz6czUgNOC3dedQ', 'UCy7aAIBUtGqqTVDezGO85hg', 'UCdwdFOhBP9CoAOlHDTmTxaw', 'UCvNgezaSEik4utMSN4mt0OQ', 'UC95c0HfSrOyQlkGOJZ-Y_Gg', 'UCUdOoVWuWmgo1wByzcsyKDQ', 'UCv6tgIHROFZiDtK0wv4ujZQ', 'UCa2yQjbhV7-zMdygwZRFxYQ', 'UCjv-ybGow0ChcTBOi5ebyhQ', 'UCBWF6OT9sHQU0rnMmUPdmyA', 'UCLN2yXoHn-tYuaXHvLIdVrw', 'UCeDNjau4QiuaMfp4m7SMxLw', 'UCa2yQjbhV7-zMdygwZRFxYQ', 'UCBWF6OT9sHQU0rnMmUPdmyA', 'UC3bRVqfLpexxvzmoIyYc-KQ', 'UCpyYUq9kcBMLPlfE8EzguvA', 'UCZJVasw883s8g_2hUru51EQ', 'UCUBIrDsIVzRpKsClMlSlTpQ', 'UCPH3Oz99Y_jrVBCQMjQZN ...

# %%
len(channel_ids)
# Out:
# 719

# %%
video_ids = []  # Lista para almacenar los videoIds

# Iterar sobre cada elemento de all_videos
for video_info in all_video:
    # Acceder a la clave 'id' y luego a 'videoId'
    video_id = video_info.get('id', {}).get('videoId') #.get() para acceder al valor de 'videoId' dentro de la estructura del diccionario. Si se encuentra un 'videoId', se agrega a la lista video_ids.
    
    # Verificar si se encontró el 'videoId' y agregarlo a la lista video_ids
    if video_id:
        video_ids.append(video_id) 
    else:
        # Si no se encuentra el 'videoId', agregar None a la lista video_ids
        video_ids.append(None)

# %%
len(video_ids)
# Out:
# 719

# %%
v_title = []
for item in all_video:
    video_title = item['snippet']['title'] 
    v_title.append(video_title)
    print(video_title)
# Out:
# 🌍 TERRITORIOS ESPAÑOLES  fuera de ESPAÑA 🌍 | la ESPAÑA desconocida
# Por qué Ceuta y Melilla pertenecen a España si están en África
# ¿Por que España tiene un territorio atrapado en Francia?
# Fueron territorios de ESPAÑA pero YA NO hablan español 😱
# ESTO PIENSO sobre  España y los Españoles ¿Son raros?
# Mi OPINIÓN Sobre ESPAÑA y los ESPAÑOLES
# España es un país hecho para la guerra descubre el porque 🤯😵
# Por qué la América española se dividió en muchos países y Brasil quedó en uno solo | BBC Mundo
# 5 Territorios españoles que quizás no conoces
# Aprender español: Comunidades autónomas de España (nivel básico)
# 5 países que fueron territorios españoles pero no hablan español ¿¿O SI??
# Todo sobre ESPAÑA | Cultura, datos y curiosidades
# Territorios Menos Conocidos del Imperio Español
# 5 islas del pacifico que aun podrían ser territorio español
# Aprender español: Geografía de España (nivel básico)
# ⚠️¿Por qué ESPAÑA NO entró en la SEGUNDA GUERRA MUNDIAL?⚠️
# Esclavos negros en territorio español
# España es África, en parte
# El origen del conflicto en el Sahara Occidental (y qué papel tiene España)
# 😱🇪🇦Mi honesta opinión sobre ESPAÑA¡COSTUMBRES ESPAÑOLAS QUE ME HAN SORPRENDIDO !
# ¡NO PUEDE SER!😲Entrevista a EXTRANJEROS🎤¿ESTO OPINAN DE ESPAÑA? 🇪🇸
# ✅ La CONQUISTA y COLONIZACIÓN española de AMÉRICA | Historia, mitos, verdades, leyenda negra...
# TERRITORIOS ESPAÑOLES fuera de ESPAÑA 🌍 | REACCIONANDO por PRIMERA VEZ
# ✅ La HISTORIA DE ESPAÑA en 15 minutos | El RESUMEN definitivo
# Territorios de España que no conocías🇪🇦 | Curiosidades Geográficas🌍
# EL VIRREINATO DE NUEVA ESPAÑA
# 30 Datos y Curiosidades que no sabías de España
# ¿Por qué GIBRALTAR es el lugar más EXITOSO de EUROPA? - VisualPolitik
# NO ENTIENDO A LOS ESPAÑOLES 🇪🇸🇨🇺. 7 meses en España|@DanyLike
# Breve historia del nacionalismo vasco
# LOS SIMPSON MUY ESPAÑOLES Y MUCHO ESPAÑOLES
# Por qué Filipinas no es hispanohablante si fue una colonia de España durante 300 años  | BBC Mundo
# El Salvador: el Estado ya controla el 80% del territorio del país
# Diálogos de España en América V: España en el territorio de los actuales EEUU.
# 🔥 La CRISIS del SÁHARA OCCIDENTAL en 8 minutos 🔥 | ¿Qué está pasando en el SÁHARA OCCIDENTAL?
# El franquismo
# MEXICANO REACCION A LA MENTIRA SOBRE ESPAÑA, LA VERDAD EN ESPAÑA @DarwinDeViajes
# ¿Cómo sería México si Estados Unidos no se hubiera apropiado de más de la mitad de su territorio?
# Andalucía, España - Viaje por el Mediterráneo | DW Documental
# ✅ CURIOSIDADES sobre ESPAÑA en 1 minuto
# Así empezó el Alzamiento Nacional en julio de 1936  | España dividida: La Guerra Civil en color
# HISTORIA DE ESPAÑA - Antigua y Medieval - Hasta 1492 - (Documental resumen)
# Los cinco primeros sobres interceptados fueron enviados desde territorio español
# La EXPANSIÓN EUROPEA entre los Siglos XV y XVIII  | Portugal, España, Países Bajos, Francia...
# La Guerra Civil española
# ¿Por qué Bolivia perdió territorios contra Brasil? #shorts
# FRANCE 24 Español – EN VIVO – Información internacional y noticias del mundo 24 horas
# Permiso de estudios en el territorio español o visado de estudios en el Consulado de España
# 🔥La GUERRA CIVIL ESPAÑOLA🇪🇸 en 13 minutos 🔥 - El Mapa de Sebas
# ¿Esclavos negros en territorio español?
# los territorios español la fuerza española
# La ÉPOCA COLONIAL en Hispanoamérica - Resumen | Organización Política, Económica y Social.
# El Esequibo, el territorio que enfrenta a Venezuela y Guyana desde hace casi dos siglos | BBC Mundo
# ¿Esclavos negros en territorio español?
# La carrera contrarreloj en Alemania para juzgar a los últimos nazis de la Segunda Guerra Mundial
# Así reaccionan playistas que captan llegada de inmigrantes | Noticias Telemundo
# En visita a Nueva Caledonia, Emmanuel Macron aseguró que seguirá siendo territorio francés
# Gibraltar, el lugar más extraño de Europa
# “La frontera partió nuestro territorio”: los indígenas que pueden votar en México y en Estados Unido
# Se aproxima el fenómeno de El Niño y varios países sienten las consecuencias
# 3 cosas que cambian para los venezolanos en EE.UU. tras el acuerdo de Biden con México | BBC Mundo
# La España que está en todos los territorios de España.
# ¿Cuál es el ORIGEN de la GUERRA DE UCRANIA? | EL PAÍS
# Napoleón Bonaparte y las guerras napoleónicas
# La Segunda Guerra Mundial en 17 minutos
# BRICS, el brazo económico del nuevo Sur Global frente a Occidente
# Los depredadores de África en acción | Ríos de África | Animal Planet
# Geopolítica sobre los escombros de la Unión Soviética | DW Documental
# El atractivo y la política económica de México dan alas al &quot;superpeso&quot;
# La DESCOLONIZACIÓN de África y Asia - Resumen | La independencia de la India, Argelia, Egipto...
# 💃 Cómo RECONQUISTAR los territorios americanos del IMPERIO ESPAÑOL (Parte 2) Victoria 2
# ¿Qué pasaría si Cristóbal Colón no hubiera descubierto América?
# El Salvador: el Estado ya controla el 80% del territorio del país
# Por qué Jerusalén es clave en el conflicto entre israelíes y palestinos | BBC Mundo
# Confusión por altercado entre militares de México y EU
# HISTORIA DE GALICIA EN 10 MINUTOS
# Organización Colonial
# Rumbo al corazón de la Patagonia | DW Documental
# La REVOLUCIÓN FRANCESA | Draw My Life
# SKODA IRRITA a VOLKSWAGEN POR... ¿HACERLO DEMASIADO BIEN? LO QUE DEBES SABER
# Los polémicos videos racistas que youtubers chinos graban en África para ganar dinero
# Marcando territorio
# 🚀 El Increíble PLAN de BRASIL para Expandir su Territorio 🌍 | Cambiará el Mapa Mundial
# Como hacer 1 doctorado: lo que no te han contado, ni te contarán | José Luis Arroyo | TEDxManzanares
# El nacimiento del Estado Moderno en 15 minutos
# El LIBERALISMO - Resumen | Liberalismo Político y Liberalismo Económico
# 🇫🇷El MAPA antes y después de NAPOLEÓN Bonaparte 🇫🇷 - El Mapa de Sebas
# El conflicto palestino-israelí (resumen histórico)
# La Guerra de Vietnam
# Los Reyes Católicos en 10 minutos! | El reinado de Isabel y Fernando
# Union Española 0 - Universidad de Chile 2 - Territorio Hispano
# &quot;Argentina entra en territorio desconocido&quot;: &#39;El País&#39; tras la victoria del ultra Milei en las PASO
# La expansión del islam
# La REVOLUCIÓN CUBANA en 10 minutos | Breve historia de CUBA
# Stalingrado, el ocaso del III Reich
# La Guerra de la Independencia Española
# ¿Por qué perdió Alemania la Segunda Guerra Mundial?
# ASÍ SE VIVE EN ISLANDIA: ¿El país más extraño del mundo?
# ¿4.200.000 en casi 30 años? La gran inmigración en Argentina (1880 a 1914)
# Los ricos, los pobres y la basura | DW Documental
# La desinformación en la invasión rusa a Ucrania
# 🇳🇱🇳🇱HISTORIA del IMPERIO NEERLANDÉS en 13 minutos 🇳🇱🇳🇱 - El Mapa de Sebas
# El nacimiento del Estado Moderno en 15 minutos
# LA REALIDAD SUPERA LA FICCION* MEXICANO REACCIONA A LA ARMADA ESPAÑOLA RESCATE DE CIUDADANA FRANCESA
# REACCIONANDO A ¿ES POSIBLE INVADIR ESPAÑA EN LA ACTUALIDAD?
# Los depredadores de África en acción | Ríos de África | Animal Planet
# La REVOLUCIÓN CUBANA en 10 minutos | Breve historia de CUBA
# ¿Cuál de los siguientes TERRITORIOS no son entidades locales? [LANDLFORMACION] #shorts
# El SAHARA OCCIDENTAL: ¿La última COLONIA de ESPAÑA?   - VisualPolitik
# ¿Quién llegó a América antes que Colón?
# El País Vasco y la ETA | DW Documental
# El litio latinoamericano “preocupa” a EE.UU. ¿Por qué y qué esperar? | Inna Afinogenova
# CONGRESO: El DISCURSO de ARMENGOL, que NO ha GUSTADO a la OPOSICIÓN (ÍNTEGRO) | RTVE Noticias
# 🇨🇴¿Por qué COLOMBIA perdió PANAMÁ? (Sí. ¡Fueron un solo país!) 🇵🇦 - El Mapa de Sebas
# Cómo Puerto Rico se convirtió en un territorio de Estados Unidos | BBC Mundo
# 🇲🇽 🇪🇸 reaccion 😱&quot;ESTE ES EL VERDADERO PODER MILITAR DE ESPAÑA&quot; Mexicano reacciona a españa
# La expansión del islam
# Un ESPAÑOL en las FILAS de ZELENSKI: &quot;Los ucranianos no se rendirán en la vida&quot; | RTVE Noticias
# 1. ¿Qué es y para qué sirve la Constitución?
# ¿4.200.000 en casi 30 años? La gran inmigración en Argentina (1880 a 1914)
# Los Viajes de Cristobal Colón | Videos Educativos Aula365
# ¿Se dice español o castellano?
# SÁNCHEZ: &quot;Tengo FRANCAS DUDAS de que ISRAEL esté cumpliendo con el DERECHO INTERNACIONAL&quot; | RTVE
# La majestuosa águila real | National Geographic España
# LA INDEPENDENCIA DE MÉXICO en minutos
# Territorio Revival | 2x19 | Los Simpson: Doblaje ft. David García Vázquez
# Orden de Malta, el país sin territorio
# SORTEO DE UN JAMÓN CURADO, EN TERRITORIO ESPAÑOL PENINSULAR. JAMÓN DEL SUPERMERCADO PERÁN.
# 🚨 ULTIMA HORA BARÇA 💣¡LAPORTA y GASPART EXPLOTAN!🔥PALANCA TODIBO - REUNIÓN GUNDOGAN y CHRISTENSEN
# Cómo México perdió más de la mitad de su territorio contra Estados Unidos
# 💪MILITAR ® COLOMBIANO REACCIONA Arges Artiaga: Un español contra el Est*do Isl*mico💪
# HISTORIA DE GALICIA EN 10 MINUTOS
# España Territorio de Innovación Bibliotecaria
# El LIBERALISMO - Resumen | Liberalismo Político y Liberalismo Económico
# ¿Qué es la interculturalidad?
# Guerra Civil Española: Exhumación en Farlete | Territorio Vivo ATV 252
# HISTORIA DE ANDALUCÍA EN 10 MINUTOS
# ¿Cómo se formaron las Primeras CIVILIZACIONES? - Resumen | El Surgimiento de la Civilización.
# ✅ ¿Por qué ÁFRICA es tan POBRE y por qué puede ser la próxima SUPERPOTENCIA?
# La esposa de Lot y el monte Sodoma | NATIONAL GEOGRAPHIC ESPAÑA
# Territorio Fútbol
# 6 conflictos armados que están ocurriendo en el mundo más allá de Rusia y Ucrania | BBC Mundo
# Resumen. La GUERRA CIVIL ESPAÑOLA en 7 minutos // +HD
# La Guayana Esequiba, el rico territorio que Venezuela quiere recuperar ¿Por qué?
# Los ricos, los pobres y la basura | DW Documental
# ✅ ¿Por qué LATINOAMERICA es MÁS POBRE que ESTADOS UNIDOS y CANADÁ? ¿Y cómo puede dejar de serlo?
# 3 cosas que cambian para los venezolanos en EE.UU. tras el acuerdo de Biden con México | BBC Mundo
# 👨‍👩‍👧‍👦 La POBLACION 👨‍👩‍👧‍👦 para NIÑOS de PRIMARIA
# MUNDO EN GUERRA | Europa contra sus miembros, Blinken corre a Israel y la opinión de China
# 🇧🇪Historia de BÉLGICA en 16 minutos y 13 mapas  (resumen) 🇧🇪 - El Mapa de Sebas
# El territorio más aislado de EE. UU. | GUAM 🇬🇺🇺🇸
# 🇪🇸¿Por qué ESPAÑA fue NEUTRAL durante la Segunda GUERRA Mundial? 💣 🔥 - El Mapa de Sebas
# MUNDO EN GUERRA | Europa contra sus miembros, Blinken corre a Israel y la opinión de China
# Rebeliones indígenas en América | Resistencia indígena
# Políticas Activas de Empleo: personas y territorio
# ¿De dónde son los mapuche?
# ¿Por qué los españoles utilizan &quot;vosotros&quot; y los latinos no?
# AtE La ingeniería española en los territorios de Ultramar un homenaje en su tricentenario
# ¿Cuál es el origen del conflicto en los territorios de los indígenas mapuches?
# Territorios de Latinoamerica que fueron Colonizados por otros Países Europeos.
# ✅✅✅ Evolución GEOLÓGICA de la PENÍNSULA IBÉRICA ✅✅✅
# EL VIRREINATO DEL RIÓ DE LA PLATA en minutos
# 🇲🇽 🇪🇸🤔&quot;Por ESTO CUBANA SE SIENTE ESPAÑOLA&quot; mexicano reacciona a españa extranjero reaccionaa a españ
# La Caída del Imperio Incaico - La Guerra Civil Inca # 1
# Seminario 6 b REHT: Daniel Tirado &quot;Capital humano y territorio en la historia&quot;
# Union Española 0 - Universidad de Chile 2 - Territorio Hispano
# Huáscar: el barco que divide a Chile y a Perú | BBC Mundo
# CIVILIZACIÓN MAYA
# El enigma del origen (y otras curiosidades) del euskera, la singular lengua de los vascos
# Se aproxima el fenómeno de El Niño y varios países sienten las consecuencias
# Google: las preguntas más buscadas sobre América Latina
# ⚔ CONQUISTA y COLONIZACIÓN de AMÉRICA ⚔ para NIÑOS
# 🚀 El Increíble PLAN de BRASIL para Expandir su Territorio 🌍 | Cambiará el Mapa Mundial
# ¿Reacción Inesperada de Cuba al Ver la Fuerza Militar de España? 🤔
# Por Qué Vive Tan Poca Gente en Esta ENORME ZONA del Centro de España
# ¿Y si COLÓN NO hubiese DESCUBIERTO AMÉRICA?
# 🚨 EXCLUSIVO: ¡España Refuerza Seguridad en Letonia! 🇪🇸🔍 Nuevos Sistemas de Vigilancia para la OTAN🛡️
# Cómo perdió Bolivia su salida al mar ante Chile (y en qué le afecta realmente)
# El caso de los 5 misioneros que fueron asesinados por una tribu aislada en Ecuador
# Carlos III, el mejor alcalde de Madrid
# 🚨 Preparativos Militares en España: ¿Se Avecina un Ataque Químico o Biológico? 🛑 Análisis 2023
# “Integración del territorio nacional y defensa geocultural argentina” Prof. Roberto Magliano
# Qué TERRITORIO RECLAMA GUATEMALA a MÉXICO?
# Escándalo en España de la lista de los Next Generation: ahora se entiende por qué la escondían
# La pérdida de los últimos territorios de ultramar
# &quot;Argentina entra en territorio desconocido&quot;: &#39;El País&#39; tras la victoria del ultra Milei en las PASO
# Cómo fue la Gran Colombia, la ambiciosa república que dio lugar a 4 países de América Latina
# LA INDEPENDENCIA DEL PERÚ en minutos
# ✅ La GUERRA DEL GOLFO en 10 minutos | La primera GUERRA televisada de la historia
# EL IMPERIALISMO en 6 minutos
# Cómo fue la guerra más sangrienta de la historia de América Latina | BBC Mundo
# GUERRA UCRANIA: RUSIA AMENAZA con una ESCALADA BÉLICA, tras la REUNIÓN en RAMSTEIN | RTVE Noticias
# 🇪🇸¿ESTE PAÍS POSEE ESTO EN TODO SU TERRITORIO⁉️ España | RoKush0 informa
# Mi review de Napoleón I Todo mal en mi mayor decepción
# Moreira podrá salir del territorio español  / Yuriria Sierra
# El Esequibo, el territorio que enfrenta a Venezuela y Guyana desde hace casi dos siglos | BBC Mundo
# Geopolítica sobre los escombros de la Unión Soviética | DW Documental
# Los polémicos videos racistas que youtubers chinos graban en África para ganar dinero
# 🇪🇸 ESPAÑOLES REACCIONAN a LOS 10 PAÍSES con MÁS CIUDADANOS en MÉXICO 🇲🇽😱 *NO ESPERÁBAMOS ESTO*
# 15 actuales paises que antes pertenecian a MEXICO, virreynato de la nueva España
# Structurer l&#39;argumentation : les connecteurs logiques - Espagnol - Terminale - Les Bons Profs
# MEXICANO REACCION A LA MENTIRA SOBRE ESPAÑA, LA VERDAD EN ESPAÑA @DarwinDeViajes
# ¿Y si COLÓN NO hubiese DESCUBIERTO AMÉRICA?
# España Territorio de Innovación Bibliotecaria
# Qué TERRITORIO RECLAMA GUATEMALA a MÉXICO?
# Cómo fue la guerra más sangrienta de la historia de América Latina | BBC Mundo
# ¿Qué buscan realmente las tropas rusas en Nicaragua? | Contexto DW
# Cómo Israel se Convirtió en el País más Avanzado en Agricultura
# FRANCE 24 Español – EN VIVO – Información internacional y noticias del mundo 24 horas
# El IMPERIALISMO durante el Siglo XIX - Resumen | El Imperialismo en África y en Asia.
# Territorio Revival | 1x20 | Bob Esponja ft. Álex Saudinós
# Reflexiones sobre el Territorio como bien de Derecho Público
# Escándalo en España de la lista de los Next Generation: ahora se entiende por qué la escondían
# ¿Bolivia realmente perdió tantos territorios? -Video opinión-
# NO ENTIENDO A LOS ESPAÑOLES 🇪🇸🇨🇺. 7 meses en España|@DanyLike
# Cómo empezó la guerra de Corea y qué tuvo que ver EE.UU. en ese conflicto | BBC Mundo
# La Conquista de México en 10 minutos! | Hernán Cortés y el Imperio Azteca
# Un viaje por Corea del Norte | DW Documental
# #ContraPrograma REPASO de la ACTUALIDAD SEMANAL (con Manu Levin y Paula Pof) | PANDEMIA DIGITAL
# La Primera Guerra Mundial
# 🇨🇱⚔︎🇵🇪🇧🇴La GUERRA del PACÍFICO (o del GUANO y el SALITRE) en 11 minutos 🇨🇱⚔︎🇵🇪🇧🇴 - El Mapa de Sebas
# De los Territorios No Autónomos: Aproximaciones, Miradas y Perspectivas
# REACCION a CUIDANDO EL TERRITORIO - SANTA FE KLAN, BETO SIERRA Y CALIBRE 50
# Territorio Revival | 2x33 | Indiana Jones ft. Ernesto Sevilla
# La Guayana Esequiba, el rico territorio que Venezuela quiere recuperar ¿Por qué?
# TODO ES GEOPOLÍTICA | EEUU y Europa podrían dejar sin ayudas a Ucrania, Irán carga contra Biden
# Entrevista News | Pompeyo Torrealba: no queremos territorio de Guyana
# Alejandro Magno y el Imperio de Macedonia
# Territorio de leones: Rivales de sangre || Documentales nat geo wild Español 2020 HD
# Israel llama a consultas a su embajadora en España tras declaraciones de Pedro Sánchez • FRANCE 24
# Métodos para evaluar los riesgos
# ¿Qué opinan los alemanes? | Berlín político
# Volvo XC40 SUV | Primera prueba / Test / Review en español | coches.net
# ¿Qué Armas de Fuego y Calibres Están Permitidos para Civiles en México?
# La pérdida de los últimos territorios de ultramar
# Las noticias económicas más destacadas de la semana
# CONEXIÓN VILAR: El futuro de Ucrania, amenazado; Lagarde vuelve a hablar y oro en máximos históricos
# Las 10 Fases del Genocidio
# SANCHEZ MANDA AL NÚMERO 2 DEL PSOE  RENDIR ESPAÑA A UN GOLPISTA EN SUIZA
# Cómo Panamá ha pasado de ser un ejemplo de prosperidad y estabilidad a vivir masivas protestas
# NO SE VIVE MEJOR QUE EN ESTE PAÍS
# ¿ANDALUCIA COLONIA INTERIOR? | ZONA COMANCHE
# Proceso de formación del territorio argentino
# ✅ ¿Por qué ÁFRICA es tan POBRE y por qué puede ser la próxima SUPERPOTENCIA?
# Arqueología encontrada en la ruta del Tren Maya
# 60 CURIOSIDADES💥 que no SABÍAS🤔 sobre ESPAÑA🇪🇦 HACE 5 MINUTOS⏰️ /Cubano Reacciona 2023
# La Conquista del Perú en 10 minutos! | Francisco Pizarro y el Imperio Inca
# Más se Perdió en Cuba | 02/12/23
# TERRITORIO de LEONES #2: CAZADOR de GIGANTES | Documental National Geographic (HD)
# ¿Por qué perdió Alemania la Segunda Guerra Mundial?
# FRANCIA ALERTA con ESPAÑA ¡A-FOX para TARSIS! ¿MISIL FNSM en 2035?
# Mundo Maldini
# ¿Es ESPAÑA el país que PEOR ha GESTIONADO el CORONAVIRUS? - VisualPolitik
# ¿Qué piensan los rusos de la guerra?
# EEUU: Más armas que habitantes | Españoles en conflicto
# 🇫🇷El MAPA antes y después de NAPOLEÓN Bonaparte 🇫🇷 - El Mapa de Sebas
# ASENTAMIENTO INGLÉS EN TERRITORIOS ESPAÑOL EN ÁFRICA
# TERRITORIO — trailer
# V. completa: “Hablar en público es un privilegio que deberíamos aprovechar”. Manuel Campo Vidal
# 🇬🇾HISTORIA de GUYANA en 9 minutos 🇬🇾 - El Mapa de Sebas
# 30 Curiosidades que no Sabías sobre Turquía | La cuna del Imperio Otomano
# Marruecos ame.naza la soberanía de España:«Ceuta y Melilla son territorios marroquíes como el Sáhara
# ¿POR QUÉ PERÚ PERDIÓ TANTO TERRITORIO? || HISTORIA TERRITORIAL DEL PERÚ
# GUERRA: RUSIA acusa a UCRANIA de intentar MATAR a PUTIN en un ATAQUE con DRONES al KREMLIN | RTVE
# Conoce las misiones a Día de hoy en las que se encuentra el ejercito español ,Cubano reacciona
# Ciclo Territorio y poder (y 4) La frontera oriental de Europa
# Asómate a la UAM: Grado en Geografía y Ordenación del Territorio
# CONSTRUYAMOS TERRITORIOS LIBRES DE VIOLENCIAS MACHISTAS Viernes 15 octubre
# Versión Completa. Lo que nos enseña la naturaleza. Joaquín Araújo, naturalista y escritor
# La Guerra de Vietnam
# ¿Latino o hispano? Cómo se usan estos términos en Estados Unidos | BBC Mundo
# JORNADA INFORMATIVA ‘LISTA (LEY DE IMPULSO PARA LA SOSTENIBILIDAD DEL TERRITORIO DE ANDALUCÍA)’
# La verdad sobre la moda rápida - ¿Mienten los fabricantes de moda a sus clientes? | DW Documental
# Militares del Grupo Wagner bloquean el centro de Rostov del Don, territorio ruso
# GARFIO ¿HÉROE O VILLANO? #territoriorevival #podcast #humor #viral #parati #peterpan #disney #shorts
# ¿Cómo se puede enfriar el planeta y frenar el calentamiento global? | BBC Mundo
# Hernán Cortés y la Conquista de México
# 🚨 Preparativos Militares en España: ¿Se Avecina un Ataque Químico o Biológico? 🛑 Análisis 2023
# Organización social en las colonias
# TIERMAKER - ¿CUÁL ES LA MEJOR REGIÓN DE ESPAÑA?
# PEDRO SÁNCHEZ: 1ª ENTREVISTA tras ser INVESTIDO PRESIDENTE del GOBIERNO | RTVE
# España no se rompe, YA ESTÁ ROTA
# La Educación Prohibida - Película Completa HD Oficial
# Alejandro Magno y el Imperio de Macedonia
# El Salvador: las medidas del presidente Nayib Bukele en contra de las pandillas
# 🔴 La ILUSTRACIÓN del SIGLO XVIII en 5 minutos ‼
# Los Reyes Católicos en 10 minutos! | El reinado de Isabel y Fernando
# 🌎La HISTORIA DE ESTADOS UNIDOS en 13 minutos🌎 | Resumen rápido
# 🚨 ¿SOY UN FACHA? 📢 ¿SERÉ UN ENERGÚMENO SIN ESCRÚPULOS? - SOY ESPAÑOL – VIVA ESPAÑA
# El correo entre los Estados Unidos y los antiguos territorios Españoles en Norte America
# El proceso de independencia, explicado en 5 minutos
# Stalingrado, el ocaso del III Reich
# RANGOS MILITARES del EJÉRCITO ESPAÑOL - Soldier Spain nos explica cómo funcionan y cuáles son.
# El Descubrimiento de América
# Arqueología encontrada en la ruta del Tren Maya
# ¿Qué diferencia a los aztecas de los mayas?
# 30 Curiosidades que no Sabías sobre Pakistán  | Una potencia nuclear de Asia
# 📌🤔⚔ ¿Qué territorios conquistó Francia en América? | Conquista y colonización francesa en América🌎🇫🇷
# EE.UU. a por el PETRÓLEO de El Esequibo, territorio en DISPUTA entre Venezuela y Guyana | Caféinna
# Me quedo sin palabras ante el poderío militar español ,Desfile de fuerza militar de España
# ¿Qué diferencia a los aztecas de los mayas?
# 📌🤔⚔ ¿Qué territorios conquistó Francia en América? | Conquista y colonización francesa en América🌎🇫🇷
# 30 Curiosidades que no Sabías sobre Pakistán  | Una potencia nuclear de Asia
# PEDRO SÁNCHEZ: 1ª ENTREVISTA tras ser INVESTIDO PRESIDENTE del GOBIERNO | RTVE
# Me quedo sin palabras ante el poderío militar español ,Desfile de fuerza militar de España
# La Conquista del Perú en 10 minutos! | Francisco Pizarro y el Imperio Inca
# Historia de México: El PORFIRIATO - Resumen | El gobierno de PORFIRIO DÍAZ
# 🔴 DIRECTO 27/11/2023 - &#39;LA DECADENCIA DE LA EUROPA FAKE&#39;, con Lorenzo Ramírez
# Poblamiento Americano | Teorías Inmigracionistas | Origen del Hombre Americano
# Foucault
# ✅ El IMPERIO ROMANO en 10 minutos | Resumen de la historia de la ANTIGUA ROMA
# Structurer l&#39;argumentation : les connecteurs logiques - Espagnol - Terminale - Les Bons Profs
# Diversidad cultural
# Francia le QUITÓ TERRITORIO a MÉXICO #shorts #historiaolvidada
# Día de la croqueta : Barbastro | Territorio Vivo ATV 322
# Ciclo de Conversatorios Urabá Darién Memoria de un Territorio - &quot;Balboa y Ananyansy en Urabá Darién&quot;
# Armada española rescata a ciudadana francesa secuestrada ,Cubano reacciona sorprendido 🤯😱
# Covid-19: el virus que arrasó con todo
# EL CID CAMPEADOR⚔🛡 | Draw My Life en Español
# Reconquistando marruecos y expandiendo territorio/Campaña con España Ep8/Empire Total War/Darth mod
# ¿A quién pertenece Jerusalén? | DW Documental
# ¿Y si los NAZIS hubieran GANADO la GUERRA?
# EE.UU. a por el PETRÓLEO de El Esequibo, territorio en DISPUTA entre Venezuela y Guyana | Caféinna
# Huáscar: el barco que divide a Chile y a Perú | BBC Mundo
# Aseguran que Chile se quiere quedar con parte del territorio argentino
# MÉXICO ANEXARA A GUATEMALA A SU TERRITORIO |GUATEMALTECA REACCIONA
# CUPRA BORN: Ni Seat Born ¿ni VW ID.3? | Primera Prueba / Test drive / Review en español
# 🇲🇽 El TERRITORIO que MÉXICO RECUPERÓ de EEUU | la historia del PUEBLO RIO RICO *REACCIÓN*
# COMO SON😱 los ESPAÑOLES🇪🇦 SEGÚN los ESTADOUNIDENSES🇺🇲 /Cubano Reacciona 2023 #España
# 🎥 EL PLEBE DEL CAMARO - PELICULA COMPLETA NARCOS | Ola Studios TV 🎬
# Cómo Panamá ha pasado de ser un ejemplo de prosperidad y estabilidad a vivir masivas protestas
# Territorio de Bellota 100% ibérico: Cata de jamón, paleta y otros ibéricos
# El Territorio del Fut
# *LOS ESTADOUNIDENSES ESTÁN HUYENDO A ESPAÑA | MEXICANOS REACCIONAN
# ¿PUEDO REAGRUPAR A UN FAMILIAR UNA VEZ ÉSTE SE ENCUENTRE EN TERRITORIO ESPAÑOL?
# Las colonias más ricas de las Américas terminaron siendo los territorios más pobres
# Venezuela - María Corina Machado rechaza diálogo entre España y Gobierno venezolano - VPItv
# GRUPO WAGNER: PRIGOZHIN y el &quot;EJÉRCITO PARALELO&quot; de PUTIN en la GUERRA de UCRANIA | RTVE
# La Guerra de las Malvinas
# Proceso de formación del territorio argentino
# Comisión de Medio Ambiente y Ordenación del Territorio - 1 de septiembre de 2.015
# ¿La Tierra es plana? 🌎 5 pruebas... en contra
# Hannah Arendt
# 💣La GUERRA DE VIETNAM en 11 minutos💣 | resumen FÁCIL y RÁPIDO
# ¡GIBRALTAR! - Canción Franquista española sobre Gibraltar.
# 20 ciudades imprescindibles de España. Argentinos reaccionan
# La Guayana Esequiba, el rico territorio que Venezuela quiere recuperar ¿Por qué?
# Napoleón Bonaparte y las guerras napoleónicas
# Los paisajes de montaña y de llanura. EL RELIEVE⛰| Vídeos Educativos para Niños
# La Reforma protestante y Lutero
# ASÍ SE VIVE EN ISLANDIA: ¿El país más extraño del mundo?
# De 1619 a 1865, un repaso por la historia de esclavitud en los Estados Unidos
# XLV Aniversario de la Constitución Española. Lectura de la Constitución 9h (29/11/2023)
# La invasión a Palestina le saldrá muy cara a Israel - Entrevista con Ezequiel Bistoletti
# EL CANTAR DEL MÍO CID EN 3 MINUTOS
# ¿QUE ES EL MARXISMO? en 4 minutos
# LA SEGUNDA GUERRA MUNDIAL EN 20 MINUTOS | INFONIMADOS
# ¿Qué son las NORMAS JURÍDICAS y cuáles son sus características? (Con ejemplos)👨‍⚖️
# Comida para todos - El futuro de la alimentación | DW Documental
# Papi Wilo - Mi Historia [Official Video]
# Métodos para evaluar los riesgos
# ¿Son habladores los españoles? Un estudio revela el ranking de las ciudades más y menos habladoras
# ¿Cómo nos influye la música? | DW Documental
# En México habitan 62 pueblos indígenas
# La Prehistoria en 6 minutos
# Marcando territorio
# Mesopotamia. Una civilización entre dos ríos | Vídeos educativos para niños
# Planas destaca la respuesta ante los ataques a los camiones españoles
# Homo sapiens: los orígenes de la humanidad
# Rust - Adueñándonos Del Territorio- Español
# La Edad Media: ¿Qué es el Feudalismo? | Videos Educativos Aula365
# Primeras Impresiones de España!!! #amoespaña #vidanueva
# COMO se HACE el ORO en la TIERRA | Como se EXTRAE el ORO de las MINAS 🥇
# Reacher  - Tráiler Oficial | Prime Video España
# Historia de las maras, las pandillas salvadoreñas enfrentadas a Nayib Bukele
# RODRIGO QUESADA REALIZA UN TIERLIST SOBRE COMUNIDADES AUTÓNOMAS DE ESPAÑA
# Julio César
# Historia del ANTIGUO EGIPTO - Resumen | Origen, Política, Sociedad, Economía, Aportes...
# #29.- Compraventa de territorios entre países
# SER Historia | Rodrigo de Bastidas, la fundación de Santa Marta
# EL RENACIMIENTO en 5 minutos
# GASOLINA: Los PORTUGUESES cruzan la FRONTERA para REPOSTAR con DESCUENTO en ESPAÑA | RTVE
# Cómo fue el conflicto de 1941 entre Perú y Ecuador y qué consecuencias tuvo
# PIB NOMINAL y PIB REAL - Explicado para principiantes!
# INDEPENDENCIA DE TEXAS - PERDIDA DE TERRITORIO MEXICANO
# ¿Qué Armas de Fuego y Calibres Están Permitidos para Civiles en México?
# Las multinacionales españolas salen huyendo o se trocean a fondos extranjeros.
# ¿Qué une a talibanes con narcos mexicanos? | Contexto DW
# La reacción viral de un canandiense al probar la comida española | Turno de Tarde
# Cada vez más refugiados haitianos llegan a México
# La salvaje advertencia de Guillermo Rocafort que pone patas arriba el futuro de España
# Xornada Diagnose de País. Primeira parte: Transición enerxética e territorio.
# Territorio Revival | 3x07 | La ruta hacia El Dorado ft. Masi
# Cómo Estados Unidos robó el 50% de su territorio a México y Cuba, Puerto Rico y Filipinas a España.
# La importancia de la investigación en la escuela. Juan Fernández, profesor y biólogo
# Ceuta y Melilla ¿Territorio Cuestionado por Marruecos? #geopolitica #historia
# ¿Eres descendiente de españoles?: Obtén la nacionalidad bajo la Ley de Memoria Democrática
# Agricultores: ¿Puede hacerse crecer el dinero? | DW Documental
# ¿Cómo frenar las guerras orquestadas por la inteligencia artificial? | DW Documental
# ¿Qué opinan los rusos y los ucranianos de las tensiones entre Rusia y Occidente?
# EL CANTAR DEL MÍO CID EN 3 MINUTOS
# Los Puertorriqueños 🇵🇷 quieren ser españoles🇪🇸 [Demos Hispanidad]
# 🎮 Xbox HUMILLA a prensa y haters | GTA VI trailer OFICIAL | Cyberpunk 2077 NEWS | Sony PS5 - Semons
# ¿QUE ES EL MARXISMO? en 4 minutos
# LA SEGUNDA GUERRA MUNDIAL EN 20 MINUTOS | INFONIMADOS
# Papi Wilo - Mi Historia [Official Video]
# ZONAS RURALES DE ESPAÑA CORREN PELIGRO ☣️, CUBANO QUEDA IMPACTADO
# ¿Qué son las NORMAS JURÍDICAS y cuáles son sus características? (Con ejemplos)👨‍⚖️
# Comida para todos - El futuro de la alimentación | DW Documental
# 💻 Autorización para Teletrabajar en España: Nómada Digital 🌎🇪🇸 #reels #shorts
# Métodos para evaluar los riesgos
# ARMENGOL defiende su DISCURSO en la APERTURA de las CORTES que el PP y VOX calificaron de &quot;MITIN&quot; |
# En México habitan 62 pueblos indígenas
# ¿Cómo nos influye la música? | DW Documental
# La Prehistoria en 6 minutos
# Marcando territorio
# Mesopotamia. Una civilización entre dos ríos | Vídeos educativos para niños
# Sangre y Misterio: Vampiros de la Mitología de España 🧛‍♀️🦇
# Reacher  - Tráiler Oficial | Prime Video España
# 🇲🇽 🇪🇸 reaccion &quot;LA SORPRENDENTE EXPEDICION  BALMIS&quot; extranjero reacciona a españa mexicano reacciona
# Homo sapiens: los orígenes de la humanidad
# ESTUDIAR 🔴 Preguntas de Cómo Estudiar en España en 2024 ✈️🇪🇸
# La Edad Media: ¿Qué es el Feudalismo? | Videos Educativos Aula365
# COMO se HACE el ORO en la TIERRA | Como se EXTRAE el ORO de las MINAS 🥇
# Historia de las maras, las pandillas salvadoreñas enfrentadas a Nayib Bukele
# Pensamiento ambiental sur: comprensión de fenómenos y tensiones en los territorios.
# No es válida la venta del territorio de México
# El Objetivo - El Españolisto analiza los precios españoles y su contexto
# Julio César
# Historia del ANTIGUO EGIPTO - Resumen | Origen, Política, Sociedad, Economía, Aportes...
# SOY ESPAÑOL, ¿A QUÉ QUIERES QUE TE GANE? #territoriorevival #podcast #nostalgia #deporte #humor #fy
# 60 CURIOSIDADES💥 que no SABÍAS🤔 sobre ESPAÑA🇪🇦 HACE 5 MINUTOS⏰️ /Cubano Reacciona 2023
# EL RENACIMIENTO en 5 minutos
# Cómo fue el conflicto de 1941 entre Perú y Ecuador y qué consecuencias tuvo
# INDEPENDENCIA DE TEXAS - PERDIDA DE TERRITORIO MEXICANO
# Historia de México - La Nueva España
# El día que México PERDIO la MITAD DE SU TERRITORIO
# PIB NOMINAL y PIB REAL - Explicado para principiantes!
# ¿Qué Armas de Fuego y Calibres Están Permitidos para Civiles en México?
# Cada vez más refugiados haitianos llegan a México
# Mapuches: resistencias contra el extractivismo en defensa del territorio
# Los Reyes y la princesa Leonor presiden la apertura de la XV Legislatura de las Cortes Generales
# Satanismo en Colombia: Historia &amp; Comentarios
# Territorio Revival | 3x07 | La ruta hacia El Dorado ft. Masi
# La importancia de la investigación en la escuela. Juan Fernández, profesor y biólogo
# ¿Cómo frenar las guerras orquestadas por la inteligencia artificial? | DW Documental
# Agricultores: ¿Puede hacerse crecer el dinero? | DW Documental
# Diversidad lingüística y cultural de México
# Gonzalo Pizarro y la gran rebelión de los encomenderos
# 📌🤔⚔ ¿Quiénes conquistaron los actuales territorios de 🇧🇷 Brasil? en MENOS de UN MINUTO ⏱
# Los nuevos medicamentos contra el cáncer: ¿motivo de esperanza o perjuicio? | DW Documental
# La Reconquista, ¿un término válido?
# Los Puertorriqueños 🇵🇷 quieren ser españoles🇪🇸 [Demos Hispanidad]
# 🌍La HISTORIA DEL MUNDO en 15 minutos🌍 | Resumen de la historia de la HUMANIDAD
# 🎮 Xbox HUMILLA a prensa y haters | GTA VI trailer OFICIAL | Cyberpunk 2077 NEWS | Sony PS5 - Semons
# ¿Cómo llamaba Colon al territorio que descubrió? #cristóbalcolón #historia
# ZONAS RURALES DE ESPAÑA CORREN PELIGRO ☣️, CUBANO QUEDA IMPACTADO
# ¿Y si SE DERRITE todo el HIELO del PLANETA?
# 💻 Autorización para Teletrabajar en España: Nómada Digital 🌎🇪🇸 #reels #shorts
# ARMENGOL defiende su DISCURSO en la APERTURA de las CORTES que el PP y VOX calificaron de &quot;MITIN&quot; |
# Crisis económicas a lo largo de la historia
# American Bully - Todo lo que Debes Saber | Terránea
# Alemania lucha por mantenerse en la carrera por la competitividad y sostenibilidad | A fondo DW
# Sangre y Misterio: Vampiros de la Mitología de España 🧛‍♀️🦇
# La cultura Tiahuanaco en 9 minutos | Culturas Preincas
# 🇲🇽 🇪🇸 reaccion &quot;LA SORPRENDENTE EXPEDICION  BALMIS&quot; extranjero reacciona a españa mexicano reacciona
# Las raíces históricas de los nazis modernos | DW Documental
# ESTUDIAR 🔴 Preguntas de Cómo Estudiar en España en 2024 ✈️🇪🇸
# “El territorio, la territorialidad y la territorialización.”
# Aztecas, Incas y Mayas 🌎 Resumen
# Pensamiento ambiental sur: comprensión de fenómenos y tensiones en los territorios.
# No es válida la venta del territorio de México
# El Objetivo - El Españolisto analiza los precios españoles y su contexto
# «La Florida del Inca», escrito por el Inca Garcilaso. Un diálogo con Carmen de Mora Valcárcel
# SOY ESPAÑOL, ¿A QUÉ QUIERES QUE TE GANE? #territoriorevival #podcast #nostalgia #deporte #humor #fy
# JAIME PEÑAFIEL vuelve a destrozar a LETIZIA.
# 60 CURIOSIDADES💥 que no SABÍAS🤔 sobre ESPAÑA🇪🇦 HACE 5 MINUTOS⏰️ /Cubano Reacciona 2023
# Historia de México - La Nueva España
# El día que México PERDIO la MITAD DE SU TERRITORIO
# La Prehistoria - 5 cosas que deberías saber - Historia para niños
# Mapuches: resistencias contra el extractivismo en defensa del territorio
# Los Reyes y la princesa Leonor presiden la apertura de la XV Legislatura de las Cortes Generales
# ⚠️VIAJAR a ESPAÑA últimos requisitos 2022 ❗ACTUALIZADO❗
# TIPOLOGÍAS TEXTUALES O TIPOS DE TEXTOS - edutuber
# 20 Series TURCAS en [ESPAÑOL COMPLETAS]
# Ep. 117 - Fondos de búsqueda: el camino de la inversión - Territorio Negocios
# Satanismo en Colombia: Historia &amp; Comentarios
# Chevrolet Tahoe 2021 - Mejor en todo y aún más grande - Primer Vistazo
# Territorio Revival | 2x33 | Indiana Jones ft. Ernesto Sevilla
# Mundo Maldini
# Estafas millonarias en Internet | DW Documental
# La caída del Imperio Otomano
# Territorio Revival | 1x20 | Bob Esponja ft. Álex Saudinós
# La mentira del libre comercio | DW Documental
# 📌🤔⚔ ¿Quiénes conquistaron los actuales territorios de 🇧🇷 Brasil? en MENOS de UN MINUTO ⏱
# Ni las iglesias podrían ayudar a inmigrantes: los detalles de la nueva ley antiinmigrante de Florida
# Con VOX en el gobierno, esperamos una revitalización del mercado laboral
# Yo también fui progre... y constitucionalista. FORJA 232 #progresismo #politica #actualidad #españa
# 🇲🇽 🇪🇸 😬&quot;DIFERENCIAS ENTRE ESPAÑA Y ESTADOS UNIDOS&quot;😮 mexicano reacciona a españa extranjero reaccion
# PRIMERA GUERRA MUNDIAL (Resumen) | Draw My Life
# Los territorios italianos de la Monarquía Hispánica
# Recuperando territorio para recuperarlo todo (Paleando el territorio)
# A custodia do territorio en Galicia. Oportunidades para o Ortegal | AGCT
# LA ESPAÑA DESPOBLADA: Béjar (Salamanca) (01/12/2023)
# VOX propone fomentar un entorno empresarial más libre y competitivo
# Guerras Púnicas. Roma vs. Cartago
# 08. La diversidad lingüística del español en los medios de comunicación
# ⚠️🛴Futura LEY PATINETES Electricos 2024-2027 ⛔️👮🏻‍♂️CERTIFICADO de CIRCULACION 💥
# Sugel Michelén: La historia de la Biblia en español
# Colegio Gringo vs. Colegio Latino | enchufetv
# Ugly History: The Spanish Inquisition - Kayla Wolf
# Alberto Fernández sería propietario de un hotel en España
# Resines dice lo q opina el resto de 🇪🇸🇪🇸🇪🇸 España
# ECUADOR - Territorio Demostrativo Píllaro
# Españoles por Juego de Tronos
# ¿Qué es eso de Territorio No incorporado para Puerto Rico?
# ¿Es posible acabar con las redes criminales de alcance global? | DW Documental
# Zoom.  6° Prim.  El Territorio Peruano al iniciar la República.  08/07.
# UN CASTILLO DEL IMPERIO ESPAÑOL EN TERRITORIO ESTADOUNIDENSE [Castillo De San Marcos] San Agustin Fl
# La política es para gobernar territorios, no personas
# Monólogo de Alsina, a Pedro Sánchez: &quot;Deje de criticar, que la amnistía es para usted&quot;
# ✅ UNA VEZ MAS... ¡AZERBAIYÁN es TERRITORIO de CHECO! 👏 | MAX ENCARA a RUSSELL 👊 | RESUMEN SPRINT F1
# Por qué el Ejército ruso no logra vencer en Ucrania
# Todos los territorios perdidos o ganados por países americanos! #enfemapping #revivalgeo #mapping
# «La Florida del Inca», escrito por el Inca Garcilaso. Un diálogo con Carmen de Mora Valcárcel
# Calibre 50 - Corrido De Juanito
# Así fue la batalla de Boyacá el 7 de agosto de 1819
# 🔴 DIRECTO | El rey Felipe VI abre la XV Legislatura en el Congreso (29/11/2023)
# 9° Seminario Chiloé: Historia del Contacto. Territorio histórico (2)
# NO SE VIVE MEJOR QUE EN ESTE PAÍS
# 12. The Inca - Cities in the Cloud (Part 1 of 2)
# EN DEFENSA DEL CARDENAL BURKE - ESPAÑA ESTÁ CONTIGO
# Socotra, la isla del tesoro verde entre Yemen y Somalia | DW Documental
# REGRESA IBERDROLA! REINVIERTE LO VENDIDO EN MÉXICO
# ⭐ La HISTORIA del SIGLO XX en 10 minutos⭐| El resumen definitivo
# 🔴📡 DIRECTO -  Territorios Resistentes: ‘Territorios artísticos’
# 🇧🇬HISTORIA de BULGARIA en (casi) 19 minutos  (resumen) 🇧🇬 - El Mapa de Sebas
# Historia de México cap 2 Un Territorio Mutilado
# CONQUISTA DEL DESIERTO en minutos
# ¿ESPAÑA es Ahora una DICTADURA? | Video Reacción
# GUERRA EN UCRANIA-ESPECIAL INFORMATIVO: PUTIN ataca varias ciudades ucranianas | RTVE
# ¿Por qué República Dominicana y Haití son tan distintos? | El Espectador
# Comisión de Agricultura, Desarrollo Rural, Población y Territorio 08/06/2022
# Territorio Urgente: Introducción a la filosofía de la liberación. Hacia un pensamiento decolonial.#3
# Napoleonic Wars 1805 - 09: March of the Eagles
# UNA HISTORIA CONTADA POR MUJERES: Austeridad fiscal y territorios indígenas
# LA HISTORIA DE MÉXICO🇲🇽 en 17 MINUTOS feat. Nación Tesla - El Mapa de Sebas
# Territorio Líder   Capítulo 24   Manuel Pérez Sala   Círculo de Empresarios 1080p
# 😨 Los 3 Peores Países para Emigrar desde Venezuela
# TODO ES GEOPOLÍTICA | EEUU y Europa podrían dejar sin ayudas a Ucrania, Irán carga contra Biden
# El Territorio Que Ningún País lo Reclama
# Hearts Of Iron IV | España en la Segunda Guerra Mundial | Unimos Territorios
# La Caída de Constantinopla
# Las dos Guerras Mundiales
# DARWIN EL ALCALDE FAVORITO DE DELCY | FUERA DE ORDEN 714 PARTE 2 | SÁBADO 2.12.2023
# Sobre el famoso mapa de la España incorporada o asimilada...
# 🇲🇽 🇪🇸🤔¿QUE ESTA PASANDO EN ESPAÑA? 😬 mexicano reacciona a españa extranjero reaccionando a españa
# &quot;BENDECIDOS&quot; (ANALISIS) @santasuertemusic8056 LOS GRANDES AUSENTES EN ESTE TEMA.
# 🇸🇻🇬🇹🇳🇮🇨🇷🇭🇳HISTORIA de la República Federal de CENTROAMÉRICA🇸🇻🇬🇹🇳🇮🇨🇷 🇭🇳 - El Mapa de Sebas
# ❗LO TENEMOS❗ España OFICIAL en Euro Truck Simulator 🚛💨 Mi primera ruta 🔥  🟥🟨🟥IBERIA DLC #1 🟩🟥
# La Antigua Grecia - 5 cosas que deberías saber - Historia para niños - Grecia
# AVANCE 2023 II !! RONDADOR, MEFISTO, BATTLEWORLD, DD7 y más de Marvel Strike Force en español
# CONQUISTA DEL TERRITORIO COLOMBIANO   4
# Alice  Madness Returns en Español - 05 Territorio del Sombrerero Pt 2 - 1080p 60fps
# Extremeño CLASIFICA en una TIER LIST TODAS las COMUNIDADES AUTÓNOMAS de ESPAÑA
# CONGRESO: APERTURA de la CORTES GENERALES de la XV LEGISLATURA | RTVE Noticias
# 🇲🇽 LA INDEPENDENCIA DE MEXICO Historia causa resumen
# Territorio de leones: Rivales de sangre || Documentales nat geo wild Español 2020 HD
# Vaguada sigue provocando lluvias en gran parte del territorio nacional
# La Edad Media para niños - 5 cosas que deberías saber - Historia para niños
# 𝐄𝐥 𝐯𝐚𝐥𝐨𝐫 𝐝𝐞𝐥 𝐓𝐞𝐫𝐫𝐢𝐭𝐨𝐫𝐢𝐨: 𝐃𝐢𝐩𝐥𝐨𝐦𝐚𝐜𝐢𝐚 𝐏𝐫𝐞𝐯𝐞𝐧𝐭𝐢𝐯𝐚, 𝐌𝐞𝐝𝐢𝐚𝐜𝐢𝐨́𝐧 𝐲 𝐀𝐃𝐑’𝐒
# El Pájaro Loco en Español | 1 Hora de Compilación | Dibujos Animados en Español
# &#39;Napoleón&#39; de Ridley Scott y otros estrenos en La Ventana del Cine con Carlos Boyero
# 𝗚𝘂í𝗮 𝗱𝗲 𝗧𝗲𝗿𝗿𝗶𝘁𝗼𝗿𝗶𝗼𝘀, 𝗔𝘀𝗲𝗻𝘁𝗮𝗺𝗶𝗲𝗻𝘁𝗼𝘀 𝘆 𝗛𝗼𝘂𝘀𝗶𝗻𝗴
# American Imperialism: Crash Course US History #28
# KENT ES ESPAÑOL (Y CATALÁN) #podcast #territoriorevival #destacame #humor #lossimpson #shorts
# ESPAÑOL PARA EXTRANJEROS _ Una breve Explicación del Sistema... _ Learn Spanish as a Second Language
# Por el Derecho al Territorio: Segundo Momento
# TERRITORIO de LEONES #2: CAZADOR de GIGANTES | Documental National Geographic (HD)
# &quot;Chaitén Indómito&quot;, vivir debajo de la Montaña (Territorio Minchemawida) - Pamela Mayorga
# Conoce a &quot;La Bestia&quot;, el tren que transporta a miles de migrantes
# Don Diego cocina el Territorio Linares
# ¿Por Qué La Virgen de Guadalupe de México Ya Existía en España desde el año 1326?
# ✅ La historia de los CABALLEROS TEMPLARIOS en 10 minutos
# “El territorio, la territorialidad y la territorialización.”
# CONVOCAN AL FORO &quot;POLICÍA COMUNITARIA, DEFENSA DEL TERRITORIO Y LOS DERECHOS HUMANOS&quot;
# Catalanes reaccionan por primera vez al HIMNO DE ESPAÑA | El PODCAST más ESPAÑOL - Cono-Cidos #2
# Curso sobre Recuperación y Reafirmación de Territorios Indígenas
# Ep. 117 - Fondos de búsqueda: el camino de la inversión - Territorio Negocios
# Cómo Hacer un Mapa Mental Fácil y Rápido 😱 | (Paso a Paso con Ejemplos)
# EVOLUCIÓN DEL TERRITORIO PERUANO
# Arte, comunidad y territorio: una aproximación al patrimonio
# ORGANIZADORES GRÁFICOS ✅ ¡FÁCILES DE HACER!
# Pronostican ingreso de una onda tropical  al territorio nacional
# ESPAÑOL PARA EXTRANJEROS __ práctica 2 _ Learn Spanish as a Second Language
# Cartel De Santa &quot;Babo&quot; Escuchando a Santa Fe klan &quot;Cuidando El Territorio&quot; Ft Beto Sierra Calibre 50
# DIRECTO | Sesión de Apertura de las Cortes Generales de la XV Legislatura | EL PAÍS
# ¡LO DIJIMOS! &quot;ISRAEL YA SABÍA DEL ATAQUE DE HAMÁS HACE MÁS DE UN AÑO&quot;, PUBLICA THE NYT
# VENEZUELA CURIOSIDADES SOBRE ESTE PAIS. COMO ESTA CEDIENDO SU TERRITORIO PARA CREAR UN NARCO PAÍS.
# TODO ES GEOPOLÍTICA | Europa frente a Rusia: &quot;Nuestra existencia depende de Ucrania&quot;
# Etimologías curiosas
# TERRITORIOS CON FUTURO ALCAÑICES 2023
# Así será la futurista nueva capital de España. Argentinos reaccionan
# Los hijos del sol: Los 14 incas del Tahuantinsuyo
# Venezuela es un territorio sin ley
# Primera Página | Entrevista con Oscar Arnal (1/2)
# La Cacica María Panana (Pedaleando El Territorio)
# CRYPTONEGOCIOS | España se lanza a por el dinero de las cryptos, CZ renuncia y la SEC contra Binance
# ESPAÑOL PARA EXTRANJEROS __ práctica 1 _ Learn Spanish as a Second Language
# Defendiendo el territorio y los derechos humanos frente al Proyecto Integral Morelos
# REACCION a CUIDANDO EL TERRITORIO - SANTA FE KLAN, BETO SIERRA Y CALIBRE 50
# Las Cruzadas en 14 minutos
# ¿Qué cambió en los territorios del rio de la Plata a partir de la revolución de Mayo de 1810?
# Saturday Night Live;  La humillación a España por parte de Sánchez y Puigdemont
# 🇪🇸TIERLIST de COMUNIDADES AUTÓNOMAS *se acabo el debate*
# Cómo viajar con tu mascota
# Capítulo 7. Territorio
# Santa Fe Klan x Calibre 50 x Beto Sierra - Cuidando El Territorio [Official Video]/REACCION🇲🇽 RIFADO
# Donald Trump habla desde Florida tras declararse no culpable de cargos por delitos mayores
# Persecución a la mafia en Calabria | DW Documental
# &quot;No hay problema en analizar productos españoles&quot;
# ELBIT SYSTEMS GANA CONTRATO ESPAÑOL UN VISTAZO A LOS SISTEMAS DE RADIOENLACE   TOP NOTICIAS
# Un Mundo Verde - Territorio y Medio Ambiente
# Antártida: Un mensaje de otro planeta | DW Documental
# SPIDER T REX, SPIDER SPINOSAURUS &amp; SPIDER INDOMINUS REX!!! SUPER SPIDER-SAURIOS!!!
# 🇲🇽 🇪🇸 🤔&quot;EL ORIGEN DEL CAMINO DE SANTIGO&quot; Asi COMENZO TODO,🙂 mexicano reacciona a españa extranjero
# DESPOBLACIÓN RURAL | ESPAÑA SE VACIA | VirAleX
# ¿Extinción  de Lenguas indígenas?
# La GUERRA de SECESIÓN en 10 minutos | La Guerra Civil Estadounidense
# HECTOR CARLOS JANSON - LA MONEDA CIRCULANTE EN EL TERRITORIO ARGENTINO 1574 - 2019
# Resistencias comunitarias y defensa del territorio, México, 2013-2022
# Plenaria 3: Migración y racismo_III Foro Mundial Ciudades y Territorios de Paz
# Defensa confirma que dos españoles están retenidos por piratas
# [En español] Discurso del presidente Biden sobre el Estado de la Nación
# Que soy más español que tu! Una pol.la!
# 9° Seminario Chiloé: Historia del Contacto. Territorio histórico (4)
# ¿Baraja China las cartas en la guerra de Rusia contra Ucrania? | A Fondo
# 🚨ULTIMA HORA : Cazas de la OTAN son avistados cerca del territorio Ucraniano
# Si [NOMBRE] lo dijera aquí | No nos queda más remedio que venir todos los días
# Los mercados reaccionan negativamente a las noticias macro positivas. Por Yuri Rabassa
# Territorio Comanche - Plagio
# (Voces de los) Territorios Posibles por Utopías Reales (Ep. 8). Casos barrios &quot;Santa Ana&quot; y &quot;El Sol&quot;
# GANADERO ESPAÑOL GALLEGO LA VERDAD SOBRE LOS INCENDIOS  en español cristiano
# King Felipe VI of Spain attending the opening of parliament in 2023
# NOTICIAS CINCO DÍAS 02 03 23 Onda Cádiz TV
# Marina Lobo: Tellado, de Gamarra a Macarra
# Real Madrid vs FC Barcelona (0-3) J17 2017/2018 - FULL MATCH
# Chile: Evolución de los Límites y Ocupación del Territorio (Siglo XIX) 2021
# Sorteo Samsung Galaxy S10+
# Si CÉSAR lo dijera aquí | Hemos crecido en el país del &quot;no se puede&quot;
# Murió Henry Kissinger, el hombre que odiaba a España
# Así es el saqueo de los pescadores norcoreanos en aguas extranjeras
# CONEXIÓN VILAR: El futuro de Ucrania, amenazado; Lagarde vuelve a hablar y oro en máximos históricos
# La Revolución francesa en 14 minutos
# La participación y la comunicación claves para la gestión ambiental del territorio.
# El Sultán | Capitulo 39 Completo (4K)
# DIRECTO | Pleno del Congreso de los Diputados | EL PAÍS
# El negro de VOX HUMILLA a Ana Peleteiro: “RACISTA”
# Quien hablar mejor Castellano? 🇦🇷 vs 🇪🇸
# Sigue el tradicional desfile militar con el que México celebra la independencia
# DIRECTO | Feijóo visita la Fundación Once del Perro Guía | EL PAÍS
# Campañas 0% plásticos, Zero Waste y Territorio Tortuga de la Región de Murcia
# Experiencias de investigación sobre el territorio en Uruguay, México y Guatemala
# Pasó Antes De Irte a Dormir!Angelica Rivera Revela Datos Precisos sobre Fortuna De Peña En Una Isla!
# SEÑOR GOLAZO COLOMBIANO EN CAMARA LENTA l CUADRADO EUROPA LEAGUE l MORELOS CRITICAS
# Evento CYBERTRUCK TSLA
# Las ZEDE, el polémico proyecto de &quot;ciudades privadas&quot; de Honduras - Documental BBC
# Después de varios años malos, el sector del cerdo ibérico inicia una montanera con optimismo
# PROGRES Españoles LLORAN por MILEI
# POET Ordenamiento Ecológico del Territorio en México
# 100 PREGUNTAS de MÉXICO ¿Cuánto sabes México? 🧐🧐
# A História de Portugal (Parte 1): A Origem dos Portugueses
# #HECD, con Marina Lobo 346. La última de Ayuso, Letizia: pashmina y machismo y Salvini VS Meloni
# Más se Perdió en Cuba | 02/12/23
# Grave crisis diplomática entre España e Israel
# Un MARROQUÍ D3G*ELLA a su MUJER en SAGUNTO
# CITED 2023
# INFORMATIVO: Israel planea una &quot;guerra larga&quot;, Rusia avanza, Zelensky presiona y Europa amenaza
# Feijóo, &quot;el moderado&quot;, busca su sitio entre VOX, Ayuso y Aznar
# VIAJO A EL SALVADOR
# EE.UU e ISRAEL conocían el ataque. RUSIA arrincona a UCRANIA. MILEI aleja a ARGENTINA de los BRICS
# El gobierno divide a los españoles y vende propaganda
# DIPUTADO de SUMAR HACE el RIDÍCULO HABLANDO de FLAMENCOS y JOTAS | UTBED
# 7. The Songhai Empire - Africa&#39;s Age of Gold
# Turismo. Simult. turismo e ciencias empresariais (poñente+alumnado) Xeografía ordenación territorio
# Claves del día: Enfrentamiento total en Europa, Biden cuestionado y suenan las alarmas de la crisis
# BIS narrativa y Rodrigo Rato
# ¿HABLAMOS DE GEOPOLÍTICA? Conflictos y guerras de El Esequibo a Gaza
# The Animated History of Spain
# ¿Qué sabemos del próximo NACIONAL DE RAZAS? 🇪🇸 | Bernardino Crespo | Delegado de la RFEC 👌😊
# DIRECTO | Presentación del libro &#39;El nacionalismo contra España&#39;
# EL OBJETIVO de Rusia es CONQUISTAR NOVORROSSIYA
# Kings of Cannabis (Full Length Documentary)
# El Esequibo, unas tierras ricas en petróleo y minerales son de Venezuela… ¿o no?
# GUYANA vs VENEZUELA en Poder Militar (2024)
# MÁS AMENAZAS A RUSIA! AHORA UN BANCO EUROPEO
# Conversando con Expertos | La CALIDAD DEL AIRE que respiramos
# José Luis Escrivá, no sabe no contesta
# &#39;YA DEBE SER DESTITUÍDA&#39; IÑAKI GABILONDO ESTALLA contra ISABEL DÍAZ ÁYUSO y PRESENTA PRUEBAS BOMBAS
# Ayuso: “España no es propiedad de nadie, como tampoco lo son las banderas.”
# 💪 DESPIERTA  Esto NO ES una DEMOCRACIA.
# Silvia Intxaurrondo, no sabe no contesta
# ASI NOS RECIBE SENEGAL 🇸🇳 l ES COMO CREES? l La Vida de M
# sabado
# experiencias emprendedoras en Latinoamérica
# Sergio Errasti. “No hay que tener miedo a la crítica”
# Marina Lobo: paren el genocidio en Palestina
# Dimisión del Primer Ministro Portugués Escándalo de Corrupción el Sector Litio y el Hidrógeno Verde
# 2 caminos: las &quot;paguitas&quot; de Ayuso
# El &quot;deber&quot; de la Policía de pegar patadas a las puertas. Por Marina Olmo en @conlavendasenoria3549
# Aproveche oferta AVLO de 7€ a Madrid y como no quería levantarme tan temprano de regreso pagué 15€
# los jóvenes no defienden España, pero si, a Palestina! 😅
# La tierra, al igual que nuestras aventuras, no es plana. #AventuraConDacia #VidaAlAireLibre​​
# ES OFICIAL 🌍​ Ya estamos también en… #TikTok ​
# Caporales
# Consumo y venta #españatiktok #clavero #travelvlog #podcast #short #podcastespanol #drug
# CLÍTORIS - ¿Cómo tener mejores orgasmos?
# V1r91n T3rr1t0ry  (Legend) S3x
# eeuu autoatentado para invadir y arrevatar los territorios españoles  voladura del maine

# %%
len(v_title)
# Out:
# 719

# %%
df_territorio= pd.DataFrame({'canal_ID' : channel_ids, 'video_ID': video_ids, 'video_Title' : v_title})

# %%
df_territorio.to_csv('/Users/usuario/Downloads/irunela/csv/videos_territorio.csv')

# %%
df_territorio.head()
# Out:
#                    canal_ID     video_ID  \
# 0  UCPH3Oz99Y_jrVBCQMjQZNSg  AsMZK3aGFHs
# 1  UCUBIrDsIVzRpKsClMlSlTpQ  3FFOxhBSYAs
# 2  UCaSdpaCk2nyPlxj6im46rOQ  ik1H9JEL4FY
# 3  UCPd6b5PgGntDkBZM1Rf7WfA  BUbXwUbarNI
# 4  UCyuH8LBMElHDwMaSa_kZadA  OgQigaDkZ5s
#
#                                          video_Title
# 0  🌍 TERRITORIOS ESPAÑOLES  fuera de ESPAÑA 🌍 | l...
# 1  Por qué Ceuta y Melilla pertenecen a España si...
# 2  ¿Por que España tiene un territorio atrapado e...
# 3  Fueron territorios de ESPAÑA pero YA NO hablan...
# 4  ESTO PIENSO sobre  España y los Españoles ¿Son...

# %%
from pprint import pprint
def get_comments(video_ids):
    comments = []
    try:
        response = youtube.commentThreads().list(
            part='snippet',
            videoId=video_ids,
            textFormat='plainText'
        ).execute()
    except Exception:
        print(f"Fallo conseguir comentarios de {video_ids}")
        return []

    for item in response['items']:
        try:
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            author_channel_id = item['snippet']['topLevelComment']['snippet']['authorChannelId']["value"]
            #author_channel_id = comment['authorChannelId']['value']
            comments.append({"video_id": video_ids, "author": author_channel_id, "comment": comment})
        except KeyError as e:
            print(f"Falta algun valor de un comentario, {e}")
            comments.append(None)
            continue
    return comments

# %%
from tqdm.notebook import tqdm 
comment_video = [] 
for video in tqdm(video_ids): 
    comments = get_comments(video) 
    comment_video.extend(comments)
# Out:
#   0%|          | 0/719 [00:00<?, ?it/s]
# Fallo conseguir comentarios de Y-IlMeCCtIg
# Fallo conseguir comentarios de zSRjToF864c
# Fallo conseguir comentarios de 4RKGot5zi_M
# Fallo conseguir comentarios de VMju6kZ_gDE
# Fallo conseguir comentarios de qdXk6HK8Tvo
# Fallo conseguir comentarios de None
# Fallo conseguir comentarios de WlVDqAB19o4
# Fallo conseguir comentarios de wgcd7pVjmeQ
# Fallo conseguir comentarios de Y-IlMeCCtIg
# Fallo conseguir comentarios de PYAIuQWyhwI
# Fallo conseguir comentarios de QYFXI7UnbgA
# Fallo conseguir comentarios de wfh3siBQX8Q
# Fallo conseguir comentarios de 4DYl6FumojM
# Fallo conseguir comentarios de None
# Fallo conseguir comentarios de bZdP19gt9HQ
# Fallo conseguir comentarios de TpuZUQYeB-g
# Fallo conseguir comentarios de q1SNcRB70Fg
# Fallo conseguir comentarios de None
# Fallo conseguir comentarios de icttaUwZAcU
# Fallo conseguir comentarios de AilWlQWdtIg
# Fallo conseguir comentarios de Ptz0vfOZ12w
# Fallo conseguir comentarios de ZK05C7t50dI
# Fallo conseguir comentarios de Ptz0vfOZ12w
# Fallo conseguir comentarios de Odtj82_pNCo
# Fallo conseguir comentarios de ZK05C7t50dI
# Fallo conseguir comentarios de Odtj82_pNCo
# Fallo conseguir comentarios de rQTaFmsxnXE
# Fallo conseguir comentarios de XQrZ7giSLxI
# Fallo conseguir comentarios de None
# Fallo conseguir comentarios de Myqlish0g-w
# Fallo conseguir comentarios de 8UKmgigg-5U
# Fallo conseguir comentarios de bEoz_jCGM0o
# Fallo conseguir comentarios de hfNANN1vaCI
# Fallo conseguir comentarios de QYFXI7UnbgA
# Fallo conseguir comentarios de cknXSvinhJo
# Fallo conseguir comentarios de XzNgV0ONepQ
# Fallo conseguir comentarios de 06U1p_-nOWc
# Fallo conseguir comentarios de 0CfKXpyQTXo
# Fallo conseguir comentarios de 4FkLTeApKYo
# Fallo conseguir comentarios de hKjR0qY3xx4
# Fallo conseguir comentarios de rQTaFmsxnXE
# Fallo conseguir comentarios de YNx_edYpBWE
# Fallo conseguir comentarios de tzTP0qfxyQ0
# Fallo conseguir comentarios de V3tOA3mXtx8
# Fallo conseguir comentarios de 4DYl6FumojM
# Fallo conseguir comentarios de tRi7dsoo0ak
# Fallo conseguir comentarios de bLdv3jn9N8s

# %%
len(comment_video)
# Out:
# 10323

# %%
comentarios_territorio = pd.DataFrame(filter(None, comment_video))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 comentarios_territorio = pd.DataFrame(filter(None, comment_video))
#
# NameError: name 'pd' is not defined

# %%
comentarios_territorio.to_csv('/Users/usuario/Downloads/irunela/csv/comentarios_territorio.csv')

# %% [markdown]
# Data pre-processing

# %%
 comentarios_territorio = pd.read_csv('/Users/usuario/Downloads/irunela/csv/comentarios_territorio.csv')

# %%
valores_nulos = comentarios_territorio.isnull().sum()  # Esto devuelve la cantidad de valores nulos por columna
print(valores_nulos)
# Out:
# Unnamed: 0    0
# video_id      0
# author        0
# comment       2
# dtype: int64

# %%
# Check data types
comentarios_territorio.dtypes
# Out:
# Unnamed: 0     int64
# video_id      object
# author        object
# comment       object
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
 comentarios_territorio.shape
# Out:
# (10323, 4)

# %%
index_random = np.random.randint(0,high = comentarios_territorio.shape[0])
comentario = comentarios_territorio.iloc[index_random].comment
print(index_random, comentario)
# Out:
# 5442 Altea elecrico.

# %% [markdown]
# Tokenización

# %%
comment = str(comentarios_territorio['comment'])

# %%
#sent_tokenize todo el comentario
comment_st = nltk.tokenize.sent_tokenize(comment)
comment_st
# Out:
# ['0        No me lo puedo creer .',
#  'De verdad España le ha ...\n1        Si... pero entre unos y otros ya se han encarg...\n2                                    Tabarca te ha faltado\n3        El motivo fue que el asesino franco estaba muy...\n4        Yo e tenido una duda \\nPorque España no es una...\n                               ...                        \n10318                           Excelente filme!',
#  'Obrigado!',
#  '10319                                            Muito top\n10320                                          Bom filme 😊\n10321    Próximamente subtítulos en español, ya comencé...\n10322    El gobierno no trabajan para el pueblo, trabaj...\nName: comment, Length: 10323, dtype: object']

# %%
#word_tokenize tokeniza palabra por palabra
comment_wt = nltk.tokenize.word_tokenize(comment)
comment_wt
# Out:
# ['0',
#  'No',
#  'me',
#  'lo',
#  'puedo',
#  'creer',
#  '.',
#  'De',
#  'verdad',
#  'España',
#  'le',
#  'ha',
#  '...',
#  '1',
#  'Si',
#  '...',
#  'pero',
#  'entre',
#  'unos',
#  'y',
#  'otros',
#  'ya',
#  'se',
#  'han',
#  'encarg',
#  '...',
#  '2',
#  'Tabarca',
#  'te',
#  'ha',
#  'faltado',
#  '3',
#  'El',
#  'motivo',
#  'fue',
#  'que',
#  'el',
#  'asesino',
#  'franco',
#  'estaba',
#  'muy',
#  '...',
#  '4',
#  'Yo',
#  'e',
#  'tenido',
#  'una',
#  'duda',
#  '\\nPorque',
#  'España',
#  'no',
#  'es',
#  'una',
#  '...',
#  '...',
#  '10318',
#  'Excelente',
#  'filme',
#  '!',
#  'Obrigado',
#  '!',
#  '10319',
#  'Muito',
#  'top',
#  '10320',
#  'Bom',
#  'filme',
#  '😊',
#  '10321',
#  'Próximamente',
#  'subtítulos',
#  'en',
#  'español',
#  ',',
#  'ya',
#  'comencé',
#  '...',
#  '10322',
#  'El',
#  'gobierno',
#  'no',
#  'trabajan',
#  'para',
#  'el',
#  'pueblo',
#  ',',
#  'trabaj',
#  '...',
#  'Name',
#  ':',
#  'comment',
#  ',',
#  'Length',
#  ':',
#  '10323',
#  ',',
#  'dtype',
#  ':',
#  'object']

# %% [markdown]
# Normalización

# %% [markdown]
# Stopwords

# %%
stopwords = nltk.corpus.stopwords.words('spanish')
stopwords = [palabra for palabra in stopwords if 'not' not in palabra]
stopwords
# Out:
# ['de',
#  'la',
#  'que',
#  'el',
#  'en',
#  'y',
#  'a',
#  'los',
#  'del',
#  'se',
#  'las',
#  'por',
#  'un',
#  'para',
#  'con',
#  'no',
#  'una',
#  'su',
#  'al',
#  'lo',
#  'como',
#  'más',
#  'pero',
#  'sus',
#  'le',
#  'ya',
#  'o',
#  'este',
#  'sí',
#  'porque',
#  'esta',
#  'entre',
#  'cuando',
#  'muy',
#  'sin',
#  'sobre',
#  'también',
#  'me',
#  'hasta',
#  'hay',
#  'donde',
#  'quien',
#  'desde',
#  'todo',
#  'nos',
#  'durante',
#  'todos',
#  'uno',
#  'les',
#  'ni',
#  'contra',
#  'otros',
#  'ese',
#  'eso',
#  'ante',
#  'ellos',
#  'e',
#  'esto',
#  'mí',
#  'antes',
#  'algunos',
#  'qué',
#  'unos',
#  'yo',
#  'otro',
#  'otras',
#  'otra',
#  'él',
#  'tanto',
#  'esa',
#  'estos',
#  'mucho',
#  'quienes',
#  'nada',
#  'muchos',
#  'cual',
#  'poco',
#  'ella',
#  'estar',
#  'estas',
#  'algunas',
#  'algo',
#  'nosotros',
#  'mi',
#  'mis',
#  'tú',
#  'te',
#  'ti',
#  'tu',
#  'tus',
#  'ellas',
#  'nosotras',
#  'vosotros',
#  'vosotras',
#  'os',
#  'mío',
#  'mía',
#  'míos',
#  'mías',
#  'tuyo',
#  'tuya',
#  'tuyos',
#  'tuyas',
#  'suyo',
#  'suya',
#  'suyos',
#  'suyas',
#  'nuestro',
#  'nuestra',
#  'nuestros',
#  'nuestras',
#  'vuestro',
#  'vuestra',
#  'vuestros',
#  'vuestras',
#  'esos',
#  'esas',
#  'estoy',
#  'estás',
#  'está',
#  'estamos',
#  'estáis',
#  'están',
#  'esté',
#  'estés',
#  'estemos',
#  'estéis',
#  'estén',
#  'estaré',
#  'estarás',
#  'estará',
#  'estaremos',
#  'estaréis',
#  'estarán',
#  'estaría',
#  'estarías',
#  'estaríamos',
#  'estaríais',
#  'estarían',
#  'estaba',
#  'estabas',
#  'estábamos',
#  'estabais',
#  'estaban',
#  'estuve',
#  'estuviste',
#  'estuvo',
#  'estuvimos',
#  'estuvisteis',
#  'estuvieron',
#  'estuviera',
#  'estuvieras',
#  'estuviéramos',
#  'estuvierais',
#  'estuvieran',
#  'estuviese',
#  'estuvieses',
#  'estuviésemos',
#  'estuvieseis',
#  'estuviesen',
#  'estando',
#  'estado',
#  'estada',
#  'estados',
#  'estadas',
#  'estad',
#  'he',
#  'has',
#  'ha',
#  'hemos',
#  'habéis',
#  'han',
#  'haya',
#  'hayas',
#  'hayamos',
#  'hayáis',
#  'hayan',
#  'habré',
#  'habrás',
#  'habrá',
#  'habremos',
#  'habréis',
#  'habrán',
#  'habría',
#  'habrías',
#  'habríamos',
#  'habríais',
#  'habrían',
#  'había',
#  'habías',
#  'habíamos',
#  'habíais',
#  'habían',
#  'hube',
#  'hubiste',
#  'hubo',
#  'hubimos',
#  'hubisteis',
#  'hubieron',
#  'hubiera',
#  'hubieras',
#  'hubiéramos',
#  'hubierais',
#  'hubieran',
#  'hubiese',
#  'hubieses',
#  'hubiésemos',
#  'hubieseis',
#  'hubiesen',
#  'habiendo',
#  'habido',
#  'habida',
#  'habidos',
#  'habidas',
#  'soy',
#  'eres',
#  'es',
#  'somos',
#  'sois',
#  'son',
#  'sea',
#  'seas',
#  'seamos',
#  'seáis',
#  'sean',
#  'seré',
#  'serás',
#  'será',
#  'seremos',
#  'seréis',
#  'serán',
#  'sería',
#  'serías',
#  'seríamos',
#  'seríais',
#  'serían',
#  'era',
#  'eras',
#  'éramos',
#  'erais',
#  'eran',
#  'fui',
#  'fuiste',
#  'fue',
#  'fuimos',
#  'fuisteis',
#  'fueron',
#  'fuera',
#  'fueras',
#  'fuéramos',
#  'fuerais',
#  'fueran',
#  'fuese',
#  'fueses',
#  'fuésemos',
#  'fueseis',
#  'fuesen',
#  'sintiendo',
#  'sentido',
#  'sentida',
#  'sentidos',
#  'sentidas',
#  'siente',
#  'sentid',
#  'tengo',
#  'tienes',
#  'tiene',
#  'tenemos',
#  'tenéis',
#  'tienen',
#  'tenga',
#  'tengas',
#  'tengamos',
#  'tengáis',
#  'tengan',
#  'tendré',
#  'tendrás',
#  'tendrá',
#  'tendremos',
#  'tendréis',
#  'tendrán',
#  'tendría',
#  'tendrías',
#  'tendríamos',
#  'tendríais',
#  'tendrían',
#  'tenía',
#  'tenías',
#  'teníamos',
#  'teníais',
#  'tenían',
#  'tuve',
#  'tuviste',
#  'tuvo',
#  'tuvimos',
#  'tuvisteis',
#  'tuvieron',
#  'tuviera',
#  'tuvieras',
#  'tuviéramos',
#  'tuvierais',
#  'tuvieran',
#  'tuviese',
#  'tuvieses',
#  'tuviésemos',
#  'tuvieseis',
#  'tuviesen',
#  'teniendo',
#  'tenido',
#  'tenida',
#  'tenidos',
#  'tenidas',
#  'tened']

# %%
comment_wt_sin_sw = [word for word in comment_wt if word not in stopwords]
comment_wt_sin_sw
# Out:
# ['0',
#  'No',
#  'puedo',
#  'creer',
#  '.',
#  'De',
#  'verdad',
#  'España',
#  '...',
#  '1',
#  'Si',
#  '...',
#  'encarg',
#  '...',
#  '2',
#  'Tabarca',
#  'faltado',
#  '3',
#  'El',
#  'motivo',
#  'asesino',
#  'franco',
#  '...',
#  '4',
#  'Yo',
#  'duda',
#  '\\nPorque',
#  'España',
#  '...',
#  '...',
#  '10318',
#  'Excelente',
#  'filme',
#  '!',
#  'Obrigado',
#  '!',
#  '10319',
#  'Muito',
#  'top',
#  '10320',
#  'Bom',
#  'filme',
#  '😊',
#  '10321',
#  'Próximamente',
#  'subtítulos',
#  'español',
#  ',',
#  'comencé',
#  '...',
#  '10322',
#  'El',
#  'gobierno',
#  'trabajan',
#  'pueblo',
#  ',',
#  'trabaj',
#  '...',
#  'Name',
#  ':',
#  'comment',
#  ',',
#  'Length',
#  ':',
#  '10323',
#  ',',
#  'dtype',
#  ':',
#  'object']

# %% [markdown]
# Frecuencia de palabras

# %%
freq = nltk.FreqDist(comment_wt_sin_sw)
freq
# Out:
# FreqDist({'...': 8, ',': 4, ':': 3, 'España': 2, 'El': 2, 'filme': 2, '!': 2, '0': 1, 'No': 1, 'puedo': 1, ...})

# %%
# Importamos esta libreria que nos permite reemplzar caracteres
import re

# Importamos la función que nos permite Stemmizar de nltk y definimos el stemmer
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# Traemos nuevamente las stopwords
spanish_stopwords = nltk.corpus.stopwords.words('spanish')
#spanish_stopwords.remove('no')
#stopword.remove('not')

# %%
# Recorremos todos los comentarios y le vamos aplicando la Normalizacion y luega el Stemming a cada uno
comment_list=[]
for comment in comentarios_territorio.comment:
    # Vamos a reemplzar los caracteres que no sean letras por espacios, limpiando los numeros 
    comment=re.sub("[^a-zA-Z]"," ",str(comment))
    # Pasamos todo a minúsculas
    comment=comment.lower()
    # Remover caracteres especiales
    comment = re.sub(r'\W', ' ', comment)
    # Remover múltiples espacios con uno solo
    comment = re.sub(r'\s+', ' ', comment, flags=re.I)
    # Tokenizar el texto
    # Tokenizamos para separar las palabras del titular 
    comment=nltk.word_tokenize(comment)
    # Eliminamos las palabras de menos de 3 letras
    comment= [palabra for palabra in comment if len(palabra)>3]
    # Sacamos las Stopwords
    comment = [palabra for palabra in comment if not palabra in stopwords]

    ## Hasta acá Normalizamos, ahora a stemmizar

    # Aplicamos la funcion para buscar la raiz de las palabras
    comment=[stemmer.stem(palabra) for palabra in comment]
    # Por ultimo volvemos a unir el titular
    comment=" ".join(comment)

    # Vamos armando una lista con todos los titulares
    comment_list.append(comment)
    #dataset["titular_normalizado"] = titular_list

# %%
comentarios_territorio["comment_stem"] = comment_list
comentarios_territorio.tail()
# Out:
#        Unnamed: 0     video_id                    author  \
# 10318       10318  _4WGKLXSsfo  UC5ERoAHkQ6OnV8wUtSzY7Qw
# 10319       10319  _4WGKLXSsfo  UCiqHUTaCkd0gF_yYUgnM-ng
# 10320       10320  _4WGKLXSsfo  UCCVICtpqlhnmcvnM57q-zmA
# 10321       10321  _4WGKLXSsfo  UCV7TS0re9PSDk_w_E64j3GQ
# 10322       10322  u_PPscUNQ5U  UCOk2lCrsPwj-Mzuwq-jrU8A
#
#                                                  comment  \
# 10318                         Excelente filme! Obrigado!
# 10319                                          Muito top
# 10320                                        Bom filme 😊
# 10321  Próximamente subtítulos en español, ya comencé...
# 10322  El gobierno no trabajan para el pueblo, trabaj...
#
#                                             comment_stem
# 10318                             excelent film obrigado
# 10319                                              muito
# 10320                                               film
# 10321             ximament subt tulo espa comenc hacerlo
# 10322  gobierno trabajan pueblo trabajan transnaciona...

# %% [markdown]
# Vectorizar

# %%
list_comment = list(comentarios_territorio['comment_stem'].values)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Usaremos solo las 1000 palabras con mas frecuencia en todo el corpus para generar los vectores
max_features=1000
# spanish=stopwords.words("spanish")
# Es decir que cada instancia tendrá 1000 features
cou_vec=CountVectorizer(max_features=max_features, stop_words = spanish_stopwords) # stop_words="english" , ngram_range=(1, 2)

# %%
#enerarnos los vectores para cada título a partir del corpus total. 
matriz_titulos = cou_vec.fit_transform(list_comment)

# Tomamos las palabras
all_words = cou_vec.get_feature_names_out()

# Vizualizamos las 50 palabras mas usadas
print("50 palabras mas usadas: ",all_words[0:50])
# Out:
# 50 palabras mas usadas:  ['abrazo' 'abuso' 'acab' 'acabar' 'acaso' 'accion' 'actitud' 'actual'
#  'actualidad' 'actualment' 'acuerdo' 'adelant' 'adem' 'adema' 'adulto'
#  'africa' 'africano' 'agua' 'ahora' 'alejandro' 'alem' 'aleman' 'alemania'
#  'alguien' 'algun' 'alguna' 'aliado' 'alma' 'alto' 'amazon' 'amenaza'
#  'america' 'americano' 'amigo' 'amo' 'amor' 'andaluc' 'anglosajon'
#  'animal' 'anterior' 'antigua' 'antiguo' 'apart' 'apellido' 'apena'
#  'apoyo' 'aprend' 'aquel' 'aquello' 'aqui']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()

# Transformar el texto en vectores TF-IDF
vectores_tfidf = vectorizer.fit_transform(list_comment)

# Obtener el tamaño del vocabulario
tamaño_vocabulario = len(vectorizer.get_feature_names_out())

# Ver los vectores TF-IDF resultantes 
print(vectores_tfidf)
# Out:
#   (0, 7067)	0.4461283221170715
#   (0, 13031)	0.28645380166390755
#   (0, 15622)	0.3813613270322811
#   (0, 11500)	0.3875998484403832
#   (0, 3483)	0.4137448245746763
#   (0, 7884)	0.1464563748292821
#   (0, 21256)	0.23074400602143535
#   (0, 5161)	0.3151566950923495
#   (0, 16943)	0.27936149892863493
#   (1, 4310)	0.40134904704015606
#   (1, 4514)	0.49405129005007103
#   (1, 10425)	0.2862512358546859
#   (1, 6333)	0.4730732929308045
#   (1, 7335)	0.4730732929308045
#   (1, 21256)	0.25553045658530543
#   (2, 8648)	0.6627148559625508
#   (2, 19817)	0.7488718312812517
#   (3, 18222)	0.45266313484718795
#   (3, 14674)	0.5162920908207886
#   (3, 9105)	0.3716696472656163
#   (3, 1801)	0.4035189492892021
#   (3, 13827)	0.4369107357817921
#   (3, 7884)	0.1915246802133319
#   (4, 12080)	0.3118097400743345
#   (4, 18124)	0.2210387782629611
#   :	:
#   (10318, 14591)	0.6861020667822617
#   (10318, 8274)	0.3925587271979136
#   (10319, 13905)	1.0
#   (10320, 8866)	1.0
#   (10321, 21780)	0.5080972815862852
#   (10321, 19582)	0.45934233763121823
#   (10321, 4162)	0.4865228751955155
#   (10321, 20760)	0.3658084173699716
#   (10321, 9947)	0.3640045485819976
#   (10321, 7884)	0.16679973503724962
#   (10322, 12753)	0.29003918034789156
#   (10322, 20591)	0.2827310425636899
#   (10322, 9401)	0.2827310425636899
#   (10322, 20427)	0.26348053808116373
#   (10322, 12720)	0.2138188906091023
#   (10322, 15791)	0.23135756037659247
#   (10322, 20473)	0.49802029241831075
#   (10322, 2314)	0.2219357320909888
#   (10322, 16524)	0.2827310425636899
#   (10322, 6331)	0.23135756037659247
#   (10322, 16937)	0.15184677680625464
#   (10322, 21211)	0.1992345826720212
#   (10322, 9573)	0.16159127603382492
#   (10322, 2856)	0.16555025900212378
#   (10322, 21087)	0.20080692472116163

# %%
# Convertir la matriz dispersa a un array NumPy
vectores_tfidf_array = vectores_tfidf.toarray()

# Asegurar que el número de filas en vectores_tfidf coincida con la cantidad de filas en comentarios_inmigracion
# (vectores_tfidf_array debe tener la misma cantidad de filas que comentarios_inmigracion)
if vectores_tfidf_array.shape[0] == len(comentarios_territorio):
    # Asignar los vectores TF-IDF al DataFrame como una nueva columna
    comentarios_territorio['vectores_tfidf'] = list(vectores_tfidf_array)
else:
    print("Las longitudes no coinciden entre la matriz dispersa y el DataFrame.")

# %%
comentarios_territorio['comment_stem'][10]
# Out:
# 'pienso injusta ment marrueco quier'
