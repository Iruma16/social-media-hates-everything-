# %%
from googleapiclient.discovery import build
from dateutil import parser
import pandas as pd

# Data viz packages
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# NLP
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
from wordcloud import WordCloud
from FunctionsYoutube import *
# !pip install wordcloud 
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/usuario/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/usuario/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 17
#      15 nltk.download('punkt')
#      16 from wordcloud import WordCloud
# ---> 17 from FunctionsYoutube import *
#      18 get_ipython().system('pip install wordcloud')
#      19 from wordcloud import WordCloud
#
# ModuleNotFoundError: No module named 'FunctionsYoutube'

# %%
api_key="AIzaSyDBJWJl3fxjbiVb4PE2YG4xRviQ5MJj1Mk"

# %%
api_service_name = "youtube"
api_version = "v3"

# Creamos la conexión con youtube API
youtube = build(
    api_service_name, api_version, developerKey=api_key)

# %%
next_page_token = None
all_video = []

while True:
    search_response = youtube.search().list(
        q="Opiniones españolas sobre la amnistia", # q es la query 
        part="id,snippet",
        maxResults= 50, 
        regionCode='ES', 
        pageToken=next_page_token if next_page_token else ""
    ).execute()  # Mover la ejecución aquí

    for item in search_response['items']:
        all_video.append(item) 
        

    next_page_token = search_response.get('nextPageToken')

    if not next_page_token:
        break

# %%
len(all_video)
# Out:
# 739

# %%
[x['snippet']['title'] for x in all_video]
# Out:
# ['AMNISTÍA: La COMISIÓN EUROPEA pide al GOBIERNO más INFORMACIÓN sobre la futura LEY | RTVE',
#  'Felipe González, sobre la amnistía: “Es el Estado el que pide perdón, no el que perdona”',
#  'Ley de Amnistía: ¿ESPAÑA podría PERDER FONDOS de la UNIÓN EUROPEA?',
#  'AMNISTÍA: El PP acusa a SÁNCHEZ de poner la CONSTITUCIÓN al servicio del INDEPENDENTISMO | RTVE',
#  '¿Se puede aprobar una ley de amnistía? Difícil, pero no imposible',
#  'AMNISTÍA: PARTE del CGPJ pide un PLENO EXTRAORDINARIO para RECHAZAR la LEY | RTVE',
#  'Bruselas analiza la ley de amnistía con &quot;objetividad&quot; e &quot;independencia&quot;',
#  'AMNISTÍA: ARAGONÈS y GARRIGA protagonizan un BRONCO DEBATE en el PARLAMENT | RTVE Noticias',
#  '¿Qué es la amnistía y en qué se diferencia del indulto del procés de Cataluña? | EL PAÍS',
#  'LEY AMNISTÍA: El PSOE la REGISTRA en el CONGRESO SIN sus SOCIOS y la explica los DETALLES I RTVE',
#  'Las cuatro veces que Sánchez negó la amnistía «por convicción personal y política»',
#  'AMNISTÍA: Los PROGRESISTAS del CGPJ se plantean NO ACUDIR al PLENO para RECHAZAR la LEY | RTVE',
#  'Ley de amnistía: ¿Qué es? ¿Es posible su aprobación?',
#  'LEY AMNISTÍA: El GOBIERNO dice que es &quot;IMPECABLE JURÍDICAMENTE&quot; y pide CONFIANZA | RTVE Noticias',
#  'INVESTIDURA: SÁNCHEZ dice que “SERÁ CLARO&quot; sobre la AMNISTÍA &quot;CUANDO TOQUE&quot; y NO PREVÉ ELECCIONES',
#  'DIRECTO | Debate en la Eurocámara por la ley de amnistía española',
#  'INVESTIDURA SÁNCHEZ: ZAPATERO defiende la AMNISTÍA y dice que “NO es INCONSTITUCIONAL” | RTVE',
#  'AMNISTÍA: PSOE y JUNTS alcanzan un ACUERDO sobre la LEY y la INVESTIDURA de SÁNCHEZ se allana | RTVE',
#  'AMNISTÍA A PUIGDEMONT: Sánchez Sin Escrúpulos',
#  'La polémica ley de amnistía en España que permitirá seguir al actual presidente Pedro Sánchez',
#  'Pedro Sánchez defiende la amnistía en el comité federal del PSOE por “el interés de España&quot; |EL PAÍS',
#  'CONCENTRACIONES AMNISTÍA: CIENTOS DE MILES DE PERSONAS &quot;POR LA IGUALDAD&quot; a petición del PP | RTVE',
#  'Los Fiscales piden a Bruselas que si Sánchez aprueba la amnistía actúe con España como con Polonia',
#  'INVESTIDURA: El PP califica de HUMILLACIÓN el ACUERDO de ERC y PSOE sobre la AMNISTÍA | RTVE',
#  'AMNISTÍA: PSOE se DESMARCA de sus HISTÓRICOS y criticas a GUERRA por su COMENTARIO sobre DÍAZ | RTVE',
#  'La polémica ley de amnistía en España que permitirá seguir al actual presidente Pedro Sánchez • RFI',
#  'ÚLTIMA HORA | El Gobierno de España se adelanta: irá a Europa a explicar la ley de la amnistia',
#  'Acuerdo por ley de amnistía desata protestas en España',
#  'AMNISTÍA: JUNQUERAS y OTEGI piden AVANZAR en el INDEPENDENTISMO en ACTO del SINN FÉIN | RTVE',
#  'AMNISTÍA: Voces CRÍTICAS del PP NO VEN &quot;ACERTADA&quot; la CONVOCATORIA tras las palabras de AZNAR | RTVE',
#  'INVESTIDURA: IBARRA compara la AMNISTÍA con una VIOLACIÓN y ALEGRÍA le pide &quot;CONTENCIÓN&quot; | RTVE',
#  'Las reacciones del Gobierno ante una futura ley de amnistía: &quot;No estamos en ese momento&quot;',
#  'La hemeroteca de Sánchez y su Gobierno: «Amnistía no»',
#  '🇪🇺 ¿Qué opina la UE sobre la amnistía en España? | Simple Política',
#  'MANIFESTACIONES en CONTRA de la LEY de AMNISTÍA ante la SEDE del PSOE en 10 CIUDADES ESPAÑOLA | RTVE',
#  'AMNISTÍA | El comisario europeo Reynders: &quot;Cataluña es &#39;un asunto interno&#39; español&quot; | EL PAÍS',
#  'LEY AMNISTÍA: La COMISIÓN de JUSTICIA de la UE la estudiará &quot;CUIDADOSAMENTE&quot; cuando se APRUEBE |',
#  'El Debate, a pie de calle: «La amnistía no la necesitan los españoles, la necesita Sánchez»',
#  'FERRAZ | Dentro de la manifestación más numerosa contra la amnistía y la investidura de Sánchez',
#  'SÁNCHEZ habla de AMNISTÍA: &quot;Una FORMA de SUPERAR las CONSECUENCIAS JUDICIALES de la CRISIS&quot; | RTVE',
#  'UE: El PP EUROPEO llevará la AMNISTÍA al próximo PLENO del PARLAMENTO EUROPEO | RTVE Noticias',
#  'Alfonso Guerra, sobre la amnistía: &quot;Me rebelo, no lo aguanto, no lo voy a soportar&quot;',
#  'CGPJ: APRUEBA una DECLARACIÓN contra la LEY de AMNISTÍA gracias a la MAYORÍA CONSERVADORA | RTVE',
#  'AMNISTÍA: BOLAÑOS emplaza a BRUSELAS a abordar la LEY cuando se REGISTRE en el CONGRESO | RTVE',
#  'El PP MUEVE FICHA contra la AMNISTÍA en vísperas de la INVESTIDURA de FEIJÓO | RTVE Noticias',
#  'Así ha evolucionado el discurso de Pedro Sánchez sobre la amnistía',
#  'Europa pide explicaciones al Gobierno por la amnistía',
#  'INVESTIDURA | Bolaños explica la ley de amnistía del PSOE: &quot;Queremos cerrar heridas&quot; | EL PAÍS',
#  'PROTESTAS AMNISTÍA: ¿QUIÉNES son los ULTRAS que han provocado DISTURBIOS en la sede del PSOE? | RTVE',
#  'FERRAZ | Manifestantes protestan contra la amnistía ante la investidura: &quot;Puigdemont, a prisión&quot;',
#  'Europa se tapa los ojos ante la crisis política en España: ¿amnistía a &quot;delitos de terrorismo”?',
#  'DIRECTO | &#39;La amnistía, a debate&#39;, con expertos juristas y moderado por María Jamardo',
#  'Sánchez defiende la amnistía para &quot;tener un gobierno&quot; y &quot;avanzar en la concordia&quot;',
#  'Borrell, sobre la ley de amnistía: &quot;Ya se pueden imaginar lo que pienso&quot;',
#  '¿Puede el Senado o los jueces parar la amnistía de Sánchez y Puigdemont?',
#  'El PSOE y Sumar enfrían la ley de amnistía antes de la investidura de Sánchez',
#  'España desarma la amnistía de Sánchez: «Ha quebrado la Constitución»',
#  'INVESTIDURA: El PP anuncia NUEVAS MOVILIZACIONES para protestar contra la AMNISTÍA | RTVE',
#  'AMNISTÍA | La &quot;humillación&quot; del mediador y otros titulares de la manifestación del PP | EL PAÍS',
#  'El Rey de España ante la amnistía: su poder para evitar la desaparición del Estado de Derecho',
#  'Page rechaza la amnistía y avisa que aunque cupiera en la Constitución &quot;no casa con valores de PSOE&quot;',
#  'Alsina, sobre la ley de amnistía: &quot;Ahora el conflicto es entre españoles&quot;',
#  'Sánchez: &quot;Ni el referéndum ni la amnistía son posibles, pero espero llegar a una posición pactada&quot;',
#  'El enésimo &quot;cambio de opinión&quot; de Sánchez: cuando decía que &quot;la amnistía no es posible&quot;',
#  'La BROMA de BIDEN a FELIPE VI que dejó al REY a carcajada limpia | Diario AS',
#  'ÚLTIMA HORA | España: Mas tensión por la amnistía: La Guardia Civil dispuesta a “derramar la sangre”',
#  'AMNISTÍA: La POLICÍA justifica en la &quot;PRESENCIA de ULTRAS&quot; su POLÉMICA CARGA en FERRAZ  | RTVE',
#  '&quot;El último que puede echar atrás la ley de amnistía es el Tribunal Constitucional&quot;. Leopoldo Abad',
#  'España: intensas manifestaciones tras firma de acuerdo de amnistía entre PSOE y Junts per Catalunya',
#  'Investidura de Pedro Sánchez; protestas contra la ley de amnistía en Madrid',
#  'La reacción de Pedro Sánchez cuando un vecino le grita ‘¡que te vote Txapote!’ el 28M',
#  'El oscuro vaticinio de Felipe González sobre la amnistía: &quot;Puigdemont lo podrá volver a hacer&quot;',
#  'VOX-AMNISTÍA: ABASCAL anuncia ACCIONES LEGALES contra INTERIOR por las CARGAS POLICIALES en FERRAZ |',
#  'LEY AMNISTÍA: El PSOE decidió presentarla SIN SUS SOCIOS ante las PEGAS de algún PARTIDO | RTVE',
#  'Miles de personas protestan contra la amnistía frente a las sedes del PSOE en toda España',
#  'ÚLTIMA HORA | Más tensión en España por la amnistía: represalia del Gobierno contra la Guardia Civil',
#  'Vox se querellará mañana contra Sánchez por la ley de amnistía',
#  'JORNADAS VOX AMNISTÍA | ‘No vamos a permitir que se destruya la nación española’',
#  'LEY AMNISTÍA: Abarca MÁS de una DÉCADA de &#39;PROCÉS&#39;, incluye a los POLICÍAS del 1-O | RTVE Noticias',
#  'El comisario de Justicia de la UE avisa de que &quot;hay algunos límites&quot; a una ley de amnistía',
#  '¿QUÉ OPINA LA UNIÓN EUROPEA SOBRE LA AMNISTÍA? ¿SALVARÁ A ESPAÑA?',
#  'INVESTIDURA FEIJÓO: ERC y JUNTS piden ir más allá de la AMNISTÍA y PACTAR un nuevo REFERÉNDUM | RTVE',
#  'Page critica la amnistía ante Sánchez y le afea que choca con el «proyecto del PSOE»',
#  'LEY AMNISTÍA: La BRONCA se traslada al PARLAMENTO EUROPEO | RTVE Noticias',
#  'Expósito: &quot;Es un escándalo que Pedro Sánchez y Puigdemont estén negociando el poder y la amnistía&quot;',
#  'DIRECTO | Feijóo habla sobre la amnistía en el Congreso de los Diputados',
#  'La calle, ante la amnistía de Puigdemont: «Es una barbaridad, tiene que estar en la cárcel»',
#  '🎙 PODCAST | España - Catalunya: del abismo a la amnistía',
#  'CATALUÑA | Aragonès: &quot;La amnistía es imprescindible&quot; | EL PAÍS',
#  'MANIFESTACIÓN | Miles de personas protestan contra la amnistía en Cibeles | EL PAÍS',
#  'MANIFESTACIÓN BARCELONA: FEIJÓO acusa a SÁNCHEZ de hacer &quot;NEGOCIO&quot; con la AMNISTÍA | RTVE Noticias',
#  'Carlos Alsina avisa de la nueva ‘trola’ que nos colará Sánchez para tragar con la amnistía',
#  'Aguirre se manifiesta en contra de la amnistía y reclama al PSOE un referéndum',
#  'PROTESTAS AMNISTÍA: 24 DETENIDOS y 7 POLICÍAS HERIDOS tras el CIERRE del ACUERDO PSOE-JUNTS | RTVE',
#  'Conferencia &#39;Desmontando las mentiras de la #amnistía&#39;, con Teresa Freixes',
#  'El gobierno y la oposición chocan en la Eurocámara en el debate sobre la ley de amnistía',
#  'El nacionalismo catalán, explicado en 4 minutos | España',
#  'Informe desde Madrid: protestas contra la amnistía a independentistas catalanes',
#  'Tomás Gómez: &quot;Sánchez sacará adelante la ley de amnistía y luego el referéndum de autodeterminación&quot;',
#  'Protestas en España | ¿En qué consiste la polémica ley de amnistía pactada por Pedro Sánchez?',
#  'SÁNCHEZ-AMNISTÍA: &quot;Estamos NEGOCIANDO, cuando tengamos una posición concreta la expondremos&quot; | RTVE',
#  'INVESTIDURA: SÁNCHEZ se reunirá con todos los PARTIDOS menos con VOX y evita decir &quot;AMNISTÍA&quot; | RTVE',
#  'AMNISTÍA | Rodríguez Ibarra compara la amnistía con una violación y Alegría le responde | EL PAÍS',
#  'LEY AMNISTÍA: El PSOE tras REGISTRARLA SIN la FIRMA de sus SOCIOS, &quot;ES PLENAMENTE CONSTITUCIONAL&quot;',
#  'LEY AMNISTÍA: La COMISIÓN EUROPEA estudiará el TEXTO y se reunirá PRÓXIMAMENTE con el GOBIERNO |RTVE',
#  'AÑO JUDICIAL: El presidente del SUPREMO pide a PP y PSOE sacar sus INTERESES de la JUSTICIA |',
#  'Felipe González y Alfonso Guerra contra la amnistía: los dardos de los veteranos contra el Gobierno',
#  '«Sánchez, vete ya», la protesta contra la amnistía desborda Colón',
#  'INVESTIDURA: FEIJÓO acusa a SÁNCHEZ de &quot;ATRACAR a la DEMOCRACIA española&quot; con la AMNISTÍA | RTVE',
#  'INVESTIDURA | Manifestaciones contra la amnistía y la investidura de Sánchez en el Congreso |EL PAÍS',
#  'España sale a la calle: indignación ante la ley de amnistía que prepara Sánchez con Puigdemont',
#  'Tres detenidos en la protesta contra la amnistía ante la sede del PSOE de Madrid',
#  'Alfonso Guerra, sobre la amnistía: &quot;Me rebelo, no lo aguanto, no lo voy a soportar&quot;',
#  'INVESTIDURA: SÁNCHEZ DEFIENDE la AMNISTÍA ante el COMITÉ FEDERAL del PSOE | RTVE Noticias',
#  'LEY AMNISTÍA. CONOCE SUS CONSECUENCIAS #amnistia #ley #noticia #derecho #viral #curiosidades #españa',
#  'Manifestantes contra la amnistía interrumpen el minuto de silencio por Marruecos en Barcelona',
#  'SERRAT interrumpe un concierto cuando le piden que cante el CATALÁN',
#  '📈 ¿Qué opinan los españoles sobre la AMNISTÍA? | Simple Política',
#  'LEY AMNISTÍA: Abarca MÁS de una DÉCADA de &#39;PROCÉS&#39;, incluye a los POLICÍAS del 1-O | RTVE Noticias',
#  'Pedro Sánchez defiende la amnistía en el comité federal del PSOE por “el interés de España&quot; #shorts',
#  'AMNISTÍA: TRES detenidos en las PROTESTAS ante la SEDE del PSOE en MADRID | RTVE Noticias',
#  'Mensaje de Miguel Ángel Revilla a Pedro Sánchez por la amnistía: &quot;Piénsatelo bien&quot; - El Hormiguero',
#  'Opinión de Julián Galán sobre la Ley de Amnistía: &quot;Tiene difícil encaje constitucional&quot;.',
#  '¿Se puede APROBAR una AMNISTÍA en ESPAÑA? | Simple Política',
#  'Sánchez anuncia su apoyo a la amnistía &quot;en el nombre de España&quot;',
#  'Manifestación en Madrid contra la amnistía\xa0a los líderes del &#39;procés&#39;',
#  'La manifestación de Barcelona contra la amnistía en 1 minuto, por Alán Barroso',
#  'García-Page se subleva por fin contra Sánchez y la miserable amnistía: &quot;¡Vamos a plantear batalla!&quot;',
#  'Cantabria denuncia en Bruselas la ley de amnistía',
#  'Una magistrada, sobre la amnistía cree que aunque la Constitución no la mencione «no prejuzga»',
#  'Pedro Sánchez: &quot;En el nombre de España, del interés de España, defiendo la amnistía en Catalunya&quot;',
#  'LEY AMNISTÍA: SUMAR se QUERELLA contra los VOCALES CONSERVADORES del CGPJ y el PSOE se DESMARCA |',
#  'Zapatero: &quot;La ley de amnistía no tiene reproches. Es valiente e inteligente&quot;',
#  'Miles de personas protestan contra la amnistía frente a las sedes del PSOE en toda España',
#  'Independencia de Cataluña: dos chicas discuten sus visiones a favor y en contra',
#  'Manifestantes contra la amnistía CORTAN GRAN VÍA y se concentran frente al CONGRESO',
#  'Feijóo: &quot;Si Puigdemont nos propone la amnistía como requisito, nos podemos ahorrar la reunión&quot;',
#  'El socialista Ibarra compara la amnistía con violar a 40 millones de españoles #Ibarra #Amnistía',
#  'PUIGDEMONT: Marca las CONDICIONES para empezar a NEGOCIAR la INVESTIDURA | RTVE Noticias',
#  'El Senado aprueba reformar el Reglamento para retrasar la ley de amnistía',
#  'La reacción de Pedro Sánchez cuando un vecino le grita ‘¡que te vote Txapote!’ el 28M',
#  'SENADO: APROBADA la REFORMA del REGLAMENTO que DILATARÁ la LEY de AMNISTÍA | RTVE',
#  'Informe desde Madrid: manifestación masiva contra ley de amnistía a independentistas',
#  'Informe desde Madrid: seguidores del PP protestan contra posible amnistía a independentistas',
#  'Almeida clama contra la amnistía y critica la «deshonra y el deshonor» de Pedro Sánchez',
#  'Alsina comenta con Susanna Griso la ley de amnistía: &quot;Hay 13 gobiernos autonómicos en contra&quot;',
#  'Unos cincuenta españoles se concentran en Bruselas contra la ley de amnistía',
#  'ARAGONÈS, tras el pacto ERC-PSOE sobre la AMNISTÍA: &quot;Es hora de AVANZAR hacia el REFERÉNDUM&quot; | RTVE',
#  'La BROMA de BIDEN a FELIPE VI que dejó al REY a carcajada limpia | Diario AS',
#  'Miles de personas salen a la calle en contra de la amnistía en Barcelona',
#  'Zapatero: &quot;La ley de amnistía no tiene reproches. Es valiente e inteligente&quot;',
#  'LEY AMNISTÍA: SUMAR se QUERELLA contra los VOCALES CONSERVADORES del CGPJ y el PSOE se DESMARCA |',
#  'Independencia de Cataluña: dos chicas discuten sus visiones a favor y en contra',
#  'Manifestantes contra la amnistía CORTAN GRAN VÍA y se concentran frente al CONGRESO',
#  'LEY AMNISTÍA: FEIJÓO se reúne con CORRESPONSALES EXTRANJEROS para expresar su &quot;PREOCUPACIÓN&quot; | RTVE',
#  'Feijóo: &quot;Si Puigdemont nos propone la amnistía como requisito, nos podemos ahorrar la reunión&quot;',
#  'El socialista Ibarra compara la amnistía con violar a 40 millones de españoles #Ibarra #Amnistía',
#  'PUIGDEMONT: Marca las CONDICIONES para empezar a NEGOCIAR la INVESTIDURA | RTVE Noticias',
#  'El Senado aprueba reformar el Reglamento para retrasar la ley de amnistía',
#  'SENADO: APROBADA la REFORMA del REGLAMENTO que DILATARÁ la LEY de AMNISTÍA | RTVE',
#  'Informe desde Madrid: manifestación masiva contra ley de amnistía a independentistas',
#  'Informe desde Madrid: seguidores del PP protestan contra posible amnistía a independentistas',
#  'Alsina comenta con Susanna Griso la ley de amnistía: &quot;Hay 13 gobiernos autonómicos en contra&quot;',
#  'Almeida clama contra la amnistía y critica la «deshonra y el deshonor» de Pedro Sánchez',
#  'Unos cincuenta españoles se concentran en Bruselas contra la ley de amnistía',
#  'ARAGONÈS, tras el pacto ERC-PSOE sobre la AMNISTÍA: &quot;Es hora de AVANZAR hacia el REFERÉNDUM&quot; | RTVE',
#  'Miles de personas salen a la calle en contra de la amnistía en Barcelona',
#  'Catalanes reaccionan al discurso del rey de España',
#  'INVESTIDURA: FEIJÓO ofrece a SÁNCHEZ &quot;una TERCERA VÍA&quot; a la AMNISTÍA con &quot;PACTOS de ESTADO&quot; | RTVE',
#  'Sánchez: &quot;Defiendo la amnistía para hacer de la necesidad, virtud&quot;',
#  'Eneko Andueza, candidato socialista a lehendakari, se posiciona a favor de la amnistía en Cataluña',
#  'Pérez-Reverte: &quot;Estoy en contra de la amnistía, me parece mal&quot; - El Hormiguero',
#  'Crisis en España por la Ley de Amnistía',
#  'Girauta, sobre la amnistía: «Toda España es víctima de un golpe de Estado»',
#  'Alfonso Guerra carga contra Puigdemont y contra la amnistía',
#  'AMNISTÍA: El CERCLE D&#39;ECONOMIA la CONSIDERA &quot;UNA OPORTUNIDAD&quot; para REFORZAR la DEMOCRACIA | RTVE',
#  'JUNQUERAS: Afirma que la LEY de AMNISTÍA &quot;ya está PACTADA&quot; con el PSOE desde AGOSTO | RTVE Noticias',
#  '🔴 DIRECTO | El Parlamento Europeo trata la cuestión de la amnistía',
#  'Feijóo, tajante con las mentiras de Sánchez sobre la amnistía: «Su palabra no vale nada»',
#  'Rajoy clama contra la amnistía: «Me pone muy nervioso»',
#  'Sánchez opta a la investidura y avisa sobre la ley de amnistía: &quot;El diálogo es el método y la Consti',
#  'Leguina: «La amnistía es una bajada de pantalones impresentable, y todo por volver a la Moncloa»',
#  'DIRECTO | ESPECIAL: España en jaque. PSOE y Junts pactan la amnistía y avanza el acuerdo de gobierno',
#  'AMNISTÍA : PROTESTA  en &quot;DEFENSA DE LA CONSTITUCIÓN, por la UNIDAD y la IGUALDAD&quot; |RTVE',
#  'FEIJÓO tilda de &quot;CACICADA&quot; e &quot;INDIGNIDAD&quot; la posible AMNISTÍA en un ACTO MULTITUDINARIO del PP |',
#  'Rufián se abre la chaqueta para responder a Abascal y le deja este recado',
#  'AMNISTÍA: La POLICÍA CARGA contra los RADICALES en la PROTESTA cerca de FERRAZ (MADRID) | RTVE',
#  'INVESTIDURA SÁNCHEZ: JUNTS NO confirma su SÍ al acuerdo ERC y PSOE sobre la AMNISTÍA | RTVE',
#  'EL PP CONSIGUE FRENAR LA LEY DE LA AMNISTÍA EN EL SENADO- PEDRO SANCHEZ TIEMBLA',
#  '🎙 PODCAST | Amnistía: claves básicas para el debate que viene',
#  'Felipe González alerta del &quot;chantaje&quot; de la amnistía que no es constitucional',
#  'ITALIA: ¿En qué se nota que gobierna la ultraderecha de Meloni? | EL PAÍS',
#  'El plan secreto de Sánchez y Pumpido para colar la amnistía',
#  'AMNISTÍA A LOS INDEPENDENTISTAS, ¿DEBE HACERSE? - El periodista David Jiménez responde a Jordi Wild',
#  'Decenas de miles de personas dicen no a la amnistía en Barcelona',
#  'Sánchez se quita la careta: «Por el interés de España defiendo hoy la amnistía en Cataluña»',
#  'INVESTIDURA SÁNCHEZ: INMINENTE, pero DIFÍCIL de ENCAJAR con tantas CITAS en el CALENDARIO | RTVE',
#  'AMNISTÍA: La POLICÍA CARGA contra MANIFESTANTES cerca de la sede del PSOE en FERRAZ (MADRID) | RTVE',
#  'DIRECTO | El Parlamento Europeo debate sobre la ley de amnistía tras el pacto del PSOE con Junts',
#  'El Gobierno, en 2021: «La amnistía no es planteable en un estado constitucional y democrático»',
#  'DIRECTO | El Parlamento Europeo debate sobre la ley de amnistía tras el pacto del PSOE con Junts',
#  'La Encuesta| ¿Cree que debería darse la amnistía a los independentistas catalanes?',
#  'ÚLTIMA HORA | Europa avisa a Sánchez y Puigdemont: vigilarán de “muy cerca” la ley de amnistía',
#  'El Gobierno, en 2021: «La amnistía no es planteable en un estado constitucional y democrático»',
#  'Àngels Barceló: &quot;Todo el mundo debería ser capaz de confrontar la amnistía con argumentos&quot;',
#  'La ley de amnistía y sus opiniones 2023',
#  'BOLAÑOS, tras el ACUERDO con ERC: “La AMNISTÍA devolverá lo que nunca debió salir de la política”',
#  'El contundente vídeo de Ayuso que desmiente al PSOE con la amnistía',
#  'DIRECTO / Nuevas protestas contra la amnistía ante la sede del PSOE en la calle Ferraz de Madrid',
#  'Pedro Sanchez fue reelegido como Presidente de España a pesar de su Ley de Amnistía',
#  'ANÁLISIS | Una semana de protestas contra la amnistía: &quot;No se debe andar encendiendo cerillas&quot;',
#  'Aznar equipara el rechazo a la amnistía con el &quot;¡Basta ya!&quot; a ETA y el Gobierno le acusa de golpista',
#  'CONGRESO: El REY FELIPE VI defiende la CONSTITUCIÓN y una España &quot;SÓLIDA y UNIDA&quot; | RTVE',
#  'Esto es lo que debes saber de la ley de amnistía: claves, afectados y tiempos',
#  'INVESTIDURA SÁNCHEZ: El PSOE y ERC pactan el TRASPASO INTEGRAL de los RODALIES en CATALUÑA | RTVE',
#  'El Debate, en la protesta contra la amnistía de Valencia: &quot;No quiero que se venda España&quot;',
#  'FERRAZ | Diez lemas usados en la manifestación contra la amnistía en la sede del PSOE | EL PAÍS',
#  'Amnistía en España: &quot;El poder legislativo se ha cargado al judicial&quot;. José María Pernas',
#  'Qué es mentir para Pedro Sánchez - El Hormiguero',
#  'El PARLAMENTO EUROPEO debate sobre la protección del ESTADO de DERECHO en ESPAÑA | RTVE',
#  'Feijóo responde a Sánchez por su defensa de la amnistía: &quot;Nos ha mentido desde el primer instante&quot;',
#  '8M: MUJERES contra la &#39;LEY TRANS&#39; interrumpen el ACTO FEMINISTA presidido por IRENE MONTERO | RTVE',
#  'ERC y PSOE LLEGAN a un ACUERDO GLOBAL para la INVESTIDURA de SÁNCHEZ a FALTA del SÍ de JUNTS | RTVE',
#  'FERRAZ | Muñecas hinchables y consignas soeces en la protesta contra la amnistía y la investidura',
#  'Los VOTANTES del PSOE: ¿A favor de la AMNISTÍA? 😳',
#  'La AMNISTÍA es un ATENTADO contra España',
#  'Así ha sido la manifestación contra la amnistía en Madrid',
#  'UE: BOLAÑOS asegura que BRUSELAS tiene &quot;CERO PREOCUPACIÓN&quot; por la LEY de AMNISTÍA | RTVE Noticias',
#  'Miles de personas se manifiestan en las capitales españolas contra la ley de amnistía',
#  'Page avisa que pactar amnistía con independentistas no tiene &quot;base moral&quot;',
#  'Josep Pedrerol se moja sobre la amnistía de forma tajante - El Hormiguero',
#  'AMNISTÍA | Bolaños, en Bruselas: &quot;En la Comisión Europea hay cero preocupación&quot; por la amnistía',
#  'Todas las veces que el PSOE creyó que una amnistía &quot;era incostitucional&quot;',
#  'Mensaje del Rey sobre Cataluña | España',
#  'Seis minutos de broncas: el vídeo que resume el tenso clima político en España',
#  '🤔 ¿DE VERDAD alguien duda de si PEDRO SÁNCHEZ concederá la AMNISTÍA y el REFERÉNDUM a PUIGDEMONT? 😄',
#  'El GOBIERNO envía a BRUSELAS la LEY de AMNISTÍA y solicita una reunión con REYNDERS | RTVE',
#  'El PSOE y la amnistía',
#  '&quot;Puigdemont ha puesto de rodillas a Pedro Sánchez&quot; Ayuso sobre la amnistía',
#  '¿Qué es la AMNISTÍA? CONCEDERLA ES EL FIN DE LA DEMOCRACIA. SANCHEZ Y  CARLES PUIGDEMONT',
#  'Ayuso sobre la amnistía: &quot;Nos lleva a un estado dictatorial&quot;',
#  '&quot;Hoy defiendo la amnistía en Cataluña&quot; Pedro Sánchez #shorts',
#  '&quot;¿Por qué nos ha mentido tanto, presidente?&quot; La respuesta de Pedro Sánchez a Alsina',
#  'Abascal carga contra Sánchez y la amnistía: &quot;No lo vamos a permitir&quot;',
#  '¿CÓMO viven hoy el ‘PROCÉS’ los JÓVENES catalanes? | Reportaje',
#  'Vicente Vallés saca a la luz un vídeo que echa por tierra el perverso plan de Sánchez con Puigdemont',
#  '&quot;Es de COBARDES&quot; Feijóo sobre la votación interna sobre Amnistía de Sánchez #shorts',
#  'Alsina debate con Susanna Griso sobre la ley de amnistía recalcando que el PSOE &quot;no ha cumplido&quot;',
#  'PÉREZ-REVERTE EN EL HORMIGUERO contra #PedroSánchez',
#  'PEDRO SÁNCHEZ: 1ª ENTREVISTA tras ser INVESTIDO PRESIDENTE del GOBIERNO | RTVE',
#  'PÉREZ-REVERTE EN EL HORMIGUERO contra #PedroSánchez',
#  'PEDRO SÁNCHEZ: 1ª ENTREVISTA tras ser INVESTIDO PRESIDENTE del GOBIERNO | RTVE',
#  'Ley de amnistía: texto, incógnitas y discrepancias | PODCAST Hoy en EL PAÍS',
#  'DIRECTO | La amnistía, a debate en el Pleno del Ayuntamiento de Madrid | EL PAÍS',
#  'Ministros intentan desviar la atención sobre la amnistía e insisten en la vía del diálogo',
#  'Zapatero sobre la amnistía:  &quot;En el Gobierno, si hay que cambiar de opinión, se cambia&quot;',
#  'Concentraciones ante las sedes del partido socialista contra la amnistía',
#  'DIRECTO | Jornadas del PP sobre la amnistía en el Congreso',
#  'La Comisión Europea dice estar «atenta a la evolución» de la amnistía a los golpistas',
#  'Alsina, sobre Sánchez y la amnistía: &quot;Le es necesaria para sacar adelante su investidura&quot;',
#  'TODO lo que querías Saber sobre la LEY DE AMNISTÍA, con Joaquim Bosch | CANAL RED @LauraArroyo',
#  '💥 TODAS LAS MENTIRAS de PEDRO SÁNCHEZ y el PSOE sobre la AMNISTÍA antes del chantaje de PUIGDEMONT',
#  'ABASCAL a SÁNCHEZ: &quot;Si das esa amnistía tendrás que pedir una habitación a PUIGDEMONT en Waterloo”',
#  '&quot;¡A tu puto país, sinvergüenza!&quot; | Agresión RACISTA a una mujer en un autobús de la EMT',
#  'José Luis Corcuera: «La amnistía es la antítesis de la democracia, el autoritarismo»',
#  '¡MIRA, PEDRÍN! 🎵 | PUIGDEMONT y PEDRO SÁNCHEZ negocian AMNISTÍA y REFERÉNDUM | Las Ketchup - ASEREJÉ',
#  'Un 60% de los españoles creen que la amnistía es injusta y un privilegio',
#  'ESPAÑOLES, PREPÁRENSE, ¡EL FELÓN YA TIENE LA AMNISTÍA!',
#  'El vídeo de un diputado del PSOE defendiendo la Ley de Amnistía demoledor para Sánchez',
#  'Page rechaza la amnistía: &quot;Si hay que ejercer recurso, lo haré&quot;',
#  'DIRECTO | Acto del PP en Madrid contra una posible ley de amnistía | EL PAÍS',
#  'CONGRESO: APERTURA de la CORTES GENERALES de la XV LEGISLATURA | RTVE Noticias',
#  'Resines contra la AMNISTÍA, Pedro Sánchez, el PSOE y EH BILDU #shorts',
#  'PP moviliza a MILES de PERSONAS en MADRID en CONTRA de una POSIBLE AMINISTÍA a INDEPENDENTISTAS',
#  'ESPAÑA NO SE VENDE | No a la Amnistía | EL TAMBORILERO - Raphael (COVER) | VILLANCICO PEDRO SÁNCHEZ',
#  'Borrell ‘pilota’ el rechazo europeo | LA OPINION DE GABI SANZ',
#  'DEBATE de INVESTIDURA | LA FUERTE BRONCA COMPLETA durante la intervención de EH BILDU',
#  '¿ESTA VD A FAVOR O EN CONTRA DE UNA AMNISTÍA A PUIGDEMONT Y LOS ENCAUSADOS CATALANES?',
#  'Senador republicano Marco Rubio reacciona a nueva ley de inmigración en Florida',
#  'Alfonso Guerra pide al PSOE rechazar la ley de amnistía: &quot;Es la condena de la Transición&quot;',
#  'Manifestantes contra la amnistía interrumpen el minuto de silencio por Marruecos en Barcelona',
#  '&quot;El PP rompe España&quot; Sánchez sobre la Amnistía y Cataluña #shorts',
#  '&quot;QUE NO NOS TOMEN EL PELO&quot; Feijóo sobre la Amnistía y la investidura de Sánchez #shorts',
#  'Sánchez, sobre la amnistía: &quot;En nombre de España, vamos a conceder una amnistía&quot;',
#  'PIQUÉ y SU FEO GESTO a la NOVIA de FRENKIE DE JONG en 2019 | Diario AS',
#  '🔴 DIRECTO MADRID | Mitin del PP en contra de la amnistía',
#  'Arturo Pérez-Reverte analiza a los líderes políticos actuales - El Hormiguero',
#  'El PSOE ESTÁ DANDO VERGÜENZA con la AMNISTÍA ❌ #noticias #amnistía #psoe #ley  #amnistía #reaccion',
#  'Vicente Vallés desmonta la sucia estrategia de Sánchez con la amnistía en dos minutos demoledores',
#  'Herrera: &quot;En Europa cada vez hay más alarmas contra la amnistía&quot;',
#  'Amnistía y condonación de la deuda en Cataluña: la máquina de hacer dinero y la sociedad Peter Pan',
#  'DIRECTO FERRAZ | Así ha sido la manifestación contra la amnistía en la sede del PSOE | EL PAÍS',
#  'Amnistía para condenados por secuestro y narcotráfico. Juanita Gómez opina',
#  'Puigdemont pide la amnistía y un mediador para negociar: &quot;O elecciones o pactan con nosotros&quot;',
#  '1/4 Ley de Amnistía: línea roja, pierde la política. Rueda de prensa de Miguel Ángel Revilla',
#  'Los REYES FELIPE y LETIZIA RECREAN en el SET de RTVE su SALUDO CÓMPLICE DOS DÉCADAS DESPUÉS | RTVE',
#  'DIRECTO | Manifestación de Sociedad Civil Catalana en Barcelona contra la amnistía | EL PAÍS',
#  'Alsina critica la ley de amnistía: &quot;No estaríamos hablando de esto si no fuera por los siete votos&quot;',
#  'Aznar, demoledor contra Sánchez: &quot;Es un peligro para la democracia constitucional&quot;',
#  'Felipe González despelleja a Zapatero y a Sánchez por querer colar una inexplicable amnistía',
#  'Felipe González despelleja a Zapatero y a Sánchez por querer colar una inexplicable amnistía',
#  'INVESTIDURA SÁNCHEZ: El PSOE reconoce que es COMPLEJA pero ve POSIBLE sacarla ADELANTE | RTVE',
#  'CONGRESO-LENGUAS COOFICIALES: VOX sale del HEMICICLO y deja sus PINGANILLOS en el SITIO de SÁNCHEZ',
#  'Experta en derecho constitucional contra la amnistía: &quot;Se negocia por un puñado de votos&quot;',
#  'Manuel Valls, sobre la amnistía: &quot;Es una humillación deliberada a la generación de la Transición&quot;',
#  'INVESTIDURA-ACUERDO PSOE-ERC: JUNQUERAS, &quot;HOY gana CATALUÑA con una AMNISTÍA SIN EXCEPCIONES&quot; | RTVE',
#  'BARCELONA: SUMAR propone una AMNISTÍA de 2013 a 2023 por la &quot;FALTA de PROPORCIONALIDAD JUDICIAL&quot;',
#  'AMNISTÍA INTERNACIONAL: &quot;En ESPAÑA, lo MÁS PREOCUPANTE es la IMPUNIDAD en ciertos temas&quot; | RTVE',
#  'Pedro Sánchez confía en su investidura: &quot;El acuerdo se puede, se debe y se va a alcanzar” | EL PAÍS',
#  'ESPAÑA QUEMA LA CALLE CON LA AMNISTÍA: ¡SERÁ IMPOSIBLE DE REVERTIR!',
#  '&quot;DIMISIÓN es lo que tiene que hacer Pedro Sánchez&quot; Feijóo sobre Amnistía',
#  'El Gobierno cree que la ley de amnistía es &quot;impecable&quot;',
#  'La Ley de amnistía desde un punto de vista jurídico',
#  'El Senado vota en contra de la amnistía',
#  'Protestas masivas en España contra ley de amnistía',
#  'Alsina, sobre la amnistía: &quot;Has corrompido la Generalitat de Cataluña. Pero eso se perdona pronto&quot;',
#  'El Programa de Cuesta: La amnistía, los nuevos ridículos de Yoli y la reducción de jornada laboral',
#  'El monólogo de las ocho: &quot;Pedro Sánchez ha comprado su investidura a cargo del Estado&quot;',
#  'Alfonso Guerra se “rebela” contra la amnistía: &quot;Yo no me resigno&quot;',
#  'Del Estatut a la amnistía: todas las veces que se ha roto España según el PP',
#  'Amnistía y asalto al poder judicial,¿qué está en juego? con Álvaro Bernad e Ignacio Fernández Larrea',
#  'Ayuso ve &quot;fundamental&quot; la manifestación del 8 de octubre contra la amnistía en Barcelona',
#  'Informe desde Madrid: Pedro Sánchez defiende la ley de amnistía en su debate de investidura',
#  'Para qué sirve una amnistía | PODCAST Hoy en EL PAÍS',
#  'A inmigrantes: “esta ley no te va a afectar si estás en tu proceso”',
#  'Sánchez defiende la amnistía que &quot;pide una parte muy relevante de la sociedad catalana&quot;',
#  '¿Qué  hace Amnistía Internacional en la junta de accionistas de la empresa CAF?',
#  'Estas son las voces críticas del PSOE contra la amnistía | La 7',
#  'Javier Nart clava como nadie la rendición de Sánchez a los separatistas',
#  'MALVERSACIÓN: El GOBIERNO elude las CRÍTICAS de GARCÍA-PAGE y defiende la REFORMA PENAL | RTVE',
#  'INFORME SEMANAL: La REINA LETIZIA felicita al PROGRAMA que PRESENTÓ hace MÁS de 20 AÑOS | RTVE',
#  'DIRECTO | Europa ante la elusión de las sanciones a Rusia y blanqueo de capitales',
#  'PABLO IGLESIAS abandona el debate de la Cadena Ser tras un enfrentamiento con MONASTERIO (VOX)',
#  'Monólogo de Alsina, a Pedro Sánchez: &quot;Deje de criticar, que la amnistía es para usted&quot;',
#  'El juez MARCHENA: &quot;El juicio no puede ser una lección a los magistrados&quot;',
#  'El cómico británico que quiso reírse de la Tamborrada donostiarra. Cadena SER',
#  'Federico a las 7: Dos varapalos del Poder Judicial a Pedro Sánchez',
#  'FELIPE: “Sánchez está a tiempo de decir a Puigdemont, hasta aquí hemos llegado y parar la amnistía&quot;',
#  '¿Están RESURGIENDO los grupos NEONAZIS en España? I RTVE Noticias',
#  'YO VOTO A VOX: José Esteban| Reportaje | El  País Semanal',
#  'Vicente Vallés destroza las maniobras de Bolaños por la amnistía en Europa',
#  'Buxadé: &quot;No es la extrema derecha, estúpidos, es sentido común&quot;',
#  'Las frases más polémicas del discurso de investidura de Pedro Sánchez',
#  'España: Pedro Sánchez asume nuevo gobierno a cambio de amnistía a independentistas catalanes',
#  'Discurso de investidura de Pedro Sánchez: &quot;La amnistía no va a ser un ataque a la Constitución&quot;',
#  'El lapsus de Felipe VI que tuvo que corregir la reina Letizia',
#  'Aznar promete batallar contra la amnistía y afirma que &quot;Sánchez es un peligro para la democracia&quot;',
#  'DIRECTO | Manifestación de DENAES contra la amnistía',
#  'Las niñas afganas tienen prohibido estudiar. La experiencia de Adela',
#  'Amnistía 1976 #españa #democracia #amnistía',
#  'Alfonso Guerra arremete contra los planes de amnistía del Gobierno en la presentación de su libro',
#  'PAGE defiende la solvencia de FEIJÓO y critica a los SOCIOS &quot;DISOLVENTES&quot; del GOBIERNO | RTVE',
#  'ISRAEL -GAZA : Los judíos ULTRAORTODOXOS sostienen a NETANYAHU y NO combaten | RTVE Noticias',
#  'ONU: SÁNCHEZ advierte de una la OLA EXTREMISTA y dice que el FEMINISMO es &quot;el MAYOR ANTÍDOTO&quot; | RTVE',
#  'Discursos de odio y libertad de expresión - Educación en derechos humanos',
#  '&quot;La Amnistía de Sánchez sólo busca una transacción&quot; Feijóo #shorts',
#  'Diferencia el INDULTO de la AMNISTÍA #ortografía #amnistía #aprendevocabulario #aprendelexico #ebau',
#  'Aznar desmonta la amnistía ante Carlos Herrera: &quot;No es una cuestión de legalidad, es política&quot;',
#  'Carlos Herrera: &quot;La amnistía significa reconocer que la razón política la tenían los golpistas&quot;',
#  'ABASCAL ¡SE PLANTA EN EL PARLAMENTO EUROPEO! y💥HUNDE A SÁNCHEZ💥 al RETRATARLO por TIRANO ante EUROPA',
#  'DIRECTO | Manifestación del Partido Popular contra la amnistía',
#  'La acertada pregunta de Vicente Vallés tras la bochornosa foto entre Yolanda Díaz y Puigdemont',
#  'Sánchez ya habla de AMNISTÍA para &quot;superar las consecuencias judiciales de una de las peores CRISIS&quot;',
#  'Jordi Cañas en El Toro TV sobre el acuerdo de #amnistía entre PSOE y #Puigdemont',
#  'Sale a la luz un vídeo de ADA COLAU OKUPANDO un piso cuando era joven',
#  '&quot;Recursos de VOX contra la ley de Amnistía&quot; Jorge Buxadé (VOX) #shorts',
#  'Letizia, en estado puro con una joven escritora',
#  'Felipe González, sobre la reunión de Díaz y Puigdemont: &quot;Si va por su cuenta, que lo pague&quot;',
#  'ÚLTIMA HORA| Europa no sabe dónde está el dinero de los fondos europeos en España y señala a Calviño',
#  '&quot;No nos vamos a callar hasta que haya elecciones&quot; Feijóo sobre Amnistía de Sánchez',
#  'SÁNCHEZ EXPLICA su &quot;CAMBIO de OPINIÓN&quot; con la AMNISTÍA y ADMITE que LOS ESPAÑOLES NO LE APOYAN',
#  'Diputado Schalper a Boric: &quot;Ríase todo lo que quiera, le va a servir para bajar de peso&quot;',
#  'Sánchez sobre si habrá amnistía o no: &quot;Estamos negociando con los grupos&quot;',
#  'Aznar dice que la amnistía legitima la sedición y es &quot;una invitación a volver a hacerlo&quot;',
#  'John de Zulueta no da crédito al esperpento de la amnistía y los pinganillos: “¡Es un despropósito!”',
#  '&quot;No tenemos Rey&quot;: escuche el discurso de ERC, Bildu, BNG, JxCAT y CUP',
#  'Qué es Amnistía Internacional',
#  '30/11/2023 Miras defiende una enmienda contra la Ley de Amnistía en Europa',
#  'Pablo Iglesias: &quot;Sería saludable publicar la lista de la amnistía fiscal&quot;',
#  'Intervención de Fernando López Miras ante la UE',
#  'Las cinco perlas de Aznar sobre la &quot;autodestrucción&quot; de España',
#  'MAGISTRADA DEL T.C. DICE QUE LA AMNISTÍA PUEDE TENER ENCAJE CONSTITUCIONAL. ESTÁ TODO HECHO!!',
#  'EL XOKAS genera POLÉMICA al elogiar a quienes se aprovechan de MUJERES &quot;COLOCADAS&quot; | RTVE Noticias',
#  'Herrera y el &quot;francomodín&quot; de Sánchez para acabar con la ley de Amnistía de 1977',
#  '&quot;AMNISTÍA NO, yo tengo principios y límites&quot; Feijóo durante investidura #shorts',
#  '¿Derogar la ley de Amnistía es la solución para cerrar las heridas que siguen abiertas?',
#  'De &#39;Help Catalonia&#39; a &#39;Help Spain&#39;: La cuestión catalana choca contra la realidad política europea',
#  'Aprobar Guardia Civil en UN AÑO ☝️',
#  'La opinión de #ayuso sobre el pacto de #pedrosánchez ¿QUÉ OPINAS? #amnistía  #investidura #noticias',
#  'El Parlamente Europeo debatirá la amnistía de Sánchez. Estamos al nivel de Hungría y Polonia',
#  'Masiva manifestación en Barcelona contra la independencia de Cataluña',
#  'Conferencia Javier Pérez Royo',
#  '“¡El Rey no puede proponer a Sánchez si necesita el apoyo de golpistas!” El grito de John de Zulueta',
#  'La amnistía que a nadie gusta y que a todos beneficia',
#  'DIRECTO I Manifestaciones en contra de la amnistía en todas las capitales de provinciade España',
#  'Por qué Ceuta y Melilla pertenecen a España si están en África',
#  '¡Sánchez, tu amnistía es inmoral!',
#  'La controvertida empresa Desokupa llega a Barcelona y advierte con actuar',
#  '¿DÓNDE DEBERÍAN JUGAR los equipos catalanes en caso de INDEPENDENCIA?',
#  'Iñaki Gabilondo desmonta EN DOS MINUTOS a la derecha española #LasEntrevistasDeAimar',
#  'Por qué Ceuta y Melilla pertenecen a España si están en África',
#  '¡Sánchez, tu amnistía es inmoral!',
#  'La controvertida empresa Desokupa llega a Barcelona y advierte con actuar',
#  '&quot;De un gobierno ilegítimo a un gobierno ILEGAL&quot; Santiago Abascal VOX #shorts',
#  '¿DÓNDE DEBERÍAN JUGAR los equipos catalanes en caso de INDEPENDENCIA?',
#  'Iñaki Gabilondo desmonta EN DOS MINUTOS a la derecha española #LasEntrevistasDeAimar',
#  'Ciudadano Cake, en una manifestación contra la dispersión de los presos de ETA',
#  '💥 La guasa de Pablo Motos y Miguel Lago ante la denuncia de Podemos: “Me pido la litera de arriba”',
#  '🔴📡 El ministro de Justicia y Presidencia Félix Bolaños comparece en rueda de prensa en Bruselas',
#  'La frialdad de Txapote indigna a la magistrada',
#  'Colosal paliza de Carlos Alsina a Zapatero por defender la amnistía a los golpistas',
#  'LA ANTORCHA| Ayuso vuelve: activa al PP contra la amnistía de Sánchez y las amenazas de Yolanda Díaz',
#  'OLIVER KAHN HABLA DEL REAL MADRID EN CHAMPIONS | Diario AS',
#  '🔴 DIRECTO BARCELONA | Manifestación de Societat Civil Catalana contra la amnistía',
#  '✅ RESUMEN: la PRESIDENCIA de SÁNCHEZ en 10 minutos | ¿Qué ha hecho PEDRO SÁNCHEZ en 4 años?',
#  'La hemeroteca vuelve a traicionar a Sánchez: «Líderes independentistas, nunca significa nunca»',
#  'A FAVOR O EN CONTRA DE LA MANIFESTACIÓN Y LA AMNISTÍA / ENTREVISTAS / DERECHAS VS IZQUIERDAS',
#  '🔴 RESPONDO A IRENE MONTERO y al MINISTERIO DE IGUALDAD | Xokas',
#  'La REINA LETIZIA cumple 50 AÑOS: Cómo era la JOVEN PERIODISTA que conocimos en el TELEDIARIO | RTVE',
#  'Bolaños, tras reunirse con la Comisión Europea:  &quot;Hay cero preocupación&quot; por la ley de amnistía',
#  'Cándido Méndez: &quot;La palabra amnistía no es interpretable, significa borrar los delitos&quot;',
#  'LA CONSTITUCIÓN ESPAÑOLA DE 1978: LA RECONCILIACIÓN',
#  'AMNISTIA, LA VERDAD DE LA MANIFESTACIÓN, en Directo',
#  '¿Por qué perdió la voz Miguel Bosé? - El Hormiguero',
#  'Aznar habla claro del plan de Pedro Sánchez: &quot;Voy a gobernar contra vosotros&quot;',
#  'Jaime Bayly le hace un traje a Pedro Sánchez: «ha hecho un Gobierno mediocre»',
#  'Rifirrafe entre Bescansa y Nart a propósito de la &quot;Justicia para ricos y pobres&quot;',
#  'La Guerra Civil española',
#  'Ayuso hace gala del anticatalanismo en la Asamblea de Madrid y así le responde la izquierda',
#  'Sánchez admite ya el diálogo sobre la amnistía: &quot;Estamos negociando con los grupos&quot;',
#  'BONANOVA: BLINDAN la ZONA al COINCIDIR concentraciones a FAVOR y en CONTRA de la OKUPACIÓN | RTVE',
#  'FEIJÓO o AMNISTÍA: Aitor Esteban responde a Cuca Gamarra #shorts',
#  'Así empezó el Alzamiento Nacional en julio de 1936  | España dividida: La Guerra Civil en color',
#  '¿ÉS LEGAL la AMNISTÍA en ESPAÑA?',
#  '#TuEspacioINACIPE | &quot;Reflexiones sobre la Ley de Amnistía&quot;.',
#  'Alsina: &quot;Sánchez admite que la amnistía es su investidura y da por seguro que tiene a Puigdemont&quot;',
#  '¿ESPAÑA QUIERE LA AMNISTÍA?',
#  'Rechazo la amnistía como solución para los independentistas radicales;',
#  'Eurodiputados SE REBELAN contra la amnistía en Europa: “Va en contra de la ley”',
#  'Sistemas de financiación internacional de Amnistía Internacional',
#  'HOY EN SUIZA PUIGDEMONT DIRIGE ESPAÑA',
#  'El 23-F PASO A PASO: cómo transcurrió el intento de golpe de Estado | RTVE Noticias',
#  'REQUISITOS para VIAJAR a ESPAÑA actualizados | Mayo 2023',
#  'PREGUNTAS A MUJERES SOBRE LA LEY SOLO SÍ ES SÍ #feminismo',
#  '💥 APOTEÓSICO repaso de VICENTE VALLÉS a PEDRO SÁNCHEZ por su nueva contradicción electoral 💥',
#  'Mujeres en Afganistán: ¿Cómo ha cambiado su vida bajo el régimen talibán? | EL PAÍS',
#  'La amnistía para los que quebrantan la ley en nombre del independentismo es un desprecio al estado',
#  'Hombre irrumpe acto feminista con grito machista en España',
#  'LA RESISTENCIA - Entrevista a María Pombo | #LaResistencia 15.11.2022',
#  '💥 RAY DALIO PREDICE una HORRIBLE CRISIS económica donde TODO COLAPSARÁ |👉 CÓMO puedes PROTEGERTE?',
#  'EEUU anuncia nuevo programa de parole humanitario: abogado de inmigración responde dudas al respecto',
#  'INVESTIDURA: PP pide &quot;RECAPACITAR&quot; al PSOE, que exige el CESE del llamamiento al TRANSFUGISMO | RTVE',
#  'EE.UU.: La Reserva Federal MANTIENE los TIPOS de INTERÉS entre el 5,25 y el 5,5% I RTVE',
#  'Antonio Resines - OPINIÓN AMNISTÍA',
#  'Javier Cercas: “Fui a la literatura buscando un sucedáneo de la religión” | El País',
#  '💥 PABLO MOTOS y su tropa de &#39;El Hormiguero&#39; despellejan al esbirro de SÁNCHEZ que blanquea a BILDU 💥',
#  'Federico a las 7: Sánchez consuma la traición a España',
#  'Manifestación contra la posible amnistía en la Plaza Mayor de Guadalajara',
#  'PORTUGAL: POLÉMICA por el ALTAR de CINCO MILLONES para las JMJ que presenciará el PAPA | RTVE',
#  'Así se fraguó la negociación entre Bukele y la MS-13, según una acusación de EE.UU.',
#  'Biden quiere facilitar la inmigración legal en EE.UU. | Noticias Telemundo',
#  'La VIRAL ENCUESTA que HUNDE la amnistía y a Sánchez',
#  'XXI Lección sobre la Constitución Española, por Ascensión Elvira Perales',
#  '👑ÚLTIMA HORA👑 El REY FELIPE VI NO FIRMARÁ la LEY de AMNISTÍA y la GUARDIA REAL echó a SÁNCHEZ 👑',
#  'Vicente Vallés DESMONTA las mentiras de Bolaños sobre la amnistía en Europa',
#  'Cantabria reclama a Europa que &quot;no mire a otro lado&quot; con la ley de amnistía',
#  'Observatorio Derechos Humanos',
#  'Y TÚ QUE OPINAS? | #pedrosánchez #españa #presidente #psoe #pp #vox #amnistía  #sanchez #cataluña',
#  '&quot;La Ley de Amnistía no es un obstáculo para acabar con la impunidad del franquismo&quot;',
#  '&quot;Referéndum de independencia en Cataluña en 2024&quot;: El plan de Pedro Sánchez',
#  'FEIJÓO califica el DISCURSO de ARMENGOL como &quot;LAMENTABLE&quot; y ABASCAL lo tilda de &quot;MITIN&quot; | RTVE',
#  'Ortega califica de amnistía encubierta de los golpistas y fraude de ley la reforma de la sedición',
#  'Nayib Bukele en la ONU: La libertad es algo por lo que aún luchamos en nuestro país, en El Salvador',
#  'El independentismo, cuando transgrede la ley, no puede ser recompensado con amnistía',
#  'La profecía de Albert Rivera sobre el &#39;Plan Sánchez&#39;, que se ha cumplido para desgracia de España',
#  'No puede haber amnistía sin responsabilidad; el independentismo no debe ser incentivado',
#  'Explicación de la Ley De Amnistía',
#  '😡El cabreo más brutal de Almansa por las acusaciones a España de país racista😡',
#  '💥 Frank Cuesta y el revolcón histórico a Pedro Sánchez e Ione Belarra por sus leyes chapuceras 💥',
#  'Como se siente uno al ganar un concurso de escritura  #escribir #ddhh 👇',
#  '🚨PEDRO BAÑOS la democracia ficticia, el sistema electoral y promesas incumplidas de los gobernantes',
#  'AMNISTÍA y PACTOS de INVESTIDURA. Te dejo mi opinión.',
#  '😱🇪🇸¿QUÉ OPINAN LOS ESPAÑOLES DE LOS CUBANOS? ¿APOYAN LA DICTADURA?',
#  'GOLPE de Europa a la amnistía de Sánchez: “Es un atentado contra la ley”',
#  'Una amnistía para la investidura NO VOY A CALLAR',
#  '🔍 ¿PUEDE EL REY NEGARSE A FIRMAR LA AMNISTÍA? 👑  ¿Corre algún peligro la corona? 👑  Riesgos y Retos',
#  'García-Margallo, con Herrera, alerta: &quot;Estamos en un momento muy grave para España&quot;',
#  'La amnistía no es una herramienta para aplacar el independentismo, es un escape que evita enfrentar',
#  'Pablo Motos responde a la campaña de Igualdad que utiliza una frase suya: &quot;El Ministerio miente&quot;',
#  '&quot;BORIC NO SE ATREVE&quot;: El intenso debate por amnistía a presos de la revuelta - Contigo en Directo',
#  'Piqué explica el conflicto catalán: &quot;Es como el padre y el hijo de 18 años que se quiere ir&quot;',
#  'Pérez-Reverte:  &quot;No puedes tratar igual al alumno brillante que al que no tiene el talento&quot;',
#  'ENTREVISTAS A UNIVERSITARIOS SOCIALISTAS ¿POR QUÉ VOTAN AL PSOE?¿AMNISTÍA? ¿PEDRO SÁNCHEZ MENTIROSO?',
#  'CAYETANA Álvarez de Toledo, las FRASES más POLÉMICAS de la candidata del PP',
#  '💥 Las seis mejores ‘estocadas’ de Arturo Pérez-Reverte al Gobierno 💥',
#  'PEDRO SANCHEZ ACEPTA QUE PUIGDEMONT TENDRA AMNISTIA #shorts #pedrosanchez #amnistía #puigdemont',
#  '¿EL REY FELIPE VI PUEDE NEGARSE A FIRMAR LA LEY DE AMNISTÍA?',
#  'Bruselas estudia la compatibilidad de la amnistía de Pedro Sánchez con las leyes de la Unión Europea',
#  '🔍 ¿PUEDE EL REY NEGARSE A FIRMAR LA AMNISTÍA? 👑  ¿Corre algún peligro la corona? 👑  Riesgos y Retos',
#  'Abascal zarandea a Silvia Intxaurrondo (TVE) por lanzar una grave acusación contra VOX',
#  '🔍 ¿PUEDE EL REY NEGARSE A FIRMAR LA AMNISTÍA? 👑  ¿Corre algún peligro la corona? 👑  Riesgos y Retos',
#  'Abascal zarandea a Silvia Intxaurrondo (TVE) por lanzar una grave acusación contra VOX',
#  'Frente Obrero, a Iglesias: &quot;Fuera vende obreros de la universidad&quot;',
#  'La reflexión de Pablo Motos: &quot;La preocupación nunca cura, pero te roba la vida&quot; - El Hormiguero',
#  'DIRECTO | Especial de Hora 25 desde Vitoria',
#  'AZNAR a IGLESIAS: &quot;Usted me parece un peligro para las libertades y la democracia en España&quot;',
#  '&quot;No son de los tuyos&quot;: el repaso de Rufián a Vox en 4 minutos',
#  'LA AMNISTIA DE SANCHEZ ES OLVIDAR ESTO DE PUIGDEMONT #shorts #sanchez #amnistía #puigdemont #vox',
#  'ABASCAL BRUTAL &#39;Amnistía = Golpe de Estado&#39;  Congreso Vox',
#  '🔥 Un 41% de votantes del PSOE está en contra de la Amnistía 🤔 ¡Lo que Piensan los Españoles! 🇪🇸',
#  '💥 &quot;¡INDECENTE!&quot; 💥 PABLO MOTOS sopapea a IRENE MONTERO por DIFAMARLE en una campaña publicitaria',
#  'Rosa Díez, a Herrera: &quot;El PSOE es ahora una empresa familiar a nombre de Sánchez&quot;',
#  'Adrián Vázquez en COPE',
#  'Mi opinión sobre la situación política actual de España: la &quot;AMNISTÍA&quot; y el proceso de investidura',
#  'Sánchez: retrato de una gran mentira',
#  'APPLE: FRANCIA RETIRA IPHONE 12 por EXCESO DE RADIOFRECUENCIA. La COMPAÑÍA lo NIEGA |RTVE Noticias',
#  'En el surrealista templo franquista de Ávila con el &#39;antirrojos&#39; Eladio: Perros sí, perroflautas no',
#  'GONZALEZ / &quot;El Futuro de Cataluña: ¿Autodeterminación o Amnistía?#shorts',
#  'Eurodiputado francés HUNDE a Sánchez: “Miserable y peligroso”',
#  '¡Netanyahu debe romper relaciones con Pedro Sánchez! ¡Ortega Smith más valiente que nunca!',
#  'El Rey Felipe VI PLANTA CARA a Sánchez: “No firmaré la amnistía”',
#  'SEÑORA MAYOR GRITA A PEDRO SANCHEZ POR LA AMNISTIA #shorts #amnistía #pedrosanchez #sanchez #vox',
#  'Zapatero defiende la normalización de Bildu: &quot;España va mejor si los que la cuestionan participan&quot;',
#  'SÁNCHEZ dijo que la AMNISTÍA iba contra la CONSTITUCIÓN, ahora cambia de opinión',
#  'Cristina Almeida y su falsedad sobre la amnistía a Puigdemont.',
#  'Felipe GONZÁLEZ sacude a SÁNCHEZ y los compinches del PSOE: &#39;Crean pobreza y destruyen ESPAÑA&#39;',
#  'El Programa de Cuesta: El plan de Sánchez contra los jueces antiamnistía y la frutera Yolanda Día',
#  'Reacciones al nuevo &quot;escándalo&quot; de Juan Carlos I: &quot;Ya no nos puede sorprender&quot;',
#  'UNIVERSITARIOS OPINAN SOBRE LA AMNISTIA del PSOE 🌹',
#  '🔍 ¿PUEDE EL REY NEGARSE A FIRMAR LA AMNISTÍA? 👑  ¿Corre algún peligro la corona? 👑  Riesgos y Retos',
#  'Arturo Pérez-Reverte habla del lenguaje inclusivo y la evolución de la lengua - El Hormiguero',
#  'Javier Aroca, sobre la &#39;ley del solo sí es sí&#39;: &quot;Estos jueces no tienen ni puñetera idea&quot;',
#  'Albanta San Román: &quot;Se enfocan en la minoría de las denuncias falsas y no ven todo lo demás&quot;',
#  'Retransmitiendo en directo ahora desde Salón de Plenos',
#  'Una anécdota de Millán Salcedo provoca un ataque de risa a Pablo Motos - El Hormiguero 3.0',
#  'GUARDAR ESTE VIDEO DE LA AMNISTIA DE SANCHEZ 2 SEMANAS #shorts #amnistía #puigdemont #sanchez #vox',
# ...
#  'ENTRÉ CON VISA DE TURISTA Y ME VOLVÍ RESIDENTE 2022/USA 🇺🇸',
#  'La única esperanza contra la amnistía de Sánchez puede ser la Unión Europea',
#  '¿PUEDE DONALD TRUMP SER REELEGIDO COMO PRESIDENTE? - David Jiménez no es optimista al respecto',
#  'YOLANDA DIAZ TIENE UN COMITE DE EXPERTOS PARA LA AMNISTIA #shorts #yolandadíaz #amnistía #puigdemont',
#  '💥 Alfonso Guerra hace un traje a Sánchez: &quot;¡Es el peor PSOE desde la República!&quot; 💥',
#  'YOLANDA DIAZ PIDE QUE NADIE SE MANIFIESTE #shorts #yolandadíaz #aznar #puigdemont #amnistía #vox',
#  '¿Pueden las PENSIONES ARRUINAR a ESPAÑA?  - VisualEconomik',
#  '&quot;Comisión Europea Solicita Información Sobre Ley de Amnistía en España 🇪🇺 - Lo que Debes Saber',
#  'Felipe González ESTALLA contra la amnistía de Sánchez: “Es intolerable”',
#  'Pedrerol: &quot;Los que dicen que van a salvar Catalunya la van a hundir&quot;',
#  'Javier Nart no se corta y le mete un repaso a Rodríguez Pam: &quot;Incompetente y analfabeta mental&quot;',
#  'PEDRO SANCHEZ:Más Allá de la Política.DESCUBRE LA VIDA Y TRAYECTORIA del Presidente de ESPAÑA',
#  'Pedro Sánchez Defiende la Ley amnistía en su discurso de investidura',
#  'Cinco situaciones que ocurren en una consulta de salud mental en la sanidad pública.',
#  'Pablo Iglesias y Virginia P. Alonso entrevistan a Inna Afinogenova, nuevo fichaje de &#39;La Base&#39;',
#  'Informe Europeo PARALIZA LA AMNISTÍA de Pedro Sánchez: “Vulnera el tratado”',
#  'ESPAÑA | Pedro Sánchez defiende la Amnistía en CATALUÑA por la Convivencia entre Españoles',
#  '✅  La GUERRA CIVIL ESPAÑOLA en 13 minutos | Resumen fácil y divertido',
#  'ANTONIO RESINES CARGA DURAMENTE CONTRA LA LEY DE AMNISTÍA DEL GOBIERNO DE PEDRO SÁNCHEZ',
#  '🔥 ¿Creen que terminaremos aceptando la amnistía? 🤔 ¿Es la Amnistía de Puigdemont la Solución? 🌍',
#  'MUNDO EN GUERRA | Europa contra sus miembros, Blinken corre a Israel y la opinión de China',
#  'Ni superhéroes ni pobrecitos: personas con discapacidad claman contra el estigma social y mediático',
#  'Las noticias del JUEVES 30 de NOVIEMBRE en 10 minutos | RTVE Noticias',
#  'HEMEROTECA 4: AMNISTIA #shorts #hemeroteca #humor #comedia #memes',
#  '8M ENTREVISTAS A FEMINISTAS EN EL 8M 2023',
#  'García Page: O Puigemont se apea del referéndum o será una legislatura complicada',
#  'YOLANDA DIAZ Y SANCHEZ YA TIENEN PACTO DE AMNISTIA #shorts #yolandadíaz #pedrosanchez #amnistía #vox',
#  'PIDEN AMNISTIA Y DICEN A CAKE MUNIESA ESTO #shorts #CAKEMUNIESA #amnistía #puigdemont #vox #abascal',
#  'LEY DE MALESTAR ANIMAL',
#  'VOX DESTAPA LAS MENTIRAS DE LOS CATALANES #shorts #vox #cataluña #puigdemont #abascal #amnistía',
#  'PEDRO SANCHEZ SE BURLA DE LA JUSTICIA POR LA AMNISTIA #shorts #amnistía #pedrosanchez #vox #abascal',
#  'Foro Técnico ALNYLAM | Litiasis de origen genético sospechando la hiperoxaluria primaria',
#  'A PATXI LOPEZ NO LE CONSTA LA AMNISTIA DE SANCHEZ #shorts #pedrosanchez #amnistía #PATXILOPEZ #vox',
#  'Cadena SER',
#  'Europa DESMIENTE a Félix Bolaños por la ley de amnistía',
#  'El chasco de Sánchez al descubrir que el trono no es para él',
#  'Declaración de Serrat y respuesta a quienes le llamaron fascista',
#  'Alsina entrevista a Pedro Sánchez: &quot;No es cierto que haya gobernando con Bildu&quot;',
#  'Hora Veintipico #179 | Entrevista a Nieves Concostrina',
#  '¿Debe intervenir el Estado en la economía?',
#  'SANCHEZ TIENE PACTADA YA LA AMNISTIA CON PUIGDEMONT #shorts #sanchez #puigdemont #amnistía #vox',
#  'OPINION El circo de la amnistía',
#  'ALFONSO GUERRA &quot;SE REBELA&quot; contra PEDRO SÁNCHEZ ¡POR PACTAR LA AMNISTÍA CON PUIGDEMONT!',
#  'FEIJOO AVISA EL REFERENDUM ES EL CEBO DE LA AMNISTIA #shorts #feijoo #sanchez #referendum #amnistía',
#  'opiniones 👇🏽 Fuente: Kloshletter y 20 minutos #noticiastiktok #8deoctubre #amnistia #barcelona',
#  '¡VERGÜENZA! PROPUESTA CUOTA AUTÓNOMOS E IMPUESTOS | CRÍTICA 🇪🇸',
#  'AMPLIACION DE LA AMNISTÍA (15-10-1977)',
#  '💥El Parlamento europeo acuerda debatir la amnistía y sitúa a España al nivel de Hungría y Polonia💥',
#  'Tibia respuesta del PSOE a la exigencia de referéndum de ERC y Junts',
#  'Jordi Wild da su opinión sobre la amnistía',
#  'EMILIANO GARCIA PAGE CRITICA A PEDRO SANCHEZ #shorts #pedrosanchez #emilianogarciapage #amnistía',
#  'The Wild Project #21 feat Roma Gallardo | Feminismo, VOX, Okupas y Menas, Risto Mejide',
#  'Otorgar amnistía a aquellos que buscan la independencia por medios ilegales es traicionar',
#  '77/ Model per armar: la llei d&#39;amnistia i la justícia transicional',
#  'RIDÍCULO APOTEÓSICO de Cristina Almeida por DEFENDER la Ley de Amnistía',
#  'ÁLVARO PRIETO: La POLICÍA BARAJA la ELECTROCUCIÓN como PRINCIPAL HIPÓTESIS sobre SU MUERTE | RTVE',
#  'BORRASCA CIARÁN: Casi TODA ESPAÑA en ALERTA por rachas de VIENTO, fuertes LLUVIAS y mala MAR | RTVE',
#  'SE DESATA LA POLÉMICA EN LA INAUGURACIÓN DE LA XV LEGISLATURA.',
#  'Leguina sopapea al lugarteniente de Sánchez: &quot;¿Qué puedo decir de alguien que se acuesta con Bildu?&quot;',
#  'CRISTINA ALMEIDA TRENDING TOPIC, DE LA AMNISTIA NO, A LA AMNISTIA SI, cambio de opinión una semana',
#  '🔴 DIRECTO | El rey Felipe VI abre la XV Legislatura en el Congreso (29/11/2023)',
#  'PEDRO SANCHEZ DECIA QUE HAY QUE PASAR DE PUIGDEMONT #shorts #puigdemont #amnistía #sanchez #vox',
#  'Villarroya sobre Rússia, Xina i Espanya | OpinaCat',
#  '¿Amenaza Sánchez al Rey para la firma de la amnistía?',
#  'Descifrando el Presente Político en España (Pablo Lucini) | Ep 10 Breaking Limits',
#  'Diferencia entre amnistía e indulto. Ley de amnistía presentado por el PSOE-Pedro Sánchez en España',
#  'Contra la amnistía y por la dignidad de España',
#  'España ARDE contra Sánchez por la amnistía: “Tiene que acabar en prisión”',
#  'Pedro Sanchez y su opinión acerca de la amnistía',
#  'Feijoo EXTRAVAGANTE en la manifestación contra la AMNISTÍA En Malaga💥😱😱',
#  'Los españoles ESTALLAN contra Sánchez y la AMNISTÍA en la manifestación del 8O',
#  'PUIGDEMONT Y SANCHEZ SE RIEN DEL TRIBUNAL SUPERIOR #shorts #puigdemont #amnistía #pedrosanchez #vox',
#  'La salvaje advertencia de Guillermo Rocafort que pone patas arriba el futuro de España',
#  'La Unión Europea ya está estudiando la ley de amnistía, son la única esperanza para salvar a España',
#  'Tres historias para empezar el día, con Carlos Alsina 30/11/2023',
#  'FEMINISTA VS ROMA GALLARDO',
#  'ISRAEL-GAZA: BELARRA defiende su DERECHO a PRONUNCIARSE como parte de la COALICIÓN de GOBIERNO |RTVE',
#  'CRITICAS AL REY en la manifestación contra la Amnistía de Barcelona',
#  '🇪🇸 La Falange marcha contra la amnistía separatista desde Génova hasta Ferraz, Madrid (18 nov 2023)',
#  'El Gobierno de Italia ARREMETE contra Sánchez: “Gobierna la extrema izquierda”',
#  'PEDRO SÁNCHEZ AMNISTÍA  - VIVA ESPAÑA 🇪🇸',
#  'PEDRO SANCHEZ GASTA 140.000€ EN UNA CENA #shorts #pedrosanchez #vox #abascal #amnistía #puigdemont',
#  'NO TODO VALE CUANDO SE VA CONTRA LA CONSTITUCIÓN!!',
#  'ESPAÑA | ¡NO a la Amnistía! ¡Viva ESPAÑA! | Eso Gritan los Españoles',
#  '¿QUÉ ES LA AMNISTÍA?',
#  'THE BEATLES: JOHN LENNON y GEORGE HARRISON recobran vida gracias a la IA en su ÚLTIMA CANCIÓN I RTVE',
#  'Vanguardia Española - La IZQUIERDA NACIONAL [Entrevista a Santiago ARMESILLA en El Gato al Agua]',
#  'Herrera: “Sánchez es el único presidente que ha logrado que 3 países le retiren sus embajadores&quot;',
#  'Amnistía y manifestaciones ciudadanas. Fenómeno Milei',
#  'Feijóo,contra la amnistía: “España funciona gracias a los españoles que desprecian&quot;',
#  'VOX en Bruselas criticando la ley de amnistía. Esto es la política de los contrarios al gobierno.',
#  'El impulsor de los rezos en Ferraz: «Las grandes batallas se han ganado con un Rosario en las manos»',
#  'Sobre la amnistía #shorts #unciudadanolibre #españa #política #declaraciones #conservador #opina',
#  '🚨 Amnistía de Sánchez: ¿Atentado Histórico? Garriga lo Explica. #shorts',
#  'Solemne Sesión de Apertura de las Cortes Generales de la XV legislatura',
#  'Sánchez RECONOCE LA AMNISTÍA y Europa TRAICIONA a España',
#  'CONEXIÓN VILAR: El futuro de Ucrania, amenazado; Lagarde vuelve a hablar y oro en máximos históricos',
#  '💥BOMBA💥EL ERROR DE SÁNCHEZ QUE PUEDE 💥TUMBAR LA AMNISTÍA💥NADIE HA FIRMADO EL INFORME QUE LA AVALA💥',
#  'SANCHEZ Y LA AMNISTÍA PUIGDEMONT, TODO POR EL PODER',
#  'JOSE LUIS CORCUERA sobre la AMNISTÍA: SÁNCHEZ está BLANQUEANDO a los GOLPISTAS',
#  'ARABIA SAUDÍ: Será la SEDE del MUNDIAL de FÚTBOL 2034 tras la RETIRADA de AUSTRALIA I RTVE',
#  '¿Es posible la amnistía en España?',
#  'SEMANA TRÁGICA PARA FÉLIX BOLAÑOS. DESCRÉDITO INTERNACIONAL Y RAPAPOLVO DE LA JUSTICIA:',
#  '#EnRigurosoDirecto: Manifestación nº14 contra la Amnistia desde Ferraz en la sede del PSOE en Madrid',
#  '#EnRigurosoDirecto: Manifestación nº14 contra la Amnistia desde Ferraz en la sede del PSOE en Madrid',
#  '¿Puede frenar el Rey la Ley de amnistía? Hablan dos expertos con visiones distintas',
#  'LAS GORDAS DE TIKTOK ODIAN A IBAI',
#  'Siga en directo la rueda de prensa del ministro de transportes, Óscar Puente en Bruselas',
#  'Bruselas confirma que el ministro Bolaños miente, Europa si que está preocupada por la amnistía',
#  'Arcadi Espada, Juan Luis Cebrián y Álvaro Nieto comentan la situación actual de la prensa española',
#  '¡¡¡ACTIVISTA CONTRA LA GORDOFOBIA ME EXPULSA TRAS DEJARLE SIN PALABRAS!!! Y ENTREVISTO A SUS FANS',
#  'La Unión Europea exige a Pedro Sánchez que informe a quien y por qué delitos va a dar la amnistía',
#  'AMNISTÍA: ExDirigente PSOE opina | Pedro Sánchez |  Cataluña | Salud Mental | TheCUCast ep. #3',
#  'Borja Sémper: &quot;La ley de amnistía a la que nos vamos a oponer con toda la contundencia&quot;',
#  'SANCHEZ MANDA AL NÚMERO 2 DEL PSOE  RENDIR ESPAÑA A UN GOLPISTA EN SUIZA',
#  'Entrevista a Nieves Concostrina : &quot;No quiero a nadie a mi lado que me impida pensar...&quot;',
#  'El portavoz del ECR Group en el Parlamento Europeo, Michael Strauss, denuncia la ley de amnistía.',
#  'ESTO ES LO QUE HA PASADO DE VERDAD EN CARABANCHEL.',
#  'AMNISTIA para PUIGDEMONT si firma un papel de NO VOLVER HACER REFERÉNDUM | LEY IGUAL para ¿todos?',
#  'Pedro Sánchez habla de la separación de poderes en España 🇪🇸⚖️ #pedrosánchez #psoe #amnistía',
#  'La izquierda española en ridículo',
#  '👁️ PROYECCIÓN SEMANAL SMC + CATALIZADORES 🔴 EN VIVO - LUNES 4 DICIEMBRE 2023',
#  '🔥MILES DE ESPAÑOLES SALEN / CONVOCADOS POR EL PARTIDO POPULAR CONTRA LA AMNISTÍA y PEDRO SÁNCHEZ',
#  '🔥MANIFESTACIÓN EN ESPAÑA CONTRA PEDRO SÁNCHEZ Y LA POSIBLE AMNISTÍA ‼️',
#  'Roberto Vaquero',
#  'Dalas DEBATE con la &#39;Afro-Feminista&#39; de TikTok sobre RAClSMO 😱🤣',
#  'Conoce la polémica reforma a la Ley de Amnistía de Guatemala',
#  '❤️💛❤️Análisis completo de las últimas noticias sobre Amnistía y del Día de la Constitución. 👨\u200d⚖️📄🌹🤝',
#  'EL PRESIDENTE DE CATALUÑA IGNORA A LOS ESPAÑOLES Y APOYA LA AMNISTÍA',
#  'La Guardia Civil contra la amnistía de Puigdemont | El Tribuno de Rafa Fernández Actualidad Amnistía',
#  'Mitos izquierdistas de la II República española',
#  '📄🌹🤝 Ley de AMNISTÍA, Reunión SECRETA entre PSOE y Junts en Ginebra con un VERIFICADOR. ❤️💛❤️',
#  '❤️💛❤️ Últimas noticias: Amnistía, Día de la Constitución, Medida de gracia y comisiones legislativas',
#  '👿💥PEDRO SÁNCHEZ CONSUMA LA TRAICIÓN A ESPAÑA VENDIENDO LA DEMOCRACIA POR 7 VOTOS.👿💥',
#  'Pérez Reverte EXPLOTA contra Pedro Sánchez en el HORMIGUERO',
#  'Más se Perdió en Cuba | 02/12/23',
#  'El ´´APLAUDIDO REPASO´´ de Marisa Paredes a Isabel Díaz Ayuso',
#  'Sánchez no cierra la puerta a Podemos: &quot;No diría &#39;no&#39;, pero la coalición que dicen es inviable&quot;',
#  '¡Sánchez coloniza Hacienda! ¡Los inspectores denuncian ya nombramientos a dedo!',
#  'Ayuso: &quot;La amnistía no es perdonar, es pedir perdón a los que cometieron los delitos&quot;',
#  'Debate sobre Ley de Amnistía en el Ayuntamiento',
#  'Bruselas no tolera el descomunal bu.lo de Félix Bolaños sobre la am.nistía y le desmiente frente a..',
#  'Política Española - Memoria democrática.',
#  '¡EL REY NO PUEDE AVALAR LA AMNISTIA, LA CONDICIÓN PARA INVESTIR A SÁNCHEZ, SEGÚN LA CONSTITUCIÓN!',
#  'Ayuso: &quot;La amnistía no es perdonar, es pedir perdón a los que cometieron los delitos&quot;',
#  'Eurodiputado nos explica sobre la AMNISTÍA',
#  'Abascal acusa de “COBARDE Y ESTAFADOR” al Partido Popular en Madrid',
#  'Rubén Gisbert',
#  'BORRASCA CIARÁN: EUROPA en ALERTA por los FUERTES VIENTOS que dejan un MUERTO en FRANCIA | RTVE',
#  'Así es como el presidente del Gobierno de España Pedro Sanchez pacta con prófugos y los amnistía',
#  'REACCIONO A VOTANTES SOCIALISTAS POR QUÉ VOTAN PSOE',
#  'Correa sobre Amnistía Internacional(LINKS INFORMES AMNISTÍA EN LA DESCRIPCIÓN)',
#  'Resines hablando claro sobre la amnistia',
#  'NEGOCIACIÓN ENTRE JUNTS Y PSOE EN GINEBRA: ¿QUIÉN INTERMEDIA? ¿PARA QUÉ?',
#  'NEGOCIACIÓN ENTRE JUNTS Y PSOE EN GINEBRA: ¿QUIÉN INTERMEDIA? ¿PARA QUÉ?',
#  'CHOCAN #ESPAÑA E #ITALIA. PARLAMENTO EUROPEO SE DIVIDE. ISRAEL RETIRA EMBAJADORA EN MADRID',
#  'Fuego en el Estudio: Marta Nebot Desquiciada por las Palabras de Abascal (VOX)',
#  '👿💥PEDRO SÁNCHEZ CONSUMA LA TRAICIÓN A ESPAÑA VENDIENDO LA DEMOCRACIA POR 7 VOTOS.👿💥',
#  'GUERRA entre PALESTINA e ISRAEL con Jose Antonio Zorrilla',
#  'Amnistía Internacional condena España por su represión el 1-0 en Cataluña en su informe global',
#  'Jesús Á.Rojo:💥Juan Carlos I se planta ente la AMNISTÍA y golpea a Sánchez y a todos sus ministros💥',
#  'El enfado de Thais Villas con un señor que afirma que el feminismo es lo mismo que el machismo',
#  'EE.UU e ISRAEL conocían el ataque. RUSIA arrincona a UCRANIA. MILEI aleja a ARGENTINA de los BRICS',
#  'Jesús Á.Rojo💥Letizia toma partido por políticas radicales mientras Felipe VI calla sobre la amnistía',
#  'Pedro Sánchez y Pablo Iglesias &#39;Al rojo vivo&#39; | José Mota',
#  'La Ley de Amnistia precipitará la caída política de los tres poderes del estado democratico Español',
#  '#shorts Santiago #abascal  habla contra la Amnistía de Pedro #sanchez  al separatismo en Colón',
#  '🔥BOMBAZO EN EL CONSTITUCIONAL🔥EMPIEZAN LAS RENUNCIAS por la AMNISTÍA de Pedro Sánchez.',
#  'DURO GOLPE A PEDRO SÁNCHEZ LA AMNISTÍA ES ANTICONSTITUCIONAL Top Ten Life Noticias Actualidad',
#  'VIDEO MUY URGENTE sobre ELECCIONES y AMNISTÍA',
#  '👉𝐁𝐑𝐔𝐓𝐀𝐋!! 𝐀𝐏𝐎𝐘𝐎 𝐀 𝐋𝐀 𝐀𝐌𝐍𝐈𝐒𝐓𝐈́𝐀 𝐃𝐄𝐒𝐃𝐄 𝐋𝐀 𝐃𝐄𝐑𝐄𝐂𝐇𝐀!!👈😱😱😱 ISRAEL INCREMENTA PRESIÓN SOBRE ESPAÑA❌',
#  'Precio de la Cruzcampo en 🇬🇧 #pedrosánchez #podemos #sumar#amnistia #pp#vox#cataluña  #yolandadíaz',
#  '🔴#ENVIVO/MUNDO ROJO:Mosad confirma, Sánchez ha provocado la crisis con Israel para tapar la amnistía',
#  'El NO a la Amnistía es tan sólo el primer paso, la punta del iceberg!. EL PUEBLO DECIDE!.QUE OPINAS?',
#  '💥Escándalo.Juristas revelan impactantes violaciones constitucionales por la amnistía: 7 artículos💥',
#  '😱 Escándalo: La élite compra el sistema de Derechos Humanos | Agustín Laje',
#  'Yolanda Díaz expresa su “satisfacción” ante los datos del paro en noviembre',
#  'Saturday Night Live;  La humillación a España por parte de Sánchez y Puigdemont',
#  'Sam y Cat | Fans de Sam y Cat | Nickelodeon en Español',
#  'DIRECTO | Manifestación contra Pedro Sánchez en Madrid Ferraz',
#  '💥BRUTAL💥El PSOE con el &quot;alma en un puño&quot;: SÁNCHEZ se descompone por momentos',
#  '¡ÚLTIMA HORA! EL GOBIERNO AMENAZA A LOS JUECES por la amnistia a Puigdemont.',
#  'Pedro Sánchez, PILLADO mintiendo con Ferreras en La Sexta',
#  'Víctimas españoles nolotil🇪🇦 #yahorasonsoles #stopnolotil #fármacos #agranulocitosis  #AEMPS',
#  'PEDRO SÁNCHEZ Y LA AMNISTÍA #español #noticias #shorts',
#  'Pedro Sánchez y la amnistía a Puigdemont #endikafl #liberalismo #españa #soloquedavox #vivaespaña',
#  'LHDC 268 &quot;Memoria democrática&quot;, amnistía y 20N: el PSOE a lo suyo mientras España muere de hambre.',
#  '🔴#ENVIVO/MUNDO ROJO: 💥¡SÁNCHEZ SE HUNDE!💥: Bofetón histórico del Poder Judicial al Gobierno',
#  'Ni amnistía , ni autodeterminación! Viva España 🇪🇸',
#  '🔥ÚLTIMA HORA🔥LA JUSTICIA HUNDE la AMNISTÍA a PUIGDEMONT',
#  '🔴#ENVIVO/MUNDO ROJO:Felipe VI defrauda a la nación y allana el camino del golpe de Estado de Sánchez',
#  '💥SOROS y ROCKEFELLER, financiadores de  Henry Dunant que supervisa el pacto SÁNCHEZ y PUIGDEMONT💥',
#  'ESTO NO VA DE FOROFISMOS, VA DE LÓGICA']

# %%
channel_ids = []  
for item in all_video:
    channelId = item['snippet']['channelId']
    channel_ids.append(channelId)  

print(channel_ids)
# Out:
# ['UC7QZIf0dta-XPXsp9Hv4dTw', 'UCVimQoXNCZuEnZRVAbuYMiw', 'UCwtM4HFU4o6E41cKpvsHJVg', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCVimQoXNCZuEnZRVAbuYMiw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCyoGb3SMlTlB8CLGVH4c8Rw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCnsvJeZO4RigQ898WdDNoBw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UC8FOhz3iXhF1iqqzAFfBjmA', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCvmXCP4_uD4Imt8npcFXZ4A', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCnsvJeZO4RigQ898WdDNoBw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCoA66gIqiExUIjwyw1cB9Dw', 'UCUdOoVWuWmgo1wByzcsyKDQ', 'UCnsvJeZO4RigQ898WdDNoBw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UC8FOhz3iXhF1iqqzAFfBjmA', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UC4O4jH5PBsZagQ6aPWPibRQ', 'UCwd8Byi93KbnsYmCcKLExvQ', 'UCT4Jg8h03dD0iN3Pb5L0PMA', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCVimQoXNCZuEnZRVAbuYMiw', 'UC8FOhz3iXhF1iqqzAFfBjmA', 'UCdRY2RSPw1xg5g0N_hQCzWw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCnsvJeZO4RigQ898WdDNoBw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UC8FOhz3iXhF1iqqzAFfBjmA', 'UCnsvJeZO4RigQ898WdDNoBw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UC-9V-k1ugOGSePgIw3UevTQ', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UC8FOhz3iXhF1iqqzAFfBjmA', 'UCUS73_bjTYwBFAfXbvIjM8Q', 'UCnsvJeZO4RigQ898WdDNoBw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCnsvJeZO4RigQ898WdDNoBw', 'UCwd8Byi93KbnsYmCcKLExvQ', 'UC8FOhz3iXhF1iqqzAFfBjmA', 'UCvJS-YNyaWyOucx8bGrHVvw', 'UClLLRs_mFTsNT5U-DqTYAGg', 'UCUS73_bjTYwBFAfXbvIjM8Q', 'UCVimQoXNCZuEnZRVAbuYMiw', 'UC8FOhz3iXhF1iqqzAFfBjmA', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCnsvJeZO4RigQ898WdDNoBw', 'UCwd8Byi93KbnsYmCcKLExvQ', 'UCGXbLrVe8vnkiFv7q2vYv3w', 'UCPd-Lf5gQkAJD5XdTmT_GGA', 'UCVimQoXNCZuEnZRVAbuYMiw', 'UCf6W-gNFClPt_XtQ6P44NTg', 'UCXISYK3xagaK5DHnhQ4X0hw', 'UCwd8Byi93KbnsYmCcKLExvQ', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCwd8Byi93KbnsYmCcKLExvQ', 'UCUdOoVWuWmgo1wByzcsyKDQ', 'UCba3hpU7EFBSk817y9qZkiA', 'UCnsvJeZO4RigQ898WdDNoBw', 'UCrdGjkqTZVMmAOk4YDjFV-w', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCGXbLrVe8vnkiFv7q2vYv3w', 'UCwd8Byi93KbnsYmCcKLExvQ', 'UCvmXCP4_uD4Imt8npcFXZ4A', 'UCvvWGe6qnO-7LxnH3sPKMIg', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCvmXCP4_uD4Imt8npcFXZ4A', 'UCknyABjdbf5eQdzp0FKVt5g', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UC8FOhz3iXhF1iqqzAFfBjmA', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UC-9V-k1ugOGSePgIw3UevTQ', 'UCnsvJeZO4RigQ898WdDNoBw', 'UC8FOhz3iXhF1iqqzAFfBjmA', 'UCig8aKQHLt8E35_LJKwOscA', 'UCnsvJeZO4RigQ898WdDNoBw', 'UCnsvJeZO4RigQ898WdDNoBw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCrdGjkqTZVMmAOk4YDjFV-w', 'UClLLRs_mFTsNT5U-DqTYAGg', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCi4JOMSiIJxdNyUbYKS1vJQ', 'UCvJS-YNyaWyOucx8bGrHVvw', 'UCnsvJeZO4RigQ898WdDNoBw', 'UCUdOoVWuWmgo1wByzcsyKDQ', 'UC-9V-k1ugOGSePgIw3UevTQ', 'UC7E9Dj_lmrJdDrH2Bg7rNqQ', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCnsvJeZO4RigQ898WdDNoBw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCig8aKQHLt8E35_LJKwOscA', 'UC8FOhz3iXhF1iqqzAFfBjmA', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCnsvJeZO4RigQ898WdDNoBw', 'UCwd8Byi93KbnsYmCcKLExvQ', 'UCvJS-YNyaWyOucx8bGrHVvw', 'UC-9V-k1ugOGSePgIw3UevTQ', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCBKBDf4G9Ha4nrutKb02fJA', 'UCGXbLrVe8vnkiFv7q2vYv3w', 'UCnsvJeZO4RigQ898WdDNoBw', 'UCdRY2RSPw1xg5g0N_hQCzWw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCnsvJeZO4RigQ898WdDNoBw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UC84t25xqhPEPpGY7NBZJ_eA', 'UCEomZLuz_697Z_-KAVTqjPQ', 'UCdRY2RSPw1xg5g0N_hQCzWw', 'UClLLRs_mFTsNT5U-DqTYAGg', 'UCyoGb3SMlTlB8CLGVH4c8Rw', 'UCTJXx9onKH6g4cWHS9pLqsQ', 'UCrdGjkqTZVMmAOk4YDjFV-w', 'UCUS73_bjTYwBFAfXbvIjM8Q', 'UC8FOhz3iXhF1iqqzAFfBjmA', 'UCVimQoXNCZuEnZRVAbuYMiw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCOxQk41rWFLWLPAPP_as6uA', 'UCGXbLrVe8vnkiFv7q2vYv3w', 'UCUBIrDsIVzRpKsClMlSlTpQ', 'UCig8aKQHLt8E35_LJKwOscA', 'UCnsvJeZO4RigQ898WdDNoBw', 'UCGXbLrVe8vnkiFv7q2vYv3w', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCvJS-YNyaWyOucx8bGrHVvw', 'UCnsvJeZO4RigQ898WdDNoBw', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCUdOoVWuWmgo1wByzcsyK ...

# %%
len(channel_ids)
# Out:
# 739

# %%
video_ids = []  # Lista para almacenar los videoIds

# Iterar sobre cada elemento de all_videos
for video_info in all_video:
    # Acceder a la clave 'id' y luego a 'videoId'
    video_id = video_info.get('id', {}).get('videoId') #.get() para acceder al valor de 'videoId' dentro de la estructura del diccionario. Si se encuentra un 'videoId', se agrega a la lista video_ids.
    
    # Verificar si se encontró el 'videoId' y agregarlo a la lista video_ids
    if video_id:
        video_ids.append(video_id) 
    else:
        # Si no se encuentra el 'videoId', agregar None a la lista video_ids
        video_ids.append(None)

# %%
len(video_ids)
# Out:
# 739

# %%
v_title = []
for item in all_video:
    video_title = item['snippet']['title'] 
    v_title.append(video_title)
    print(video_title)
# Out:
# AMNISTÍA: La COMISIÓN EUROPEA pide al GOBIERNO más INFORMACIÓN sobre la futura LEY | RTVE
# Felipe González, sobre la amnistía: “Es el Estado el que pide perdón, no el que perdona”
# Ley de Amnistía: ¿ESPAÑA podría PERDER FONDOS de la UNIÓN EUROPEA?
# AMNISTÍA: El PP acusa a SÁNCHEZ de poner la CONSTITUCIÓN al servicio del INDEPENDENTISMO | RTVE
# ¿Se puede aprobar una ley de amnistía? Difícil, pero no imposible
# AMNISTÍA: PARTE del CGPJ pide un PLENO EXTRAORDINARIO para RECHAZAR la LEY | RTVE
# Bruselas analiza la ley de amnistía con &quot;objetividad&quot; e &quot;independencia&quot;
# AMNISTÍA: ARAGONÈS y GARRIGA protagonizan un BRONCO DEBATE en el PARLAMENT | RTVE Noticias
# ¿Qué es la amnistía y en qué se diferencia del indulto del procés de Cataluña? | EL PAÍS
# LEY AMNISTÍA: El PSOE la REGISTRA en el CONGRESO SIN sus SOCIOS y la explica los DETALLES I RTVE
# Las cuatro veces que Sánchez negó la amnistía «por convicción personal y política»
# AMNISTÍA: Los PROGRESISTAS del CGPJ se plantean NO ACUDIR al PLENO para RECHAZAR la LEY | RTVE
# Ley de amnistía: ¿Qué es? ¿Es posible su aprobación?
# LEY AMNISTÍA: El GOBIERNO dice que es &quot;IMPECABLE JURÍDICAMENTE&quot; y pide CONFIANZA | RTVE Noticias
# INVESTIDURA: SÁNCHEZ dice que “SERÁ CLARO&quot; sobre la AMNISTÍA &quot;CUANDO TOQUE&quot; y NO PREVÉ ELECCIONES
# DIRECTO | Debate en la Eurocámara por la ley de amnistía española
# INVESTIDURA SÁNCHEZ: ZAPATERO defiende la AMNISTÍA y dice que “NO es INCONSTITUCIONAL” | RTVE
# AMNISTÍA: PSOE y JUNTS alcanzan un ACUERDO sobre la LEY y la INVESTIDURA de SÁNCHEZ se allana | RTVE
# AMNISTÍA A PUIGDEMONT: Sánchez Sin Escrúpulos
# La polémica ley de amnistía en España que permitirá seguir al actual presidente Pedro Sánchez
# Pedro Sánchez defiende la amnistía en el comité federal del PSOE por “el interés de España&quot; |EL PAÍS
# CONCENTRACIONES AMNISTÍA: CIENTOS DE MILES DE PERSONAS &quot;POR LA IGUALDAD&quot; a petición del PP | RTVE
# Los Fiscales piden a Bruselas que si Sánchez aprueba la amnistía actúe con España como con Polonia
# INVESTIDURA: El PP califica de HUMILLACIÓN el ACUERDO de ERC y PSOE sobre la AMNISTÍA | RTVE
# AMNISTÍA: PSOE se DESMARCA de sus HISTÓRICOS y criticas a GUERRA por su COMENTARIO sobre DÍAZ | RTVE
# La polémica ley de amnistía en España que permitirá seguir al actual presidente Pedro Sánchez • RFI
# ÚLTIMA HORA | El Gobierno de España se adelanta: irá a Europa a explicar la ley de la amnistia
# Acuerdo por ley de amnistía desata protestas en España
# AMNISTÍA: JUNQUERAS y OTEGI piden AVANZAR en el INDEPENDENTISMO en ACTO del SINN FÉIN | RTVE
# AMNISTÍA: Voces CRÍTICAS del PP NO VEN &quot;ACERTADA&quot; la CONVOCATORIA tras las palabras de AZNAR | RTVE
# INVESTIDURA: IBARRA compara la AMNISTÍA con una VIOLACIÓN y ALEGRÍA le pide &quot;CONTENCIÓN&quot; | RTVE
# Las reacciones del Gobierno ante una futura ley de amnistía: &quot;No estamos en ese momento&quot;
# La hemeroteca de Sánchez y su Gobierno: «Amnistía no»
# 🇪🇺 ¿Qué opina la UE sobre la amnistía en España? | Simple Política
# MANIFESTACIONES en CONTRA de la LEY de AMNISTÍA ante la SEDE del PSOE en 10 CIUDADES ESPAÑOLA | RTVE
# AMNISTÍA | El comisario europeo Reynders: &quot;Cataluña es &#39;un asunto interno&#39; español&quot; | EL PAÍS
# LEY AMNISTÍA: La COMISIÓN de JUSTICIA de la UE la estudiará &quot;CUIDADOSAMENTE&quot; cuando se APRUEBE |
# El Debate, a pie de calle: «La amnistía no la necesitan los españoles, la necesita Sánchez»
# FERRAZ | Dentro de la manifestación más numerosa contra la amnistía y la investidura de Sánchez
# SÁNCHEZ habla de AMNISTÍA: &quot;Una FORMA de SUPERAR las CONSECUENCIAS JUDICIALES de la CRISIS&quot; | RTVE
# UE: El PP EUROPEO llevará la AMNISTÍA al próximo PLENO del PARLAMENTO EUROPEO | RTVE Noticias
# Alfonso Guerra, sobre la amnistía: &quot;Me rebelo, no lo aguanto, no lo voy a soportar&quot;
# CGPJ: APRUEBA una DECLARACIÓN contra la LEY de AMNISTÍA gracias a la MAYORÍA CONSERVADORA | RTVE
# AMNISTÍA: BOLAÑOS emplaza a BRUSELAS a abordar la LEY cuando se REGISTRE en el CONGRESO | RTVE
# El PP MUEVE FICHA contra la AMNISTÍA en vísperas de la INVESTIDURA de FEIJÓO | RTVE Noticias
# Así ha evolucionado el discurso de Pedro Sánchez sobre la amnistía
# Europa pide explicaciones al Gobierno por la amnistía
# INVESTIDURA | Bolaños explica la ley de amnistía del PSOE: &quot;Queremos cerrar heridas&quot; | EL PAÍS
# PROTESTAS AMNISTÍA: ¿QUIÉNES son los ULTRAS que han provocado DISTURBIOS en la sede del PSOE? | RTVE
# FERRAZ | Manifestantes protestan contra la amnistía ante la investidura: &quot;Puigdemont, a prisión&quot;
# Europa se tapa los ojos ante la crisis política en España: ¿amnistía a &quot;delitos de terrorismo”?
# DIRECTO | &#39;La amnistía, a debate&#39;, con expertos juristas y moderado por María Jamardo
# Sánchez defiende la amnistía para &quot;tener un gobierno&quot; y &quot;avanzar en la concordia&quot;
# Borrell, sobre la ley de amnistía: &quot;Ya se pueden imaginar lo que pienso&quot;
# ¿Puede el Senado o los jueces parar la amnistía de Sánchez y Puigdemont?
# El PSOE y Sumar enfrían la ley de amnistía antes de la investidura de Sánchez
# España desarma la amnistía de Sánchez: «Ha quebrado la Constitución»
# INVESTIDURA: El PP anuncia NUEVAS MOVILIZACIONES para protestar contra la AMNISTÍA | RTVE
# AMNISTÍA | La &quot;humillación&quot; del mediador y otros titulares de la manifestación del PP | EL PAÍS
# El Rey de España ante la amnistía: su poder para evitar la desaparición del Estado de Derecho
# Page rechaza la amnistía y avisa que aunque cupiera en la Constitución &quot;no casa con valores de PSOE&quot;
# Alsina, sobre la ley de amnistía: &quot;Ahora el conflicto es entre españoles&quot;
# Sánchez: &quot;Ni el referéndum ni la amnistía son posibles, pero espero llegar a una posición pactada&quot;
# El enésimo &quot;cambio de opinión&quot; de Sánchez: cuando decía que &quot;la amnistía no es posible&quot;
# La BROMA de BIDEN a FELIPE VI que dejó al REY a carcajada limpia | Diario AS
# ÚLTIMA HORA | España: Mas tensión por la amnistía: La Guardia Civil dispuesta a “derramar la sangre”
# AMNISTÍA: La POLICÍA justifica en la &quot;PRESENCIA de ULTRAS&quot; su POLÉMICA CARGA en FERRAZ  | RTVE
# &quot;El último que puede echar atrás la ley de amnistía es el Tribunal Constitucional&quot;. Leopoldo Abad
# España: intensas manifestaciones tras firma de acuerdo de amnistía entre PSOE y Junts per Catalunya
# Investidura de Pedro Sánchez; protestas contra la ley de amnistía en Madrid
# La reacción de Pedro Sánchez cuando un vecino le grita ‘¡que te vote Txapote!’ el 28M
# El oscuro vaticinio de Felipe González sobre la amnistía: &quot;Puigdemont lo podrá volver a hacer&quot;
# VOX-AMNISTÍA: ABASCAL anuncia ACCIONES LEGALES contra INTERIOR por las CARGAS POLICIALES en FERRAZ |
# LEY AMNISTÍA: El PSOE decidió presentarla SIN SUS SOCIOS ante las PEGAS de algún PARTIDO | RTVE
# Miles de personas protestan contra la amnistía frente a las sedes del PSOE en toda España
# ÚLTIMA HORA | Más tensión en España por la amnistía: represalia del Gobierno contra la Guardia Civil
# Vox se querellará mañana contra Sánchez por la ley de amnistía
# JORNADAS VOX AMNISTÍA | ‘No vamos a permitir que se destruya la nación española’
# LEY AMNISTÍA: Abarca MÁS de una DÉCADA de &#39;PROCÉS&#39;, incluye a los POLICÍAS del 1-O | RTVE Noticias
# El comisario de Justicia de la UE avisa de que &quot;hay algunos límites&quot; a una ley de amnistía
# ¿QUÉ OPINA LA UNIÓN EUROPEA SOBRE LA AMNISTÍA? ¿SALVARÁ A ESPAÑA?
# INVESTIDURA FEIJÓO: ERC y JUNTS piden ir más allá de la AMNISTÍA y PACTAR un nuevo REFERÉNDUM | RTVE
# ARAGONÈS, tras el pacto ERC-PSOE sobre la AMNISTÍA: &quot;Es hora de AVANZAR hacia el REFERÉNDUM&quot; | RTVE
# La BROMA de BIDEN a FELIPE VI que dejó al REY a carcajada limpia | Diario AS
# Miles de personas salen a la calle en contra de la amnistía en Barcelona
# Zapatero: &quot;La ley de amnistía no tiene reproches. Es valiente e inteligente&quot;
# LEY AMNISTÍA: SUMAR se QUERELLA contra los VOCALES CONSERVADORES del CGPJ y el PSOE se DESMARCA |
# Independencia de Cataluña: dos chicas discuten sus visiones a favor y en contra
# Manifestantes contra la amnistía CORTAN GRAN VÍA y se concentran frente al CONGRESO
# LEY AMNISTÍA: FEIJÓO se reúne con CORRESPONSALES EXTRANJEROS para expresar su &quot;PREOCUPACIÓN&quot; | RTVE
# Feijóo: &quot;Si Puigdemont nos propone la amnistía como requisito, nos podemos ahorrar la reunión&quot;
# El socialista Ibarra compara la amnistía con violar a 40 millones de españoles #Ibarra #Amnistía
# PUIGDEMONT: Marca las CONDICIONES para empezar a NEGOCIAR la INVESTIDURA | RTVE Noticias
# El Senado aprueba reformar el Reglamento para retrasar la ley de amnistía
# SENADO: APROBADA la REFORMA del REGLAMENTO que DILATARÁ la LEY de AMNISTÍA | RTVE
# Informe desde Madrid: manifestación masiva contra ley de amnistía a independentistas
# Informe desde Madrid: seguidores del PP protestan contra posible amnistía a independentistas
# Alsina comenta con Susanna Griso la ley de amnistía: &quot;Hay 13 gobiernos autonómicos en contra&quot;
# Almeida clama contra la amnistía y critica la «deshonra y el deshonor» de Pedro Sánchez
# Unos cincuenta españoles se concentran en Bruselas contra la ley de amnistía
# ARAGONÈS, tras el pacto ERC-PSOE sobre la AMNISTÍA: &quot;Es hora de AVANZAR hacia el REFERÉNDUM&quot; | RTVE
# Miles de personas salen a la calle en contra de la amnistía en Barcelona
# Catalanes reaccionan al discurso del rey de España
# INVESTIDURA: FEIJÓO ofrece a SÁNCHEZ &quot;una TERCERA VÍA&quot; a la AMNISTÍA con &quot;PACTOS de ESTADO&quot; | RTVE
# Sánchez: &quot;Defiendo la amnistía para hacer de la necesidad, virtud&quot;
# Eneko Andueza, candidato socialista a lehendakari, se posiciona a favor de la amnistía en Cataluña
# Pérez-Reverte: &quot;Estoy en contra de la amnistía, me parece mal&quot; - El Hormiguero
# Crisis en España por la Ley de Amnistía
# Girauta, sobre la amnistía: «Toda España es víctima de un golpe de Estado»
# Alfonso Guerra carga contra Puigdemont y contra la amnistía
# AMNISTÍA: El CERCLE D&#39;ECONOMIA la CONSIDERA &quot;UNA OPORTUNIDAD&quot; para REFORZAR la DEMOCRACIA | RTVE
# JUNQUERAS: Afirma que la LEY de AMNISTÍA &quot;ya está PACTADA&quot; con el PSOE desde AGOSTO | RTVE Noticias
# 🔴 DIRECTO | El Parlamento Europeo trata la cuestión de la amnistía
# Feijóo, tajante con las mentiras de Sánchez sobre la amnistía: «Su palabra no vale nada»
# Rajoy clama contra la amnistía: «Me pone muy nervioso»
# Sánchez opta a la investidura y avisa sobre la ley de amnistía: &quot;El diálogo es el método y la Consti
# &quot;El PP rompe España&quot; Sánchez sobre la Amnistía y Cataluña #shorts
# &quot;QUE NO NOS TOMEN EL PELO&quot; Feijóo sobre la Amnistía y la investidura de Sánchez #shorts
# Sánchez, sobre la amnistía: &quot;En nombre de España, vamos a conceder una amnistía&quot;
# PIQUÉ y SU FEO GESTO a la NOVIA de FRENKIE DE JONG en 2019 | Diario AS
# 🔴 DIRECTO MADRID | Mitin del PP en contra de la amnistía
# Arturo Pérez-Reverte analiza a los líderes políticos actuales - El Hormiguero
# El PSOE ESTÁ DANDO VERGÜENZA con la AMNISTÍA ❌ #noticias #amnistía #psoe #ley  #amnistía #reaccion
# Vicente Vallés desmonta la sucia estrategia de Sánchez con la amnistía en dos minutos demoledores
# Herrera: &quot;En Europa cada vez hay más alarmas contra la amnistía&quot;
# Amnistía y condonación de la deuda en Cataluña: la máquina de hacer dinero y la sociedad Peter Pan
# DIRECTO FERRAZ | Así ha sido la manifestación contra la amnistía en la sede del PSOE | EL PAÍS
# Amnistía para condenados por secuestro y narcotráfico. Juanita Gómez opina
# Puigdemont pide la amnistía y un mediador para negociar: &quot;O elecciones o pactan con nosotros&quot;
# 1/4 Ley de Amnistía: línea roja, pierde la política. Rueda de prensa de Miguel Ángel Revilla
# Los REYES FELIPE y LETIZIA RECREAN en el SET de RTVE su SALUDO CÓMPLICE DOS DÉCADAS DESPUÉS | RTVE
# DIRECTO | Manifestación de Sociedad Civil Catalana en Barcelona contra la amnistía | EL PAÍS
# Alsina critica la ley de amnistía: &quot;No estaríamos hablando de esto si no fuera por los siete votos&quot;
# Aznar, demoledor contra Sánchez: &quot;Es un peligro para la democracia constitucional&quot;
# Felipe González despelleja a Zapatero y a Sánchez por querer colar una inexplicable amnistía
# Felipe González despelleja a Zapatero y a Sánchez por querer colar una inexplicable amnistía
# INVESTIDURA SÁNCHEZ: El PSOE reconoce que es COMPLEJA pero ve POSIBLE sacarla ADELANTE | RTVE
# CONGRESO-LENGUAS COOFICIALES: VOX sale del HEMICICLO y deja sus PINGANILLOS en el SITIO de SÁNCHEZ
# Experta en derecho constitucional contra la amnistía: &quot;Se negocia por un puñado de votos&quot;
# Manuel Valls, sobre la amnistía: &quot;Es una humillación deliberada a la generación de la Transición&quot;
# INVESTIDURA-ACUERDO PSOE-ERC: JUNQUERAS, &quot;HOY gana CATALUÑA con una AMNISTÍA SIN EXCEPCIONES&quot; | RTVE
# BARCELONA: SUMAR propone una AMNISTÍA de 2013 a 2023 por la &quot;FALTA de PROPORCIONALIDAD JUDICIAL&quot;
# AMNISTÍA INTERNACIONAL: &quot;En ESPAÑA, lo MÁS PREOCUPANTE es la IMPUNIDAD en ciertos temas&quot; | RTVE
# Pedro Sánchez confía en su investidura: &quot;El acuerdo se puede, se debe y se va a alcanzar” | EL PAÍS
# ESPAÑA QUEMA LA CALLE CON LA AMNISTÍA: ¡SERÁ IMPOSIBLE DE REVERTIR!
# &quot;DIMISIÓN es lo que tiene que hacer Pedro Sánchez&quot; Feijóo sobre Amnistía
# PAGE defiende la solvencia de FEIJÓO y critica a los SOCIOS &quot;DISOLVENTES&quot; del GOBIERNO | RTVE
# ISRAEL -GAZA : Los judíos ULTRAORTODOXOS sostienen a NETANYAHU y NO combaten | RTVE Noticias
# ONU: SÁNCHEZ advierte de una la OLA EXTREMISTA y dice que el FEMINISMO es &quot;el MAYOR ANTÍDOTO&quot; | RTVE
# Discursos de odio y libertad de expresión - Educación en derechos humanos
# &quot;La Amnistía de Sánchez sólo busca una transacción&quot; Feijóo #shorts
# Diferencia el INDULTO de la AMNISTÍA #ortografía #amnistía #aprendevocabulario #aprendelexico #ebau
# Aznar desmonta la amnistía ante Carlos Herrera: &quot;No es una cuestión de legalidad, es política&quot;
# Carlos Herrera: &quot;La amnistía significa reconocer que la razón política la tenían los golpistas&quot;
# ABASCAL ¡SE PLANTA EN EL PARLAMENTO EUROPEO! y💥HUNDE A SÁNCHEZ💥 al RETRATARLO por TIRANO ante EUROPA
# DIRECTO | Manifestación del Partido Popular contra la amnistía
# La acertada pregunta de Vicente Vallés tras la bochornosa foto entre Yolanda Díaz y Puigdemont
# Sánchez ya habla de AMNISTÍA para &quot;superar las consecuencias judiciales de una de las peores CRISIS&quot;
# Jordi Cañas en El Toro TV sobre el acuerdo de #amnistía entre PSOE y #Puigdemont
# Sale a la luz un vídeo de ADA COLAU OKUPANDO un piso cuando era joven
# &quot;Recursos de VOX contra la ley de Amnistía&quot; Jorge Buxadé (VOX) #shorts
# Letizia, en estado puro con una joven escritora
# Felipe González, sobre la reunión de Díaz y Puigdemont: &quot;Si va por su cuenta, que lo pague&quot;
# ÚLTIMA HORA| Europa no sabe dónde está el dinero de los fondos europeos en España y señala a Calviño
# &quot;No nos vamos a callar hasta que haya elecciones&quot; Feijóo sobre Amnistía de Sánchez
# SÁNCHEZ EXPLICA su &quot;CAMBIO de OPINIÓN&quot; con la AMNISTÍA y ADMITE que LOS ESPAÑOLES NO LE APOYAN
# Diputado Schalper a Boric: &quot;Ríase todo lo que quiera, le va a servir para bajar de peso&quot;
# Sánchez sobre si habrá amnistía o no: &quot;Estamos negociando con los grupos&quot;
# Aznar dice que la amnistía legitima la sedición y es &quot;una invitación a volver a hacerlo&quot;
# John de Zulueta no da crédito al esperpento de la amnistía y los pinganillos: “¡Es un despropósito!”
# &quot;No tenemos Rey&quot;: escuche el discurso de ERC, Bildu, BNG, JxCAT y CUP
# Qué es Amnistía Internacional
# 30/11/2023 Miras defiende una enmienda contra la Ley de Amnistía en Europa
# Pablo Iglesias: &quot;Sería saludable publicar la lista de la amnistía fiscal&quot;
# Intervención de Fernando López Miras ante la UE
# Las cinco perlas de Aznar sobre la &quot;autodestrucción&quot; de España
# MAGISTRADA DEL T.C. DICE QUE LA AMNISTÍA PUEDE TENER ENCAJE CONSTITUCIONAL. ESTÁ TODO HECHO!!
# EL XOKAS genera POLÉMICA al elogiar a quienes se aprovechan de MUJERES &quot;COLOCADAS&quot; | RTVE Noticias
# Herrera y el &quot;francomodín&quot; de Sánchez para acabar con la ley de Amnistía de 1977
REINA LETIZIA cumple 50 AÑOS: Cómo era la JOVEN PERIODISTA que conocimos en el TELEDIARIO | RTVE
# Bolaños, tras reunirse con la Comisión Europea:  &quot;Hay cero preocupación&quot; por la ley de amnistía
# Cándido Méndez: &quot;La palabra amnistía no es interpretable, significa borrar los delitos&quot;
# LA CONSTITUCIÓN ESPAÑOLA DE 1978: LA RECONCILIACIÓN
# AMNISTIA, LA VERDAD DE LA MANIFESTACIÓN, en Directo
# ¿Por qué perdió la voz Miguel Bosé? - El Hormiguero
# Aznar habla claro del plan de Pedro Sánchez: &quot;Voy a gobernar contra vosotros&quot;
# Jaime Bayly le hace un traje a Pedro Sánchez: «ha hecho un Gobierno mediocre»
# Rifirrafe entre Bescansa y Nart a propósito de la &quot;Justicia para ricos y pobres&quot;
# La Guerra Civil española
# Ayuso hace gala del anticatalanismo en la Asamblea de Madrid y así le responde la izquierda
# Sánchez admite ya el diálogo sobre la amnistía: &quot;Estamos negociando con los grupos&quot;
# BONANOVA: BLINDAN la ZONA al COINCIDIR concentraciones a FAVOR y en CONTRA de la OKUPACIÓN | RTVE
# FEIJÓO o AMNISTÍA: Aitor Esteban responde a Cuca Gamarra #shorts
# Así empezó el Alzamiento Nacional en julio de 1936  | España dividida: La Guerra Civil en color
# ¿ÉS LEGAL la AMNISTÍA en ESPAÑA?
# #TuEspacioINACIPE | &quot;Reflexiones sobre la Ley de Amnistía&quot;.
# Alsina: &quot;Sánchez admite que la amnistía es su investidura y da por seguro que tiene a Puigdemont&quot;
# ¿ESPAÑA QUIERE LA AMNISTÍA?
# Rechazo la amnistía como solución para los independentistas radicales;
# Eurodiputados SE REBELAN contra la amnistía en Europa: “Va en contra de la ley”
# Sistemas de financiación internacional de Amnistía Internacional
# HOY EN SUIZA PUIGDEMONT DIRIGE ESPAÑA
# El 23-F PASO A PASO: cómo transcurrió el intento de golpe de Estado | RTVE Noticias
# REQUISITOS para VIAJAR a ESPAÑA actualizados | Mayo 2023
# PREGUNTAS A MUJERES SOBRE LA LEY SOLO SÍ ES SÍ #feminismo
# 💥 APOTEÓSICO repaso de VICENTE VALLÉS a PEDRO SÁNCHEZ por su nueva contradicción electoral 💥
# Mujeres en Afganistán: ¿Cómo ha cambiado su vida bajo el régimen talibán? | EL PAÍS
# La amnistía para los que quebrantan la ley en nombre del independentismo es un desprecio al estado
# Hombre irrumpe acto feminista con grito machista en España
# LA RESISTENCIA - Entrevista a María Pombo | #LaResistencia 15.11.2022
# 💥 RAY DALIO PREDICE una HORRIBLE CRISIS económica donde TODO COLAPSARÁ |👉 CÓMO puedes PROTEGERTE?
# EEUU anuncia nuevo programa de parole humanitario: abogado de inmigración responde dudas al respecto
# INVESTIDURA: PP pide &quot;RECAPACITAR&quot; al PSOE, que exige el CESE del llamamiento al TRANSFUGISMO | RTVE
# EE.UU.: La Reserva Federal MANTIENE los TIPOS de INTERÉS entre el 5,25 y el 5,5% I RTVE
# Antonio Resines - OPINIÓN AMNISTÍA
# Javier Cercas: “Fui a la literatura buscando un sucedáneo de la religión” | El País
# 💥 PABLO MOTOS y su tropa de &#39;El Hormiguero&#39; despellejan al esbirro de SÁNCHEZ que blanquea a BILDU 💥
# Federico a las 7: Sánchez consuma la traición a España
# Manifestación contra la posible amnistía en la Plaza Mayor de Guadalajara
# PORTUGAL: POLÉMICA por el ALTAR de CINCO MILLONES para las JMJ que presenciará el PAPA | RTVE
# Así se fraguó la negociación entre Bukele y la MS-13, según una acusación de EE.UU.
# ÁLVARO PRIETO: La POLICÍA BARAJA la ELECTROCUCIÓN como PRINCIPAL HIPÓTESIS sobre SU MUERTE | RTVE
# BORRASCA CIARÁN: Casi TODA ESPAÑA en ALERTA por rachas de VIENTO, fuertes LLUVIAS y mala MAR | RTVE
# SE DESATA LA POLÉMICA EN LA INAUGURACIÓN DE LA XV LEGISLATURA.
# Leguina sopapea al lugarteniente de Sánchez: &quot;¿Qué puedo decir de alguien que se acuesta con Bildu?&quot;
# CRISTINA ALMEIDA TRENDING TOPIC, DE LA AMNISTIA NO, A LA AMNISTIA SI, cambio de opinión una semana
# 🔴 DIRECTO | El rey Felipe VI abre la XV Legislatura en el Congreso (29/11/2023)
# PEDRO SANCHEZ DECIA QUE HAY QUE PASAR DE PUIGDEMONT #shorts #puigdemont #amnistía #sanchez #vox
# Villarroya sobre Rússia, Xina i Espanya | OpinaCat
# ¿Amenaza Sánchez al Rey para la firma de la amnistía?
# Descifrando el Presente Político en España (Pablo Lucini) | Ep 10 Breaking Limits
# Diferencia entre amnistía e indulto. Ley de amnistía presentado por el PSOE-Pedro Sánchez en España
# Contra la amnistía y por la dignidad de España
# España ARDE contra Sánchez por la amnistía: “Tiene que acabar en prisión”
# Pedro Sanchez y su opinión acerca de la amnistía
# Feijoo EXTRAVAGANTE en la manifestación contra la AMNISTÍA En Malaga💥😱😱
# Los españoles ESTALLAN contra Sánchez y la AMNISTÍA en la manifestación del 8O
# PUIGDEMONT Y SANCHEZ SE RIEN DEL TRIBUNAL SUPERIOR #shorts #puigdemont #amnistía #pedrosanchez #vox
# La salvaje advertencia de Guillermo Rocafort que pone patas arriba el futuro de España
# La Unión Europea ya está estudiando la ley de amnistía, son la única esperanza para salvar a España
# Tres historias para empezar el día, con Carlos Alsina 30/11/2023
# FEMINISTA VS ROMA GALLARDO
# ISRAEL-GAZA: BELARRA defiende su DERECHO a PRONUNCIARSE como parte de la COALICIÓN de GOBIERNO |RTVE
# CRITICAS AL REY en la manifestación contra la Amnistía de Barcelona
# 🇪🇸 La Falange marcha contra la amnistía separatista desde Génova hasta Ferraz, Madrid (18 nov 2023)
# El Gobierno de Italia ARREMETE contra Sánchez: “Gobierna la extrema izquierda”
# PEDRO SÁNCHEZ AMNISTÍA  - VIVA ESPAÑA 🇪🇸
# PEDRO SANCHEZ GASTA 140.000€ EN UNA CENA #shorts #pedrosanchez #vox #abascal #amnistía #puigdemont
# NO TODO VALE CUANDO SE VA CONTRA LA CONSTITUCIÓN!!
# ESPAÑA | ¡NO a la Amnistía! ¡Viva ESPAÑA! | Eso Gritan los Españoles
# ¿QUÉ ES LA AMNISTÍA?
# THE BEATLES: JOHN LENNON y GEORGE HARRISON recobran vida gracias a la IA en su ÚLTIMA CANCIÓN I RTVE
# Vanguardia Española - La IZQUIERDA NACIONAL [Entrevista a Santiago ARMESILLA en El Gato al Agua]
# Herrera: “Sánchez es el único presidente que ha logrado que 3 países le retiren sus embajadores&quot;
# Amnistía y manifestaciones ciudadanas. Fenómeno Milei
# Feijóo,contra la amnistía: “España funciona gracias a los españoles que desprecian&quot;
# VOX en Bruselas criticando la ley de amnistía. Esto es la política de los contrarios al gobierno.
# El impulsor de los rezos en Ferraz: «Las grandes batallas se han ganado con un Rosario en las manos»
# GUERRA entre PALESTINA e ISRAEL con Jose Antonio Zorrilla
# Amnistía Internacional condena España por su represión el 1-0 en Cataluña en su informe global
# Jesús Á.Rojo:💥Juan Carlos I se planta ente la AMNISTÍA y golpea a Sánchez y a todos sus ministros💥
# El enfado de Thais Villas con un señor que afirma que el feminismo es lo mismo que el machismo
# EE.UU e ISRAEL conocían el ataque. RUSIA arrincona a UCRANIA. MILEI aleja a ARGENTINA de los BRICS
# Jesús Á.Rojo💥Letizia toma partido por políticas radicales mientras Felipe VI calla sobre la amnistía
# Pedro Sánchez y Pablo Iglesias &#39;Al rojo vivo&#39; | José Mota
# La Ley de Amnistia precipitará la caída política de los tres poderes del estado democratico Español
# #shorts Santiago #abascal  habla contra la Amnistía de Pedro #sanchez  al separatismo en Colón
# 🔥BOMBAZO EN EL CONSTITUCIONAL🔥EMPIEZAN LAS RENUNCIAS por la AMNISTÍA de Pedro Sánchez.
# DURO GOLPE A PEDRO SÁNCHEZ LA AMNISTÍA ES ANTICONSTITUCIONAL Top Ten Life Noticias Actualidad
# VIDEO MUY URGENTE sobre ELECCIONES y AMNISTÍA
# 👉𝐁𝐑𝐔𝐓𝐀𝐋!! 𝐀𝐏𝐎𝐘𝐎 𝐀 𝐋𝐀 𝐀𝐌𝐍𝐈𝐒𝐓𝐈́𝐀 𝐃𝐄𝐒𝐃𝐄 𝐋𝐀 𝐃𝐄𝐑𝐄𝐂𝐇𝐀!!👈😱😱😱 ISRAEL INCREMENTA PRESIÓN SOBRE ESPAÑA❌
# Precio de la Cruzcampo en 🇬🇧 #pedrosánchez #podemos #sumar#amnistia #pp#vox#cataluña  #yolandadíaz
# 🔴#ENVIVO/MUNDO ROJO:Mosad confirma, Sánchez ha provocado la crisis con Israel para tapar la amnistía
# El NO a la Amnistía es tan sólo el primer paso, la punta del iceberg!. EL PUEBLO DECIDE!.QUE OPINAS?
# 💥Escándalo.Juristas revelan impactantes violaciones constitucionales por la amnistía: 7 artículos💥
# 😱 Escándalo: La élite compra el sistema de Derechos Humanos | Agustín Laje
# Yolanda Díaz expresa su “satisfacción” ante los datos del paro en noviembre
# Saturday Night Live;  La humillación a España por parte de Sánchez y Puigdemont
# Sam y Cat | Fans de Sam y Cat | Nickelodeon en Español
# DIRECTO | Manifestación contra Pedro Sánchez en Madrid Ferraz
# 💥BRUTAL💥El PSOE con el &quot;alma en un puño&quot;: SÁNCHEZ se descompone por momentos
# ¡ÚLTIMA HORA! EL GOBIERNO AMENAZA A LOS JUECES por la amnistia a Puigdemont.
# Pedro Sánchez, PILLADO mintiendo con Ferreras en La Sexta
# Víctimas españoles nolotil🇪🇦 #yahorasonsoles #stopnolotil #fármacos #agranulocitosis  #AEMPS
# PEDRO SÁNCHEZ Y LA AMNISTÍA #español #noticias #shorts
# Pedro Sánchez y la amnistía a Puigdemont #endikafl #liberalismo #españa #soloquedavox #vivaespaña
# LHDC 268 &quot;Memoria democrática&quot;, amnistía y 20N: el PSOE a lo suyo mientras España muere de hambre.
# 🔴#ENVIVO/MUNDO ROJO: 💥¡SÁNCHEZ SE HUNDE!💥: Bofetón histórico del Poder Judicial al Gobierno
# Ni amnistía , ni autodeterminación! Viva España 🇪🇸
# 🔥ÚLTIMA HORA🔥LA JUSTICIA HUNDE la AMNISTÍA a PUIGDEMONT
# 🔴#ENVIVO/MUNDO ROJO:Felipe VI defrauda a la nación y allana el camino del golpe de Estado de Sánchez
# 💥SOROS y ROCKEFELLER, financiadores de  Henry Dunant que supervisa el pacto SÁNCHEZ y PUIGDEMONT💥
# ESTO NO VA DE FOROFISMOS, VA DE LÓGICA

# %%
len(v_title)
# Out:
# 719

# %%
df_amnistia= pd.DataFrame({'canal_ID' : channel_ids, 'video_ID': video_ids, 'video_Title' : v_title})

# %%
df_amnistia.to_csv('/Users/usuario/Downloads/irunela/csv/videos_amnistia.csv')

# %%
df_amnistia.head()
# Out:
#                    canal_ID     video_ID  \
# 0  UC7QZIf0dta-XPXsp9Hv4dTw  T-smnnEAdM0
# 1  UCVimQoXNCZuEnZRVAbuYMiw  0HVzuoDgkkY
# 2  UCwtM4HFU4o6E41cKpvsHJVg  aXLB8r1t8ec
# 3  UC7QZIf0dta-XPXsp9Hv4dTw  ESCHnb7VfnY
# 4  UCVimQoXNCZuEnZRVAbuYMiw  -xFqEigRo4w
#
#                                          video_Title
# 0  AMNISTÍA: La COMISIÓN EUROPEA pide al GOBIERNO...
# 1  Felipe González, sobre la amnistía: “Es el Est...
# 2  Ley de Amnistía: ¿ESPAÑA podría PERDER FONDOS ...
# 3  AMNISTÍA: El PP acusa a SÁNCHEZ de poner la CO...
# 4  ¿Se puede aprobar una ley de amnistía? Difícil...

# %%
from pprint import pprint
def get_comments(video_ids):
    comments = []
    try:
        response = youtube.commentThreads().list(
            part='snippet',
            videoId=video_ids,
            textFormat='plainText'
        ).execute()
    except Exception:
        print(f"Fallo conseguir comentarios de {video_ids}")
        return []

    for item in response['items']:
        try:
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            author_channel_id = item['snippet']['topLevelComment']['snippet']['authorChannelId']["value"]
            #author_channel_id = comment['authorChannelId']['value']
            comments.append({"video_id": video_ids, "author": author_channel_id, "comment": comment})
        except KeyError as e:
            print(f"Falta algun valor de un comentario, {e}")
            comments.append(None)
            continue
    return comments

# %%
from tqdm.notebook import tqdm 
comment_video = [] 
for video in tqdm(video_ids): 
    comments = get_comments(video) 
    comment_video.extend(comments)
# Out:
#   0%|          | 0/739 [00:00<?, ?it/s]
# Fallo conseguir comentarios de EoXnrI-2KWI
# Fallo conseguir comentarios de vpvdcm2Un28
# Fallo conseguir comentarios de ZvjIaeya6l8
# Fallo conseguir comentarios de s4PfK-_0zk0
# Fallo conseguir comentarios de 4qcCJ40q298
# Fallo conseguir comentarios de 1Hgp3tbD0sc
# Fallo conseguir comentarios de ZJT9C4VvX8A
# Fallo conseguir comentarios de aJPthTgdg8Y
# Fallo conseguir comentarios de None
# Fallo conseguir comentarios de gAwWUUC4E-w
# Fallo conseguir comentarios de Xsj1toVLl8Y
# Fallo conseguir comentarios de xxgpwHH7wSE
# Fallo conseguir comentarios de 2bXIhneDbkE
# Fallo conseguir comentarios de 4DYl6FumojM
# Fallo conseguir comentarios de b36QGKLbgXI
# Fallo conseguir comentarios de KEdACakOoCw
# Fallo conseguir comentarios de None
# Fallo conseguir comentarios de None
# Fallo conseguir comentarios de AiFxwqM0_9o
# Fallo conseguir comentarios de u4ieWAMM7CA
# Fallo conseguir comentarios de hu2Eo2BF-s4

# %%
len(comment_video)
# Out:
# 11908

# %%
comentarios_amnistia = pd.DataFrame(filter(None, comment_video))

# %%
comentarios_amnistia.to_csv('/Users/usuario/Downloads/irunela/csv/comentarios_amnistia.csv')

# %% [markdown]
# Data pre-processing

# %%
comentarios_amnistia = pd.read_csv('/Users/usuario/Downloads/irunela/csv/comentarios_amnistia.csv')

# %%
valores_nulos = comentarios_amnistia.isnull().sum()  # Esto devuelve la cantidad de valores nulos por columna
print(valores_nulos)
# Out:
# Unnamed: 0    0
# video_id      0
# author        0
# comment       0
# dtype: int64

# %%
# Check data types
comentarios_amnistia.dtypes
# Out:
# Unnamed: 0     int64
# video_id      object
# author        object
# comment       object
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
comentarios_amnistia.shape
# Out:
# (11908, 4)

# %%
index_random = np.random.randint(0,high = comentarios_amnistia.shape[0])
comentario = comentarios_amnistia.iloc[index_random].comment
print(index_random, comentario)
# Out:
# 3011 La derecha quiere reventar la constitución

# %%
comment = str(comentarios_amnistia['comment'])

# %%
#sent_tokenize todo el comentario
comment_st = nltk.tokenize.sent_tokenize(comment)
comment_st
# Out:
# ['0        No me creo que les importemos algo.',
#  'Estos son ...\n1        No a la ANMISTIA y no AL PERDONA LA DEUDA DE C...\n2        Que no te enteras,Contreras\\nQue se la trae fl...\n3        ¿Como puede ser impecable?, si hasta hace poco...\n4        Osea que cuando gobierna el PP nos roba y mete...\n                               ...                        \n11903    Bermejo tú siempre has sido lo mismo un Comuni...\n11904    Hablemos de lo que nos importa ese pacto y sor...\n11905    Si señora, una nube de humo para tapar el golp...\n11906    Pero fijaros que no enseñan todo esa informaci...\n11907    Pero también Israel quiere gaza desde siempre ...\nName: comment, Length: 11908, dtype: object']

# %%
#word_tokenize tokeniza palabra por palabra
comment_wt = nltk.tokenize.word_tokenize(comment)
comment_wt
# Out:
# ['0',
#  'No',
#  'me',
#  'creo',
#  'que',
#  'les',
#  'importemos',
#  'algo',
#  '.',
#  'Estos',
#  'son',
#  '...',
#  '1',
#  'No',
#  'a',
#  'la',
#  'ANMISTIA',
#  'y',
#  'no',
#  'AL',
#  'PERDONA',
#  'LA',
#  'DEUDA',
#  'DE',
#  'C',
#  '...',
#  '2',
#  'Que',
#  'no',
#  'te',
#  'enteras',
#  ',',
#  'Contreras\\nQue',
#  'se',
#  'la',
#  'trae',
#  'fl',
#  '...',
#  '3',
#  '¿Como',
#  'puede',
#  'ser',
#  'impecable',
#  '?',
#  ',',
#  'si',
#  'hasta',
#  'hace',
#  'poco',
#  '...',
#  '4',
#  'Osea',
#  'que',
#  'cuando',
#  'gobierna',
#  'el',
#  'PP',
#  'nos',
#  'roba',
#  'y',
#  'mete',
#  '...',
#  '...',
#  '11903',
#  'Bermejo',
#  'tú',
#  'siempre',
#  'has',
#  'sido',
#  'lo',
#  'mismo',
#  'un',
#  'Comuni',
#  '...',
#  '11904',
#  'Hablemos',
#  'de',
#  'lo',
#  'que',
#  'nos',
#  'importa',
#  'ese',
#  'pacto',
#  'y',
#  'sor',
#  '...',
#  '11905',
#  'Si',
#  'señora',
#  ',',
#  'una',
#  'nube',
#  'de',
#  'humo',
#  'para',
#  'tapar',
#  'el',
#  'golp',
#  '...',
#  '11906',
#  'Pero',
#  'fijaros',
#  'que',
#  'no',
#  'enseñan',
#  'todo',
#  'esa',
#  'informaci',
#  '...',
#  '11907',
#  'Pero',
#  'también',
#  'Israel',
#  'quiere',
#  'gaza',
#  'desde',
#  'siempre',
#  '...',
#  'Name',
#  ':',
#  'comment',
#  ',',
#  'Length',
#  ':',
#  '11908',
#  ',',
#  'dtype',
#  ':',
#  'object']

# %% [markdown]
# Normalización

# %% [markdown]
# Stopwords

# %%
stopwords = nltk.corpus.stopwords.words('spanish')
stopwords = [palabra for palabra in stopwords if 'not' not in palabra]
stopwords
# Out:
# ['de',
#  'la',
#  'que',
#  'el',
#  'en',
#  'y',
#  'a',
#  'los',
#  'del',
#  'se',
#  'las',
#  'por',
#  'un',
#  'para',
#  'con',
#  'no',
#  'una',
#  'su',
#  'al',
#  'lo',
#  'como',
#  'más',
#  'pero',
#  'sus',
#  'le',
#  'ya',
#  'o',
#  'este',
#  'sí',
#  'porque',
#  'esta',
#  'entre',
#  'cuando',
#  'muy',
#  'sin',
#  'sobre',
#  'también',
#  'me',
#  'hasta',
#  'hay',
#  'donde',
#  'quien',
#  'desde',
#  'todo',
#  'nos',
#  'durante',
#  'todos',
#  'uno',
#  'les',
#  'ni',
#  'contra',
#  'otros',
#  'ese',
#  'eso',
#  'ante',
#  'ellos',
#  'e',
#  'esto',
#  'mí',
#  'antes',
#  'algunos',
#  'qué',
#  'unos',
#  'yo',
#  'otro',
#  'otras',
#  'otra',
#  'él',
#  'tanto',
#  'esa',
#  'estos',
#  'mucho',
#  'quienes',
#  'nada',
#  'muchos',
#  'cual',
#  'poco',
#  'ella',
#  'estar',
#  'estas',
#  'algunas',
#  'algo',
#  'nosotros',
#  'mi',
#  'mis',
#  'tú',
#  'te',
#  'ti',
#  'tu',
#  'tus',
#  'ellas',
#  'nosotras',
#  'vosotros',
#  'vosotras',
#  'os',
#  'mío',
#  'mía',
#  'míos',
#  'mías',
#  'tuyo',
#  'tuya',
#  'tuyos',
#  'tuyas',
#  'suyo',
#  'suya',
#  'suyos',
#  'suyas',
#  'nuestro',
#  'nuestra',
#  'nuestros',
#  'nuestras',
#  'vuestro',
#  'vuestra',
#  'vuestros',
#  'vuestras',
#  'esos',
#  'esas',
#  'estoy',
#  'estás',
#  'está',
#  'estamos',
#  'estáis',
#  'están',
#  'esté',
#  'estés',
#  'estemos',
#  'estéis',
#  'estén',
#  'estaré',
#  'estarás',
#  'estará',
#  'estaremos',
#  'estaréis',
#  'estarán',
#  'estaría',
#  'estarías',
#  'estaríamos',
#  'estaríais',
#  'estarían',
#  'estaba',
#  'estabas',
#  'estábamos',
#  'estabais',
#  'estaban',
#  'estuve',
#  'estuviste',
#  'estuvo',
#  'estuvimos',
#  'estuvisteis',
#  'estuvieron',
#  'estuviera',
#  'estuvieras',
#  'estuviéramos',
#  'estuvierais',
#  'estuvieran',
#  'estuviese',
#  'estuvieses',
#  'estuviésemos',
#  'estuvieseis',
#  'estuviesen',
#  'estando',
#  'estado',
#  'estada',
#  'estados',
#  'estadas',
#  'estad',
#  'he',
#  'has',
#  'ha',
#  'hemos',
#  'habéis',
#  'han',
#  'haya',
#  'hayas',
#  'hayamos',
#  'hayáis',
#  'hayan',
#  'habré',
#  'habrás',
#  'habrá',
#  'habremos',
#  'habréis',
#  'habrán',
#  'habría',
#  'habrías',
#  'habríamos',
#  'habríais',
#  'habrían',
#  'había',
#  'habías',
#  'habíamos',
#  'habíais',
#  'habían',
#  'hube',
#  'hubiste',
#  'hubo',
#  'hubimos',
#  'hubisteis',
#  'hubieron',
#  'hubiera',
#  'hubieras',
#  'hubiéramos',
#  'hubierais',
#  'hubieran',
#  'hubiese',
#  'hubieses',
#  'hubiésemos',
#  'hubieseis',
#  'hubiesen',
#  'habiendo',
#  'habido',
#  'habida',
#  'habidos',
#  'habidas',
#  'soy',
#  'eres',
#  'es',
#  'somos',
#  'sois',
#  'son',
#  'sea',
#  'seas',
#  'seamos',
#  'seáis',
#  'sean',
#  'seré',
#  'serás',
#  'será',
#  'seremos',
#  'seréis',
#  'serán',
#  'sería',
#  'serías',
#  'seríamos',
#  'seríais',
#  'serían',
#  'era',
#  'eras',
#  'éramos',
#  'erais',
#  'eran',
#  'fui',
#  'fuiste',
#  'fue',
#  'fuimos',
#  'fuisteis',
#  'fueron',
#  'fuera',
#  'fueras',
#  'fuéramos',
#  'fuerais',
#  'fueran',
#  'fuese',
#  'fueses',
#  'fuésemos',
#  'fueseis',
#  'fuesen',
#  'sintiendo',
#  'sentido',
#  'sentida',
#  'sentidos',
#  'sentidas',
#  'siente',
#  'sentid',
#  'tengo',
#  'tienes',
#  'tiene',
#  'tenemos',
#  'tenéis',
#  'tienen',
#  'tenga',
#  'tengas',
#  'tengamos',
#  'tengáis',
#  'tengan',
#  'tendré',
#  'tendrás',
#  'tendrá',
#  'tendremos',
#  'tendréis',
#  'tendrán',
#  'tendría',
#  'tendrías',
#  'tendríamos',
#  'tendríais',
#  'tendrían',
#  'tenía',
#  'tenías',
#  'teníamos',
#  'teníais',
#  'tenían',
#  'tuve',
#  'tuviste',
#  'tuvo',
#  'tuvimos',
#  'tuvisteis',
#  'tuvieron',
#  'tuviera',
#  'tuvieras',
#  'tuviéramos',
#  'tuvierais',
#  'tuvieran',
#  'tuviese',
#  'tuvieses',
#  'tuviésemos',
#  'tuvieseis',
#  'tuviesen',
#  'teniendo',
#  'tenido',
#  'tenida',
#  'tenidos',
#  'tenidas',
#  'tened']

# %%
comment_wt_sin_sw = [word for word in comment_wt if word not in stopwords]
comment_wt_sin_sw
# Out:
# ['0',
#  'No',
#  'creo',
#  'importemos',
#  '.',
#  'Estos',
#  '...',
#  '1',
#  'No',
#  'ANMISTIA',
#  'AL',
#  'PERDONA',
#  'LA',
#  'DEUDA',
#  'DE',
#  'C',
#  '...',
#  '2',
#  'Que',
#  'enteras',
#  ',',
#  'Contreras\\nQue',
#  'trae',
#  'fl',
#  '...',
#  '3',
#  '¿Como',
#  'puede',
#  'ser',
#  'impecable',
#  '?',
#  ',',
#  'si',
#  'hace',
#  '...',
#  '4',
#  'Osea',
#  'gobierna',
#  'PP',
#  'roba',
#  'mete',
#  '...',
#  '...',
#  '11903',
#  'Bermejo',
#  'siempre',
#  'sido',
#  'mismo',
#  'Comuni',
#  '...',
#  '11904',
#  'Hablemos',
#  'importa',
#  'pacto',
#  'sor',
#  '...',
#  '11905',
#  'Si',
#  'señora',
#  ',',
#  'nube',
#  'humo',
#  'tapar',
#  'golp',
#  '...',
#  '11906',
#  'Pero',
#  'fijaros',
#  'enseñan',
#  'informaci',
#  '...',
#  '11907',
#  'Pero',
#  'Israel',
#  'quiere',
#  'gaza',
#  'siempre',
#  '...',
#  'Name',
#  ':',
#  'comment',
#  ',',
#  'Length',
#  ':',
#  '11908',
#  ',',
#  'dtype',
#  ':',
#  'object']

# %% [markdown]
# Frecuencia de palabras

# %%
freq = nltk.FreqDist(comment_wt_sin_sw)
freq
# Out:
# FreqDist({'...': 11, ',': 5, ':': 3, 'No': 2, 'siempre': 2, 'Pero': 2, '0': 1, 'creo': 1, 'importemos': 1, '.': 1, ...})

# %% [markdown]
# Stemming

# %%
# Importamos esta libreria que nos permite reemplzar caracteres
import re

# Importamos la función que nos permite Stemmizar de nltk y definimos el stemmer
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# Traemos nuevamente las stopwords
spanish_stopwords = nltk.corpus.stopwords.words('spanish')
#spanish_stopwords.remove('no')
#stopword.remove('not')

# %%
# Recorremos todos los comentarios y le vamos aplicando la Normalizacion y luega el Stemming a cada uno
comment_list=[]
for comment in comentarios_amnistia.comment:
    # Vamos a reemplzar los caracteres que no sean letras por espacios, limpiando los numeros 
    comment=re.sub("[^a-zA-Z]"," ",str(comment))
    # Pasamos todo a minúsculas
    comment=comment.lower()
    # Remover caracteres especiales
    comment = re.sub(r'\W', ' ', comment)
    # Remover múltiples espacios con uno solo
    comment = re.sub(r'\s+', ' ', comment, flags=re.I)
    # Tokenizar el texto
    # Tokenizamos para separar las palabras del titular 
    comment=nltk.word_tokenize(comment)
    # Eliminamos las palabras de menos de 3 letras
    comment= [palabra for palabra in comment if len(palabra)>3]
    # Sacamos las Stopwords
    comment = [palabra for palabra in comment if not palabra in stopwords]

    ## Hasta acá Normalizamos, ahora a stemmizar

    # Aplicamos la funcion para buscar la raiz de las palabras
    comment=[stemmer.stem(palabra) for palabra in comment]
    # Por ultimo volvemos a unir el titular
    comment=" ".join(comment)

    # Vamos armando una lista con todos los titulares
    comment_list.append(comment)
    #dataset["titular_normalizado"] = titular_list

# %%
comentarios_amnistia["comment_stem"] = comment_list
comentarios_amnistia.tail()
# Out:
#        Unnamed: 0     video_id                    author  \
# 11903       11903  UCypRjGGvik  UC9Bf43fR7XaU5kx6cL9TQzQ
# 11904       11904  UCypRjGGvik  UCyK_y121VHJG3boqeWcmukg
# 11905       11905  UCypRjGGvik  UCyK_y121VHJG3boqeWcmukg
# 11906       11906  UCypRjGGvik  UCyK_y121VHJG3boqeWcmukg
# 11907       11907  UCypRjGGvik  UCyK_y121VHJG3boqeWcmukg
#
#                                                  comment  \
# 11903  Bermejo tú siempre has sido lo mismo un Comuni...
# 11904  Hablemos de lo que nos importa ese pacto y sor...
# 11905  Si señora, una nube de humo para tapar el golp...
# 11906  Pero fijaros que no enseñan todo esa informaci...
# 11907  Pero también Israel quiere gaza desde siempre ...
#
#                                             comment_stem
# 11903  bermejo siempr sido mismo comunista agazapado ...
# 11904  hablemo importa pacto soro padrino rockiflelin...
# 11905  nube humo tapar golp totalment sanchez sabe ju...
# 11906  fijaro ens informaci pegaso misma banda enfang...
# 11907  tambi israel quier gaza siempr cualquier excus...

# %% [markdown]
# Vectorizar

# %%
list_comment = list(comentarios_amnistia['comment_stem'].values)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Usaremos solo las 1000 palabras con mas frecuencia en todo el corpus para generar los vectores
max_features=1000
# spanish=stopwords.words("spanish")
# Es decir que cada instancia tendrá 1000 features
cou_vec=CountVectorizer(max_features=max_features, stop_words = spanish_stopwords) # stop_words="english" , ngram_range=(1, 2)

# %%
#enerarnos los vectores para cada título a partir del corpus total. 
matriz_titulos = cou_vec.fit_transform(list_comment)

# Tomamos las palabras
all_words = cou_vec.get_feature_names_out()

# Vizualizamos las 50 palabras mas usadas
print("50 palabras mas usadas: ",all_words[0:50])
# Out:
# 50 palabras mas usadas:  ['abajo' 'abasc' 'abogado' 'abrazo' 'absoluta' 'abuelo' 'acab' 'acaba'
#  'acabar' 'acaso' 'accion' 'aceptar' 'acto' 'actual' 'actuar' 'acuerda'
#  'acuerdo' 'adelant' 'adem' 'adema' 'agenda' 'agua' 'ahora' 'alfonso'
#  'alguien' 'algun' 'alguna' 'alguno' 'alsina' 'alta' 'alto' 'amenaza'
#  'amigo' 'amnist' 'amnistia' 'amo' 'amor' 'anciano' 'anda' 'anmistia'
#  'anterior' 'antonio' 'apart' 'apoyar' 'apoyo' 'aprend' 'aprobar' 'aquel'
#  'aquello' 'aqui']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()

# Transformar el texto en vectores TF-IDF
vectores_tfidf = vectorizer.fit_transform(list_comment)

# Obtener el tamaño del vocabulario
tamaño_vocabulario = len(vectorizer.get_feature_names_out())

# Ver los vectores TF-IDF resultantes 
print(vectores_tfidf)
# Out:
#   (0, 13767)	0.4258732359323959
#   (0, 12679)	0.4282592977471616
#   (0, 9932)	0.7052639054748211
#   (0, 4836)	0.37125299250508487
#   (1, 14474)	0.31358673347620103
#   (1, 6176)	0.2510578994904414
#   (1, 19348)	0.3340372659268034
#   (1, 7443)	0.11542193448828125
#   (1, 5970)	0.3038774373062602
#   (1, 13042)	0.31181050990751386
#   (1, 10111)	0.24178155649648675
#   (1, 17834)	0.25326707623511474
#   (1, 18062)	0.2862350685350658
#   (1, 3219)	0.23158764108252416
#   (1, 6042)	0.27371760868571704
#   (1, 14573)	0.3193968760115349
#   (1, 1123)	0.29843140932407625
#   (2, 14999)	0.16562395106575614
#   (2, 9051)	0.11564675221303697
#   (2, 8367)	0.20366654983725735
#   (2, 16274)	0.19246332003016875
#   (2, 20503)	0.21255905360674865
#   (2, 12242)	0.21255905360674865
#   (2, 16212)	0.13587500349089773
#   (2, 4928)	0.21255905360674865
#   :	:
#   (11905, 7106)	0.22699633672367428
#   (11905, 19074)	0.26143548087007984
#   (11905, 17350)	0.16602483248608652
#   (11905, 19159)	0.19298305882464584
#   (11905, 13441)	0.16373678729707042
#   (11905, 17529)	0.14187325928994463
#   (11905, 8978)	0.1740572240609684
#   (11906, 18411)	0.3697431211944727
#   (11906, 7025)	0.3697431211944727
#   (11906, 14431)	0.3697431211944727
#   (11906, 8318)	0.3542747511430691
#   (11906, 10253)	0.25741367332648657
#   (11906, 7106)	0.5354503337269558
#   (11906, 2130)	0.24694399147183405
#   (11906, 12679)	0.22452010970699213
#   (11907, 10699)	0.29489817789509365
#   (11907, 12239)	0.34264146536123546
#   (11907, 14049)	0.3361607264782104
#   (11907, 8818)	0.3403790732631544
#   (11907, 7843)	0.36632836771909943
#   (11907, 16117)	0.22388386386172526
#   (11907, 4949)	0.2666414502109255
#   (11907, 19919)	0.2211043148846844
#   (11907, 17940)	0.2130735652977306
#   (11907, 18643)	0.46590166408172934

# %%
# Convertir la matriz dispersa a un array NumPy
vectores_tfidf_array = vectores_tfidf.toarray()

# Asegurar que el número de filas en vectores_tfidf coincida con la cantidad de filas en comentarios_inmigracion
# (vectores_tfidf_array debe tener la misma cantidad de filas que comentarios_inmigracion)
if vectores_tfidf_array.shape[0] == len(comentarios_amnistia):
    # Asignar los vectores TF-IDF al DataFrame como una nueva columna
    comentarios_amnistia['vectores_tfidf'] = list(vectores_tfidf_array)
else:
    print("Las longitudes no coinciden entre la matriz dispersa y el DataFrame.")

# %%
comentarios_amnistia['comment_stem'][10]
# Out:
# 'sido actor extraordinario haciendo creer haciendo flirteando daba cuenta cosa dicho descend debe reina debe mismo nacer reina consort nunca quieren'
