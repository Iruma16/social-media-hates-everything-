# %%
from googleapiclient.discovery import build
from dateutil import parser
import pandas as pd

# Data viz packages
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# NLP
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
from wordcloud import WordCloud
from FunctionsYoutube import *
# !pip install wordcloud 
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/usuario/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/usuario/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/usuario/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/usuario/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ...

# %%
api_key="AIzaSyAwbJ-cYUjSvlyd51VGBtlR2-8SvplFeLI"

# %%
api_service_name = "youtube"
api_version = "v3"

# Creamos la conexión con youtube API
youtube = build(
    api_service_name, api_version, developerKey=api_key)

# %%
next_page_token = None
all_video = []

while True:
    search_response = youtube.search().list(
        q="Opiniones españolas sobre genero reciente", # q es la query 
        part="id,snippet",
        maxResults= 50, 
        regionCode='ES', 
        pageToken=next_page_token if next_page_token else ""
    ).execute()  # Mover la ejecución aquí

    for item in search_response['items']:
        all_video.append(item) 
        

    next_page_token = search_response.get('nextPageToken')

    if not next_page_token:
        break

# %%
len(all_video)
# Out:
# 721

# %%
[x['snippet']['title'] for x in all_video]
# Out:
# ['IRENE MONTERO: EDUCACIÓN SEXUAL para la MINISTRA, PEDERASTIA para VOX y Cs que piden su CESE | RTVE',
#  '¿Igualdad de género?',
#  'La igualdad de género es injusta - Agustín Laje',
#  'Doble moral de las mujeres (igualdad de género)',
#  'Feminista trata de darme clase de feminismo y sale mal - [Agustín Laje]',
#  'La rotunda respuesta de una niña trans a la intrusiva pregunta sobre sus genitales - El Intermedio',
#  '¿Por qué existe aún desigualdad entre hombres y mujeres? EP8: El desafío de la Igualdad',
#  'LA LEY TRANS. MI OPINIÓN',
#  'Santiago Abascal sobre la violencia de género: &quot;Busca la guerra de sexos y criminalizar al hombre&quot;',
#  'Chica vs chico, otro pleito de igualdad de género',
#  'Seis minutos de broncas: el vídeo que resume el tenso clima político en España',
#  'Mayores y jóvenes, ante el sexo: la experiencia real que enfrenta el amor - El Hormiguero',
#  'Cómo educar en la igualdad de género. Marina Subirats, socióloga',
# ...

# %%
channel_ids = []  
for item in all_video:
    channelId = item['snippet']['channelId']
    channel_ids.append(channelId)  

print(channel_ids)
# Out:
# ['UC7QZIf0dta-XPXsp9Hv4dTw', 'UCT4Jg8h03dD0iN3Pb5L0PMA', 'UCJKjzEoy91UYS-bZLc4CLCQ', 'UCF2oqnugs_-7JTp--XIt9rA', 'UCJKjzEoy91UYS-bZLc4CLCQ', 'UCh1OgMIWOlDBhFEYL3DHWjQ', 'UCI6QcXatdaEAaRTRjl3dc0w', 'UC1KFgMi-KVzNKnvYIkFxqCg', 'UC84t25xqhPEPpGY7NBZJ_eA', 'UCcHtke0raf8vNYLM1Hbq3Jw', 'UClLLRs_mFTsNT5U-DqTYAGg', 'UC84t25xqhPEPpGY7NBZJ_eA', 'UCI6QcXatdaEAaRTRjl3dc0w', 'UCnsvJeZO4RigQ898WdDNoBw', 'UCG7riaPPOKsezc5wPxanoUg', 'UCacWETW7N0ohwNaWJgOQBpA', 'UCnsvJeZO4RigQ898WdDNoBw', 'UCUdOoVWuWmgo1wByzcsyKDQ', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCwtu3Ul-eiQEN81HNN6RQtw', 'UC84t25xqhPEPpGY7NBZJ_eA', 'UCsT0YIqwnpJCM-mx7-gSA4Q', 'UCEIuOP1ex5JjB4JhtJ4Sbjg', 'UCf-GWfVtbdHNNdhdYw1t3iw', 'UCRwA1NUcUnwsly35ikGhp0A', 'UCW_bztVayeDCLYe3ea0TxBA', 'UC_u0e_16erqBDHdJ9v2hvlQ', 'UC7QZIf0dta-XPXsp9Hv4dTw', 'UCUdOoVWuWmgo1wByzcsyKDQ', 'UC7aT3v_pMF2nOoaNpBVc-EA', 'UCrspXDsTGqrFI9C-k9azQew', 'UC84t25xqhPEPpGY7NBZJ_eA', 'UCXISYK3xagaK5DHnhQ4X0hw', 'UC4Nd2eNT45ByX-N7u_zoRmg', 'UCnsvJeZO4RigQ898WdDNoBw', 'UCsT0YIqwnpJCM-m
# ...

# %%
len(channel_ids)
# Out:
# 721

# %%
video_ids = []  # Lista para almacenar los videoIds

# Iterar sobre cada elemento de all_videos
for video_info in all_video:
    # Acceder a la clave 'id' y luego a 'videoId'
    video_id = video_info.get('id', {}).get('videoId') #.get() para acceder al valor de 'videoId' dentro de la estructura del diccionario. Si se encuentra un 'videoId', se agrega a la lista video_ids.
    
    # Verificar si se encontró el 'videoId' y agregarlo a la lista video_ids
    if video_id:
        video_ids.append(video_id) 
    else:
        # Si no se encuentra el 'videoId', agregar None a la lista video_ids
        video_ids.append(None)

# %%
len(video_ids)
# Out:
# 721

# %%
v_title = []
for item in all_video:
    video_title = item['snippet']['title'] 
    v_title.append(video_title)
    print(video_title)
# Out:
# IRENE MONTERO: EDUCACIÓN SEXUAL para la MINISTRA, PEDERASTIA para VOX y Cs que piden su CESE | RTVE
# ¿Igualdad de género?
# La igualdad de género es injusta - Agustín Laje
# Doble moral de las mujeres (igualdad de género)
# Feminista trata de darme clase de feminismo y sale mal - [Agustín Laje]
# La rotunda respuesta de una niña trans a la intrusiva pregunta sobre sus genitales - El Intermedio
# ¿Por qué existe aún desigualdad entre hombres y mujeres? EP8: El desafío de la Igualdad
# LA LEY TRANS. MI OPINIÓN
# Santiago Abascal sobre la violencia de género: &quot;Busca la guerra de sexos y criminalizar al hombre&quot;
# Chica vs chico, otro pleito de igualdad de género
# Seis minutos de broncas: el vídeo que resume el tenso clima político en España
# Mayores y jóvenes, ante el sexo: la experiencia real que enfrenta el amor - El Hormiguero
# Cómo educar en la igualdad de género. Marina Subirats, socióloga
# ...

# %%
len(v_title)
# Out:
# 721

# %%
df_genero= pd.DataFrame({'canal_ID' : channel_ids, 'video_ID': video_ids, 'video_Title' : v_title})

# %%
df_genero.to_csv('/Users/usuario/Downloads/irunela/csv/videos_genero.csv')

# %%
df_genero.head()
# Out:
#                    canal_ID     video_ID  \
# 0  UC7QZIf0dta-XPXsp9Hv4dTw  fN48ESWAa_g
# 1  UCT4Jg8h03dD0iN3Pb5L0PMA  PmgbmeGMRRw
# 2  UCJKjzEoy91UYS-bZLc4CLCQ  tiv5h0C_r_g
# 3  UCF2oqnugs_-7JTp--XIt9rA  2xyG1eptb6U
# 4  UCJKjzEoy91UYS-bZLc4CLCQ  WtVBQrzvQok
#
#                                          video_Title
# 0  IRENE MONTERO: EDUCACIÓN SEXUAL para la MINIST...
# 1                               ¿Igualdad de género?
# 2    La igualdad de género es injusta - Agustín Laje
# 3    Doble moral de las mujeres (igualdad de género)
# 4  Feminista trata de darme clase de feminismo y ...

# %%
from pprint import pprint
def get_comments(video_ids):
    comments = []
    try:
        response = youtube.commentThreads().list(
            part='snippet',
            videoId=video_ids,
            textFormat='plainText'
        ).execute()
    except Exception:
        print(f"Fallo conseguir comentarios de {video_ids}")
        return []

    for item in response['items']:
        try:
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            author_channel_id = item['snippet']['topLevelComment']['snippet']['authorChannelId']["value"]
            #author_channel_id = comment['authorChannelId']['value']
            comments.append({"video_id": video_ids, "author": author_channel_id, "comment": comment})
        except KeyError as e:
            print(f"Falta algun valor de un comentario, {e}")
            comments.append(None)
            continue
    return comments

# %%
from tqdm.notebook import tqdm 
comment_video = [] 
for video in tqdm(video_ids): 
    comments = get_comments(video) 
    comment_video.extend(comments)
# Out:
#   0%|          | 0/721 [00:00<?, ?it/s]
# Fallo conseguir comentarios de qh7WNAG117w
# Fallo conseguir comentarios de None
# Fallo conseguir comentarios de jjkjaoeYx58
# Fallo conseguir comentarios de UHgU4tZdWko
# Fallo conseguir comentarios de APF2wBZizo4
# Fallo conseguir comentarios de 23_0yPHmrDM
# Fallo conseguir comentarios de ECJMTTsN6BM
# Fallo conseguir comentarios de UDiSJajN2s0
# Fallo conseguir comentarios de xU_Nn_ArxDw
# Fallo conseguir comentarios de 2d7K7nP-2Ro
# Fallo conseguir comentarios de wU_Hvy96FTE
# Fallo conseguir comentarios de 1U0FhAKC2so
# Fallo conseguir comentarios de n7RIOiCh44Q
# Fallo conseguir comentarios de IXKloVaGbhg
# Fallo conseguir comentarios de MPjjxELtLig
# Fallo conseguir comentarios de svobiWJ4qc0
# Fallo conseguir comentarios de wKwolnmC3Qs
# Fallo conseguir comentarios de sRF2DT-XgbI
# Fallo conseguir comentarios de kExHJ-Ne26M
# Fallo conseguir comentarios de 4nyTxRR7GJQ
# Fallo conseguir comentarios de Ww5ouPGrD4I
# ...

# %%
len(comment_video)
# Out:
# 10005

# %%
comentarios_genero = pd.DataFrame(filter(None, comment_video))

# %%
comentarios_genero.to_csv('/Users/usuario/Downloads/irunela/csv/comentarios_genero.csv')

# %%
#no es importante
stop_words = set(stopwords.words('spanish'))
comentarios_genero['comment_no_stopword'] = comentarios_genero['comment'].apply(lambda x: [item for item in str(x).split() if item.lower() not in stop_words])
custom_stop_words = ["si", "q", "solo", "ma"]
all_words = [a for b in comentarios_genero['comment_no_stopword'].tolist() for a in b]
all_words_str = ' '.join([x for x in all_words if x.lower() not in custom_stop_words]) 


# Define la fuente TrueType que quieres usar (asegúrate de que sea compatible)
#font_path = 'font.ttf'

# Resto de tu código para procesar el texto y generar la WordCloud...
wordcloud = WordCloud(
    width=2000,
    height=1000,
    random_state=1,
    background_color='black',
    colormap='viridis',
    font_path=font_path
).generate(all_words_str)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[30], line 20
#       6 all_words_str = ' '.join([x for x in all_words if x.lower() not in custom_stop_words])
#       9 # Define la fuente TrueType que quieres usar (asegúrate de que sea compatible)
#      10 #font_path = 'font.ttf'
#      11
#      12 # Resto de tu código para procesar el texto y generar la WordCloud...
#      13 wordcloud = WordCloud(
#      14     width=2000,
#      15     height=1000,
#      16     random_state=1,
#      17     background_color='black',
#      18     colormap='viridis',
#      19     font_path=font_path
# ---> 20 ).generate(all_words_str)
#
# File ~/anaconda3/lib/python3.11/site-packages/wordcloud/wordcloud.py:639, in WordCloud.generate(self, text)
#     624 def generate(self, text):
#     625     """Generate wordcloud from text.
#     626
# ...

# %%
def plot_cloud(wordcloud):
    plt.figure(figsize=(30, 20))
    plt.imshow(wordcloud) 
    plt.axis("off");

# %%
plot_cloud(wordcloud)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 plot_cloud(wordcloud)
#
# NameError: name 'wordcloud' is not defined
